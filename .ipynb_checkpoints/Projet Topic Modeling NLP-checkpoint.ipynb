# %% [markdown]
# Bonjour à tous,
# J’espère que vous allez bien !
# Je vous contacte pour vous partager le sujet du projet final de Natural Language
# Processing, dont le thème est l’exploration de méthodologies de Topic Modeling.
# Contexte
#
# Mentionné durant le cours, le Topic Modeling est un sous-champ du Natural
# Language Processing visant à extraire les sujets de discussions principaux d’un
# corpus de texte. On appelle un sujet de discussion un groupe de mots ou un groupe de
# phrases partageant une thématique spécifique.
# Cette problématique est donc un sujet non-supervisé qui s'apparente à du clustering.
#
# De fait, de nombreuses méthodes de clustering existent – K-means, DBScan,
# Agglomerative clustering, etc. Cependant les données textuelles possèdent des
# particularités qui ont résulté en la création d’algorithmes spécifiques tirant profit de ces
# dernières.
#
# Il est possible d'appliquer des méthodologies de Topic Modeling à n'importe quelle
# source de textes : commentaires postés sur les réseaux sociaux, articles scientifiques,
# pages Wikipédia, review de produits, etc. Le type de corpus analysé conditionne
# fortement la méthodologie à utiliser (vous verrez probablement que plus les textes sont
# courts, plus la tâche devient ardue).
# Dans le cadre de ce projet, vous travaillerez sur le jeu de données News Category
# Dataset utilisé dans le TD NLP #2 - Data Pipeline, contenant 200K headlines de journaux
# en anglais.
#
# ## Sujet
#
# L’objectif de ce projet est d’étudier les performances d’algorithmes de Topic Modeling
# sur les données mentionnées ci-avant. Pour ce faire, vous devrez :
#
# 1. Analyser le corpus de texte pour en extraire ses caractéristiques spécifiques (taille moyenne, types de mots utilisés, mots les plus fréquents, stopwords, etc.).
#
# 2. Sélectionner 3 méthodologies de Topic Modeling / Clustering vous semblant en phase avec les données à traiter
# 3. Définir une ou plusieurs métriques permettant de mesurer la qualité de vos modèles
# a. Note : vous pouvez utiliser les catégories des headlines fournies dans le
# jeu de données. Cependant, il s’agit ici d’un problème de clustering avant
# tout, il faut donc que vous mettiez également en avant des métriques
# prenant en compte cela.
#
# 4. Réaliser les tests comparatifs de chacun des modèles que vous avez sélectionné
#
# 5. Conclure sur la meilleure méthodologie à utiliser dans votre cas et préciser les pistes d’améliorations de votre analyse
# Pensez à justifier vos choix !
#
# ## Modalités de rendu
#
# ### • Taille des équipes : 3 personnes
#
# ### • Format de rendu : Notebook Jupyter présentant les résultats de l’étude
# o Import à mettre dans la première cellule du projet
# o A déposer sur Sharepoint à ce lien
# o Nom du fichier : Nom1_Nom2_Nom3_ProjectTopicModeling.ipynb
#
# ### • Critères d’évaluation :
#
# o Qualité de l’étude des caractéristiques du corpus et de la sélection des
# méthodologies à tester /5
#
# o Qualité des métriques sélectionnées ou/et créées /5
#
# o Qualité de l’analyse des différentes méthodologies /5
#
# o Qualité de la conclusion finale /5
#
#
# ### • Date de rendu : 26/11/2021 -> (si cela pose problème vis-à-vis de vos examens,
# faites le moi savoir)
# Ressources
#
# Vous trouverez dans le dossier Teams lié à ce cours trois documents pouvant vous aider
# pour ce projet, à savoir :
#
# • La version finale du cours auquel vous avez assisté, disponible ici
#
# • Une brève présentation sur le Topic Modeling présentant différents types de
# méthodologies, disponible ici
#
# • Le TD de NLP Data Pipeline corrigé qui vous servira de base pour ce
# projet, disponible ici
#
# Pourriez-vous s’il vous plaît ajouter les équipes à l’excel disponible à ce lien une
# fois celles-ci établies ?
#
# Si vous avez la moindre question n’hésitez pas à me contacter par retour de mail !
# Bonne journée à vous,

# %% [markdown]
# # I. Exploration du Dataset

# %%
#Import des librairies nécessaires pour nos calculs
import pandas as pd
import numpy as np
import itertools
import itertools
import os
import re
import secrets
import string

import pandas as pd
import spacy

from itertools import chain

from gensim.models.callbacks import CallbackAny2Vec
from gensim.models import Word2Vec, Phrases, KeyedVectors
from gensim.models.phrases import Phraser
from gensim.utils import simple_preprocess
from nltk.corpus import wordnet
# from pattern.en import pluralize, singularize
from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from tqdm import tqdm

from spacy.parts_of_speech import IDS as POS_map

# %%
#Import du dataset
dataset = pd.read_json("News_Category_Dataset_v2.json", lines=True, dtype={"headline": str})

# %%
dataset
# Out:
#              category                                           headline  \
# 0               CRIME  There Were 2 Mass Shootings In Texas Last Week...
# 1       ENTERTAINMENT  Will Smith Joins Diplo And Nicky Jam For The 2...
# 2       ENTERTAINMENT    Hugh Grant Marries For The First Time At Age 57
# 3       ENTERTAINMENT  Jim Carrey Blasts 'Castrato' Adam Schiff And D...
# 4       ENTERTAINMENT  Julianna Margulies Uses Donald Trump Poop Bags...
# ...               ...                                                ...
# 200848           TECH  RIM CEO Thorsten Heins' 'Significant' Plans Fo...
# 200849         SPORTS  Maria Sharapova Stunned By Victoria Azarenka I...
# 200850         SPORTS  Giants Over Patriots, Jets Over Colts Among  M...
# 200851         SPORTS  Aldon Smith Arrested: 49ers Linebacker Busted ...
# 200852         SPORTS  Dwight Howard Rips Teammates After Magic Loss ...
#
#                  authors                                               link  \
# 0        Melissa Jeltsen  https://www.huffingtonpost.com/entry/texas-ama...
# 1          Andy McDonald  https://www.huffingtonpost.com/entry/will-smit...
# 2             Ron Dicker  https://www.huffingtonpost.com/entry/hugh-gran...
# 3             Ron Dicker  https://www.huffingtonpost.com/entry/jim-carre...
# 4             Ron Dicker  https://www.huffingtonpost.com/entry/julianna-...
# ...                  ...                                                ...
# 200848  Reuters, Reuters  https://www.huffingtonpost.com/entry/rim-ceo-t...
# 200849                    https://www.huffingtonpost.com/entry/maria-sha...
# 200850                    https://www.huffingtonpost.com/entry/super-bow...
# 200851                    https://www.huffingtonpost.com/entry/aldon-smi...
# 200852                    https://www.huffingtonpost.com/entry/dwight-ho...
#
#                                         short_description       date
# 0       She left her husband. He killed their children... 2018-05-26
# 1                                Of course it has a song. 2018-05-26
# 2       The actor and his longtime girlfriend Anna Ebe... 2018-05-26
# 3       The actor gives Dems an ass-kicking for not fi... 2018-05-26
# 4       The "Dietland" actress said using the bags is ... 2018-05-26
# ...                                                   ...        ...
# 200848  Verizon Wireless and AT&T are already promotin... 2012-01-28
# 200849  Afterward, Azarenka, more effusive with the pr... 2012-01-28
# 200850  Leading up to Super Bowl XLVI, the most talked... 2012-01-28
# 200851  CORRECTION: An earlier version of this story i... 2012-01-28
# 200852  The five-time all-star center tore into his te... 2012-01-28
#
# [200853 rows x 6 columns]

# %% [markdown]
# On observe que ce dataset comprend 6 variables : catégory, headline, authors, link, short description et date de format 200853 * 6. Il représente des articles de journaux anglais classés par catégories.
#
# # Sujet
#
# Isoler la variable headline et traiter les différents corpus de texte afin de les catégoriser sous forme de thème à l'aide de méthodes de Topic Modeling en apprentissage non-supervisé : Clusterisation.

# %% [markdown]
# # Avant le traitement des mots
# ### Cette partie n'est pas dans le pipeline mais permet de l'appliquer sur des corpus plus lisibles
#
# Première modification : on travail uniquement sur les headline du dataset

# %%
df = pd.DataFrame(dataset["headline"])
df
# Out:
#                                                  headline
# 0       There Were 2 Mass Shootings In Texas Last Week...
# 1       Will Smith Joins Diplo And Nicky Jam For The 2...
# 2         Hugh Grant Marries For The First Time At Age 57
# 3       Jim Carrey Blasts 'Castrato' Adam Schiff And D...
# 4       Julianna Margulies Uses Donald Trump Poop Bags...
# ...                                                   ...
# 200848  RIM CEO Thorsten Heins' 'Significant' Plans Fo...
# 200849  Maria Sharapova Stunned By Victoria Azarenka I...
# 200850  Giants Over Patriots, Jets Over Colts Among  M...
# 200851  Aldon Smith Arrested: 49ers Linebacker Busted ...
# 200852  Dwight Howard Rips Teammates After Magic Loss ...
#
# [200853 rows x 1 columns]

# %% [markdown]
# On ajoute les token, on met nos mots en minuscules et on supprime la ponctuaction sur le dataset

# %%
#Mise en minuscule du dataframe
df = df["headline"].str.lower()
df
# Out:
# 0         there were 2 mass shootings in texas last week...
# 1         will smith joins diplo and nicky jam for the 2...
# 2           hugh grant marries for the first time at age 57
# 3         jim carrey blasts 'castrato' adam schiff and d...
# 4         julianna margulies uses donald trump poop bags...
#                                 ...
# 200848    rim ceo thorsten heins' 'significant' plans fo...
# 200849    maria sharapova stunned by victoria azarenka i...
# 200850    giants over patriots, jets over colts among  m...
# 200851    aldon smith arrested: 49ers linebacker busted ...
# 200852    dwight howard rips teammates after magic loss ...
# Name: headline, Length: 200853, dtype: object

# %%
#Suppression de la ponctuation
df = df.str.replace('[^\w\s]','')

df
# Out:
# 0         there were 2 mass shootings in texas last week...
# 1         will smith joins diplo and nicky jam for the 2...
# 2           hugh grant marries for the first time at age 57
# 3         jim carrey blasts castrato adam schiff and dem...
# 4         julianna margulies uses donald trump poop bags...
#                                 ...
# 200848    rim ceo thorsten heins significant plans for b...
# 200849    maria sharapova stunned by victoria azarenka i...
# 200850    giants over patriots jets over colts among  mo...
# 200851    aldon smith arrested 49ers linebacker busted f...
# 200852    dwight howard rips teammates after magic loss ...
# Name: headline, Length: 200853, dtype: object

# %%
df
# Out:
# 0         there were 2 mass shootings in texas last week...
# 1         will smith joins diplo and nicky jam for the 2...
# 2           hugh grant marries for the first time at age 57
# 3         jim carrey blasts castrato adam schiff and dem...
# 4         julianna margulies uses donald trump poop bags...
#                                 ...
# 200848    rim ceo thorsten heins significant plans for b...
# 200849    maria sharapova stunned by victoria azarenka i...
# 200850    giants over patriots jets over colts among  mo...
# 200851    aldon smith arrested 49ers linebacker busted f...
# 200852    dwight howard rips teammates after magic loss ...
# Name: headline, Length: 200853, dtype: object

# %%
# On sépare nos mots de chaque phrase
def dummy_word_split(texts):
    """Function identifying words in a sentence in a really dummy way.
        
        Argument:
            - texts (list of str): a list of raw texts in which we'd like to identify words
            
        Return:
            - list of list containing each word separately.
    """
    texts_out = []
    for text in texts:
        texts_out.append(text.split(" "))#Méthode permettant de séparer nos mots 
        
    return texts_out

# %%
splitted_text =  dummy_word_split(df.tolist())

# %%
splitted_text
# Out:
# [['there',
#   'were',
#   '2',
#   'mass',
#   'shootings',
#   'in',
#   'texas',
#   'last',
#   'week',
#   'but',
#   'only',
#   '1',
#   'on',
#   'tv'],
#  ['will',
#   'smith',
#   'joins',
#   'diplo',
#   'and',
#   'nicky',
#   'jam',
#   'for',
#   'the',
#   '2018',
#   'world',
#   'cups',
#   'official',
#   'song'],
#  ['hugh',
#   'grant',
#   'marries',
#   'for',
#   'the',
#   'first',
#   'time',
#   'at',
#   'age',
#   '57'],
#  ['jim',
#   'carrey',
#   'blasts',
#   'castrato',
#   'adam',
#   'schiff',
#   'and',
#   'democrats',
#   'in',
#   'new',
#   'artwork'],
#  ['julianna',
#   'margulies',
#   'uses',
#   'donald',
#   'trump',
#   'poop',
#   'bags',
#   'to',
#   'pick',
#   'up',
#   'after',
#   'her',
#   'dog'],
#  ['morgan',
#   'freeman',
#   'devastated',
#   'that',
#   'sexual',
#   'harassment',
#   'claims',
#   'could',
#   'undermine',
#   'legacy'],
#  ['donald',
#   'trump',
#   'is',
#   'lovin',
#   'new',
#   'mcdonalds',
#   'jingle',
#   'in',
#   'tonight',
#   'show',
#   'bit'],
#  ['what',
#   'to',
#   'watch',
#   'on',
#   'amazon',
#   'prime',
#   'thats',
#   'new',
#   'this',
#   'week'],
#  ['mike',
#   'myers',
#   'reveals',
#   'hed',
#   'like',
#   'to',
#   'do',
#   'a',
#   'fourth',
#   'austin',
#   'powers',
#   'film'],
#  ['what', 'to', 'watch', 'on', 'hulu', 'thats', 'new', 'this', 'week'],
#  ['justin', 'timberlake', 'visits', 'texas', 'school', 'shooting', 'victims'],
#  ['south',
#   'korean',
#   'president',
#   'meets',
#   'north',
#   'koreas',
#   'kim',
#   'jong',
#   'un',
#   'to',
#   'talk',
#   'trump',
#   'summit'],
#  ['with',
#   'its',
#   'way',
#   'of',
#   'life',
#   'at',
#   'risk',
#   'this',
#   'remote',
#   'oystergrowing',
#   'region',
#   'called',
#   'in',
#   'robots'],
#  ['trumps',
#   'crackdown',
#   'on',
#   'immigrant',
#   'parents',
#   'puts',
#   'more',
#   'kids',
#   'in',
#   'an',
#   'already',
#   'strained',
#   'system'],
#  ['trumps',
#   'son',
#   'should',
#   'be',
#   'concerned',
#   'fbi',
#   'obtained',
#   'wiretaps',
#   'of',
#   'putin',
#   'ally',
#   'who',
#   'met',
#   'with',
#   'trump',
#   'jr'],
#  ['edward',
#   'snowden',
#   'theres',
#   'no',
#   'one',
#   'trump',
#   'loves',
#   'more',
#   'than',
#   'vladimir',
#   'putin'],
#  ['booyah',
#   'obama',
#   'photographer',
#   'hilariously',
#   'trolls',
#   'trumps',
#   'spy',
#   'claim'],
#  ['ireland',
#   'votes',
#   'to',
#   'repeal',
#   'abortion',
#   'amendment',
#   'in',
#   'landslide',
#   'referendum'],
#  ['ryan',
#   'zinke',
#   'looks',
#   'to',
#   'reel',
#   'back',
#   'some',
#   'critics',
#   'with',
#   'grand',
#   'pivot',
#   'to',
#   'conservation'],
#  ['trumps',
#   'scottish',
#   'golf',
#   'resort',
#   'pays',
#   'women',
#   'significantly',
#   'less',
#   'than',
#   'men',
#   'report'],
#  ['weird',
#   'fathers',
#   'day',
#   'gifts',
#   'your',
#   'dad',
#   'doesnt',
#   'know',
#   'he',
#   'wants',
#   'but',
#   'he',
#   'does'],
#  ['twitter',
#   'putstarwarsinotherfilms',
#   'and',
#   'it',
#   'was',
#   'universally',
#   'entertaining'],
#  ['mystery',
#   'wolflike',
#   'animal',
#   'reportedly',
#   'shot',
#   'in',
#   'montana',
#   'baffles',
#   'wildlife',
#   'officials'],
#  ['north',
#   'korea',
#   'still',
#   'open',
#   'to',
#   'talks',
#   'after',
#   'trump',
#   'cancels',
#   'summit'],
#  ['2',
#   'men',
#   'detonate',
#   'bomb',
#   'inside',
#   'indian',
#   'restaurant',
#   'near',
#   'toronto',
#   'authorities',
#   'say'],
#  ['thousands',
#   'travel',
#   'home',
#   'to',
#   'ireland',
#   'to',
#   'vote',
#   'on',
#   'abortion',
#   'access'],
#  ['irish',
#   'voters',
#   'set',
#   'to',
#   'liberalize',
#   'abortion',
#   'laws',
#   'in',
#   'landslide',
#   'exit',
#   'poll',
#   'signals'],
#  ['warriors',
#   'coach',
#   'steve',
#   'kerr',
#   'calls',
#   'nfl',
#   'ban',
#   'on',
#   'protests',
#   'fake',
#   'patriotism'],
#  ['in',
#   'historic',
#   'victory',
#   'barbados',
#   'elects',
#   'first',
#   'female',
#   'prime',
#   'minister'],
#  ['police',
#   'killed',
#   'at',
#   'least',
#   '378',
#   'black',
#   'americans',
#   'from',
#   'the',
#   'moment',
#   'colin',
#   'kaepernick',
#   'protested'],
#  ['jack',
#   'johnson',
#   'was',
#   'pardoned',
#   'but',
#   'taboo',
#   'sex',
#   'is',
#   'still',
#   'being',
#   'criminalized'],
#  ['bet', 'chairman', 'and', 'ceo', 'debra', 'lee', 'is', 'stepping', 'down'],
#  ['rachel',
#   'dolezal',
#   'faces',
#   'felony',
#   'charges',
#   'for',
#   'welfare',
#   'fraud'],
#  ['bishop',
#   'michael',
#   'curry',
#   'joins',
#   'christian',
#   'march',
#   'to',
#   'white',
#   'house',
#   'to',
#   'reclaim',
#   'jesus'],
#  ['kanye',
#   'west',
#   'spent',
#   '85000',
#   'on',
#   'photo',
#   'of',
#   'whitney',
#   'houstons',
#   'bathroom',
#   'for',
#   'album',
#   'cover'],
#  ['morgan',
#   'freeman',
#   'dropped',
#   'from',
#   'marketing',
#   'campaigns',
#   'after',
#   'harassment',
#   'accusations'],
#  ['how',
#   'the',
#   'chinese',
#   'exclusion',
#   'act',
#   'can',
#   'help',
#   'us',
#   'understand',
#   'immigration',
#   'politics',
#   'today'],
#  ['trumps', 'new', 'magathemed', 'swimwear', 'sinks', 'on', 'twitter'],
#  ['seth',
#   'meyers',
#   'has',
#   '1',
#   'funny',
#   'regret',
#   'after',
#   'trump',
#   'cancels',
#   'north',
#   'korea',
#   'summit'],
#  ['colbert',
#   'wants',
#   'to',
#   'turn',
#   'nyc',
#   'subway',
#   'rides',
#   'into',
#   'a',
#   'new',
#   'and',
#   'terrible',
#   'punishment'],
#  ['man',
#   'faces',
#   'charges',
#   'after',
#   'pulling',
#   'knife',
#   'stun',
#   'gun',
#   'on',
#   'muslim',
#   'students',
#   'at',
#   'mcdonalds'],
#  ['jimmy',
#   'kimmel',
#   'knows',
#   'why',
#   'irans',
#   'supreme',
#   'leader',
#   'watches',
#   'tom',
#   'and',
#   'jerry'],
#  ['2', 'people', 'injured', 'in', 'indiana', 'school', 'shooting'],
#  ['people',
#   'are',
#   'rattled',
#   'by',
#   'how',
#   'much',
#   'this',
#   'nigerian',
#   'man',
#   'looks',
#   'like',
#   'chadwick',
#   'boseman'],
#  ['david',
#   'cross',
#   'proves',
#   'yet',
#   'again',
#   'that',
#   'hes',
#   'terrible',
#   'at',
#   'apologizing'],
#  ['sesame',
#   'street',
#   'creators',
#   'sue',
#   'makers',
#   'of',
#   'upcoming',
#   'adultthemed',
#   'puppet',
#   'film'],
#  ['what',
#   'you',
#   'missed',
#   'about',
#   'the',
#   'saddest',
#   'death',
#   'in',
#   'avengers',
#   'infinity',
#   'war'],
#  ['george',
#   'takei',
#   'accuser',
#   'walks',
#   'back',
#   'story',
#   'of',
#   'drugging',
#   'and',
#   'sexual',
#   'assault'],
#  ['samantha',
#   'bees',
#   'parents',
#   'think',
#   'america',
#   'is',
#   'basically',
#   'a',
#   'war',
#   'zone'],
#  ['pete',
#   'davidson',
#   'says',
#   'his',
#   'mental',
#   'illness',
#   'doesnt',
#   'ruin',
#   'romance'],
#  ['james',
#   'corden',
#   'and',
#   'adam',
#   'levine',
#   'get',
#   'pulled',
#   'over',
#   'during',
#   'carpool',
#   'karaoke'],
#  ['emilia',
#   'clarke',
#   'dishes',
#   'on',
#   'her',
#   'final',
#   'game',
#   'of',
#   'thrones',
#   'scene'],
#  ['hollywood',
#   'doesnt',
#   'need',
#   'difficult',
#   'men',
#   'to',
#   'make',
#   'great',
#   'tv'],
#  ['harvey',
#   'weinstein',
#   'accusers',
#   'say',
#   'they',
#   'never',
#   'thought',
#   'he',
#   'would',
#   'be',
#   'arrested'],
#  ['harvey',
#   'weinstein',
#   'turns',
#   'himself',
#   'in',
#   'to',
#   'police',
#   'for',
#   'alleged',
#   'sex',
#   'crimes'],
#  ['john',
#   'mayers',
#   'weird',
#   'new',
#   'lowbudget',
#   'video',
#   'is',
#   'a',
#   'memeworthy',
#   'masterpiece'],
#  ['now',
#   'boba',
#   'fett',
#   'is',
#   'getting',
#   'his',
#   'own',
#   'star',
#   'wars',
#   'movie'],
#  ['trump', 'suggests', 'north', 'korea', 'summit', 'could', 'still', 'happen'],
#  ['roger',
#   'stone',
#   'pressed',
#   'for',
#   'damaging',
#   'emails',
#   'about',
#   'hillary',
#   'clinton',
#   'from',
#   'wikileaks',
#   'report'],
#  ['publix',
#   'suspends',
#   'contributions',
#   'to',
#   'nrabacked',
#   'politician',
#   'amid',
#   'protests'],
#  ['twitter',
#   'bots',
#   'may',
#   'have',
#   'delivered',
#   'donald',
#   'trumps',
#   'victory',
#   'research',
#   'paper',
#   'says'],
#  ['a',
#   'bag',
#   'of',
#   'wet',
#   'socks',
#   'is',
#   'apparently',
#   'living',
#   'in',
#   'the',
#   'white',
#   'house',
#   'press',
#   'briefing',
#   'room'],
#  ['a',
#   'member',
#   'of',
#   'the',
#   'farright',
#   'proud',
#   'boys',
#   'menaced',
#   'a',
#   'twitter',
#   'user',
#   'on',
#   'his',
#   'doorstep'],
#  ['all',
#   'the',
#   'things',
#   'the',
#   'nra',
#   'has',
#   'blamed',
#   'for',
#   'the',
#   'texas',
#   'school',
#   'shooting'],
#  ['heres',
#   'what',
#   'happens',
#   'when',
#   'a',
#   'catholic',
#   'hospital',
#   'wont',
#   'try',
#   'to',
#   'save',
#   'you'],
#  ['trumps',
#   'new',
#   'executive',
#   'orders',
#   'make',
#   'it',
#   'easier',
#   'to',
#   'fire',
#   'federal',
#   'workers'],
#  ['monsanto',
#   'and',
#   'bayer',
#   'are',
#   'set',
#   'to',
#   'merge',
#   'heres',
#   'why',
#   'you',
#   'should',
#   'care'],
#  ['the', 'joy', 'of', 'watching', 'harvey', 'weinsteins', 'perp', 'walk'],
#  ['the', '20', 'funniest', 'tweets', 'from', 'women', 'this', 'week'],
#  ['queer',
#   'eye',
#   'star',
#   'bobby',
#   'berk',
#   'gave',
#   'me',
#   'a',
#   'desk',
#   'makeover',
#   '',
#   'and',
#   'it',
#   'was',
#   'incredible'],
#  ['older',
#   'gay',
#   'men',
#   'try',
#   'out',
#   'new',
#   'gay',
#   'slang',
#   'in',
#   'this',
#   'hilarious',
#   'video'],
#  ['how',
#   'rupauls',
#   'drag',
#   'race',
#   'is',
#   'teaching',
#   'straight',
#   'people',
#   'about',
#   'queer',
#   'culture'],
#  ['fish',
#   'market',
#   'buys',
#   'freedom',
#   'for',
#   'fred',
#   'the',
#   '70pound',
#   'octopus'],
#  ['north',
#   'korea',
#   'threatens',
#   'again',
#   'to',
#   'call',
#   'off',
#   'trump',
#   'summit',
#   'warns',
#   'of',
#   'nuclear',
#   'showdown'],
#  ['investigation',
#   'finds',
#   'russian',
#   'missile',
#   'shot',
#   'down',
#   'flight',
#   'mh17'],
#  ['north',
#   'korea',
#   'demolishes',
#   'tunnels',
#   'at',
#   'nuclear',
#   'test',
#   'site',
#   'reports',
#   'say'],
#  ['how',
#   'kim',
#   'jong',
#   'un',
#   'baited',
#   'trump',
#   'into',
#   'canceling',
#   'the',
#   'north',
#   'korea',
#   'summit'],
#  ['michelle',
#   'obama',
#   'reveals',
#   'cover',
#   'for',
#   'upcoming',
#   'memoir',
#   'becoming'],
#  ['late',
#   'night',
#   'writers',
#   'breathless',
#   'royal',
#   'wedding',
#   'recap',
#   'is',
#   'the',
#   'only',
#   'one',
#   'you',
#   'need'],
#  ['morgan',
#   'freeman',
#   'accused',
#   'of',
#   'inappropriate',
#   'behavior',
#   'and',
#   'sexual',
#   'harassment'],
#  ['jets',
#   'chairman',
#   'christopher',
#   'johnson',
#   'wont',
#   'fine',
#   'players',
#   'for',
#   'anthem',
#   'protests'],
#  ['andy',
#   'cohen',
#   'and',
#   'taylor',
#   'swift',
#   'are',
#   'over',
#   'their',
#   'katy',
#   'perry',
#   'drama'],
#  ['infinity',
#   'war',
#   'writers',
#   'try',
#   'to',
#   'clear',
#   'up',
#   'marvels',
#   'problematic',
#   'timeline'],
#  ['david',
#   'blaine',
#   'chews',
#   'glass',
#   'and',
#   'lets',
#   'james',
#   'corden',
#   'puncture',
#   'his',
#   'cheek'],
#  ['amy',
#   'poehler',
#   'a',
#   'parks',
#   'and',
#   'recreation',
#   'revival',
#   'would',
#   'be',
#   'amazing'],
#  ['colbert',
#   'exposes',
#   'the\xa0biggest',
#   'flaw',
#   'in',
#   'trumps',
#   'latest',
#   'conspiracy',
#   'theory'],
#  ['seth',
#   'meyers',
#   'gives',
#   'donald',
#   'trump',
#   'some',
#   'valuable',
#   'marketing',
#   'advice'],
#  ['us',
#   'launches',
#   'auto',
#   'import',
#   'probe',
#   'china',
#   'vows',
#   'to',
#   'defend',
#   'its',
#   'interests'],
#  ['this',
#   'women',
#   'pulled',
#   'out',
#   'all',
#   'the',
#   'stops',
#   'to',
#   'land',
#   'her',
#   'dream',
#   'job'],
#  ['wife',
#   'asked',
#   'husband',
#   'for',
#   'fenty',
#   'highlighter',
#   'and',
#   'got',
#   'a',
#   'pack',
#   'of',
#   'highlighters',
#   'hairbrush'],
#  ['trump',
#   'roasted',
#   'for',
#   'rushing',
#   'to',
#   'defend',
#   'tomi',
#   'lahren',
#   'while',
#   'ignoring',
#   'real',
#   'victims'],
#  ['trump',
#   'abruptly',
#   'cancels',
#   'north',
#   'korea',
#   'summit',
#   'with',
#   'kim',
#   'jong',
#   'un'],
#  ['devin',
#   'nuneslinked',
#   'winery',
#   'faced',
#   'suit',
#   'over',
#   'alleged',
#   'coke',
#   'and',
#   'prostitute',
#   'yacht',
#   'party'],
#  ['immigrant',
#   'children',
#   'accuse',
#   'border',
#   'patrol',
#   'of',
#   'abuse',
#   'and',
#   'neglect',
#   'report',
#   'shows'],
#  ['irelands',
#   'historic',
#   'vote',
#   'on',
#   'legalizing',
#   'abortion',
#   'is',
#   'haunted',
#   'by',
#   'trump',
#   'and',
#   'brexit'],
#  ['trump',
#   'lawyer',
#   'attended',
#   'doj',
#   'meeting',
#   'on',
#   'confidential',
#   'fbi',
#   'informant'],
#  ['senate',
#   'advances',
#   'court',
#   'pick',
#   'who',
#   'said',
#   'planned',
#   'parenthood',
#   'kills',
#   'over',
#   '150000',
#   'females',
#   'a',
#   'year'],
#  ['rudy',
#   'giuliani',
#   'trump',
#   'wont',
#   'interview',
#   'with',
#   'mueller',
#   'until',
#   'we',
#   'get',
#   'spygate',
#   'report'],
#  ['kentucky',
#   'attorney',
#   'running',
#   'for',
#   'judge',
#   'dies',
#   '1',
#   'day',
#   'after',
#   'primary',
#   'win'],
#  ['chrissy',
#   'teigen',
#   'taunts',
#   'donald',
#   'trump',
#   'over',
#   'twitter',
#   'blocking',
#   'ruling'],
#  ['the',
#   'koch',
#   'network',
#   'is',
#   'going',
#   'after',
#   'one',
#   'of',
#   'trumps',
#   'favorite',
#   'congressmen'],
#  ['trump', 'posthumously', 'pardons', 'boxer', 'jack', 'johnson'],
#  ['ellen',
#   'tears',
#   'up',
#   'when',
#   'ashton',
#   'kutcher',
#   'donates',
#   '4',
#   'million',
#   'to',
#   'her',
#   'wildlife',
#   'fund'],
#  ['ariana',
#   'grande',
#   'reveals',
#   'bee',
#   'tattoo',
#   'in',
#   'honor',
#   'of',
#   'the',
#   'manchester',
#   'attack'],
#  ['kim',
#   'kardashian',
#   'wished',
#   'kanye',
#   'west',
#   'a',
#   'happy',
#   'anniversary',
#   'and',
#   'fine',
#   'its',
#   'pretty',
#   'cute'],
#  ['chris',
#   'hemsworth',
#   'dances',
#   'wrecking',
#   'ball',
#   'with',
#   'his',
#   'kids',
#   'in',
#   'the',
#   'living',
#   'room'],
#  ['moses',
#   'farrow',
#   'defends',
#   'woody',
#   'allen',
#   'and',
#   'accuses',
#   'mia',
#   'farrow',
#   'of',
#   'abuse'],
#  ['gwyneth',
#   'paltrow',
#   'says',
#   'brad',
#   'pitt',
#   'threatened',
#   'to',
#   'kill',
#   'harvey',
#   'weinstein'],
#  ['stephen',
#   'king',
#   'reveals',
#   'why',
#   'donald',
#   'trump',
#   'blocked',
#   'him',
#   'on',
#   'twitter'],
#  ['fans',
#   'back',
#   'jessica',
#   'walter',
#   'after',
#   'she',
#   'addressed',
#   'verbal',
#   'harassment',
#   'by',
#   'jeffrey',
#   'tambor'],
#  ['jessica',
#   'walter',
#   'discusses',
#   'jeffrey',
#   'tambors',
#   'alleged',
#   'harassment',
#   'while',
#   'male',
#   'costars',
#   'brush',
#   'it',
#   'off'],
#  ['harvey',
#   'weinstein',
#   'expected',
#   'to',
#   'turn',
#   'himself',
#   'in',
#   'to',
#   'the',
#   'nypd',
#   'for',
#   'sex',
#   'crimes'],
#  ['samantha',
#   'bee',
#   'torches',
#   'ice',
#   'lets',
#   'shut',
#   'it',
#   'the',
#   'fk',
#   'down'],
#  ['scott',
#   'pruitt',
#   'twice',
#   'introduced',
#   'antiabortion',
#   'bills',
#   'giving',
#   'men',
#   'property',
#   'rights',
#   'over',
#   'fetuses'],
#  ['twitter',
#   'critics',
#   'mercilessly',
#   'mock',
#   'trump',
#   'for',
#   'canceling',
#   'summit',
#   'with',
#   'kim'],
#  ['civil',
#   'rights',
#   'groups',
#   'rip',
#   'senate',
#   'bill',
#   'revising',
#   'its',
#   'own',
#   'sexual',
#   'harassment',
#   'policy'],
#  ['alabama',
#   'sues',
#   'to',
#   'exclude',
#   'undocumented',
#   'immigrants',
#   'from',
#   'census',
#   'count'],
#  ['cynthia',
#   'nixon',
#   'vows',
#   'to',
#   'keep',
#   'fighting',
#   'after',
#   'predictably',
#   'losing',
#   'party',
#   'endorsement'],
#  ['white',
#   'house',
#   'officials',
#   'reportedly',
#   'considered',
#   'just',
#   'ignoring',
#   'new',
#   'climate',
#   'research'],
#  ['read',
#   'trumps',
#   'letter',
#   'to',
#   'kim',
#   'jong',
#   'un',
#   'canceling',
#   'north',
#   'korea',
#   'summit'],
#  ['south',
#   'korea',
#   'responds',
#   'to',
#   'trumps',
#   'sudden',
#   'cancellation',
#   'of',
#   'kim',
#   'jong',
#   'un',
#   'summit'],
#  ['facebooks',
#   'new',
#   'ad',
#   'rules',
#   'prove',
#   'its',
#   'basically',
#   'in',
#   'charge',
#   'of',
#   'regulating',
#   'elections',
#   'now'],
#  ['border', 'agent', 'fatally', 'shoots', 'migrant', 'woman', 'in', 'texas'],
#  ['trump',
#   'opens',
#   'door',
#   'for',
#   'us',
#   'gun',
#   'industry',
#   'to',
#   'sell',
#   'more',
#   'firearms',
#   'abroad'],
#  ['stormy',
#   'daniels',
#   'day',
#   'declared',
#   'in',
#   'west',
#   'hollywood',
#   'as',
#   'adult',
#   'star',
#   'gets',
#   'key',
#   'to',
#   'city'],
#  ['youre',
#   'going',
#   'to',
#   'use',
#   'that',
#   'selfcheckout',
#   'machine',
#   'whether',
#   'you',
#   'like',
#   'it',
#   'or',
#   'not'],
#  ['14',
#   'ways',
#   'to',
#   'make',
#   'family',
#   'road',
#   'trips',
#   'easier',
#   'from',
#   'parents',
#   'whove',
#   'been',
#   'there'],
#  ['jake',
#   'tapper',
#   'shreds',
#   'donald',
#   'trump',
#   'with',
#   'a',
#   'long',
#   'list',
#   'of',
#   'his',
#   'conspiracy',
#   'theories'],
#  ['new',
#   'york',
#   'daily',
#   'news',
#   'rips',
#   'nfl',
#   'over',
#   'anthem',
#   'kneeling',
#   'ban'],
#  ['a',
#   'judge',
#   'ruled',
#   'one',
#   'immigrant',
#   'had',
#   'a',
#   'right',
#   'to',
#   'a',
#   'hearing',
#   'what',
#   'about',
#   'all',
#   'the',
#   'others'],
#  ['house',
#   'democrats',
#   'offer',
#   'internships',
#   'for',
#   'students',
#   'affected',
#   'by',
#   'gun',
#   'violence'],
#  ['tig',
#   'notaro',
#   'tells',
#   'ellen',
#   'degeneres',
#   'about',
#   'her',
#   'sons',
#   'passion',
#   'for',
#   'trash'],
#  ['stormy',
#   'daniels',
#   'thanks',
#   'wonderful',
#   'gay',
#   'dads',
#   'as',
#   'west',
#   'hollywood',
#   'hands',
#   'her',
#   'keys',
#   'to',
#   'city'],
#  ['can',
#   'you',
#   'believe',
#   'queer',
#   'eye',
#   'season',
#   '2',
#   'drops',
#   'next',
#   'month'],
#  ['gay',
#   'man',
#   'denied',
#   'marriage',
#   'license',
#   'by',
#   'kim',
#   'davis',
#   'loses',
#   'bid',
#   'to',
#   'unseat',
#   'her'],
#  ['anna',
#   'kournikova',
#   'dancing',
#   'with',
#   'her',
#   'bouncing',
#   'baby',
#   'is',
#   'the',
#   'cutest',
#   'thing'],
#  ['trump',
#   'says',
#   'nfl',
#   'players',
#   'unwilling',
#   'to',
#   'stand',
#   'for',
#   'anthem',
#   'maybe',
#   'shouldnt',
#   'be',
#   'in',
#   'the',
#   'country'],
#  ['facebook',
#   'accused',
#   'of',
#   'reading',
#   'texts',
#   'and',
#   'accessing',
#   'microphones',
#   'in',
#   'lawsuit'],
#  ['selfdriving',
#   'uber',
#   'in',
#   'fatal',
#   'accident',
#   'had',
#   '6',
#   'seconds',
#   'to',
#   'react',
#   'before',
#   'crash'],
#  ['amazon',
#   'admits',
#   'alexa',
#   'device',
#   'eavesdropped',
#   'on',
#   'portland',
#   'family'],
#  ['man',
#   'discovers',
#   'handgun',
#   'impaled',
#   'in',
#   'front',
#   'bumper',
#   'of',
#   'car'],
#  ['rescue',
#   'cat',
#   'has',
#   'hilarious',
#   'wideeyed',
#   'expression',
#   'after',
#   'scan',
#   'confirms',
#   'she',
#   'is',
#   'pregnant'],
#  ['weirdest',
#   'promposals',
#   'of',
#   '2018',
#   'include',
#   'teen',
#   'who',
#   'faked',
#   'his',
#   'own',
#   'birth'],
#  ['trump',
#   'and',
#   'the',
#   'american',
#   'far',
#   'right',
#   'stoke',
#   'hate',
#   'in',
#   'canada'],
#  ['farright',
#   'and',
#   'antiestablishment',
#   'parties',
#   'set',
#   'to',
#   'form',
#   'italys',
#   'new',
#   'government'],
#  ['sarah',
#   'silverman',
#   'sees',
#   'no',
#   'reason',
#   'why',
#   'louis',
#   'ck',
#   'cant',
#   'continue',
#   'being',
#   'an',
#   'artist'],
#  ['southern',
#   'baptist',
#   'leader',
#   'who',
#   'said',
#   'abused',
#   'women',
#   'should',
#   'just',
#   'pray',
#   'is',
#   'removed',
#   'from',
#   'post'],
#  ['more', 'americans', 'than', 'ever', 'support', 'samesex', 'marriage'],
#  ['brynn',
#   'cartelli',
#   'becomes',
#   'youngestever',
#   'winner',
#   'of',
#   'the',
#   'voice'],
#  ['betsy',
#   'devos',
#   'stirs',
#   'uproar',
#   'by',
#   'saying',
#   'schools',
#   'can',
#   'call',
#   'ice',
#   'on',
#   'undocumented',
#   'kids'],
#  ['6',
#   'sandy',
#   'hook',
#   'families',
#   'fbi',
#   'agent',
#   'sue',
#   'alex',
#   'jones',
#   'for',
#   'defamation'],
#  ['high',
#   'school',
#   'teacher',
#   'defeats',
#   'kentucky',
#   'house',
#   'majority',
#   'leader',
#   'in',
#   'gop',
#   'primary'],
#  ['lupe',
#   'valdez',
#   'makes',
#   'history',
#   'in',
#   'texas',
#   'by',
#   'winning',
#   'democratic',
#   'nod',
#   'for',
#   'governor'],
#  ['report',
#   'michael',
#   'cohens',
#   'business',
#   'partner',
#   'cooperating',
#   'with',
#   'prosecutors'],
#  ['brandi',
#   'chastain',
#   'totally',
#   'agrees',
#   'her',
#   'hall',
#   'of',
#   'fame',
#   'plaque',
#   'looks',
#   'nothing',
#   'like',
#   'her'],
#  ['scientists',
#   'turn',
#   'to',
#   'dna',
#   'technology',
#   'to',
#   'search',
#   'for',
#   'loch',
#   'ness',
#   'monster'],
#  ['late',
#   'night',
#   'writer',
#   'vows',
#   'to',
#   'take',
#   'red',
#   'hats',
#   'back',
#   'from',
#   'trump',
#   'supporters'],
#  ['julia',
#   'louisdreyfus',
#   'to',
#   'receive',
#   '2018',
#   'mark',
#   'twain',
#   'prize',
#   'for',
#   'american',
#   'humor'],
#  ['michelle',
#   'obama',
#   'shares',
#   'intimate',
#   'wedding',
#   'photo',
#   'in',
#   'tribute',
#   'to',
#   'husband',
#   'barack'],
#  ['did',
#   'you',
#   'spot',
#   'trevor',
#   'noah',
#   'in',
#   'black',
#   'panther',
#   'the',
#   'daily',
#   'show',
#   'hosts',
#   'stealth',
#   'cameo',
#   'revealed'],
#  ['donald',
#   'glover',
#   'fans',
#   'execute',
#   'stunning',
#   'coup',
#   'on',
#   'donald',
#   'trumpthemed',
#   'reddit',
#   'forum'],
#  ['ti',
#   'calls',
#   'for',
#   'boycott',
#   'of',
#   'restaurant',
#   'after',
#   'offduty',
#   'cop',
#   'allegedly',
#   'assaults',
#   '3',
#   'black',
#   'women'],
#  ['survivor',
#   'of',
#   'rwandan',
#   'genocide',
#   'to',
#   'be',
#   'countrys',
#   'first',
#   'female',
#   'neurosurgeon'],
#  ['stacey',
#   'abrams',
#   'wins',
#   'democratic',
#   'primary',
#   'for',
#   'georgia',
#   'governor'],
#  ['trevor',
#   'noah',
#   'reveals',
#   'the',
#   'question',
#   'hed',
#   'ask',
#   'donald',
#   'trump',
#   'that',
#   'no',
#   'else',
#   'has',
#   'dared',
#   'to'],
#  ['michelle',
#   'obama',
#   'reflects',
#   'on',
#   'scary',
#   'time',
#   'at',
#   'princeton',
#   'with',
#   'sweet',
#   'throwback',
#   'snap'],
#  ['13',
#   'reasons',
#   'why',
#   'started',
#   'a',
#   'conversation',
#   'whos',
#   'responsible',
#   'for',
#   'finishing',
#   'it'],
#  ['lourdes',
#   'leon',
#   'gives',
#   'us',
#   'major',
#   'madonna',
#   'vibes',
#   'in',
#   'moody',
#   'new',
#   'ad',
#   'campaign',
#   'pics'],
#  ['5',
#   'ways',
#   'netflix',
#   'tricks',
#   'you',
#   'into',
#   'watching',
#   'more',
#   'shows',
#   'and',
#   'movies'],
#  ['brad',
#   'pitt',
#   'made',
#   'ryan',
#   'reynolds',
#   'do',
#   'one',
#   'demeaning',
#   'thing',
#   'in',
#   'exchange',
#   'for',
#   'deadpool',
#   '2',
#   'cameo'],
#  ['robert',
#   'de',
#   'niro',
#   'bans',
#   'trump',
#   'from',
#   'every',
#   'nobu',
#   'restaurant'],
#  ['ariana',
#   'grande',
#   'shuts',
#   'down',
#   'fan',
#   'blaming',
#   'her',
#   'for',
#   'heartbreaking',
#   'mac',
#   'miller',
#   'split'],
#  ['parents',
#   'slam',
#   'show',
#   'dogs',
#   'scenes',
#   'as',
#   'grooming',
#   'children',
#   'for',
#   'sexual',
#   'abuse'],
#  ['dave',
#   'grohl',
#   'wants',
#   'to',
#   'apologize',
#   'to',
#   'the',
#   'world',
#   'for',
#   'massive',
#   'jerk',
#   'trump'],
#  ['emilia',
#   'clarke',
#   'introduced',
#   'herself',
#   'to',
#   'prince',
#   'william',
#   'in',
#   'a',
#   'pretty',
#   'embarrassing',
#   'way'],
#  ['sarah',
#   'paulson',
#   'takes',
#   'impressions',
#   'to',
#   'next',
#   'level',
#   'on',
#   'tonight',
#   'show'],
#  ['the',
#   'b52s',
#   'are',
#   'still',
#   'ready',
#   'to',
#   'party',
#   'and',
#   'be',
#   'taken',
#   'seriously'],
#  ['gina',
#   'ortiz',
#   'jones',
#   'wins',
#   'democratic',
#   'runoff',
#   'in',
#   'texas',
#   'congressional',
#   'race'],
#  ['fighter',
#   'pilot',
#   'amy',
#   'mcgrath',
#   'wins',
#   'democratic',
#   'primary',
#   'in',
#   'kentucky',
#   'swing',
#   'district'],
#  ['trump',
#   'rallies',
#   'conservatives',
#   'with',
#   'promise',
#   'of',
#   'more',
#   'abortion',
#   'curbs'],
#  ['the',
#   'aclu',
#   'is',
#   'suing',
#   'to',
#   'strike',
#   'down',
#   'ohios',
#   'congressional',
#   'map'],
#  ['the',
#   'latest',
#   'school',
#   'shooting',
#   'hasnt',
#   'really',
#   'stirred',
#   'the',
#   'gun',
#   'debate'],
#  ['donald',
#   'trump',
#   'tweet',
#   'rescues',
#   'roseanne',
#   'and',
#   'family',
#   'in',
#   'season',
#   'finale'],
#  ['ellen',
#   'grills',
#   'mark',
#   'wahlberg',
#   'about',
#   'his',
#   'shirtless',
#   'instagram',
#   'selfies'],
#  ['idris',
#   'elba',
#   'to',
#   'star',
#   'as',
#   'the',
#   'new',
#   'hunchback',
#   'of',
#   'notre',
#   'dame',
#   'for',
#   'netflix'],
#  ['maryland',
#   'police',
#   'charge',
#   '3',
#   'church',
#   'leaders',
#   'with',
#   'past',
#   'abuse',
#   'of',
#   'atrisk',
#   'teen',
#   'girls'],
#  ['nfl', 'bans', 'kneeling', 'during', 'the', 'national', 'anthem'],
#  ['conan',
#   'obrien',
#   'muscles',
#   'in',
#   'on',
#   'the',
#   'royal',
#   'wedding',
#   'with',
#   'his',
#   'own',
#   'spoof',
#   'ads'],
#  ['house',
#   'republicans',
#   'report',
#   'progress',
#   'on',
#   'an',
#   'immigration',
#   'deal'],
#  ['democrats',
#   'werent',
#   'invited',
#   'to',
#   'review',
#   'classified',
#   'documents',
#   'on',
#   'fbi',
#   'informant'],
#  ['gop',
#   'candidate',
#   'who',
#   'pointed',
#   'gun',
#   'at',
#   'teenager',
#   'advances',
#   'to',
#   'georgia',
#   'governor',
#   'primary',
#   'runoff'],
#  ['walking',
#   'definition',
#   'of',
#   'an',
#   'entitled',
#   'millennial',
#   'swears',
#   'hes',
#   'not',
#   'an',
#   'entitled',
#   'millennial'],
#  ['democrats',
#   'push',
#   'to',
#   'be',
#   'included',
#   'in',
#   'classified',
#   'briefing',
#   'on',
#   'fbi',
#   'informant'],
#  ['machines',
#   'dont',
#   'always',
#   'steal',
#   'our',
#   'jobs',
#   'increasingly',
#   'they',
#   'rob',
#   'our',
#   'work',
#   'of',
#   'humanity'],
#  ['trump',
#   'praises',
#   'tomi',
#   'lahren',
#   'after',
#   'restaurant',
#   'crowd',
#   'tosses',
#   'water',
#   'insults'],
#  ['sarah', 'sanders', 'it', 'bothers', 'me', 'being', 'called', 'a', 'liar'],
#  ['trump',
#   'blocking',
#   'people',
#   'on',
#   'twitter',
#   'is',
#   'unconstitutional',
#   'judge',
#   'rules'],
#  ['a',
#   'mostly',
#   'nonchristian',
#   'militia',
#   'won',
#   '2',
#   'of',
#   'iraqi',
#   'christians',
#   'parliamentary',
#   'seats',
#   'now',
#   'christians',
#   'want',
#   'trump',
#   'to',
#   'intervene'],
#  ['tulsi',
#   'gabbards',
#   'syria',
#   'views',
#   'cost',
#   'her',
#   'support',
#   'of',
#   'hawaii',
#   'teachers',
#   'union'],
#  ['jared', 'kushner', 'received', 'his', 'security', 'clearance', 'reports'],
#  ['arizona',
#   'gop',
#   'congressional',
#   'candidate',
#   'compares',
#   'abortion',
#   'to',
#   'holocaust'],
#  ['gun',
#   'reform',
#   'advocate',
#   'lucy',
#   'mcbath',
#   'heads',
#   'to',
#   'runoff',
#   'for',
#   'georgia',
#   'house',
#   'seat'],
#  ['star',
#   'wars',
#   'burlesque',
#   'show',
#   'storms',
#   'west',
#   'coast',
#   'with',
#   'sexy',
#   'stormtroopers'],
#  ['establishmentbacked',
#   'moderate',
#   'wins',
#   'heated',
#   'democratic',
#   'house',
#   'primary',
#   'in',
#   'texas'],
#  ['senators',
#   'unveil',
#   'bill',
#   'to',
#   'crack',
#   'down',
#   'on',
#   'their',
#   'sexual',
#   'harassment'],
#  ['14',
#   'trips',
#   'to',
#   'take',
#   'from',
#   'new',
#   'york',
#   'city',
#   'on',
#   'a',
#   'long',
#   'weekend'],
#  ['disney',
#   'reveals',
#   'opening',
#   'seasons',
#   'for',
#   'star',
#   'wars',
#   'theme',
#   'park',
#   'lands'],
#  ['the',
#   'latest',
#   'entries',
#   'from',
#   'the',
#   'comedy',
#   'wildlife',
#   'photo',
#   'awards',
#   'will',
#   'cheer',
#   'you',
#   'up'],
#  ['bad',
#   'lip',
#   'reading',
#   'reveals',
#   'what',
#   'was',
#   'really',
#   'said',
#   'at',
#   'the',
#   'royal',
#   'wedding'],
#  ['australian',
#   'archbishop',
#   'convicted',
#   'of',
#   'covering',
#   'up',
#   'child',
#   'sex',
#   'abuse'],
#  ['commander',
#   'says',
#   'irans',
#   'people',
#   'will',
#   'respond',
#   'to',
#   'pompeos',
#   'threats',
#   'with',
#   'a',
#   'punch',
#   'in',
#   'the',
#   'mouth'],
#  ['mark',
#   'zuckerberg',
#   'extends',
#   'facebook',
#   'apology',
#   'tour',
#   'with',
#   'european',
#   'gig'],
#  ['ariana',
#   'grande',
#   'tweets',
#   'message',
#   'of',
#   'support',
#   'on',
#   'manchester',
#   'bombing',
#   'anniversary'],
#  ['katy', 'perry', 'says', 'shes', 'not', 'single', 'on', 'american', 'idol'],
#  ['before',
#   'you',
#   'call',
#   'the',
#   'cops',
#   'on',
#   'him',
#   'watch',
#   'his',
#   'powerful',
#   'monologue',
#   'on',
#   'racism'],
#  ['amazon',
#   'is',
#   'selling',
#   'cops',
#   'its',
#   'facial',
#   'recognition',
#   'tool',
#   'thats',
#   'a',
#   'bad',
#   'potentially',
#   'racist',
#   'move'],
#  ['miley',
#   'cyrus',
#   'comes',
#   'in',
#   'like',
#   'a',
#   'wrecking',
#   'ball',
#   'to',
#   'prank',
#   'a',
#   'sleeping',
#   'jimmy',
#   'kimmel'],
#  ['vanessa',
#   'bayer',
#   'feared',
#   'doing',
#   'the',
#   'porn',
#   'stars',
#   'skit',
#   'with',
#   'donald',
#   'trump',
#   'on',
#   'snl'],
#  ['adam',
#   'rippon',
#   'wins',
#   'dancing',
#   'with',
#   'the',
#   'stars',
#   'because',
#   'it',
#   'was',
#   'destined'],
#  ['emilia',
#   'clarke',
#   'should',
#   'never',
#   'try',
#   'to',
#   'imitate',
#   'chewbacca',
#   'ever',
#   'again'],
#  ['maddie',
#   'poppe',
#   'wins',
#   'american',
#   'idol',
#   'after',
#   'runnerup',
#   'reveals',
#   'theyre',
#   'dating'],
#  ['colbert',
#   'just',
#   'cant',
#   'resist',
#   'turning',
#   'trumps',
#   'nickname',
#   'into',
#   'a',
#   'pee',
#   'tape',
#   'joke'],
#  ['seth',
#   'meyers',
#   'is',
#   'forced',
#   'to',
#   'tweak',
#   'donald',
#   'trumps',
#   'latest',
#   'twitter',
#   'rant',
#   'for',
#   'time'],
#  ['boy',
#   'says',
#   'teacher',
#   'told',
#   'him',
#   'it',
#   'will',
#   'be',
#   'his',
#   'fault',
#   'when',
#   'police',
#   'shoot',
#   'him',
#   'at',
#   'age',
#   '16'],
#  ['cops',
#   'accused',
#   'of',
#   'racism',
#   'after',
#   'detaining',
#   'black',
#   'man',
#   'over',
#   'vegetation'],
#  ['white',
#   'cop',
#   'shouts',
#   'at',
#   'black',
#   'suspect',
#   'pretend',
#   'like',
#   'were',
#   'going',
#   'to',
#   'shoot',
#   'you'],
#  ['florida',
#   'police',
#   'report',
#   '2',
#   'dead',
#   'after',
#   'standoff',
#   'at',
#   'panama',
#   'city',
#   'apartment',
#   'complex'],
#  ['donald',
#   'glover',
#   'is',
#   'on',
#   'board',
#   'with',
#   'lando',
#   'calrissians',
#   'pansexuality',
#   'in',
#   'solo'],
#  ['charlize',
#   'theron',
#   'to',
#   'play',
#   'megyn',
#   'kelly',
#   'in',
#   'film',
#   'about',
#   'roger',
#   'ailes'],
#  ['shoppers',
#   'boycott',
#   'publix',
#   'over',
#   'stores',
#   'donations',
#   'to',
#   'nrabacked',
#   'candidate'],
#  ['bill',
#   'de',
#   'blasio',
#   'tells',
#   'nypd',
#   'to',
#   'stop',
#   'arresting',
#   'people',
#   'for',
#   'smoking',
#   'pot',
#   'on',
#   'the',
#   'street'],
#  ['dhs',
#   'head',
#   'says',
#   'shes',
#   'still',
#   'somehow',
#   'unaware',
#   'of',
#   'intel',
#   'on',
#   'russia',
#   'interference',
#   'to',
#   'boost',
#   'trump'],
#  ['lawmaker',
#   'introduces',
#   'crowdfunding',
#   'bill',
#   'to',
#   'pay',
#   'for',
#   'trumps',
#   'border',
#   'wall'],
#  ['gop',
#   'lawmakers',
#   'will',
#   'soon',
#   'be',
#   'allowed',
#   'to',
#   'review',
#   'classified',
#   'info',
#   'on',
#   'russia',
#   'investigation'],
#  ['james',
#   'corden',
#   'reveals',
#   'the',
#   'worst',
#   'part',
#   'of',
#   'the',
#   'royal',
#   'wedding',
#   'ceremony'],
#  ['ariana',
#   'grande',
#   'reportedly',
#   'dating',
#   'snl',
#   'star',
#   'pete',
#   'davidson'],
#  ['jim',
#   'carrey',
#   'pens',
#   'new',
#   'pledge',
#   'of',
#   'allegiance',
#   'for',
#   'students',
#   'in',
#   'bulletriddled',
#   'schools'],
#  ['ellen',
#   'gets',
#   'david',
#   'spade',
#   'to',
#   'open',
#   'up',
#   'about',
#   'dating',
#   'younger',
#   'women'],
#  ['ceasefire',
#   'over',
#   'jimmy',
#   'kimmel',
#   'shreds',
#   'sean',
#   'hannity',
#   'and',
#   'those',
#   'dummies',
#   'on',
#   'fox',
#   '',
#   'friends'],
#  ['spoof',
#   'royal',
#   'wedding',
#   'video',
#   'sees',
#   'ceremony',
#   'taking',
#   'a',
#   'very',
#   'different',
#   'turn'],
#  ['the',
#   'georgia',
#   'gop',
#   'governors',
#   'primary',
#   'focuses',
#   'on',
#   'guns',
#   'and',
#   'immigration'],
#  ['glaads',
#   'movie',
#   'report',
#   'finds',
#   'troubling',
#   'drop',
#   'in',
#   'lgbtq',
#   'representation'],
#  ['sephora',
#   'now',
#   'offers',
#   'instore',
#   'beauty',
#   'classes',
#   'for',
#   'trans',
#   'nonbinary',
#   'community'],
#  ['georgia',
#   'governors',
#   'primary',
#   'highlights',
#   'competing',
#   'visions',
#   'for',
#   'the',
#   'democratic',
#   'party'],
#  ['california',
#   'moves',
#   'to',
#   'let',
#   'schools',
#   'coworkers',
#   'red',
#   'flag',
#   'dangerous',
#   'gun',
#   'owners'],
#  ['talking',
#   'grievance',
#   'and',
#   'health',
#   'care',
#   'an',
#   'outsider',
#   'kentucky',
#   'dem',
#   'found',
#   'the',
#   'inside',
#   'track'],
#  ['there',
#   'are',
#   'some',
#   'problems',
#   'with',
#   'this',
#   'commemorative',
#   'trumpkim',
#   'jong',
#   'un',
#   'coin'],
#  ['giulianis',
#   'new',
#   'stance',
#   'on',
#   'russian',
#   'collusion',
#   'so',
#   'what',
#   'its',
#   'not',
#   'illegal'],
#  ['the',
#   'onion',
#   'hilariously',
#   'trolls',
#   'michael',
#   'cohen',
#   'with',
#   'his',
#   'own',
#   'ceaseanddesist',
#   'note'],
#  ['democrats',
#   'want',
#   'to',
#   'boost',
#   'school',
#   'funding',
#   'to',
#   'address',
#   'teacher',
#   'walkouts'],
#  ['but',
#   'her',
#   'emails',
#   'lawmakers',
#   'shrug',
#   'off',
#   'trumps',
#   'lax',
#   'cellphone',
#   'security'],
#  ['we',
#   'try',
#   'stink',
#   'bugflavored',
#   'jelly',
#   'bellys',
#   'so',
#   'you',
#   'dont',
#   'have',
#   'to'],
#  ['power',
#   'outage',
#   'triggers',
#   'extreme',
#   'zombie',
#   'activity',
#   'alert',
#   'in',
#   'florida',
#   'city'],
#  ['congress',
#   'does',
#   'wall',
#   'street',
#   'a',
#   'favor',
#   'as',
#   'banks',
#   'post',
#   'record',
#   'profits'],
#  ['white', 'house', 'sinkhole', 'probably', 'metaphor', 'for', 'something'],
#  ['reporter',
#   'shoved',
#   'others',
#   'barred',
#   'from',
#   'epa',
#   'meeting',
#   'on',
#   'water',
#   'contaminants'],
#  ['garry',
#   'kasparov',
#   'donald',
#   'trump',
#   'has',
#   'more',
#   'russian',
#   'connections',
#   'than',
#   'aeroflot'],
#  ['lonely',
#   'planets',
#   'top',
#   'european',
#   'destinations',
#   'of',
#   '2018',
#   'take',
#   'aim',
#   'at',
#   'overtourism'],
#  ['attorney',
#   'aaron',
#   'schlossberg',
#   'insists',
#   'antispanish',
#   'rant',
#   'is',
#   'not',
#   'the',
#   'person',
#   'i',
#   'am'],
#  ['60',
#   'minutes',
#   'reporter',
#   'reveals',
#   'trumps',
#   'chilling',
#   'reason',
#   'for',
#   'slamming',
#   'the',
#   'press'],
#  ['trump',
#   'reportedly',
#   'rejects',
#   'phone',
#   'security',
#   'measures',
#   'as',
#   'too',
#   'inconvenient'],
#  ['federal',
#   'court',
#   'sides',
#   'with',
#   'transgender',
#   'teen',
#   'gavin',
#   'grimm',
#   'in',
#   'bathroom',
#   'fight'],
#  ['extrump',
#   'adviser',
#   'calls',
#   'presidents',
#   'claims',
#   'that',
#   'informant',
#   'spied',
#   'on',
#   'campaign',
#   'embarrassing'],
#  ['vietnam',
#   'is',
#   'a',
#   'test',
#   'for',
#   'what',
#   'happens',
#   'when',
#   'the',
#   'us',
#   'abandons',
#   'climate',
#   'diplomacy'],
#  ['just',
#   'onethird',
#   'of',
#   'americans',
#   'think',
#   'trump',
#   'is',
#   'successfully',
#   'draining',
#   'the',
#   'swamp'],
#  ['msnbc',
#   'host',
#   'hugh',
#   'hewitt',
#   'suggests',
#   'trench',
#   'coat',
#   'control',
#   'not',
#   'gun',
#   'control'],
#  ['bishop',
#   'michael',
#   'curry',
#   'harry',
#   'and',
#   'meghans',
#   'love',
#   'brought',
#   'different',
#   'worlds',
#   'together'],
#  ['sarah',
#   'paulson',
#   'is',
#   'unapologetic',
#   'about',
#   '32year',
#   'age',
#   'gap',
#   'with',
#   'girlfriend',
#   'holland',
#   'taylor'],
#  ['texans',
#   'on',
#   'both',
#   'sides',
#   'of',
#   'gun',
#   'debate',
#   'agree',
#   'on',
#   'safe',
#   'storage',
#   'but',
#   'not',
#   'on',
#   'how',
#   'to',
#   'support',
#   'it'],
#  ['family',
#   'of',
#   'gay',
#   'man',
#   'found',
#   'critically',
#   'injured',
#   'near',
#   'amtrak',
#   'route',
#   'wants',
#   'answers'],
#  ['caitlyn',
#   'jenner',
#   'trump',
#   'is',
#   'the',
#   'worst',
#   'president',
#   'we',
#   'have',
#   'ever',
#   'had',
#   'on',
#   'lgbtq',
#   'rights'],
#  ['boy',
#   'scout',
#   'allegedly',
#   'booted',
#   'from',
#   'store',
#   'because',
#   'company',
#   'wont',
#   'support',
#   'homos'],
#  ['instagram',
#   'is',
#   'adding',
#   'a',
#   'mute',
#   'button',
#   'for',
#   'the',
#   'sake',
#   'of',
#   'your',
#   'sanity'],
#  ['publix', 'censors', 'teens', 'summa', 'cum', 'laude', 'graduation', 'cake'],
#  ['what',
#   'do',
#   'you',
#   'say',
#   'to',
#   'sexist',
#   'passengers',
#   'this',
#   'female',
#   'pilot',
#   'has',
#   'the',
#   'perfect',
#   'response'],
#  ['times',
#   'up',
#   'takes',
#   'aim',
#   'at',
#   'mcdonalds',
#   'walmart',
#   'over',
#   'sexual',
#   'harassment',
#   'complaints'],
#  ['venezuelas',
#   'socialist',
#   'leader',
#   'nicolas',
#   'maduro',
#   'reelected',
#   'amid',
#   'allegations',
#   'of',
#   'irregularities'],
#  ['iran',
#   'says',
#   'europes',
#   'support',
#   'for',
#   'nuclear',
#   'deal',
#   'isnt',
#   'enough',
#   'after',
#   'americas',
#   'withdrawal'],
#  ['farright', 'mob', 'attacks', '75yearold', 'liberal', 'greek', 'mayor'],
#  ['shawn',
#   'mendes',
#   'and',
#   'khalid',
#   'perform',
#   'with',
#   'parkland',
#   'survivors',
#   'at',
#   'billboard',
#   'music',
#   'awards'],
#  ['tamir',
#   'rices',
#   'mother',
#   'is',
#   'opening',
#   'a',
#   'youth',
#   'center',
#   'to',
#   'honor',
#   'her',
#   'sons',
#   'memory'],
#  ['judge',
#   'orders',
#   'texas',
#   'to',
#   'make',
#   'voter',
#   'registration',
#   'easier',
#   'when',
#   'updating',
#   'dmv',
#   'info'],
#  ['kelly',
#   'clarkson',
#   'calls',
#   'for',
#   'moments',
#   'of',
#   'action',
#   'in',
#   'honor',
#   'of',
#   'texas',
#   'shooting',
#   'victims',
#   'at',
#   'billboard',
#   'awards'],
#  ['kendrick', 'lamar', 'stops', 'white', 'fan', 'rapping', 'nword', 'onstage'],
#  ['gay',
#   'man',
#   'says',
#   'pope',
#   'francis',
#   'told',
#   'him',
#   'god',
#   'made',
#   'you',
#   'like',
#   'that',
#   'and',
#   'loves',
#   'you',
#   'like',
#   'that'],
#  ['unusual',
#   'asteroid',
#   'could',
#   'be',
#   'an',
#   'interstellar',
#   'guest',
#   'to',
#   'our',
#   'solar',
#   'system'],
#  ['she',
#   'started',
#   'a',
#   'suicide',
#   'prevention',
#   'site',
#   'at',
#   'age',
#   '15',
#   'its',
#   'still',
#   'going',
#   'strong'],
#  ['roger',
#   'stone',
#   'says',
#   'hes',
#   'prepared',
#   'for',
#   'conjured',
#   'up',
#   'mueller',
#   'indictment'],
#  ['hillary', 'clinton', 'to', 'endorse', 'andrew', 'cuomos', 'reelection'],
#  ['the',
#   'supreme',
#   'court',
#   'just',
#   'made',
#   'it',
#   'a',
#   'lot',
#   'harder',
#   'for',
#   'you',
#   'to',
#   'sue',
#   'your',
#   'employer'],
#  ['blake',
#   'farenthold',
#   'may',
#   'have',
#   'been',
#   'hired',
#   'illegally',
#   'at',
#   'his',
#   'new',
#   'lobbyist',
#   'job'],
#  ['bill',
#   'konigsberg',
#   'explores',
#   'a',
#   'new',
#   'side',
#   'of',
#   'the',
#   'gay',
#   'experience',
#   'in',
#   'his',
#   'latest',
#   'book'],
#  ['alone',
#   'in',
#   'the',
#   'game',
#   'shows',
#   'biggest',
#   'hurdles',
#   'for',
#   'lgbtq',
#   'athletes',
#   'exist',
#   'off',
#   'the',
#   'field'],
#  ['chrissy',
#   'teigen',
#   'somehow',
#   'gets',
#   'even',
#   'more',
#   'real',
#   'about',
#   'life',
#   'after',
#   'childbirth'],
#  ['suits',
#   'creator',
#   'pens',
#   'heartfelt',
#   'open',
#   'letter',
#   'about',
#   'attending',
#   'royal',
#   'wedding'],
#  ['here', 'are', 'the', 'movies', 'coming', 'to', 'netflix', 'this', 'week'],
#  ['the', 'obamas', 'are', 'coming', 'to', 'your', 'netflix', 'queue'],
#  ['sorry',
#   'ben',
#   'affleck',
#   'make',
#   'way',
#   'for',
#   'justin',
#   'therouxs',
#   'giant',
#   'rat',
#   'tattoo'],
#  ['hillary',
#   'clinton',
#   'tips',
#   'a',
#   'russian',
#   'hat',
#   'at',
#   'trump',
#   'during',
#   'yale',
#   'commencement',
#   'speech'],
#  ['giuliani',
#   'says',
#   'mueller',
#   'cant',
#   'talk',
#   'to',
#   'trump',
#   'until',
#   'trump',
#   'hears',
#   'more',
#   'about',
#   'fbi',
#   'source'],
#  ['democrats', 'plan', 'big', 'anticorruption', 'theme', 'for', 'midterms'],
#  ['kelly',
#   'clarkson',
#   'rejects',
#   'moment',
#   'of',
#   'silence',
#   'calls',
#   'for',
#   'change',
#   'at',
#   'billboard',
#   'music',
#   'awards'],
#  ['we',
#   'asked',
#   'the',
#   'american',
#   'public',
#   'to',
#   'settle',
#   '5',
#   'of',
#   'the',
#   'internets',
#   'dumbest',
#   'debates'],
#  ['fox',
#   'news',
#   'viewers',
#   'really',
#   'dont',
#   'like',
#   'lifelong',
#   'republican',
#   'robert',
#   'mueller'],
#  ['trump',
#   'team',
#   'moves',
#   'to',
#   'lift',
#   'ban',
#   'on',
#   'extreme',
#   'hunting',
#   'tactics',
#   'in',
#   'alaska'],
#  ['howard',
#   'stern',
#   'tells',
#   'how',
#   'trump',
#   'sexualized',
#   'ivanka',
#   'and',
#   'makes',
#   'david',
#   'letterman',
#   'cringe'],
#  ['the',
#   'supreme',
#   'court',
#   'is',
#   'helping',
#   'companies',
#   'get',
#   'away',
#   'with',
#   'sexual',
#   'harassment'],
#  ['deadpool',
#   '2',
#   'steals',
#   'no',
#   '1',
#   'spot',
#   'at',
#   'the',
#   'box',
#   'office',
#   'from',
#   'avengers',
#   'infinity',
#   'war'],
#  ['did', 'westworld', 'subtly', 'tease', 'that', 'baby', 'theory'],
#  ['donald',
#   'glover',
#   'tells',
#   'ellen',
#   'about',
#   'his',
#   'full',
#   'circle',
#   'star',
#   'wars',
#   'moment',
#   'with',
#   'his',
#   'son'],
#  ['a',
#   'marvel',
#   'exec',
#   'tried',
#   'to',
#   'stop',
#   'the',
#   'most',
#   'jarring',
#   'infinity',
#   'war',
#   'death'],
#  ['jake',
#   'gyllenhaal',
#   'set',
#   'to',
#   'star',
#   'as',
#   'villain',
#   'in',
#   'spiderman',
#   'sequel'],
#  ['janet',
#   'jackson',
#   'becomes',
#   'first',
#   'black',
#   'woman',
#   'to',
#   'receive',
#   'billboard',
#   'icon',
#   'award'],
#  ['this',
#   'isnt',
#   'pakistan',
#   'bitch',
#   'video',
#   'captures',
#   'drivers',
#   'racist',
#   'rant'],
#  ['the',
#   'grey',
#   'gardens',
#   'ladies',
#   'were',
#   'the',
#   'unwitting',
#   'godmothers',
#   'of',
#   'reality',
#   'tv',
#   'archetypes'],
#  ['4yearold',
#   'boy',
#   'is',
#   'a',
#   'superhero',
#   'to',
#   'alabamas',
#   'homeless',
#   'population'],
#  ['john',
#   'oliver',
#   'has',
#   'the',
#   'best',
#   'time',
#   'mocking',
#   'the',
#   'royal',
#   'wedding'],
#  ['john',
#   'oliver',
#   'needles',
#   'the',
#   'dangerously',
#   'unregulated',
#   'rehab',
#   'industry'],
#  ['jemele',
#   'hill',
#   'honored',
#   'as',
#   'nabjs',
#   'journalist',
#   'of',
#   'the',
#   'year'],
#  ['french',
#   'digital',
#   'minister',
#   'comes',
#   'out',
#   'as',
#   'gay',
#   'to',
#   'fight',
#   'homophobia'],
#  ['belgian',
#   'transgender',
#   'ballet',
#   'drama',
#   'wins',
#   'big',
#   'at',
#   'cannes',
#   'film',
#   'festival'],
#  ['86yearold',
#   'gay',
#   'man',
#   'proves',
#   'youre',
#   'never',
#   'too',
#   'old',
#   'to',
#   'attend',
#   'your',
#   'first',
#   'pride'],
#  ['super',
#   'pacs',
#   'that',
#   'meddled',
#   'in',
#   'west',
#   'virginias',
#   'senate',
#   'primary',
#   'didnt',
#   'receive',
#   'a',
#   'penny',
#   'from',
#   'west',
#   'virginians'],
#  ['airline',
#   'passenger',
#   'arrested',
#   'after',
#   'allegedly',
#   'harassing',
#   'woman',
#   'and',
#   'peeing',
#   'on',
#   'seat'],
#  ['mike',
#   'pompeo',
#   'promises',
#   'to',
#   'crush',
#   'iran',
#   'and',
#   'achieve',
#   'a',
#   'better',
#   'deal'],
#  ['8',
#   'majestic',
#   'islands',
#   'in',
#   'europe',
#   'that',
#   'most',
#   'tourists',
#   'dont',
#   'know',
#   'about',
#   'yet'],
#  ['cuba',
#   'confirms',
#   '110',
#   'killed',
#   'in',
#   'countrys',
#   'deadliest',
#   'plane',
#   'crash',
#   'since',
#   '1989'],
#  ['us',
#   'china',
#   'putting',
#   'trade',
#   'war',
#   'on',
#   'hold',
#   'treasurys',
#   'steve',
#   'mnuchin',
#   'says'],
#  ['trumps',
#   'top',
#   'economic',
#   'adviser',
#   'says',
#   'amazon',
#   'threats',
#   'are',
#   'not',
#   'in',
#   'my',
#   'lane'],
#  ['dems',
#   'trump',
#   'admin',
#   'find',
#   'common',
#   'ground',
#   'helping',
#   'victims',
#   'of',
#   'myanmars',
#   'genocide'],
#  ['giuliani',
#   'says',
#   'mueller',
#   'will',
#   'wrap',
#   'up',
#   'trump',
#   'obstruction',
#   'probe',
#   'by',
#   'september',
#   'report'],
#  ['german',
#   'broadcaster',
#   'criticized',
#   'for',
#   'racist',
#   'coverage',
#   'of',
#   'royal',
#   'wedding'],
#  ['kathryn',
#   'newton',
#   'the',
#   'boldest',
#   'teen',
#   'on',
#   'tv',
#   'is',
#   'ready',
#   'to',
#   'grow',
#   'up'],
#  ['stephanie', 'kelton', 'has', 'the', 'biggest', 'idea', 'in', 'washington'],
#  ['texas',
#   'govs',
#   'campaign',
#   'cancels',
#   'shotgun',
#   'giveaway',
#   'after',
#   'santa',
#   'fe',
#   'school',
#   'shooting'],
#  ['tina',
#   'feys',
#   'sarah',
#   'palin',
#   'leads',
#   'snl',
#   'chorus',
#   'lamenting',
#   'what',
#   'i',
#   'did',
#   'for',
#   'trump'],
#  ['after',
#   'day',
#   'of',
#   'american',
#   'gushing',
#   'snl',
#   'goes',
#   'smart',
#   'aleck',
#   'on',
#   'the',
#   'royal',
#   'wedding'],
#  ['starbucks',
#   'says',
#   'anyone',
#   'can',
#   'now',
#   'sit',
#   'in',
#   'its',
#   'cafes',
#   '',
#   'even',
#   'without',
#   'buying',
#   'anything'],
#  ['alec',
#   'baldwins',
#   'trump',
#   'faces',
#   'ominous',
#   'sopranos',
#   'scenario',
#   'in',
#   'snl',
#   'finale'],
#  ['asia',
#   'argentos',
#   'fiery',
#   'speech',
#   'closes',
#   'cannes',
#   'i',
#   'was',
#   'raped',
#   'by',
#   'harvey',
#   'weinstein',
#   'here'],
#  ['tina',
#   'fey',
#   'tries',
#   'out',
#   'for',
#   'mean',
#   'girls',
#   'the',
#   'musical',
#   'on',
#   'snl'],
#  ['parents',
#   'of',
#   'school',
#   'shooting',
#   'victims',
#   'decry',
#   'moronic',
#   'gop',
#   'platitudes'],
#  ['trump',
#   'real',
#   'americans',
#   'should',
#   'get',
#   'tough',
#   'on',
#   'russia',
#   'probe'],
#  ['chrissy',
#   'teigen',
#   'john',
#   'legend',
#   'announce',
#   'name',
#   'of',
#   'baby',
#   'boy',
#   'with',
#   'adorable',
#   'photo'],
#  ['texas',
#   'lt',
#   'gov',
#   'dan',
#   'patrick',
#   'touts',
#   'need',
#   'to',
#   'arm',
#   'teachers'],
#  ['david',
#   'hogg',
#   'calls',
#   'on',
#   'media',
#   'to',
#   'stop',
#   'naming',
#   'santa',
#   'fe',
#   'school',
#   'shooter'],
#  ['trump',
#   'sets',
#   'up',
#   'showdown',
#   'with',
#   'doj',
#   'over',
#   'claims',
#   'of',
#   'campaign',
#   'surveillance'],
#  ['jim',
#   'carreys',
#   'latest',
#   'painting',
#   'slams',
#   'kent',
#   'state',
#   'goldilocks',
#   'and',
#   'her',
#   'ar10'],
#  ['oliver', 'north', 'blames', 'school', 'shootings', 'on', 'ritalin'],
#  ['jimmy',
#   'kimmel',
#   'tricks',
#   'royal',
#   'fans',
#   'into',
#   'reviewing',
#   'the',
#   'wedding',
#   'before',
#   'the',
#   'big',
#   'day'],
#  ['jimmy',
#   'fallon',
#   'reveals',
#   'his',
#   'viewers',
#   'biggest',
#   'wedding',
#   'fails'],
#  ['protesters',
#   'throw',
#   'a',
#   'fiesta',
#   'to',
#   'razz',
#   'lawyer',
#   'who',
#   'ranted',
#   'at',
#   'spanish',
#   'speakers'],
#  ['what',
#   'to',
#   'watch',
#   'on',
#   'amazon',
#   'prime',
#   'thats',
#   'new',
#   'this',
#   'week'],
#  ['will',
#   'ferrell',
#   'and',
#   'molly',
#   'shannon',
#   'cover',
#   'the',
#   'royal',
#   'wedding',
#   'as',
#   'cord',
#   'and',
#   'tish'],
#  ['the',
#   'artist',
#   'formerly',
#   'known',
#   'as',
#   'cedric',
#   'the',
#   'entertainer',
#   'has',
#   'arrived'],
#  ['mark',
#   'kelly',
#   'trump',
#   'rolled',
#   'over',
#   'for',
#   'nra',
#   'did',
#   'nothing',
#   'about',
#   'guns',
#   'after',
#   'parkland'],
#  ['gop',
#   'candidate',
#   'set',
#   'up',
#   'trust',
#   'that',
#   'pays',
#   'his',
#   'kids',
#   'for',
#   'marrying',
#   'white',
#   'people'],
#  ['houston',
#   'police',
#   'chief',
#   'says',
#   'hes',
#   'sick',
#   'of',
#   'inaction',
#   'on',
#   'gun',
#   'control'],
#  ['the', 'history', 'of', 'the', 'national', 'anthem', 'in', 'sports'],
#  ['bbc',
#   'trolls',
#   'president',
#   'trump',
#   'with',
#   'bigly',
#   'huge',
#   'royal',
#   'wedding',
#   'crowd'],
#  ['these',
#   'are',
#   'the',
#   'victims',
#   'of',
#   'the',
#   'santa',
#   'fe',
#   'high',
#   'school',
#   'shooting'],
#  ['this',
#   'ceo',
#   'took',
#   'a',
#   'pay',
#   'cut',
#   'to',
#   'give',
#   'employees',
#   '70000',
#   'a',
#   'year',
#   'now',
#   'hes',
#   'battling',
#   'amazon'],
#  ['trump',
#   'jr',
#   'met',
#   'with',
#   'emissary',
#   'for',
#   'gulf',
#   'princes',
#   'offering',
#   'help',
#   'with',
#   'campaign',
#   'in',
#   '2016',
#   'report'],
#  ['trump',
#   'misspells',
#   'melanias',
#   'name',
#   'in',
#   'welcome',
#   'home',
#   'tweet',
#   'twitter',
#   'roars'],
#  ['jimmy',
#   'kimmel',
#   'shreds',
#   'cowardly',
#   'trump',
#   'lawmakers',
#   'after',
#   'texas',
#   'school',
#   'shooting'],
#  ['bill',
#   'maher',
#   'reveals',
#   '25',
#   'things',
#   'you',
#   'dont',
#   'know',
#   'about',
#   'michael',
#   'cohen'],
#  ['what', 'to', 'watch', 'on', 'hulu', 'thats', 'new', 'this', 'week'],
#  ['students',
#   'stage',
#   'sitin',
#   'for',
#   'gun',
#   'control',
#   'outside',
#   'paul',
#   'ryans',
#   'office',
#   'get',
#   'arrested'],
#  ['trump',
#   'knew',
#   'a',
#   'scary',
#   'amount',
#   'about',
#   'the',
#   'appearance',
#   'of',
#   'bill',
#   'gates',
#   'daughter'],
#  ['exrussian',
#   'spy',
#   'sergei',
#   'skripal',
#   'discharged',
#   'from',
#   'uk',
#   'hospital',
#   'after',
#   'poisoning',
#   'incident'],
#  ['cuba', 'plane', 'crash', 'reportedly', 'kills', 'over', '100'],
#  ['trump',
#   'reassures',
#   'north',
#   'korea',
#   'but',
#   'threatens',
#   'total',
#   'decimation',
#   'without',
#   'a',
#   'deal'],
#  ['ariana',
#   'grande',
#   'gives',
#   'fans',
#   'singing',
#   'one',
#   'last',
#   'time',
#   'the',
#   'surprise',
#   'of',
#   'their',
#   'lives'],
#  ['cambridge',
#   'analytica',
#   'files',
#   'for',
#   'chapter',
#   '7',
#   'bankruptcy',
#   'after',
#   'facebook',
#   'privacy',
#   'row'],
#  ['santa',
#   'fe',
#   'high',
#   'schoolers',
#   'held',
#   'gun',
#   'violence',
#   'protest',
#   '1',
#   'month',
#   'before',
#   'shooting'],
#  ['michelle',
#   'wolfs',
#   'netflix',
#   'trailer',
#   'gives',
#   'us',
#   'a',
#   'closer',
#   'look',
#   'at',
#   'her',
#   'new',
#   'show'],
#  ['jeff',
#   'sessions',
#   'uses',
#   'exceptional',
#   'power',
#   'over',
#   'immigration',
#   'courts',
#   'to',
#   'limit',
#   'judges',
#   'authority'],
#  ['gop',
#   'rep',
#   'introduces',
#   'bill',
#   'that',
#   'would',
#   'demand',
#   'white',
#   'house',
#   'apologize',
#   'to',
#   'mccain'],
#  ['colbert',
#   'has',
#   'a',
#   'super',
#   'graphic',
#   'way',
#   'of',
#   'describing',
#   'how',
#   'deep',
#   'muellers',
#   'probe',
#   'goes',
#   'now'],
#  ['jack', 'osbournes', 'wife', 'files', 'for', 'divorce'],
#  ['meek',
#   'mill',
#   'backs',
#   'out',
#   'of',
#   'trump',
#   'event',
#   'on',
#   'prison',
#   'reform'],
#  ['new',
#   'trump',
#   'rule',
#   'would',
#   'cut',
#   'federal',
#   'funds',
#   'from',
#   'clinics',
#   'providing',
#   'abortions'],
#  ['twitter',
#   'users',
#   'joke',
#   'trump',
#   'wants',
#   'prison',
#   'reform',
#   'because',
#   'thats',
#   'where',
#   'hes',
#   'headed'],
#  ['every',
#   'single',
#   'chilean',
#   'bishop',
#   'offers',
#   'to',
#   'resign',
#   'over',
#   'countrys',
#   'sex',
#   'abuse',
#   'scandal'],
#  ['ariana',
#   'grande',
#   'calls',
#   'manchester',
#   'attack',
#   'the',
#   'worst',
#   'of',
#   'humanity',
#   'one',
#   'year',
#   'later'],
#  ['chrissy',
#   'teigen',
#   'spills',
#   'first',
#   'details',
#   'about',
#   'new',
#   'baby',
# ...
#   'share',
#   'about',
#   'gina',
#   'haspel'],
#  ['conservative',
#   'senate',
#   'democrat',
#   'who',
#   'backs',
#   'trumps',
#   'agenda',
#   'defeats',
#   'progressive',
#   'challenger'],
#  ['taylor',
#   'swift',
#   'mightve',
#   'made',
#   'up',
#   'with',
#   'katy',
#   'perry',
#   'but',
#   'her',
#   'kimye',
#   'feud',
#   'lives',
#   'on'],
#  ['kim',
#   'kardashian',
#   'to',
#   'make',
#   'history',
#   'with',
#   'fashion',
#   'councils',
#   'first',
#   'influencer',
#   'award'],
#  ['nbc',
#   'says',
#   'it',
#   'believes',
#   'matt',
#   'lauers',
#   'accusers',
#   'after',
#   'monthslong',
#   'investigation'],
#  ['russians',
#   'had',
#   'ability',
#   'to',
#   'change',
#   'voter',
#   'data',
#   'but',
#   'didnt',
#   'report',
#   'says'],
#  ['elizabeth',
#   'warrens',
#   'pick',
#   'wins',
#   'ohios',
#   'democratic',
#   'gubernatorial',
#   'primary'],
#  ['kkk',
#   'leader',
#   'found',
#   'guilty',
#   'of',
#   'firing',
#   'gun',
#   'at',
#   'charlottesville',
#   'rally'],
#  ['protesters',
#   'decrying',
#   'torture',
#   'dragged',
#   'from',
#   'gina',
#   'haspel',
#   'senate',
#   'hearing'],
#  ['att',
#   'hired',
#   'firm',
#   'linked',
#   'to',
#   'michael',
#   'cohen',
#   'to',
#   'get',
#   'the',
#   'inside',
#   'scoop',
#   'on',
#   'trump'],
#  ['the',
#   'rnc',
#   'is',
#   'selling',
#   'sickening',
#   'donald',
#   'trumpthemed',
#   'merch',
#   'ahead',
#   'of',
#   'mothers',
#   'day'],
#  ['don',
#   'blankenships',
#   'defeat',
#   'is',
#   'a',
#   'relief',
#   'to',
#   'the',
#   'families',
#   'of',
#   'upper',
#   'big',
#   'branch',
#   'miners'],
#  ['colbert',
#   'shreds',
#   'trump',
#   'over',
#   'broken',
#   'promises',
#   'what',
#   'are',
#   'you',
#   'talking',
#   'about'],
#  ['new',
#   'us',
#   'ambassador',
#   'to',
#   'germany',
#   'offends',
#   'hosts',
#   'just',
#   'hours',
#   'into',
#   'his',
#   'first',
#   'day'],
#  ['jordan',
#   'peeles',
#   'new',
#   'nightmare',
#   'is',
#   'coming',
#   'out',
#   'next',
#   'year'],
#  ['the',
#   'backstreet',
#   'boys',
#   'dressed',
#   'as',
#   'the',
#   'spice',
#   'girls',
#   'are',
#   'larger',
#   'than',
#   'life'],
#  ['seth',
#   'meyers',
#   'decodes',
#   'teen',
#   'slang',
#   'reveals',
#   'what',
#   'giuliani',
#   'really',
#   'means'],
#  ['heres',
#   'a',
#   'look',
#   'at',
#   'orlandos',
#   'interim',
#   'pulse',
#   'nightclub',
#   'memorial'],
#  ['trevor',
#   'noah',
#   'turns',
#   'donald',
#   'trumps',
#   'knives',
#   'comment',
#   'into',
#   'reggae',
#   'magic'],
#  ['senators',
#   'force',
#   'a',
#   'vote',
#   'that',
#   'may',
#   'ultimately',
#   'reverse',
#   'fcc',
#   'restore',
#   'net',
#   'neutrality'],
#  ['ny',
#   'legislature',
#   'has',
#   'plan',
#   'in',
#   'place',
#   'to',
#   'consider',
#   'replacements',
#   'for',
#   'eric',
#   'schneiderman'],
#  ['more',
#   'than',
#   '100',
#   'former',
#   'ambassadors',
#   'write',
#   'letter',
#   'opposing',
#   'gina',
#   'haspel',
#   'nomination'],
#  ['california',
#   'authority',
#   'says',
#   'states',
#   'new',
#   'homes',
#   'must',
#   'be',
#   'solar',
#   'powered'],
#  ['ny',
#   'governor',
#   'assigns',
#   'investigation',
#   'into',
#   'eric',
#   'schneiderman',
#   'abuse',
#   'allegations'],
#  ['how',
#   'the',
#   'refugee',
#   'caravan',
#   'became',
#   'a',
#   'scapegoat',
#   'for',
#   'trumps',
#   'border',
#   'crackdown'],
#  ['pennsylvania',
#   'becomes',
#   'latest',
#   'state',
#   'to',
#   'fund',
#   'urban',
#   'gun',
#   'violence',
#   'prevention'],
#  ['denver',
#   'mayors',
#   'son',
#   'caught',
#   'on',
#   'tape',
#   'berating',
#   'cop',
#   'as',
#   'a',
#   'faggot'],
#  ['progressive', 'prosecutors', 'win', 'primaries', 'in', 'north', 'carolina'],
#  ['what',
#   'did',
#   'att',
#   'and',
#   'novartis',
#   'get',
#   'for',
#   'the',
#   'money',
#   'they',
#   'paid',
#   'trumps',
#   'lawyer'],
#  ['the',
#   'hypocrisy',
#   'of',
#   'melania',
#   'trumps',
#   'online',
#   'safety',
#   'booklet',
#   'pointed',
#   'out',
#   'page',
#   'by',
#   'page'],
#  ['the',
#   'uninsured',
#   'rate',
#   'is',
#   'worsening',
#   'after',
#   'years',
#   'of',
#   'obamacares',
#   'gains'],
#  ['bernie', 'sanders', 'has', 'a', 'plan', 'to', 'revive', 'labor', 'unions'],
#  ['jim',
#   'carrey',
#   'bestows',
#   'scott',
#   'pruitt',
#   'with',
#   'a',
#   'savage',
#   'nickname',
#   'in',
#   'latest',
#   'painting'],
#  ['when', 'male', 'allies', 'become', 'abusers'],
#  ['mormon',
#   'church',
#   'to',
#   'end',
#   'its',
#   'centurylong',
#   'relationship',
#   'with',
#   'the',
#   'boy',
#   'scouts'],
#  ['our', 'snack', 'addiction', 'is', 'killing', 'orangutans'],
#  ['trumps',
#   'pick',
#   'for',
#   'cia',
#   'director',
#   'wont',
#   'say',
#   'torture',
#   'program',
#   'was',
#   'morally',
#   'wrong'],
#  ['anderson',
#   'cooper',
#   'burns',
#   'moronic',
#   'michael',
#   'cohen',
#   'over',
#   'russia',
#   'cash',
#   'claims'],
#  ['pinata',
#   'maker',
#   'apologizes',
#   'for',
#   'hanging',
#   'black',
#   'figures',
#   'in',
#   'the',
#   'likeness',
#   'of',
#   'lynchings'],
#  ['the', 'caliphate', 'of', 'trump', 'and', 'a', 'planet', 'in', 'ruins'],
#  ['a',
#   'gay',
#   'marriage',
#   'opponent',
#   'just',
#   'ousted',
#   'a',
#   'gop',
#   'incumbent',
#   'in',
#   'north',
#   'carolina'],
#  ['espn',
#   'eliminates',
#   'public',
#   'editor',
#   'role',
#   'calling',
#   'it',
#   'outdated'],
#  ['michael',
#   'cohen',
#   'was',
#   'selling',
#   'access',
#   'to',
#   'trump',
#   'says',
#   'group',
#   'that',
#   'paid',
#   'into',
#   'his',
#   'shell',
#   'company'],
#  ['mitch',
#   'mcconnell',
#   'mocks',
#   'blankenship',
#   'on',
#   'twitter',
#   'with',
#   'a',
#   'big',
#   'cloud',
#   'of',
#   'cocaine'],
#  ['exconvict',
#   'don',
#   'blankenship',
#   'loses',
#   'to',
#   'patrick',
#   'morrisey',
#   'in',
#   'west',
#   'virginia',
#   'senate',
#   'race'],
#  ['ohio', 'voters', 'pass', 'gerrymandering', 'reform', 'measure'],
#  ['trumps', 'iran', 'deal', 'exit', 'is', 'a', 'win', 'for', 'russia'],
#  ['cynthia',
#   'nixon',
#   'wants',
#   'new',
#   'yorkers',
#   'to',
#   'vote',
#   'for',
#   'the',
#   'homo',
#   'not',
#   'for',
#   'the',
#   'cuomo'],
#  ['ontario',
#   'canada',
#   'just',
#   'issued',
#   'its',
#   'first',
#   'nonbinary',
#   'birth',
#   'certificate'],
#  ['child',
#   'sexual',
#   'predator',
#   'roman',
#   'polanski',
#   'calls',
#   'me',
#   'too',
#   'movement',
#   'total',
#   'hypocrisy'],
#  ['this',
#   'is',
#   'america',
#   'producer',
#   'reveals',
#   'new',
#   'details',
#   'about',
#   'childish',
#   'gambinos',
#   'viral',
#   'video'],
#  ['terry',
#   'crews',
#   'black',
#   'men',
#   'arent',
#   'allowed',
#   'to',
#   'be',
#   'victims',
#   'until',
#   'theyre',
#   'dead'],
#  ['donald',
#   'glovers',
#   'this',
#   'is',
#   'america',
#   'through',
#   'the',
#   'eyes',
#   'of',
#   'a',
#   'jim',
#   'crow',
#   'historian'],
#  ['fox',
#   'news',
#   'judicial',
#   'analyst',
#   'issues',
#   'dark',
#   'warning',
#   'to',
#   'trump',
#   'over',
#   'michael',
#   'cohen'],
#  ['black',
#   'women',
#   'bishops',
#   'are',
#   'making',
#   'history',
#   'in',
#   'this',
#   'predominantly',
#   'white',
#   'church'],
#  ['geena',
#   'davis',
#   'and',
#   '4th',
#   'husband',
#   'reza',
#   'jarrahy',
#   'are',
#   'divorcing'],
#  ['pauley',
#   'perrettes',
#   'abby',
#   'has',
#   'heartwrenching',
#   'farewell',
#   'on',
#   'ncis'],
#  ['lethal',
#   'weapon',
#   'fires',
#   'clayne',
#   'crawford',
#   'and',
#   'his',
#   'character',
#   'gets',
#   'shot'],
#  ['selena',
#   'gomez',
#   'pokes',
#   'fun',
#   'at',
#   'her',
#   'met',
#   'gala',
#   'spray',
#   'tan',
#   'mishap'],
#  ['protest',
#   'leader',
#   'nikol',
#   'pashinian',
#   'elected',
#   'prime',
#   'minister',
#   'of',
#   'armenia'],
#  ['kim', 'jong', 'un', 'secretly', 'met', 'with', 'xi', 'jinping', 'again'],
#  ['netanyahus',
#   'bombastic',
#   'iran',
#   'claims',
#   'found',
#   'a',
#   'perfect',
#   'audience',
#   'in',
#   'trump'],
#  ['netanyahus',
#   'chef',
#   'blasted',
#   'for',
#   'serving',
#   'japans',
#   'prime',
#   'minister',
#   'dessert',
#   'in',
#   'a',
#   'shoe'],
#  ['world',
#   'leaders',
#   'condemn',
#   'trump',
#   'for',
#   'withdrawing',
#   'from',
#   'iran',
#   'nuclear',
#   'deal'],
#  ['senate',
#   'republicans',
#   'shun',
#   'don',
#   'blankenship',
#   'on',
#   'day',
#   'of',
#   'west',
#   'virginia',
#   'primary'],
#  ['new',
#   'yorks',
#   'harvey',
#   'weinstein',
#   'probe',
#   'set',
#   'to',
#   'continue',
#   'despite',
#   'attorney',
#   'generals',
#   'exit'],
#  ['trump',
#   'to',
#   'announce',
#   'whether',
#   'us',
#   'will',
#   'break',
#   'the',
#   'iran',
#   'nuclear',
#   'deal'],
#  ['politicians',
#   'call',
#   'for',
#   'schneiderman',
#   'to',
#   'resign',
#   'over',
#   'physical',
#   'abuse',
#   'allegations'],
#  ['joe',
#   'scarborough',
#   'trumps',
#   'legal',
#   'strategy',
#   'is',
#   'like',
#   'a',
#   'monkey',
#   'throwing',
#   'poo',
#   'against',
#   'the',
#   'wall'],
#  ['kirsten', 'dunst', 'and', 'jesse', 'plemons', 'welcome', 'baby', 'boy'],
#  ['holy',
#   'matrimony',
#   'there',
#   'was',
#   'a',
#   'proposal',
#   'at',
#   'the',
#   'met',
#   'gala'],
#  ['nordstrom',
#   'rack',
#   'president',
#   'apologizes',
#   'after',
#   'store',
#   'accuses',
#   'three',
#   'black',
#   'men',
#   'of',
#   'theft'],
#  ['giuliani',
#   'says',
#   'trump',
#   'lawyer',
#   'michael',
#   'cohen',
#   'has',
#   'no',
#   'incriminating',
#   'information',
#   'about',
#   'the',
#   'president'],
#  ['lena',
#   'waithe',
#   'stuns',
#   'at',
#   'met',
#   'gala',
#   'as',
#   'a',
#   'queer',
#   'superhero'],
#  ['r',
#   'kelly',
#   'accusers',
#   'say',
#   'they',
#   'had',
#   'to',
#   'ask',
#   'permission',
#   'to',
#   'use',
#   'the',
#   'bathroom'],
#  ['trump',
#   'reportedly',
#   'tells',
#   'macron',
#   'hes',
#   'pulling',
#   'out',
#   'of',
#   'iran',
#   'nuclear',
#   'deal'],
#  ['how',
#   'the',
#   'deportation',
#   'crackdown',
#   'is',
#   'hurting',
#   'immigrant',
#   'victims',
#   'of',
#   'crime'],
#  ['seth',
#   'meyers',
#   'says',
#   'michael',
#   'cohen',
#   'tried',
#   'to',
#   'get',
#   'him',
#   'to',
#   'apologize',
#   'onair',
#   'to',
#   'trump'],
#  ['blessing', 'you', 'with', 'the', 'best', 'met', 'gala', '2018', 'tweets'],
#  ['farm',
#   'bill',
#   'would',
#   'cut',
#   'food',
#   'stamps',
#   'is',
#   'friendly',
#   'to',
#   'farmers'],
#  ['what', 'to', 'know', 'about', 'the', 'iran', 'nuclear', 'deal'],
#  ['18',
#   'derby',
#   'day',
#   'bet',
#   'wins',
#   'thrilled',
#   'texas',
#   'woman',
#   '123',
#   'million'],
#  ['democratic',
#   'meddling',
#   'in',
#   'west',
#   'virginia',
#   'and',
#   '4',
#   'other',
#   'things',
#   'to',
#   'watch',
#   'this',
#   'election',
#   'day'],
#  ['cynthia',
#   'erivos',
#   'met',
#   'gala',
#   'nails',
#   'featured',
#   'a',
#   'sistine',
#   'chapel',
#   'painting',
#   'with',
#   'black',
#   'women'],
#  ['keanu',
#   'reeves',
#   'and',
#   'alex',
#   'winter',
#   'are',
#   'coming',
#   'back',
#   'for',
#   'bill',
#   '',
#   'ted',
#   '3',
#   'after',
#   '27',
#   'years'],
#  ['solanges',
#   'durag',
#   'was',
#   'the',
#   'true',
#   'mvp',
#   'at',
#   'the',
#   'met',
#   'gala'],
#  ['top',
#   'house',
#   'republican',
#   'threatens',
#   'to',
#   'subpoena',
#   'trump',
#   'doj',
#   'official',
#   'over',
#   'census',
#   'citizenship',
#   'request'],
#  ['jimmy',
#   'kimmel',
#   'tries',
#   'so',
#   'hard',
#   'to',
#   'make',
#   'sense',
#   'of',
#   'rudys',
#   'latest',
#   'trump',
#   'defense',
#   'then',
#   'gives',
#   'up'],
#  ['the',
#   'religious',
#   'imagery',
#   'stitched',
#   'throughout',
#   'the',
#   '2018',
#   'met',
#   'gala'],
#  ['bob',
#   'marleys',
#   'granddaughter',
#   'says',
#   'cops',
#   'racially',
#   'profiled',
#   'her',
#   'while',
#   'checking',
#   'out',
#   'of',
#   'airbnb'],
#  ['melania',
#   'trump',
#   'called',
#   'out',
#   'for',
#   'antibullying',
#   'campaign',
#   'that',
#   'ignores',
#   'her',
#   'husbands',
#   'actions'],
#  ['trevor',
#   'noah',
#   'watching',
#   'rudy',
#   'giuliani',
#   'is',
#   'like',
#   'smoking',
#   'weed',
#   'through',
#   'the',
#   'tv'],
#  ['janet',
#   'jackson',
#   'to',
#   'receive',
#   'icon',
#   'award',
#   'at',
#   '2018',
#   'billboard',
#   'music',
#   'awards'],
#  ['white',
#   'house',
#   'prepares',
#   'to',
#   'send',
#   'congress',
#   '15',
#   'billion',
#   'spending',
#   'cuts',
#   'package'],
#  ['this',
#   'jared',
#   'kushnerbacked',
#   'bill',
#   'could',
#   'be',
#   '2018s',
#   'last',
#   'shot',
#   'at',
#   'federal',
#   'prison',
#   'reform'],
#  ['george',
#   'zimmerman',
#   'accused',
#   'of',
#   'stalking',
#   'detective',
#   'working',
#   'on',
#   'trayvon',
#   'martin',
#   'film'],
#  ['passengers',
#   'lashing',
#   'out',
#   'at',
#   'scott',
#   'pruitt',
#   'justify',
#   'firstclass',
#   'travel',
#   'new',
#   'epa',
#   'memo',
#   'says'],
#  ['this',
#   'trump',
#   'country',
#   'house',
#   'district',
#   'just',
#   'became',
#   'a',
#   'key',
#   'progressive',
#   'battleground'],
#  ['mike',
#   'pences',
#   'brother',
#   'wins',
#   'primary',
#   'race',
#   'for',
#   'vice',
#   'presidents',
#   'former',
#   'house',
#   'seat'],
#  ['marines',
#   'investigating',
#   'avowed',
#   'white',
#   'supremacist',
#   'on',
#   'active',
#   'duty'],
#  ['trump',
#   'to',
#   'violate',
#   'iran',
#   'nuclear',
#   'deal',
#   'vows',
#   'to',
#   'reimpose',
#   'sanctions'],
#  ['us',
#   'olympic',
#   'committee',
#   'ignored',
#   'sexual',
#   'abuse',
#   'complaints',
#   'against',
#   'taekwondo',
#   'stars',
#   'lawsuit'],
#  ['blake',
#   'lively',
#   'brought',
#   'her',
#   'family',
#   'to',
#   'the',
#   'met',
#   'gala',
#   'without',
#   'you',
#   'even',
#   'noticing'],
#  ['bill',
#   'oreilly',
#   'offers',
#   'to',
#   'stand',
#   'next',
#   'to',
#   'sarah',
#   'sanders',
#   'to',
#   'handle',
#   'out',
#   'of',
#   'line',
#   'reporters'],
#  ['catholic',
#   'priest',
#   'praised',
#   'as',
#   'best',
#   'dressed',
#   'dude',
#   'at',
#   'met',
#   'gala',
#   'for',
#   'just',
#   'living',
#   'his',
#   'life'],
#  ['jimmy',
#   'kimmel',
#   'says',
#   'hideandseek',
#   'genius',
#   'dog',
#   'will',
#   'heal',
#   'our',
#   'nation'],
#  ['bank',
#   'of',
#   'america',
#   'appears',
#   'to',
#   'flip',
#   'on',
#   'firearm',
#   'promise',
#   'with',
#   'loan',
#   'to',
#   'remington'],
#  ['the',
#   'gentleman',
#   'caller',
#   'presents',
#   '2',
#   'queer',
#   'icons',
#   'as',
#   'youve',
#   'never',
#   'seen',
#   'them',
#   'before'],
#  ['eric', 'schneiderman', 'has', 'always', 'been', 'a', 'con', 'man'],
#  ['christiane',
#   'amanpour',
#   'heading',
#   'up',
#   'new',
#   'pbs',
#   'show',
#   'replacing',
#   'charlie',
#   'rose'],
#  ['madonna',
#   'teases',
#   'new',
#   'song',
#   'at',
#   'surprise',
#   'met',
#   'gala',
#   'performance'],
#  ['iron',
#   'man',
#   'black',
#   'widow',
#   'captain',
#   'america',
#   'thor',
#   'and',
#   'hawkeye',
#   'got',
#   'matching',
#   'tattoos'],
#  ['michael',
#   'cohen',
#   'accepted',
#   '500000',
#   'from',
#   'firm',
#   'tied',
#   'to',
#   'russian',
#   'oligarch',
#   'reports'],
#  ['stephen',
#   'colbert',
#   'hits',
#   'rudy',
#   'giuliani',
#   'with',
#   'a',
#   'brutal',
#   'fact',
#   'check'],
#  ['katy',
#   'perry',
#   'sends',
#   'olive',
#   'branch',
#   'to',
#   'taylor',
#   'swift',
#   'and',
#   'the',
#   'world',
#   'rejoices'],
#  ['jada',
#   'pinkett',
#   'smith',
#   'gets',
#   'real',
#   'about',
#   'dating',
#   'will',
#   'smith',
#   'while',
#   'he',
#   'was',
#   'married'],
#  ['whoops',
#   'mark',
#   'hamill',
#   'just',
#   'spilled',
#   'the',
#   'beans',
#   'on',
#   'a',
#   'major',
#   'cameo',
#   'in',
#   'han',
#   'solo',
#   'movie'],
#  ['shawn',
#   'mendes',
#   'sweetly',
#   'attended',
#   'to',
#   'hailey',
#   'baldwins',
#   'gown',
#   'at',
#   'the',
#   'met',
#   'gala'],
#  ['orrin',
#   'hatch',
#   'is',
#   'sorry',
#   'he',
#   'suggested',
#   'trump',
#   'should',
#   'be',
#   'allowed',
#   'at',
#   'john',
#   'mccains',
#   'funeral'],
#  ['seth',
#   'meyers',
#   'has',
#   'perfect',
#   'line',
#   'to',
#   'confront',
#   'donald',
#   'trumps',
#   'lies'],
#  ['police',
#   'hope',
#   'to',
#   'use',
#   'dna',
#   'to',
#   'catch',
#   'the',
#   'zodiac',
#   'killer'],
#  ['lili',
#   'reinhart',
#   'and',
#   'cole',
#   'sprouse',
#   'finally',
#   'make',
#   'couple',
#   'debut',
#   'at',
#   'met',
#   'gala'],
#  ['how',
#   'sweetbitter',
#   'captures',
#   'the',
#   'grit',
#   'and',
#   'glamour',
#   'of',
#   'the',
#   'restaurant',
#   'world'],
#  ['mitch',
#   'mcconnell',
#   'bends',
#   'the',
#   'rules',
#   'again',
#   'to',
#   'confirm',
#   'trumps',
#   'judges'],
#  ['ryan', 'zinke', 'and', 'the', 'tale', 'of', 'two', 'fish'],
#  ['ny',
#   'attorney',
#   'general',
#   'eric',
#   'schneiderman',
#   'resigns',
#   'amid',
#   'abuse',
#   'allegations'],
#  ['sanctuary',
#   'cities',
#   'are',
#   'working',
#   'in',
#   'the',
#   'trump',
#   'era',
#   'but',
#   'at',
#   'a',
#   'surprising',
#   'cost'],
#  ['shepard',
#   'smith',
#   'you',
#   'cant',
#   'say',
#   'trump',
#   'pulled',
#   'out',
#   'of',
#   'iran',
#   'deal',
#   'he',
#   'made',
#   'decision',
#   'to',
#   'violate',
#   'it'],
#  ['stormy',
#   'daniels',
#   'finds',
#   'a',
#   'crunchy',
#   'new',
#   'way',
#   'to',
#   'chip',
#   'away',
#   'at',
#   'trump'],
#  ['these',
#   'rainbow',
#   'mountains',
#   'in',
#   'peru',
#   'look',
#   'like',
#   'theyre',
#   'straight',
#   'out',
#   'of',
#   'a',
#   'dr',
#   'seuss',
#   'book'],
#  ...]

# %% [markdown]
# On observe que nos phrases contiennent des numéro, qui ne nous seront pas utiles lors du clustering, on décide de les supprimer aussi.

# %%
df = df.str.replace('\d+', '')

# %%
splitted_text =  dummy_word_split(df.tolist())
splitted_text
# Out:
# [['there',
#   'were',
#   '',
#   'mass',
#   'shootings',
#   'in',
#   'texas',
#   'last',
#   'week',
#   'but',
#   'only',
#   '',
#   'on',
#   'tv'],
#  ['will',
#   'smith',
#   'joins',
#   'diplo',
#   'and',
#   'nicky',
#   'jam',
#   'for',
#   'the',
#   '',
#   'world',
#   'cups',
#   'official',
#   'song'],
#  ['hugh', 'grant', 'marries', 'for', 'the', 'first', 'time', 'at', 'age', ''],
#  ['jim',
#   'carrey',
#   'blasts',
#   'castrato',
#   'adam',
#   'schiff',
#   'and',
#   'democrats',
#   'in',
#   'new',
#   'artwork'],
#  ['julianna',
#   'margulies',
#   'uses',
#   'donald',
#   'trump',
#   'poop',
#   'bags',
#   'to',
#   'pick',
#   'up',
#   'after',
#   'her',
#   'dog'],
#  ['morgan',
#   'freeman',
#   'devastated',
#   'that',
#   'sexual',
#   'harassment',
#   'claims',
#   'could',
#   'undermine',
#   'legacy'],
#  ['donald',
#   'trump',
#   'is',
#   'lovin',
#   'new',
#   'mcdonalds',
#   'jingle',
#   'in',
#   'tonight',
#   'show',
#   'bit'],
#  ['what',
#   'to',
#   'watch',
#   'on',
#   'amazon',
#   'prime',
#   'thats',
#   'new',
#   'this',
#   'week'],
#  ['mike',
#   'myers',
#   'reveals',
#   'hed',
#   'like',
#   'to',
#   'do',
#   'a',
#   'fourth',
#   'austin',
#   'powers',
#   'film'],
#  ['what', 'to', 'watch', 'on', 'hulu', 'thats', 'new', 'this', 'week'],
#  ['justin', 'timberlake', 'visits', 'texas', 'school', 'shooting', 'victims'],
#  ['south',
#   'korean',
#   'president',
#   'meets',
#   'north',
#   'koreas',
#   'kim',
#   'jong',
#   'un',
#   'to',
#   'talk',
#   'trump',
#   'summit'],
#  ['with',
#   'its',
#   'way',
#   'of',
#   'life',
#   'at',
#   'risk',
#   'this',
#   'remote',
#   'oystergrowing',
#   'region',
#   'called',
#   'in',
#   'robots'],
#  ['trumps',
#   'crackdown',
#   'on',
#   'immigrant',
#   'parents',
#   'puts',
#   'more',
#   'kids',
#   'in',
#   'an',
#   'already',
#   'strained',
#   'system'],
#  ['trumps',
#   'son',
#   'should',
#   'be',
#   'concerned',
#   'fbi',
#   'obtained',
#   'wiretaps',
#   'of',
#   'putin',
#   'ally',
#   'who',
#   'met',
#   'with',
#   'trump',
#   'jr'],
#  ['edward',
#   'snowden',
#   'theres',
#   'no',
#   'one',
#   'trump',
#   'loves',
#   'more',
#   'than',
#   'vladimir',
#   'putin'],
#  ['booyah',
#   'obama',
#   'photographer',
#   'hilariously',
#   'trolls',
#   'trumps',
#   'spy',
#   'claim'],
#  ['ireland',
#   'votes',
#   'to',
#   'repeal',
#   'abortion',
#   'amendment',
#   'in',
#   'landslide',
#   'referendum'],
#  ['ryan',
#   'zinke',
#   'looks',
#   'to',
#   'reel',
#   'back',
#   'some',
#   'critics',
#   'with',
#   'grand',
#   'pivot',
#   'to',
#   'conservation'],
#  ['trumps',
#   'scottish',
#   'golf',
#   'resort',
#   'pays',
#   'women',
#   'significantly',
#   'less',
#   'than',
#   'men',
#   'report'],
#  ['weird',
#   'fathers',
#   'day',
#   'gifts',
#   'your',
#   'dad',
#   'doesnt',
#   'know',
#   'he',
#   'wants',
#   'but',
#   'he',
#   'does'],
#  ['twitter',
#   'putstarwarsinotherfilms',
#   'and',
#   'it',
#   'was',
#   'universally',
#   'entertaining'],
#  ['mystery',
#   'wolflike',
#   'animal',
#   'reportedly',
#   'shot',
#   'in',
#   'montana',
#   'baffles',
#   'wildlife',
#   'officials'],
#  ['north',
#   'korea',
#   'still',
#   'open',
#   'to',
#   'talks',
#   'after',
#   'trump',
#   'cancels',
#   'summit'],
#  ['',
#   'men',
#   'detonate',
#   'bomb',
#   'inside',
#   'indian',
#   'restaurant',
#   'near',
#   'toronto',
#   'authorities',
#   'say'],
#  ['thousands',
#   'travel',
#   'home',
#   'to',
#   'ireland',
#   'to',
#   'vote',
#   'on',
#   'abortion',
#   'access'],
#  ['irish',
#   'voters',
#   'set',
#   'to',
#   'liberalize',
#   'abortion',
#   'laws',
#   'in',
#   'landslide',
#   'exit',
#   'poll',
#   'signals'],
#  ['warriors',
#   'coach',
#   'steve',
#   'kerr',
#   'calls',
#   'nfl',
#   'ban',
#   'on',
#   'protests',
#   'fake',
#   'patriotism'],
#  ['in',
#   'historic',
#   'victory',
#   'barbados',
#   'elects',
#   'first',
#   'female',
#   'prime',
#   'minister'],
#  ['police',
#   'killed',
#   'at',
#   'least',
#   '',
#   'black',
#   'americans',
#   'from',
#   'the',
#   'moment',
#   'colin',
#   'kaepernick',
#   'protested'],
#  ['jack',
#   'johnson',
#   'was',
#   'pardoned',
#   'but',
#   'taboo',
#   'sex',
#   'is',
#   'still',
#   'being',
#   'criminalized'],
#  ['bet', 'chairman', 'and', 'ceo', 'debra', 'lee', 'is', 'stepping', 'down'],
#  ['rachel',
#   'dolezal',
#   'faces',
#   'felony',
#   'charges',
#   'for',
#   'welfare',
#   'fraud'],
#  ['bishop',
#   'michael',
#   'curry',
#   'joins',
#   'christian',
#   'march',
#   'to',
#   'white',
#   'house',
#   'to',
#   'reclaim',
#   'jesus'],
#  ['kanye',
#   'west',
#   'spent',
#   '',
#   'on',
#   'photo',
#   'of',
#   'whitney',
#   'houstons',
#   'bathroom',
#   'for',
#   'album',
#   'cover'],
#  ['morgan',
#   'freeman',
#   'dropped',
#   'from',
#   'marketing',
#   'campaigns',
#   'after',
#   'harassment',
#   'accusations'],
#  ['how',
#   'the',
#   'chinese',
#   'exclusion',
#   'act',
#   'can',
#   'help',
#   'us',
#   'understand',
#   'immigration',
#   'politics',
#   'today'],
#  ['trumps', 'new', 'magathemed', 'swimwear', 'sinks', 'on', 'twitter'],
#  ['seth',
#   'meyers',
#   'has',
#   '',
#   'funny',
#   'regret',
#   'after',
#   'trump',
#   'cancels',
#   'north',
#   'korea',
#   'summit'],
#  ['colbert',
#   'wants',
#   'to',
#   'turn',
#   'nyc',
#   'subway',
#   'rides',
#   'into',
#   'a',
#   'new',
#   'and',
#   'terrible',
#   'punishment'],
#  ['man',
#   'faces',
#   'charges',
#   'after',
#   'pulling',
#   'knife',
#   'stun',
#   'gun',
#   'on',
#   'muslim',
#   'students',
#   'at',
#   'mcdonalds'],
#  ['jimmy',
#   'kimmel',
#   'knows',
#   'why',
#   'irans',
#   'supreme',
#   'leader',
#   'watches',
#   'tom',
#   'and',
#   'jerry'],
#  ['', 'people', 'injured', 'in', 'indiana', 'school', 'shooting'],
#  ['people',
#   'are',
#   'rattled',
#   'by',
#   'how',
#   'much',
#   'this',
#   'nigerian',
#   'man',
#   'looks',
#   'like',
#   'chadwick',
#   'boseman'],
#  ['david',
#   'cross',
#   'proves',
#   'yet',
#   'again',
#   'that',
#   'hes',
#   'terrible',
#   'at',
#   'apologizing'],
#  ['sesame',
#   'street',
#   'creators',
#   'sue',
#   'makers',
#   'of',
#   'upcoming',
#   'adultthemed',
#   'puppet',
#   'film'],
#  ['what',
#   'you',
#   'missed',
#   'about',
#   'the',
#   'saddest',
#   'death',
#   'in',
#   'avengers',
#   'infinity',
#   'war'],
#  ['george',
#   'takei',
#   'accuser',
#   'walks',
#   'back',
#   'story',
#   'of',
#   'drugging',
#   'and',
#   'sexual',
#   'assault'],
#  ['samantha',
#   'bees',
#   'parents',
#   'think',
#   'america',
#   'is',
#   'basically',
#   'a',
#   'war',
#   'zone'],
#  ['pete',
#   'davidson',
#   'says',
#   'his',
#   'mental',
#   'illness',
#   'doesnt',
#   'ruin',
#   'romance'],
#  ['james',
#   'corden',
#   'and',
#   'adam',
#   'levine',
#   'get',
#   'pulled',
#   'over',
#   'during',
#   'carpool',
#   'karaoke'],
#  ['emilia',
#   'clarke',
#   'dishes',
#   'on',
#   'her',
#   'final',
#   'game',
#   'of',
#   'thrones',
#   'scene'],
#  ['hollywood',
#   'doesnt',
#   'need',
#   'difficult',
#   'men',
#   'to',
#   'make',
#   'great',
#   'tv'],
#  ['harvey',
#   'weinstein',
#   'accusers',
#   'say',
#   'they',
#   'never',
#   'thought',
#   'he',
#   'would',
#   'be',
#   'arrested'],
#  ['harvey',
#   'weinstein',
#   'turns',
#   'himself',
#   'in',
#   'to',
#   'police',
#   'for',
#   'alleged',
#   'sex',
#   'crimes'],
#  ['john',
#   'mayers',
#   'weird',
#   'new',
#   'lowbudget',
#   'video',
#   'is',
#   'a',
#   'memeworthy',
#   'masterpiece'],
#  ['now',
#   'boba',
#   'fett',
#   'is',
#   'getting',
#   'his',
#   'own',
#   'star',
#   'wars',
#   'movie'],
#  ['trump', 'suggests', 'north', 'korea', 'summit', 'could', 'still', 'happen'],
#  ['roger',
#   'stone',
#   'pressed',
#   'for',
#   'damaging',
#   'emails',
#   'about',
#   'hillary',
#   'clinton',
#   'from',
#   'wikileaks',
#   'report'],
#  ['publix',
#   'suspends',
#   'contributions',
#   'to',
#   'nrabacked',
#   'politician',
#   'amid',
#   'protests'],
#  ['twitter',
#   'bots',
#   'may',
#   'have',
#   'delivered',
#   'donald',
#   'trumps',
#   'victory',
#   'research',
#   'paper',
#   'says'],
#  ['a',
#   'bag',
#   'of',
#   'wet',
#   'socks',
#   'is',
#   'apparently',
#   'living',
#   'in',
#   'the',
#   'white',
#   'house',
#   'press',
#   'briefing',
#   'room'],
#  ['a',
#   'member',
#   'of',
#   'the',
#   'farright',
#   'proud',
#   'boys',
#   'menaced',
#   'a',
#   'twitter',
#   'user',
#   'on',
#   'his',
#   'doorstep'],
#  ['all',
#   'the',
#   'things',
#   'the',
#   'nra',
#   'has',
#   'blamed',
#   'for',
#   'the',
#   'texas',
#   'school',
#   'shooting'],
#  ['heres',
#   'what',
#   'happens',
#   'when',
#   'a',
#   'catholic',
#   'hospital',
#   'wont',
#   'try',
#   'to',
#   'save',
#   'you'],
#  ['trumps',
#   'new',
#   'executive',
#   'orders',
#   'make',
#   'it',
#   'easier',
#   'to',
#   'fire',
#   'federal',
#   'workers'],
#  ['monsanto',
#   'and',
#   'bayer',
#   'are',
#   'set',
#   'to',
#   'merge',
#   'heres',
#   'why',
#   'you',
#   'should',
#   'care'],
#  ['the', 'joy', 'of', 'watching', 'harvey', 'weinsteins', 'perp', 'walk'],
#  ['the', '', 'funniest', 'tweets', 'from', 'women', 'this', 'week'],
#  ['queer',
#   'eye',
#   'star',
#   'bobby',
#   'berk',
#   'gave',
#   'me',
#   'a',
#   'desk',
#   'makeover',
#   '',
#   'and',
#   'it',
#   'was',
#   'incredible'],
#  ['older',
#   'gay',
#   'men',
#   'try',
#   'out',
#   'new',
#   'gay',
#   'slang',
#   'in',
#   'this',
#   'hilarious',
#   'video'],
#  ['how',
#   'rupauls',
#   'drag',
#   'race',
#   'is',
#   'teaching',
#   'straight',
#   'people',
#   'about',
#   'queer',
#   'culture'],
#  ['fish',
#   'market',
#   'buys',
#   'freedom',
#   'for',
#   'fred',
#   'the',
#   'pound',
#   'octopus'],
#  ['north',
#   'korea',
#   'threatens',
#   'again',
#   'to',
#   'call',
#   'off',
#   'trump',
#   'summit',
#   'warns',
#   'of',
#   'nuclear',
#   'showdown'],
#  ['investigation',
#   'finds',
#   'russian',
#   'missile',
#   'shot',
#   'down',
#   'flight',
#   'mh'],
#  ['north',
#   'korea',
#   'demolishes',
#   'tunnels',
#   'at',
#   'nuclear',
#   'test',
#   'site',
#   'reports',
#   'say'],
#  ['how',
#   'kim',
#   'jong',
#   'un',
#   'baited',
#   'trump',
#   'into',
#   'canceling',
#   'the',
#   'north',
#   'korea',
#   'summit'],
#  ['michelle',
#   'obama',
#   'reveals',
#   'cover',
#   'for',
#   'upcoming',
#   'memoir',
#   'becoming'],
#  ['late',
#   'night',
#   'writers',
#   'breathless',
#   'royal',
#   'wedding',
#   'recap',
#   'is',
#   'the',
#   'only',
#   'one',
#   'you',
#   'need'],
#  ['morgan',
#   'freeman',
#   'accused',
#   'of',
#   'inappropriate',
#   'behavior',
#   'and',
#   'sexual',
#   'harassment'],
#  ['jets',
#   'chairman',
#   'christopher',
#   'johnson',
#   'wont',
#   'fine',
#   'players',
#   'for',
#   'anthem',
#   'protests'],
#  ['andy',
#   'cohen',
#   'and',
#   'taylor',
#   'swift',
#   'are',
#   'over',
#   'their',
#   'katy',
#   'perry',
#   'drama'],
#  ['infinity',
#   'war',
#   'writers',
#   'try',
#   'to',
#   'clear',
#   'up',
#   'marvels',
#   'problematic',
#   'timeline'],
#  ['david',
#   'blaine',
#   'chews',
#   'glass',
#   'and',
#   'lets',
#   'james',
#   'corden',
#   'puncture',
#   'his',
#   'cheek'],
#  ['amy',
#   'poehler',
#   'a',
#   'parks',
#   'and',
#   'recreation',
#   'revival',
#   'would',
#   'be',
#   'amazing'],
#  ['colbert',
#   'exposes',
#   'the\xa0biggest',
#   'flaw',
#   'in',
#   'trumps',
#   'latest',
#   'conspiracy',
#   'theory'],
#  ['seth',
#   'meyers',
#   'gives',
#   'donald',
#   'trump',
#   'some',
#   'valuable',
#   'marketing',
#   'advice'],
#  ['us',
#   'launches',
#   'auto',
#   'import',
#   'probe',
#   'china',
#   'vows',
#   'to',
#   'defend',
#   'its',
#   'interests'],
#  ['this',
#   'women',
#   'pulled',
#   'out',
#   'all',
#   'the',
#   'stops',
#   'to',
#   'land',
#   'her',
#   'dream',
#   'job'],
#  ['wife',
#   'asked',
#   'husband',
#   'for',
#   'fenty',
#   'highlighter',
#   'and',
#   'got',
#   'a',
#   'pack',
#   'of',
#   'highlighters',
#   'hairbrush'],
#  ['trump',
#   'roasted',
#   'for',
#   'rushing',
#   'to',
#   'defend',
#   'tomi',
#   'lahren',
#   'while',
#   'ignoring',
#   'real',
#   'victims'],
#  ['trump',
#   'abruptly',
#   'cancels',
#   'north',
#   'korea',
#   'summit',
#   'with',
#   'kim',
#   'jong',
#   'un'],
#  ['devin',
#   'nuneslinked',
#   'winery',
#   'faced',
#   'suit',
#   'over',
#   'alleged',
#   'coke',
#   'and',
#   'prostitute',
#   'yacht',
#   'party'],
#  ['immigrant',
#   'children',
#   'accuse',
#   'border',
#   'patrol',
#   'of',
#   'abuse',
#   'and',
#   'neglect',
#   'report',
#   'shows'],
#  ['irelands',
#   'historic',
#   'vote',
#   'on',
#   'legalizing',
#   'abortion',
#   'is',
#   'haunted',
#   'by',
#   'trump',
#   'and',
#   'brexit'],
#  ['trump',
#   'lawyer',
#   'attended',
#   'doj',
#   'meeting',
#   'on',
#   'confidential',
#   'fbi',
#   'informant'],
#  ['senate',
#   'advances',
#   'court',
#   'pick',
#   'who',
#   'said',
#   'planned',
#   'parenthood',
#   'kills',
#   'over',
#   '',
#   'females',
#   'a',
#   'year'],
#  ['rudy',
#   'giuliani',
#   'trump',
#   'wont',
#   'interview',
#   'with',
#   'mueller',
#   'until',
#   'we',
#   'get',
#   'spygate',
#   'report'],
#  ['kentucky',
#   'attorney',
#   'running',
#   'for',
#   'judge',
#   'dies',
#   '',
#   'day',
#   'after',
#   'primary',
#   'win'],
#  ['chrissy',
#   'teigen',
#   'taunts',
#   'donald',
#   'trump',
#   'over',
#   'twitter',
#   'blocking',
#   'ruling'],
#  ['the',
#   'koch',
#   'network',
#   'is',
#   'going',
#   'after',
#   'one',
#   'of',
#   'trumps',
#   'favorite',
#   'congressmen'],
#  ['trump', 'posthumously', 'pardons', 'boxer', 'jack', 'johnson'],
#  ['ellen',
#   'tears',
#   'up',
#   'when',
#   'ashton',
#   'kutcher',
#   'donates',
#   '',
#   'million',
#   'to',
#   'her',
#   'wildlife',
#   'fund'],
#  ['ariana',
#   'grande',
#   'reveals',
#   'bee',
#   'tattoo',
#   'in',
#   'honor',
#   'of',
#   'the',
#   'manchester',
#   'attack'],
#  ['kim',
#   'kardashian',
#   'wished',
#   'kanye',
#   'west',
#   'a',
#   'happy',
#   'anniversary',
#   'and',
#   'fine',
#   'its',
#   'pretty',
#   'cute'],
#  ['chris',
#   'hemsworth',
#   'dances',
#   'wrecking',
#   'ball',
#   'with',
#   'his',
#   'kids',
#   'in',
#   'the',
#   'living',
#   'room'],
#  ['moses',
#   'farrow',
#   'defends',
#   'woody',
#   'allen',
#   'and',
#   'accuses',
#   'mia',
#   'farrow',
#   'of',
#   'abuse'],
#  ['gwyneth',
#   'paltrow',
#   'says',
#   'brad',
#   'pitt',
#   'threatened',
#   'to',
#   'kill',
#   'harvey',
#   'weinstein'],
#  ['stephen',
#   'king',
#   'reveals',
#   'why',
#   'donald',
#   'trump',
#   'blocked',
#   'him',
#   'on',
#   'twitter'],
#  ['fans',
#   'back',
#   'jessica',
#   'walter',
#   'after',
#   'she',
#   'addressed',
#   'verbal',
#   'harassment',
#   'by',
#   'jeffrey',
#   'tambor'],
#  ['jessica',
#   'walter',
#   'discusses',
#   'jeffrey',
#   'tambors',
#   'alleged',
#   'harassment',
#   'while',
#   'male',
#   'costars',
#   'brush',
#   'it',
#   'off'],
#  ['harvey',
#   'weinstein',
#   'expected',
#   'to',
#   'turn',
#   'himself',
#   'in',
#   'to',
#   'the',
#   'nypd',
#   'for',
#   'sex',
#   'crimes'],
#  ['samantha',
#   'bee',
#   'torches',
#   'ice',
#   'lets',
#   'shut',
#   'it',
#   'the',
#   'fk',
#   'down'],
#  ['scott',
#   'pruitt',
#   'twice',
#   'introduced',
#   'antiabortion',
#   'bills',
#   'giving',
#   'men',
#   'property',
#   'rights',
#   'over',
#   'fetuses'],
#  ['twitter',
#   'critics',
#   'mercilessly',
#   'mock',
#   'trump',
#   'for',
#   'canceling',
#   'summit',
#   'with',
#   'kim'],
#  ['civil',
#   'rights',
#   'groups',
#   'rip',
#   'senate',
#   'bill',
#   'revising',
#   'its',
#   'own',
#   'sexual',
#   'harassment',
#   'policy'],
#  ['alabama',
#   'sues',
#   'to',
#   'exclude',
#   'undocumented',
#   'immigrants',
#   'from',
#   'census',
#   'count'],
#  ['cynthia',
#   'nixon',
#   'vows',
#   'to',
#   'keep',
#   'fighting',
#   'after',
#   'predictably',
#   'losing',
#   'party',
#   'endorsement'],
#  ['white',
#   'house',
#   'officials',
#   'reportedly',
#   'considered',
#   'just',
#   'ignoring',
#   'new',
#   'climate',
#   'research'],
#  ['read',
#   'trumps',
#   'letter',
#   'to',
#   'kim',
#   'jong',
#   'un',
#   'canceling',
#   'north',
#   'korea',
#   'summit'],
#  ['south',
#   'korea',
#   'responds',
#   'to',
#   'trumps',
#   'sudden',
#   'cancellation',
#   'of',
#   'kim',
#   'jong',
#   'un',
#   'summit'],
#  ['facebooks',
#   'new',
#   'ad',
#   'rules',
#   'prove',
#   'its',
#   'basically',
#   'in',
#   'charge',
#   'of',
#   'regulating',
#   'elections',
#   'now'],
#  ['border', 'agent', 'fatally', 'shoots', 'migrant', 'woman', 'in', 'texas'],
#  ['trump',
#   'opens',
#   'door',
#   'for',
#   'us',
#   'gun',
#   'industry',
#   'to',
#   'sell',
#   'more',
#   'firearms',
#   'abroad'],
#  ['stormy',
#   'daniels',
#   'day',
#   'declared',
#   'in',
#   'west',
#   'hollywood',
#   'as',
#   'adult',
#   'star',
#   'gets',
#   'key',
#   'to',
#   'city'],
#  ['youre',
#   'going',
#   'to',
#   'use',
#   'that',
#   'selfcheckout',
#   'machine',
#   'whether',
#   'you',
#   'like',
#   'it',
#   'or',
#   'not'],
#  ['',
#   'ways',
#   'to',
#   'make',
#   'family',
#   'road',
#   'trips',
#   'easier',
#   'from',
#   'parents',
#   'whove',
#   'been',
#   'there'],
#  ['jake',
#   'tapper',
#   'shreds',
#   'donald',
#   'trump',
#   'with',
#   'a',
#   'long',
#   'list',
#   'of',
#   'his',
#   'conspiracy',
#   'theories'],
#  ['new',
#   'york',
#   'daily',
#   'news',
#   'rips',
#   'nfl',
#   'over',
#   'anthem',
#   'kneeling',
#   'ban'],
#  ['a',
#   'judge',
#   'ruled',
#   'one',
#   'immigrant',
#   'had',
#   'a',
#   'right',
#   'to',
#   'a',
#   'hearing',
#   'what',
#   'about',
#   'all',
#   'the',
#   'others'],
#  ['house',
#   'democrats',
#   'offer',
#   'internships',
#   'for',
#   'students',
#   'affected',
#   'by',
#   'gun',
#   'violence'],
#  ['tig',
#   'notaro',
#   'tells',
#   'ellen',
#   'degeneres',
#   'about',
#   'her',
#   'sons',
#   'passion',
#   'for',
#   'trash'],
#  ['stormy',
#   'daniels',
#   'thanks',
#   'wonderful',
#   'gay',
#   'dads',
#   'as',
#   'west',
#   'hollywood',
#   'hands',
#   'her',
#   'keys',
#   'to',
#   'city'],
#  ['can',
#   'you',
#   'believe',
#   'queer',
#   'eye',
#   'season',
#   '',
#   'drops',
#   'next',
#   'month'],
#  ['gay',
#   'man',
#   'denied',
#   'marriage',
#   'license',
#   'by',
#   'kim',
#   'davis',
#   'loses',
#   'bid',
#   'to',
#   'unseat',
#   'her'],
#  ['anna',
#   'kournikova',
#   'dancing',
#   'with',
#   'her',
#   'bouncing',
#   'baby',
#   'is',
#   'the',
#   'cutest',
#   'thing'],
#  ['trump',
#   'says',
#   'nfl',
#   'players',
#   'unwilling',
#   'to',
#   'stand',
#   'for',
#   'anthem',
#   'maybe',
#   'shouldnt',
#   'be',
#   'in',
#   'the',
#   'country'],
#  ['facebook',
#   'accused',
#   'of',
#   'reading',
#   'texts',
#   'and',
#   'accessing',
#   'microphones',
#   'in',
#   'lawsuit'],
#  ['selfdriving',
#   'uber',
#   'in',
#   'fatal',
#   'accident',
#   'had',
#   '',
#   'seconds',
#   'to',
#   'react',
#   'before',
#   'crash'],
#  ['amazon',
#   'admits',
#   'alexa',
#   'device',
#   'eavesdropped',
#   'on',
#   'portland',
#   'family'],
#  ['man',
#   'discovers',
#   'handgun',
#   'impaled',
#   'in',
#   'front',
#   'bumper',
#   'of',
#   'car'],
#  ['rescue',
#   'cat',
#   'has',
#   'hilarious',
#   'wideeyed',
#   'expression',
#   'after',
#   'scan',
#   'confirms',
#   'she',
#   'is',
#   'pregnant'],
#  ['weirdest',
#   'promposals',
#   'of',
#   '',
#   'include',
#   'teen',
#   'who',
#   'faked',
#   'his',
#   'own',
#   'birth'],
#  ['trump',
#   'and',
#   'the',
#   'american',
#   'far',
#   'right',
#   'stoke',
#   'hate',
#   'in',
#   'canada'],
#  ['farright',
#   'and',
#   'antiestablishment',
#   'parties',
#   'set',
#   'to',
#   'form',
#   'italys',
#   'new',
#   'government'],
#  ['sarah',
#   'silverman',
#   'sees',
#   'no',
#   'reason',
#   'why',
#   'louis',
#   'ck',
#   'cant',
#   'continue',
#   'being',
#   'an',
#   'artist'],
#  ['southern',
#   'baptist',
#   'leader',
#   'who',
#   'said',
#   'abused',
#   'women',
#   'should',
#   'just',
#   'pray',
#   'is',
#   'removed',
#   'from',
#   'post'],
#  ['more', 'americans', 'than', 'ever', 'support', 'samesex', 'marriage'],
#  ['brynn',
#   'cartelli',
#   'becomes',
#   'youngestever',
#   'winner',
#   'of',
#   'the',
#   'voice'],
#  ['betsy',
#   'devos',
#   'stirs',
#   'uproar',
#   'by',
#   'saying',
#   'schools',
#   'can',
#   'call',
#   'ice',
#   'on',
#   'undocumented',
#   'kids'],
#  ['',
#   'sandy',
#   'hook',
#   'families',
#   'fbi',
#   'agent',
#   'sue',
#   'alex',
#   'jones',
#   'for',
#   'defamation'],
#  ['high',
#   'school',
#   'teacher',
#   'defeats',
#   'kentucky',
#   'house',
#   'majority',
#   'leader',
#   'in',
#   'gop',
#   'primary'],
#  ['lupe',
#   'valdez',
#   'makes',
#   'history',
#   'in',
#   'texas',
#   'by',
#   'winning',
#   'democratic',
#   'nod',
#   'for',
#   'governor'],
#  ['report',
#   'michael',
#   'cohens',
#   'business',
#   'partner',
#   'cooperating',
#   'with',
#   'prosecutors'],
#  ['brandi',
#   'chastain',
#   'totally',
#   'agrees',
#   'her',
#   'hall',
#   'of',
#   'fame',
#   'plaque',
#   'looks',
#   'nothing',
#   'like',
#   'her'],
#  ['scientists',
#   'turn',
#   'to',
#   'dna',
#   'technology',
#   'to',
#   'search',
#   'for',
#   'loch',
#   'ness',
#   'monster'],
#  ['late',
#   'night',
#   'writer',
#   'vows',
#   'to',
#   'take',
#   'red',
#   'hats',
#   'back',
#   'from',
#   'trump',
#   'supporters'],
#  ['julia',
#   'louisdreyfus',
#   'to',
#   'receive',
#   '',
#   'mark',
#   'twain',
#   'prize',
#   'for',
#   'american',
#   'humor'],
#  ['michelle',
#   'obama',
#   'shares',
#   'intimate',
#   'wedding',
#   'photo',
#   'in',
#   'tribute',
#   'to',
#   'husband',
#   'barack'],
#  ['did',
#   'you',
#   'spot',
#   'trevor',
#   'noah',
#   'in',
#   'black',
#   'panther',
#   'the',
#   'daily',
#   'show',
#   'hosts',
#   'stealth',
#   'cameo',
#   'revealed'],
#  ['donald',
#   'glover',
#   'fans',
#   'execute',
#   'stunning',
#   'coup',
#   'on',
#   'donald',
#   'trumpthemed',
#   'reddit',
#   'forum'],
#  ['ti',
#   'calls',
#   'for',
#   'boycott',
#   'of',
#   'restaurant',
#   'after',
#   'offduty',
#   'cop',
#   'allegedly',
#   'assaults',
#   '',
#   'black',
#   'women'],
#  ['survivor',
#   'of',
#   'rwandan',
#   'genocide',
#   'to',
#   'be',
#   'countrys',
#   'first',
#   'female',
#   'neurosurgeon'],
#  ['stacey',
#   'abrams',
#   'wins',
#   'democratic',
#   'primary',
#   'for',
#   'georgia',
#   'governor'],
#  ['trevor',
#   'noah',
#   'reveals',
#   'the',
#   'question',
#   'hed',
#   'ask',
#   'donald',
#   'trump',
#   'that',
#   'no',
#   'else',
#   'has',
#   'dared',
#   'to'],
#  ['michelle',
#   'obama',
#   'reflects',
#   'on',
#   'scary',
#   'time',
#   'at',
#   'princeton',
#   'with',
#   'sweet',
#   'throwback',
#   'snap'],
#  ['',
#   'reasons',
#   'why',
#   'started',
#   'a',
#   'conversation',
#   'whos',
#   'responsible',
#   'for',
#   'finishing',
#   'it'],
#  ['lourdes',
#   'leon',
#   'gives',
#   'us',
#   'major',
#   'madonna',
#   'vibes',
#   'in',
#   'moody',
#   'new',
#   'ad',
#   'campaign',
#   'pics'],
#  ['',
#   'ways',
#   'netflix',
#   'tricks',
#   'you',
#   'into',
#   'watching',
#   'more',
#   'shows',
#   'and',
#   'movies'],
#  ['brad',
#   'pitt',
#   'made',
#   'ryan',
#   'reynolds',
#   'do',
#   'one',
#   'demeaning',
#   'thing',
#   'in',
#   'exchange',
#   'for',
#   'deadpool',
#   '',
#   'cameo'],
#  ['robert',
#   'de',
#   'niro',
#   'bans',
#   'trump',
#   'from',
#   'every',
#   'nobu',
#   'restaurant'],
#  ['ariana',
#   'grande',
#   'shuts',
#   'down',
#   'fan',
#   'blaming',
#   'her',
#   'for',
#   'heartbreaking',
#   'mac',
#   'miller',
#   'split'],
#  ['parents',
#   'slam',
#   'show',
#   'dogs',
#   'scenes',
#   'as',
#   'grooming',
#   'children',
#   'for',
#   'sexual',
#   'abuse'],
#  ['dave',
#   'grohl',
#   'wants',
#   'to',
#   'apologize',
#   'to',
#   'the',
#   'world',
#   'for',
#   'massive',
#   'jerk',
#   'trump'],
#  ['emilia',
#   'clarke',
#   'introduced',
#   'herself',
#   'to',
#   'prince',
#   'william',
#   'in',
#   'a',
#   'pretty',
#   'embarrassing',
#   'way'],
#  ['sarah',
#   'paulson',
#   'takes',
#   'impressions',
#   'to',
#   'next',
#   'level',
#   'on',
#   'tonight',
#   'show'],
#  ['the',
#   'bs',
#   'are',
#   'still',
#   'ready',
#   'to',
#   'party',
#   'and',
#   'be',
#   'taken',
#   'seriously'],
#  ['gina',
#   'ortiz',
#   'jones',
#   'wins',
#   'democratic',
#   'runoff',
#   'in',
#   'texas',
#   'congressional',
#   'race'],
#  ['fighter',
#   'pilot',
#   'amy',
#   'mcgrath',
#   'wins',
#   'democratic',
#   'primary',
#   'in',
#   'kentucky',
#   'swing',
#   'district'],
#  ['trump',
#   'rallies',
#   'conservatives',
#   'with',
#   'promise',
#   'of',
#   'more',
#   'abortion',
#   'curbs'],
#  ['the',
#   'aclu',
#   'is',
#   'suing',
#   'to',
#   'strike',
#   'down',
#   'ohios',
#   'congressional',
#   'map'],
#  ['the',
#   'latest',
#   'school',
#   'shooting',
#   'hasnt',
#   'really',
#   'stirred',
#   'the',
#   'gun',
#   'debate'],
#  ['donald',
#   'trump',
#   'tweet',
#   'rescues',
#   'roseanne',
#   'and',
#   'family',
#   'in',
#   'season',
#   'finale'],
#  ['ellen',
#   'grills',
#   'mark',
#   'wahlberg',
#   'about',
#   'his',
#   'shirtless',
#   'instagram',
#   'selfies'],
#  ['idris',
#   'elba',
#   'to',
#   'star',
#   'as',
#   'the',
#   'new',
#   'hunchback',
#   'of',
#   'notre',
#   'dame',
#   'for',
#   'netflix'],
#  ['maryland',
#   'police',
#   'charge',
#   '',
#   'church',
#   'leaders',
#   'with',
#   'past',
#   'abuse',
#   'of',
#   'atrisk',
#   'teen',
#   'girls'],
#  ['nfl', 'bans', 'kneeling', 'during', 'the', 'national', 'anthem'],
#  ['conan',
#   'obrien',
#   'muscles',
#   'in',
#   'on',
#   'the',
#   'royal',
#   'wedding',
#   'with',
#   'his',
#   'own',
#   'spoof',
#   'ads'],
#  ['house',
#   'republicans',
#   'report',
#   'progress',
#   'on',
#   'an',
#   'immigration',
#   'deal'],
#  ['democrats',
#   'werent',
#   'invited',
#   'to',
#   'review',
#   'classified',
#   'documents',
#   'on',
#   'fbi',
#   'informant'],
#  ['gop',
#   'candidate',
#   'who',
#   'pointed',
#   'gun',
#   'at',
#   'teenager',
#   'advances',
#   'to',
#   'georgia',
#   'governor',
#   'primary',
#   'runoff'],
#  ['walking',
#   'definition',
#   'of',
#   'an',
#   'entitled',
#   'millennial',
#   'swears',
#   'hes',
#   'not',
#   'an',
#   'entitled',
#   'millennial'],
#  ['democrats',
#   'push',
#   'to',
#   'be',
#   'included',
#   'in',
#   'classified',
#   'briefing',
#   'on',
#   'fbi',
#   'informant'],
#  ['machines',
#   'dont',
#   'always',
#   'steal',
#   'our',
#   'jobs',
#   'increasingly',
#   'they',
#   'rob',
#   'our',
#   'work',
#   'of',
#   'humanity'],
#  ['trump',
#   'praises',
#   'tomi',
#   'lahren',
#   'after',
#   'restaurant',
#   'crowd',
#   'tosses',
#   'water',
#   'insults'],
#  ['sarah', 'sanders', 'it', 'bothers', 'me', 'being', 'called', 'a', 'liar'],
#  ['trump',
#   'blocking',
#   'people',
#   'on',
#   'twitter',
#   'is',
#   'unconstitutional',
#   'judge',
#   'rules'],
#  ['a',
#   'mostly',
#   'nonchristian',
#   'militia',
#   'won',
#   '',
#   'of',
#   'iraqi',
#   'christians',
#   'parliamentary',
#   'seats',
#   'now',
#   'christians',
#   'want',
#   'trump',
#   'to',
#   'intervene'],
#  ['tulsi',
#   'gabbards',
#   'syria',
#   'views',
#   'cost',
#   'her',
#   'support',
#   'of',
#   'hawaii',
#   'teachers',
#   'union'],
#  ['jared', 'kushner', 'received', 'his', 'security', 'clearance', 'reports'],
#  ['arizona',
#   'gop',
#   'congressional',
#   'candidate',
#   'compares',
#   'abortion',
#   'to',
#   'holocaust'],
#  ['gun',
#   'reform',
#   'advocate',
#   'lucy',
#   'mcbath',
#   'heads',
#   'to',
#   'runoff',
#   'for',
#   'georgia',
#   'house',
#   'seat'],
#  ['star',
#   'wars',
#   'burlesque',
#   'show',
#   'storms',
#   'west',
#   'coast',
#   'with',
#   'sexy',
#   'stormtroopers'],
#  ['establishmentbacked',
#   'moderate',
#   'wins',
#   'heated',
#   'democratic',
#   'house',
#   'primary',
#   'in',
#   'texas'],
#  ['senators',
#   'unveil',
#   'bill',
#   'to',
#   'crack',
#   'down',
#   'on',
#   'their',
#   'sexual',
#   'harassment'],
#  ['',
#   'trips',
#   'to',
#   'take',
#   'from',
#   'new',
#   'york',
#   'city',
#   'on',
#   'a',
#   'long',
#   'weekend'],
#  ['disney',
#   'reveals',
#   'opening',
#   'seasons',
#   'for',
#   'star',
#   'wars',
#   'theme',
#   'park',
#   'lands'],
#  ['the',
#   'latest',
#   'entries',
#   'from',
#   'the',
#   'comedy',
#   'wildlife',
#   'photo',
#   'awards',
#   'will',
#   'cheer',
#   'you',
#   'up'],
#  ['bad',
#   'lip',
#   'reading',
#   'reveals',
#   'what',
#   'was',
#   'really',
#   'said',
#   'at',
#   'the',
#   'royal',
#   'wedding'],
#  ['australian',
#   'archbishop',
#   'convicted',
#   'of',
#   'covering',
#   'up',
#   'child',
#   'sex',
#   'abuse'],
#  ['commander',
#   'says',
#   'irans',
#   'people',
#   'will',
#   'respond',
#   'to',
#   'pompeos',
#   'threats',
#   'with',
#   'a',
#   'punch',
#   'in',
#   'the',
#   'mouth'],
#  ['mark',
#   'zuckerberg',
#   'extends',
#   'facebook',
#   'apology',
#   'tour',
#   'with',
#   'european',
#   'gig'],
#  ['ariana',
#   'grande',
#   'tweets',
#   'message',
#   'of',
#   'support',
#   'on',
#   'manchester',
#   'bombing',
#   'anniversary'],
#  ['katy', 'perry', 'says', 'shes', 'not', 'single', 'on', 'american', 'idol'],
#  ['before',
#   'you',
#   'call',
#   'the',
#   'cops',
#   'on',
#   'him',
#   'watch',
#   'his',
#   'powerful',
#   'monologue',
#   'on',
#   'racism'],
#  ['amazon',
#   'is',
#   'selling',
#   'cops',
#   'its',
#   'facial',
#   'recognition',
#   'tool',
#   'thats',
#   'a',
#   'bad',
#   'potentially',
#   'racist',
#   'move'],
#  ['miley',
#   'cyrus',
#   'comes',
#   'in',
#   'like',
#   'a',
#   'wrecking',
#   'ball',
#   'to',
#   'prank',
#   'a',
#   'sleeping',
#   'jimmy',
#   'kimmel'],
#  ['vanessa',
#   'bayer',
#   'feared',
#   'doing',
#   'the',
#   'porn',
#   'stars',
#   'skit',
#   'with',
#   'donald',
#   'trump',
#   'on',
#   'snl'],
#  ['adam',
#   'rippon',
#   'wins',
#   'dancing',
#   'with',
#   'the',
#   'stars',
#   'because',
#   'it',
#   'was',
#   'destined'],
#  ['emilia',
#   'clarke',
#   'should',
#   'never',
#   'try',
#   'to',
#   'imitate',
#   'chewbacca',
#   'ever',
#   'again'],
#  ['maddie',
#   'poppe',
#   'wins',
#   'american',
#   'idol',
#   'after',
#   'runnerup',
#   'reveals',
#   'theyre',
#   'dating'],
#  ['colbert',
#   'just',
#   'cant',
#   'resist',
#   'turning',
#   'trumps',
#   'nickname',
#   'into',
#   'a',
#   'pee',
#   'tape',
#   'joke'],
#  ['seth',
#   'meyers',
#   'is',
#   'forced',
#   'to',
#   'tweak',
#   'donald',
#   'trumps',
#   'latest',
#   'twitter',
#   'rant',
#   'for',
#   'time'],
#  ['boy',
#   'says',
#   'teacher',
#   'told',
#   'him',
#   'it',
#   'will',
#   'be',
#   'his',
#   'fault',
#   'when',
#   'police',
#   'shoot',
#   'him',
#   'at',
#   'age',
#   ''],
#  ['cops',
#   'accused',
#   'of',
#   'racism',
#   'after',
#   'detaining',
#   'black',
#   'man',
#   'over',
#   'vegetation'],
#  ['white',
#   'cop',
#   'shouts',
#   'at',
#   'black',
#   'suspect',
#   'pretend',
#   'like',
#   'were',
#   'going',
#   'to',
#   'shoot',
#   'you'],
#  ['florida',
#   'police',
#   'report',
#   '',
#   'dead',
#   'after',
#   'standoff',
#   'at',
#   'panama',
#   'city',
#   'apartment',
#   'complex'],
#  ['donald',
#   'glover',
#   'is',
#   'on',
#   'board',
#   'with',
#   'lando',
#   'calrissians',
#   'pansexuality',
#   'in',
#   'solo'],
#  ['charlize',
#   'theron',
#   'to',
#   'play',
#   'megyn',
#   'kelly',
#   'in',
#   'film',
#   'about',
#   'roger',
#   'ailes'],
#  ['shoppers',
#   'boycott',
#   'publix',
#   'over',
#   'stores',
#   'donations',
#   'to',
#   'nrabacked',
#   'candidate'],
#  ['bill',
#   'de',
#   'blasio',
#   'tells',
#   'nypd',
#   'to',
#   'stop',
#   'arresting',
#   'people',
#   'for',
#   'smoking',
#   'pot',
#   'on',
#   'the',
#   'street'],
#  ['dhs',
#   'head',
#   'says',
#   'shes',
#   'still',
#   'somehow',
#   'unaware',
#   'of',
#   'intel',
#   'on',
#   'russia',
#   'interference',
#   'to',
#   'boost',
#   'trump'],
#  ['lawmaker',
#   'introduces',
#   'crowdfunding',
#   'bill',
#   'to',
#   'pay',
#   'for',
#   'trumps',
#   'border',
#   'wall'],
#  ['gop',
#   'lawmakers',
#   'will',
#   'soon',
#   'be',
#   'allowed',
#   'to',
#   'review',
#   'classified',
#   'info',
#   'on',
#   'russia',
#   'investigation'],
#  ['james',
#   'corden',
#   'reveals',
#   'the',
#   'worst',
#   'part',
#   'of',
#   'the',
#   'royal',
#   'wedding',
#   'ceremony'],
#  ['ariana',
#   'grande',
#   'reportedly',
#   'dating',
#   'snl',
#   'star',
#   'pete',
#   'davidson'],
#  ['jim',
#   'carrey',
#   'pens',
#   'new',
#   'pledge',
#   'of',
#   'allegiance',
#   'for',
#   'students',
#   'in',
#   'bulletriddled',
#   'schools'],
#  ['ellen',
#   'gets',
#   'david',
#   'spade',
#   'to',
#   'open',
#   'up',
#   'about',
#   'dating',
#   'younger',
#   'women'],
#  ['ceasefire',
#   'over',
#   'jimmy',
#   'kimmel',
#   'shreds',
#   'sean',
#   'hannity',
#   'and',
#   'those',
#   'dummies',
#   'on',
#   'fox',
#   '',
#   'friends'],
#  ['spoof',
#   'royal',
#   'wedding',
#   'video',
#   'sees',
#   'ceremony',
#   'taking',
#   'a',
#   'very',
#   'different',
#   'turn'],
#  ['the',
#   'georgia',
#   'gop',
#   'governors',
#   'primary',
#   'focuses',
#   'on',
#   'guns',
#   'and',
#   'immigration'],
#  ['glaads',
#   'movie',
#   'report',
#   'finds',
#   'troubling',
#   'drop',
#   'in',
#   'lgbtq',
#   'representation'],
#  ['sephora',
#   'now',
#   'offers',
#   'instore',
#   'beauty',
#   'classes',
#   'for',
#   'trans',
#   'nonbinary',
#   'community'],
#  ['georgia',
#   'governors',
#   'primary',
#   'highlights',
#   'competing',
#   'visions',
#   'for',
#   'the',
#   'democratic',
#   'party'],
#  ['california',
#   'moves',
#   'to',
#   'let',
#   'schools',
#   'coworkers',
#   'red',
#   'flag',
#   'dangerous',
#   'gun',
#   'owners'],
#  ['talking',
#   'grievance',
#   'and',
#   'health',
#   'care',
#   'an',
#   'outsider',
#   'kentucky',
#   'dem',
#   'found',
#   'the',
#   'inside',
#   'track'],
#  ['there',
#   'are',
#   'some',
#   'problems',
#   'with',
#   'this',
#   'commemorative',
#   'trumpkim',
#   'jong',
#   'un',
#   'coin'],
#  ['giulianis',
#   'new',
#   'stance',
#   'on',
#   'russian',
#   'collusion',
#   'so',
#   'what',
#   'its',
#   'not',
#   'illegal'],
#  ['the',
#   'onion',
#   'hilariously',
#   'trolls',
#   'michael',
#   'cohen',
#   'with',
#   'his',
#   'own',
#   'ceaseanddesist',
#   'note'],
#  ['democrats',
#   'want',
#   'to',
#   'boost',
#   'school',
#   'funding',
#   'to',
#   'address',
#   'teacher',
#   'walkouts'],
#  ['but',
#   'her',
#   'emails',
#   'lawmakers',
#   'shrug',
#   'off',
#   'trumps',
#   'lax',
#   'cellphone',
#   'security'],
#  ['we',
#   'try',
#   'stink',
#   'bugflavored',
#   'jelly',
#   'bellys',
#   'so',
#   'you',
#   'dont',
#   'have',
#   'to'],
#  ['power',
#   'outage',
#   'triggers',
#   'extreme',
#   'zombie',
#   'activity',
#   'alert',
#   'in',
#   'florida',
#   'city'],
#  ['congress',
#   'does',
#   'wall',
#   'street',
#   'a',
#   'favor',
#   'as',
#   'banks',
#   'post',
#   'record',
#   'profits'],
#  ['white', 'house', 'sinkhole', 'probably', 'metaphor', 'for', 'something'],
#  ['reporter',
#   'shoved',
#   'others',
#   'barred',
#   'from',
#   'epa',
#   'meeting',
#   'on',
#   'water',
#   'contaminants'],
#  ['garry',
#   'kasparov',
#   'donald',
#   'trump',
#   'has',
#   'more',
#   'russian',
#   'connections',
#   'than',
#   'aeroflot'],
#  ['lonely',
#   'planets',
#   'top',
#   'european',
#   'destinations',
#   'of',
#   '',
#   'take',
#   'aim',
#   'at',
#   'overtourism'],
#  ['attorney',
#   'aaron',
#   'schlossberg',
#   'insists',
#   'antispanish',
#   'rant',
#   'is',
#   'not',
#   'the',
#   'person',
#   'i',
#   'am'],
#  ['',
#   'minutes',
#   'reporter',
#   'reveals',
#   'trumps',
#   'chilling',
#   'reason',
#   'for',
#   'slamming',
#   'the',
#   'press'],
#  ['trump',
#   'reportedly',
#   'rejects',
#   'phone',
#   'security',
#   'measures',
#   'as',
#   'too',
#   'inconvenient'],
#  ['federal',
#   'court',
#   'sides',
#   'with',
#   'transgender',
#   'teen',
#   'gavin',
#   'grimm',
#   'in',
#   'bathroom',
#   'fight'],
#  ['extrump',
#   'adviser',
#   'calls',
#   'presidents',
#   'claims',
#   'that',
#   'informant',
#   'spied',
#   'on',
#   'campaign',
#   'embarrassing'],
#  ['vietnam',
#   'is',
#   'a',
#   'test',
#   'for',
#   'what',
#   'happens',
#   'when',
#   'the',
#   'us',
#   'abandons',
#   'climate',
#   'diplomacy'],
#  ['just',
#   'onethird',
#   'of',
#   'americans',
#   'think',
#   'trump',
#   'is',
#   'successfully',
#   'draining',
#   'the',
#   'swamp'],
#  ['msnbc',
#   'host',
#   'hugh',
#   'hewitt',
#   'suggests',
#   'trench',
#   'coat',
#   'control',
#   'not',
#   'gun',
#   'control'],
#  ['bishop',
#   'michael',
#   'curry',
#   'harry',
#   'and',
#   'meghans',
#   'love',
#   'brought',
#   'different',
#   'worlds',
#   'together'],
#  ['sarah',
#   'paulson',
#   'is',
#   'unapologetic',
#   'about',
#   'year',
#   'age',
#   'gap',
#   'with',
#   'girlfriend',
#   'holland',
#   'taylor'],
#  ['texans',
#   'on',
#   'both',
#   'sides',
#   'of',
#   'gun',
#   'debate',
#   'agree',
#   'on',
#   'safe',
#   'storage',
#   'but',
#   'not',
#   'on',
#   'how',
#   'to',
#   'support',
#   'it'],
#  ['family',
#   'of',
#   'gay',
#   'man',
#   'found',
#   'critically',
#   'injured',
#   'near',
#   'amtrak',
#   'route',
#   'wants',
#   'answers'],
#  ['caitlyn',
#   'jenner',
#   'trump',
#   'is',
#   'the',
#   'worst',
#   'president',
#   'we',
#   'have',
#   'ever',
#   'had',
#   'on',
#   'lgbtq',
#   'rights'],
#  ['boy',
#   'scout',
#   'allegedly',
#   'booted',
#   'from',
#   'store',
#   'because',
#   'company',
#   'wont',
#   'support',
#   'homos'],
#  ['instagram',
#   'is',
#   'adding',
#   'a',
#   'mute',
#   'button',
#   'for',
#   'the',
#   'sake',
#   'of',
#   'your',
#   'sanity'],
#  ['publix', 'censors', 'teens', 'summa', 'cum', 'laude', 'graduation', 'cake'],
#  ['what',
#   'do',
#   'you',
#   'say',
#   'to',
#   'sexist',
#   'passengers',
#   'this',
#   'female',
#   'pilot',
#   'has',
#   'the',
#   'perfect',
#   'response'],
#  ['times',
#   'up',
#   'takes',
#   'aim',
#   'at',
#   'mcdonalds',
#   'walmart',
#   'over',
#   'sexual',
#   'harassment',
#   'complaints'],
#  ['venezuelas',
#   'socialist',
#   'leader',
#   'nicolas',
#   'maduro',
#   'reelected',
#   'amid',
#   'allegations',
#   'of',
#   'irregularities'],
#  ['iran',
#   'says',
#   'europes',
#   'support',
#   'for',
#   'nuclear',
#   'deal',
#   'isnt',
#   'enough',
#   'after',
#   'americas',
#   'withdrawal'],
#  ['farright', 'mob', 'attacks', 'yearold', 'liberal', 'greek', 'mayor'],
#  ['shawn',
#   'mendes',
#   'and',
#   'khalid',
#   'perform',
#   'with',
#   'parkland',
#   'survivors',
#   'at',
#   'billboard',
#   'music',
#   'awards'],
#  ['tamir',
#   'rices',
#   'mother',
#   'is',
#   'opening',
#   'a',
#   'youth',
#   'center',
#   'to',
#   'honor',
#   'her',
#   'sons',
#   'memory'],
#  ['judge',
#   'orders',
#   'texas',
#   'to',
#   'make',
#   'voter',
#   'registration',
#   'easier',
#   'when',
#   'updating',
#   'dmv',
#   'info'],
#  ['kelly',
#   'clarkson',
#   'calls',
#   'for',
#   'moments',
#   'of',
#   'action',
#   'in',
#   'honor',
#   'of',
#   'texas',
#   'shooting',
#   'victims',
#   'at',
#   'billboard',
#   'awards'],
#  ['kendrick', 'lamar', 'stops', 'white', 'fan', 'rapping', 'nword', 'onstage'],
#  ['gay',
#   'man',
#   'says',
#   'pope',
#   'francis',
#   'told',
#   'him',
#   'god',
#   'made',
#   'you',
#   'like',
#   'that',
#   'and',
#   'loves',
#   'you',
#   'like',
#   'that'],
#  ['unusual',
#   'asteroid',
#   'could',
#   'be',
#   'an',
#   'interstellar',
#   'guest',
#   'to',
#   'our',
#   'solar',
#   'system'],
#  ['she',
#   'started',
#   'a',
#   'suicide',
#   'prevention',
#   'site',
#   'at',
#   'age',
#   '',
#   'its',
#   'still',
#   'going',
#   'strong'],
#  ['roger',
#   'stone',
#   'says',
#   'hes',
#   'prepared',
#   'for',
#   'conjured',
#   'up',
#   'mueller',
#   'indictment'],
#  ['hillary', 'clinton', 'to', 'endorse', 'andrew', 'cuomos', 'reelection'],
#  ['the',
#   'supreme',
#   'court',
#   'just',
#   'made',
#   'it',
#   'a',
#   'lot',
#   'harder',
#   'for',
#   'you',
#   'to',
#   'sue',
#   'your',
#   'employer'],
#  ['blake',
#   'farenthold',
#   'may',
#   'have',
#   'been',
#   'hired',
#   'illegally',
#   'at',
#   'his',
#   'new',
#   'lobbyist',
#   'job'],
#  ['bill',
#   'konigsberg',
#   'explores',
#   'a',
#   'new',
#   'side',
#   'of',
#   'the',
#   'gay',
#   'experience',
#   'in',
#   'his',
#   'latest',
#   'book'],
#  ['alone',
#   'in',
#   'the',
#   'game',
#   'shows',
#   'biggest',
#   'hurdles',
#   'for',
#   'lgbtq',
#   'athletes',
#   'exist',
#   'off',
#   'the',
#   'field'],
#  ['chrissy',
#   'teigen',
#   'somehow',
#   'gets',
#   'even',
#   'more',
#   'real',
#   'about',
#   'life',
#   'after',
#   'childbirth'],
#  ['suits',
#   'creator',
#   'pens',
#   'heartfelt',
#   'open',
#   'letter',
#   'about',
#   'attending',
#   'royal',
#   'wedding'],
#  ['here', 'are', 'the', 'movies', 'coming', 'to', 'netflix', 'this', 'week'],
#  ['the', 'obamas', 'are', 'coming', 'to', 'your', 'netflix', 'queue'],
#  ['sorry',
#   'ben',
#   'affleck',
#   'make',
#   'way',
#   'for',
#   'justin',
#   'therouxs',
#   'giant',
#   'rat',
#   'tattoo'],
#  ['hillary',
#   'clinton',
#   'tips',
#   'a',
#   'russian',
#   'hat',
#   'at',
#   'trump',
#   'during',
#   'yale',
#   'commencement',
#   'speech'],
#  ['giuliani',
#   'says',
#   'mueller',
#   'cant',
#   'talk',
#   'to',
#   'trump',
#   'until',
#   'trump',
#   'hears',
#   'more',
#   'about',
#   'fbi',
#   'source'],
#  ['democrats', 'plan', 'big', 'anticorruption', 'theme', 'for', 'midterms'],
#  ['kelly',
#   'clarkson',
#   'rejects',
#   'moment',
#   'of',
#   'silence',
#   'calls',
#   'for',
#   'change',
#   'at',
#   'billboard',
#   'music',
#   'awards'],
#  ['we',
#   'asked',
#   'the',
#   'american',
#   'public',
#   'to',
#   'settle',
#   '',
#   'of',
#   'the',
#   'internets',
#   'dumbest',
#   'debates'],
#  ['fox',
#   'news',
#   'viewers',
#   'really',
#   'dont',
#   'like',
#   'lifelong',
#   'republican',
#   'robert',
#   'mueller'],
#  ['trump',
#   'team',
#   'moves',
#   'to',
#   'lift',
#   'ban',
#   'on',
#   'extreme',
#   'hunting',
#   'tactics',
#   'in',
#   'alaska'],
#  ['howard',
#   'stern',
#   'tells',
#   'how',
#   'trump',
#   'sexualized',
#   'ivanka',
#   'and',
#   'makes',
#   'david',
#   'letterman',
#   'cringe'],
#  ['the',
#   'supreme',
#   'court',
#   'is',
#   'helping',
#   'companies',
#   'get',
#   'away',
#   'with',
#   'sexual',
#   'harassment'],
#  ['deadpool',
#   '',
#   'steals',
#   'no',
#   '',
#   'spot',
#   'at',
#   'the',
#   'box',
#   'office',
#   'from',
#   'avengers',
#   'infinity',
#   'war'],
#  ['did', 'westworld', 'subtly', 'tease', 'that', 'baby', 'theory'],
#  ['donald',
#   'glover',
#   'tells',
#   'ellen',
#   'about',
#   'his',
#   'full',
#   'circle',
#   'star',
#   'wars',
#   'moment',
#   'with',
#   'his',
#   'son'],
#  ['a',
#   'marvel',
#   'exec',
#   'tried',
#   'to',
#   'stop',
#   'the',
#   'most',
#   'jarring',
#   'infinity',
#   'war',
#   'death'],
#  ['jake',
#   'gyllenhaal',
#   'set',
#   'to',
#   'star',
#   'as',
#   'villain',
#   'in',
#   'spiderman',
#   'sequel'],
#  ['janet',
#   'jackson',
#   'becomes',
#   'first',
#   'black',
#   'woman',
#   'to',
#   'receive',
#   'billboard',
#   'icon',
#   'award'],
#  ['this',
#   'isnt',
#   'pakistan',
#   'bitch',
#   'video',
#   'captures',
#   'drivers',
#   'racist',
#   'rant'],
#  ['the',
#   'grey',
#   'gardens',
#   'ladies',
#   'were',
#   'the',
#   'unwitting',
#   'godmothers',
#   'of',
#   'reality',
#   'tv',
#   'archetypes'],
#  ['yearold',
#   'boy',
#   'is',
#   'a',
#   'superhero',
#   'to',
#   'alabamas',
#   'homeless',
#   'population'],
#  ['john',
#   'oliver',
#   'has',
#   'the',
#   'best',
#   'time',
#   'mocking',
#   'the',
#   'royal',
#   'wedding'],
#  ['john',
#   'oliver',
#   'needles',
#   'the',
#   'dangerously',
#   'unregulated',
#   'rehab',
#   'industry'],
#  ['jemele',
#   'hill',
#   'honored',
#   'as',
#   'nabjs',
#   'journalist',
#   'of',
#   'the',
#   'year'],
#  ['french',
#   'digital',
#   'minister',
#   'comes',
#   'out',
#   'as',
#   'gay',
#   'to',
#   'fight',
#   'homophobia'],
#  ['belgian',
#   'transgender',
#   'ballet',
#   'drama',
#   'wins',
#   'big',
#   'at',
#   'cannes',
#   'film',
#   'festival'],
#  ['yearold',
#   'gay',
#   'man',
#   'proves',
#   'youre',
#   'never',
#   'too',
#   'old',
#   'to',
#   'attend',
#   'your',
#   'first',
#   'pride'],
#  ['super',
#   'pacs',
#   'that',
#   'meddled',
#   'in',
#   'west',
#   'virginias',
#   'senate',
#   'primary',
#   'didnt',
#   'receive',
#   'a',
#   'penny',
#   'from',
#   'west',
#   'virginians'],
#  ['airline',
#   'passenger',
#   'arrested',
#   'after',
#   'allegedly',
#   'harassing',
#   'woman',
#   'and',
#   'peeing',
#   'on',
#   'seat'],
#  ['mike',
#   'pompeo',
#   'promises',
#   'to',
#   'crush',
#   'iran',
#   'and',
#   'achieve',
#   'a',
#   'better',
#   'deal'],
#  ['',
#   'majestic',
#   'islands',
#   'in',
#   'europe',
#   'that',
#   'most',
#   'tourists',
#   'dont',
#   'know',
#   'about',
#   'yet'],
#  ['cuba',
#   'confirms',
#   '',
#   'killed',
#   'in',
#   'countrys',
#   'deadliest',
#   'plane',
#   'crash',
#   'since',
#   ''],
#  ['us',
#   'china',
#   'putting',
#   'trade',
#   'war',
#   'on',
#   'hold',
#   'treasurys',
#   'steve',
#   'mnuchin',
#   'says'],
#  ['trumps',
#   'top',
#   'economic',
#   'adviser',
#   'says',
#   'amazon',
#   'threats',
#   'are',
#   'not',
#   'in',
#   'my',
#   'lane'],
#  ['dems',
#   'trump',
#   'admin',
#   'find',
#   'common',
#   'ground',
#   'helping',
#   'victims',
#   'of',
#   'myanmars',
#   'genocide'],
#  ['giuliani',
#   'says',
#   'mueller',
#   'will',
#   'wrap',
#   'up',
#   'trump',
#   'obstruction',
#   'probe',
#   'by',
#   'september',
#   'report'],
#  ['german',
#   'broadcaster',
#   'criticized',
#   'for',
#   'racist',
#   'coverage',
#   'of',
#   'royal',
#   'wedding'],
#  ['kathryn',
#   'newton',
#   'the',
#   'boldest',
#   'teen',
#   'on',
#   'tv',
#   'is',
#   'ready',
#   'to',
#   'grow',
#   'up'],
#  ['stephanie', 'kelton', 'has', 'the', 'biggest', 'idea', 'in', 'washington'],
#  ['texas',
#   'govs',
#   'campaign',
#   'cancels',
#   'shotgun',
#   'giveaway',
#   'after',
#   'santa',
#   'fe',
#   'school',
#   'shooting'],
#  ['tina',
#   'feys',
#   'sarah',
#   'palin',
#   'leads',
#   'snl',
#   'chorus',
#   'lamenting',
#   'what',
#   'i',
#   'did',
#   'for',
#   'trump'],
#  ['after',
#   'day',
#   'of',
#   'american',
#   'gushing',
#   'snl',
#   'goes',
#   'smart',
#   'aleck',
#   'on',
#   'the',
#   'royal',
#   'wedding'],
#  ['starbucks',
#   'says',
#   'anyone',
#   'can',
#   'now',
#   'sit',
#   'in',
#   'its',
#   'cafes',
#   '',
#   'even',
#   'without',
#   'buying',
#   'anything'],
#  ['alec',
#   'baldwins',
#   'trump',
#   'faces',
#   'ominous',
#   'sopranos',
#   'scenario',
#   'in',
#   'snl',
#   'finale'],
#  ['asia',
#   'argentos',
#   'fiery',
#   'speech',
#   'closes',
#   'cannes',
#   'i',
#   'was',
#   'raped',
#   'by',
#   'harvey',
#   'weinstein',
#   'here'],
#  ['tina',
#   'fey',
#   'tries',
#   'out',
#   'for',
#   'mean',
#   'girls',
#   'the',
#   'musical',
#   'on',
#   'snl'],
#  ['parents',
#   'of',
#   'school',
#   'shooting',
#   'victims',
#   'decry',
#   'moronic',
#   'gop',
#   'platitudes'],
#  ['trump',
#   'real',
#   'americans',
#   'should',
#   'get',
#   'tough',
#   'on',
#   'russia',
#   'probe'],
#  ['chrissy',
#   'teigen',
#   'john',
#   'legend',
#   'announce',
#   'name',
#   'of',
#   'baby',
#   'boy',
#   'with',
#   'adorable',
#   'photo'],
#  ['texas',
#   'lt',
#   'gov',
#   'dan',
#   'patrick',
#   'touts',
#   'need',
#   'to',
#   'arm',
#   'teachers'],
#  ['david',
#   'hogg',
#   'calls',
#   'on',
#   'media',
#   'to',
#   'stop',
#   'naming',
#   'santa',
#   'fe',
#   'school',
#   'shooter'],
#  ['trump',
#   'sets',
#   'up',
#   'showdown',
#   'with',
#   'doj',
#   'over',
#   'claims',
#   'of',
#   'campaign',
#   'surveillance'],
#  ['jim',
#   'carreys',
#   'latest',
#   'painting',
#   'slams',
#   'kent',
#   'state',
#   'goldilocks',
#   'and',
#   'her',
#   'ar'],
#  ['oliver', 'north', 'blames', 'school', 'shootings', 'on', 'ritalin'],
#  ['jimmy',
#   'kimmel',
#   'tricks',
#   'royal',
#   'fans',
#   'into',
#   'reviewing',
#   'the',
#   'wedding',
#   'before',
#   'the',
#   'big',
#   'day'],
#  ['jimmy',
#   'fallon',
#   'reveals',
#   'his',
#   'viewers',
#   'biggest',
#   'wedding',
#   'fails'],
#  ['protesters',
#   'throw',
#   'a',
#   'fiesta',
#   'to',
#   'razz',
#   'lawyer',
#   'who',
#   'ranted',
#   'at',
#   'spanish',
#   'speakers'],
#  ['what',
#   'to',
#   'watch',
#   'on',
#   'amazon',
#   'prime',
#   'thats',
#   'new',
#   'this',
#   'week'],
#  ['will',
#   'ferrell',
#   'and',
#   'molly',
#   'shannon',
#   'cover',
#   'the',
#   'royal',
#   'wedding',
#   'as',
#   'cord',
#   'and',
#   'tish'],
#  ['the',
#   'artist',
#   'formerly',
#   'known',
#   'as',
#   'cedric',
#   'the',
#   'entertainer',
#   'has',
#   'arrived'],
#  ['mark',
#   'kelly',
#   'trump',
#   'rolled',
#   'over',
#   'for',
#   'nra',
#   'did',
#   'nothing',
#   'about',
#   'guns',
#   'after',
#   'parkland'],
#  ['gop',
#   'candidate',
#   'set',
#   'up',
#   'trust',
#   'that',
#   'pays',
#   'his',
#   'kids',
#   'for',
#   'marrying',
#   'white',
#   'people'],
#  ['houston',
#   'police',
#   'chief',
#   'says',
#   'hes',
#   'sick',
#   'of',
#   'inaction',
#   'on',
#   'gun',
#   'control'],
#  ['the', 'history', 'of', 'the', 'national', 'anthem', 'in', 'sports'],
#  ['bbc',
#   'trolls',
#   'president',
#   'trump',
#   'with',
#   'bigly',
#   'huge',
#   'royal',
#   'wedding',
#   'crowd'],
#  ['these',
#   'are',
#   'the',
#   'victims',
#   'of',
#   'the',
#   'santa',
#   'fe',
#   'high',
#   'school',
#   'shooting'],
#  ['this',
#   'ceo',
#   'took',
#   'a',
#   'pay',
#   'cut',
#   'to',
#   'give',
#   'employees',
#   '',
#   'a',
#   'year',
#   'now',
#   'hes',
#   'battling',
#   'amazon'],
#  ['trump',
#   'jr',
#   'met',
#   'with',
#   'emissary',
#   'for',
#   'gulf',
#   'princes',
#   'offering',
#   'help',
#   'with',
#   'campaign',
#   'in',
#   '',
#   'report'],
#  ['trump',
#   'misspells',
#   'melanias',
#   'name',
#   'in',
#   'welcome',
#   'home',
#   'tweet',
#   'twitter',
#   'roars'],
#  ['jimmy',
#   'kimmel',
#   'shreds',
#   'cowardly',
#   'trump',
#   'lawmakers',
#   'after',
#   'texas',
#   'school',
#   'shooting'],
#  ['bill',
#   'maher',
#   'reveals',
#   '',
#   'things',
#   'you',
#   'dont',
#   'know',
#   'about',
#   'michael',
#   'cohen'],
#  ['what', 'to', 'watch', 'on', 'hulu', 'thats', 'new', 'this', 'week'],
#  ['students',
#   'stage',
#   'sitin',
#   'for',
#   'gun',
#   'control',
#   'outside',
#   'paul',
#   'ryans',
#   'office',
#   'get',
#   'arrested'],
#  ['trump',
#   'knew',
#   'a',
#   'scary',
#   'amount',
#   'about',
#   'the',
#   'appearance',
#   'of',
#   'bill',
#   'gates',
#   'daughter'],
#  ['exrussian',
#   'spy',
#   'sergei',
#   'skripal',
#   'discharged',
#   'from',
#   'uk',
#   'hospital',
#   'after',
#   'poisoning',
#   'incident'],
#  ['cuba', 'plane', 'crash', 'reportedly', 'kills', 'over', ''],
#  ['trump',
#   'reassures',
#   'north',
#   'korea',
#   'but',
#   'threatens',
#   'total',
#   'decimation',
#   'without',
#   'a',
#   'deal'],
#  ['ariana',
#   'grande',
#   'gives',
#   'fans',
#   'singing',
#   'one',
#   'last',
#   'time',
#   'the',
#   'surprise',
#   'of',
#   'their',
#   'lives'],
#  ['cambridge',
#   'analytica',
#   'files',
#   'for',
#   'chapter',
#   '',
#   'bankruptcy',
#   'after',
#   'facebook',
#   'privacy',
#   'row'],
#  ['santa',
#   'fe',
#   'high',
#   'schoolers',
#   'held',
#   'gun',
#   'violence',
#   'protest',
#   '',
#   'month',
#   'before',
#   'shooting'],
#  ['michelle',
#   'wolfs',
#   'netflix',
#   'trailer',
#   'gives',
#   'us',
#   'a',
#   'closer',
#   'look',
#   'at',
#   'her',
#   'new',
#   'show'],
#  ['jeff',
#   'sessions',
#   'uses',
#   'exceptional',
#   'power',
#   'over',
#   'immigration',
#   'courts',
#   'to',
#   'limit',
#   'judges',
#   'authority'],
#  ['gop',
#   'rep',
#   'introduces',
#   'bill',
#   'that',
#   'would',
#   'demand',
#   'white',
#   'house',
#   'apologize',
#   'to',
#   'mccain'],
#  ['colbert',
#   'has',
#   'a',
#   'super',
#   'graphic',
#   'way',
#   'of',
#   'describing',
#   'how',
#   'deep',
#   'muellers',
#   'probe',
#   'goes',
#   'now'],
#  ['jack', 'osbournes', 'wife', 'files', 'for', 'divorce'],
#  ['meek',
#   'mill',
#   'backs',
#   'out',
#   'of',
#   'trump',
#   'event',
#   'on',
#   'prison',
#   'reform'],
#  ['new',
#   'trump',
#   'rule',
#   'would',
#   'cut',
#   'federal',
#   'funds',
#   'from',
#   'clinics',
#   'providing',
#   'abortions'],
#  ['twitter',
#   'users',
#   'joke',
#   'trump',
#   'wants',
#   'prison',
#   'reform',
#   'because',
#   'thats',
#   'where',
#   'hes',
#   'headed'],
#  ['every',
#   'single',
#   'chilean',
#   'bishop',
#   'offers',
#   'to',
#   'resign',
#   'over',
#   'countrys',
#   'sex',
#   'abuse',
#   'scandal'],
#  ['ariana',
#   'grande',
#   'calls',
#   'manchester',
#   'attack',
#   'the',
#   'worst',
#   'of',
#   'humanity',
#   'one',
#   'year',
#   'later'],
#  ['chrissy',
#   'teigen',
#   'spills',
#   'first',
#   'details',
#   'about',
#   'new',
#   'baby',
#   'boy',
#   'we',
#   'are',
#   'in',
#   'love'],
#  ['alec',
#   'baldwin',
#   'and',
#   'wife',
#   'hilaria',
#   'welcome',
# ...
#   'has',
#   'information',
#   'to',
#   'share',
#   'about',
#   'gina',
#   'haspel'],
#  ['conservative',
#   'senate',
#   'democrat',
#   'who',
#   'backs',
#   'trumps',
#   'agenda',
#   'defeats',
#   'progressive',
#   'challenger'],
#  ['taylor',
#   'swift',
#   'mightve',
#   'made',
#   'up',
#   'with',
#   'katy',
#   'perry',
#   'but',
#   'her',
#   'kimye',
#   'feud',
#   'lives',
#   'on'],
#  ['kim',
#   'kardashian',
#   'to',
#   'make',
#   'history',
#   'with',
#   'fashion',
#   'councils',
#   'first',
#   'influencer',
#   'award'],
#  ['nbc',
#   'says',
#   'it',
#   'believes',
#   'matt',
#   'lauers',
#   'accusers',
#   'after',
#   'monthslong',
#   'investigation'],
#  ['russians',
#   'had',
#   'ability',
#   'to',
#   'change',
#   'voter',
#   'data',
#   'but',
#   'didnt',
#   'report',
#   'says'],
#  ['elizabeth',
#   'warrens',
#   'pick',
#   'wins',
#   'ohios',
#   'democratic',
#   'gubernatorial',
#   'primary'],
#  ['kkk',
#   'leader',
#   'found',
#   'guilty',
#   'of',
#   'firing',
#   'gun',
#   'at',
#   'charlottesville',
#   'rally'],
#  ['protesters',
#   'decrying',
#   'torture',
#   'dragged',
#   'from',
#   'gina',
#   'haspel',
#   'senate',
#   'hearing'],
#  ['att',
#   'hired',
#   'firm',
#   'linked',
#   'to',
#   'michael',
#   'cohen',
#   'to',
#   'get',
#   'the',
#   'inside',
#   'scoop',
#   'on',
#   'trump'],
#  ['the',
#   'rnc',
#   'is',
#   'selling',
#   'sickening',
#   'donald',
#   'trumpthemed',
#   'merch',
#   'ahead',
#   'of',
#   'mothers',
#   'day'],
#  ['don',
#   'blankenships',
#   'defeat',
#   'is',
#   'a',
#   'relief',
#   'to',
#   'the',
#   'families',
#   'of',
#   'upper',
#   'big',
#   'branch',
#   'miners'],
#  ['colbert',
#   'shreds',
#   'trump',
#   'over',
#   'broken',
#   'promises',
#   'what',
#   'are',
#   'you',
#   'talking',
#   'about'],
#  ['new',
#   'us',
#   'ambassador',
#   'to',
#   'germany',
#   'offends',
#   'hosts',
#   'just',
#   'hours',
#   'into',
#   'his',
#   'first',
#   'day'],
#  ['jordan',
#   'peeles',
#   'new',
#   'nightmare',
#   'is',
#   'coming',
#   'out',
#   'next',
#   'year'],
#  ['the',
#   'backstreet',
#   'boys',
#   'dressed',
#   'as',
#   'the',
#   'spice',
#   'girls',
#   'are',
#   'larger',
#   'than',
#   'life'],
#  ['seth',
#   'meyers',
#   'decodes',
#   'teen',
#   'slang',
#   'reveals',
#   'what',
#   'giuliani',
#   'really',
#   'means'],
#  ['heres',
#   'a',
#   'look',
#   'at',
#   'orlandos',
#   'interim',
#   'pulse',
#   'nightclub',
#   'memorial'],
#  ['trevor',
#   'noah',
#   'turns',
#   'donald',
#   'trumps',
#   'knives',
#   'comment',
#   'into',
#   'reggae',
#   'magic'],
#  ['senators',
#   'force',
#   'a',
#   'vote',
#   'that',
#   'may',
#   'ultimately',
#   'reverse',
#   'fcc',
#   'restore',
#   'net',
#   'neutrality'],
#  ['ny',
#   'legislature',
#   'has',
#   'plan',
#   'in',
#   'place',
#   'to',
#   'consider',
#   'replacements',
#   'for',
#   'eric',
#   'schneiderman'],
#  ['more',
#   'than',
#   '',
#   'former',
#   'ambassadors',
#   'write',
#   'letter',
#   'opposing',
#   'gina',
#   'haspel',
#   'nomination'],
#  ['california',
#   'authority',
#   'says',
#   'states',
#   'new',
#   'homes',
#   'must',
#   'be',
#   'solar',
#   'powered'],
#  ['ny',
#   'governor',
#   'assigns',
#   'investigation',
#   'into',
#   'eric',
#   'schneiderman',
#   'abuse',
#   'allegations'],
#  ['how',
#   'the',
#   'refugee',
#   'caravan',
#   'became',
#   'a',
#   'scapegoat',
#   'for',
#   'trumps',
#   'border',
#   'crackdown'],
#  ['pennsylvania',
#   'becomes',
#   'latest',
#   'state',
#   'to',
#   'fund',
#   'urban',
#   'gun',
#   'violence',
#   'prevention'],
#  ['denver',
#   'mayors',
#   'son',
#   'caught',
#   'on',
#   'tape',
#   'berating',
#   'cop',
#   'as',
#   'a',
#   'faggot'],
#  ['progressive', 'prosecutors', 'win', 'primaries', 'in', 'north', 'carolina'],
#  ['what',
#   'did',
#   'att',
#   'and',
#   'novartis',
#   'get',
#   'for',
#   'the',
#   'money',
#   'they',
#   'paid',
#   'trumps',
#   'lawyer'],
#  ['the',
#   'hypocrisy',
#   'of',
#   'melania',
#   'trumps',
#   'online',
#   'safety',
#   'booklet',
#   'pointed',
#   'out',
#   'page',
#   'by',
#   'page'],
#  ['the',
#   'uninsured',
#   'rate',
#   'is',
#   'worsening',
#   'after',
#   'years',
#   'of',
#   'obamacares',
#   'gains'],
#  ['bernie', 'sanders', 'has', 'a', 'plan', 'to', 'revive', 'labor', 'unions'],
#  ['jim',
#   'carrey',
#   'bestows',
#   'scott',
#   'pruitt',
#   'with',
#   'a',
#   'savage',
#   'nickname',
#   'in',
#   'latest',
#   'painting'],
#  ['when', 'male', 'allies', 'become', 'abusers'],
#  ['mormon',
#   'church',
#   'to',
#   'end',
#   'its',
#   'centurylong',
#   'relationship',
#   'with',
#   'the',
#   'boy',
#   'scouts'],
#  ['our', 'snack', 'addiction', 'is', 'killing', 'orangutans'],
#  ['trumps',
#   'pick',
#   'for',
#   'cia',
#   'director',
#   'wont',
#   'say',
#   'torture',
#   'program',
#   'was',
#   'morally',
#   'wrong'],
#  ['anderson',
#   'cooper',
#   'burns',
#   'moronic',
#   'michael',
#   'cohen',
#   'over',
#   'russia',
#   'cash',
#   'claims'],
#  ['pinata',
#   'maker',
#   'apologizes',
#   'for',
#   'hanging',
#   'black',
#   'figures',
#   'in',
#   'the',
#   'likeness',
#   'of',
#   'lynchings'],
#  ['the', 'caliphate', 'of', 'trump', 'and', 'a', 'planet', 'in', 'ruins'],
#  ['a',
#   'gay',
#   'marriage',
#   'opponent',
#   'just',
#   'ousted',
#   'a',
#   'gop',
#   'incumbent',
#   'in',
#   'north',
#   'carolina'],
#  ['espn',
#   'eliminates',
#   'public',
#   'editor',
#   'role',
#   'calling',
#   'it',
#   'outdated'],
#  ['michael',
#   'cohen',
#   'was',
#   'selling',
#   'access',
#   'to',
#   'trump',
#   'says',
#   'group',
#   'that',
#   'paid',
#   'into',
#   'his',
#   'shell',
#   'company'],
#  ['mitch',
#   'mcconnell',
#   'mocks',
#   'blankenship',
#   'on',
#   'twitter',
#   'with',
#   'a',
#   'big',
#   'cloud',
#   'of',
#   'cocaine'],
#  ['exconvict',
#   'don',
#   'blankenship',
#   'loses',
#   'to',
#   'patrick',
#   'morrisey',
#   'in',
#   'west',
#   'virginia',
#   'senate',
#   'race'],
#  ['ohio', 'voters', 'pass', 'gerrymandering', 'reform', 'measure'],
#  ['trumps', 'iran', 'deal', 'exit', 'is', 'a', 'win', 'for', 'russia'],
#  ['cynthia',
#   'nixon',
#   'wants',
#   'new',
#   'yorkers',
#   'to',
#   'vote',
#   'for',
#   'the',
#   'homo',
#   'not',
#   'for',
#   'the',
#   'cuomo'],
#  ['ontario',
#   'canada',
#   'just',
#   'issued',
#   'its',
#   'first',
#   'nonbinary',
#   'birth',
#   'certificate'],
#  ['child',
#   'sexual',
#   'predator',
#   'roman',
#   'polanski',
#   'calls',
#   'me',
#   'too',
#   'movement',
#   'total',
#   'hypocrisy'],
#  ['this',
#   'is',
#   'america',
#   'producer',
#   'reveals',
#   'new',
#   'details',
#   'about',
#   'childish',
#   'gambinos',
#   'viral',
#   'video'],
#  ['terry',
#   'crews',
#   'black',
#   'men',
#   'arent',
#   'allowed',
#   'to',
#   'be',
#   'victims',
#   'until',
#   'theyre',
#   'dead'],
#  ['donald',
#   'glovers',
#   'this',
#   'is',
#   'america',
#   'through',
#   'the',
#   'eyes',
#   'of',
#   'a',
#   'jim',
#   'crow',
#   'historian'],
#  ['fox',
#   'news',
#   'judicial',
#   'analyst',
#   'issues',
#   'dark',
#   'warning',
#   'to',
#   'trump',
#   'over',
#   'michael',
#   'cohen'],
#  ['black',
#   'women',
#   'bishops',
#   'are',
#   'making',
#   'history',
#   'in',
#   'this',
#   'predominantly',
#   'white',
#   'church'],
#  ['geena',
#   'davis',
#   'and',
#   'th',
#   'husband',
#   'reza',
#   'jarrahy',
#   'are',
#   'divorcing'],
#  ['pauley',
#   'perrettes',
#   'abby',
#   'has',
#   'heartwrenching',
#   'farewell',
#   'on',
#   'ncis'],
#  ['lethal',
#   'weapon',
#   'fires',
#   'clayne',
#   'crawford',
#   'and',
#   'his',
#   'character',
#   'gets',
#   'shot'],
#  ['selena',
#   'gomez',
#   'pokes',
#   'fun',
#   'at',
#   'her',
#   'met',
#   'gala',
#   'spray',
#   'tan',
#   'mishap'],
#  ['protest',
#   'leader',
#   'nikol',
#   'pashinian',
#   'elected',
#   'prime',
#   'minister',
#   'of',
#   'armenia'],
#  ['kim', 'jong', 'un', 'secretly', 'met', 'with', 'xi', 'jinping', 'again'],
#  ['netanyahus',
#   'bombastic',
#   'iran',
#   'claims',
#   'found',
#   'a',
#   'perfect',
#   'audience',
#   'in',
#   'trump'],
#  ['netanyahus',
#   'chef',
#   'blasted',
#   'for',
#   'serving',
#   'japans',
#   'prime',
#   'minister',
#   'dessert',
#   'in',
#   'a',
#   'shoe'],
#  ['world',
#   'leaders',
#   'condemn',
#   'trump',
#   'for',
#   'withdrawing',
#   'from',
#   'iran',
#   'nuclear',
#   'deal'],
#  ['senate',
#   'republicans',
#   'shun',
#   'don',
#   'blankenship',
#   'on',
#   'day',
#   'of',
#   'west',
#   'virginia',
#   'primary'],
#  ['new',
#   'yorks',
#   'harvey',
#   'weinstein',
#   'probe',
#   'set',
#   'to',
#   'continue',
#   'despite',
#   'attorney',
#   'generals',
#   'exit'],
#  ['trump',
#   'to',
#   'announce',
#   'whether',
#   'us',
#   'will',
#   'break',
#   'the',
#   'iran',
#   'nuclear',
#   'deal'],
#  ['politicians',
#   'call',
#   'for',
#   'schneiderman',
#   'to',
#   'resign',
#   'over',
#   'physical',
#   'abuse',
#   'allegations'],
#  ['joe',
#   'scarborough',
#   'trumps',
#   'legal',
#   'strategy',
#   'is',
#   'like',
#   'a',
#   'monkey',
#   'throwing',
#   'poo',
#   'against',
#   'the',
#   'wall'],
#  ['kirsten', 'dunst', 'and', 'jesse', 'plemons', 'welcome', 'baby', 'boy'],
#  ['holy',
#   'matrimony',
#   'there',
#   'was',
#   'a',
#   'proposal',
#   'at',
#   'the',
#   'met',
#   'gala'],
#  ['nordstrom',
#   'rack',
#   'president',
#   'apologizes',
#   'after',
#   'store',
#   'accuses',
#   'three',
#   'black',
#   'men',
#   'of',
#   'theft'],
#  ['giuliani',
#   'says',
#   'trump',
#   'lawyer',
#   'michael',
#   'cohen',
#   'has',
#   'no',
#   'incriminating',
#   'information',
#   'about',
#   'the',
#   'president'],
#  ['lena',
#   'waithe',
#   'stuns',
#   'at',
#   'met',
#   'gala',
#   'as',
#   'a',
#   'queer',
#   'superhero'],
#  ['r',
#   'kelly',
#   'accusers',
#   'say',
#   'they',
#   'had',
#   'to',
#   'ask',
#   'permission',
#   'to',
#   'use',
#   'the',
#   'bathroom'],
#  ['trump',
#   'reportedly',
#   'tells',
#   'macron',
#   'hes',
#   'pulling',
#   'out',
#   'of',
#   'iran',
#   'nuclear',
#   'deal'],
#  ['how',
#   'the',
#   'deportation',
#   'crackdown',
#   'is',
#   'hurting',
#   'immigrant',
#   'victims',
#   'of',
#   'crime'],
#  ['seth',
#   'meyers',
#   'says',
#   'michael',
#   'cohen',
#   'tried',
#   'to',
#   'get',
#   'him',
#   'to',
#   'apologize',
#   'onair',
#   'to',
#   'trump'],
#  ['blessing', 'you', 'with', 'the', 'best', 'met', 'gala', '', 'tweets'],
#  ['farm',
#   'bill',
#   'would',
#   'cut',
#   'food',
#   'stamps',
#   'is',
#   'friendly',
#   'to',
#   'farmers'],
#  ['what', 'to', 'know', 'about', 'the', 'iran', 'nuclear', 'deal'],
#  ['',
#   'derby',
#   'day',
#   'bet',
#   'wins',
#   'thrilled',
#   'texas',
#   'woman',
#   '',
#   'million'],
#  ['democratic',
#   'meddling',
#   'in',
#   'west',
#   'virginia',
#   'and',
#   '',
#   'other',
#   'things',
#   'to',
#   'watch',
#   'this',
#   'election',
#   'day'],
#  ['cynthia',
#   'erivos',
#   'met',
#   'gala',
#   'nails',
#   'featured',
#   'a',
#   'sistine',
#   'chapel',
#   'painting',
#   'with',
#   'black',
#   'women'],
#  ['keanu',
#   'reeves',
#   'and',
#   'alex',
#   'winter',
#   'are',
#   'coming',
#   'back',
#   'for',
#   'bill',
#   '',
#   'ted',
#   '',
#   'after',
#   '',
#   'years'],
#  ['solanges',
#   'durag',
#   'was',
#   'the',
#   'true',
#   'mvp',
#   'at',
#   'the',
#   'met',
#   'gala'],
#  ['top',
#   'house',
#   'republican',
#   'threatens',
#   'to',
#   'subpoena',
#   'trump',
#   'doj',
#   'official',
#   'over',
#   'census',
#   'citizenship',
#   'request'],
#  ['jimmy',
#   'kimmel',
#   'tries',
#   'so',
#   'hard',
#   'to',
#   'make',
#   'sense',
#   'of',
#   'rudys',
#   'latest',
#   'trump',
#   'defense',
#   'then',
#   'gives',
#   'up'],
#  ['the',
#   'religious',
#   'imagery',
#   'stitched',
#   'throughout',
#   'the',
#   '',
#   'met',
#   'gala'],
#  ['bob',
#   'marleys',
#   'granddaughter',
#   'says',
#   'cops',
#   'racially',
#   'profiled',
#   'her',
#   'while',
#   'checking',
#   'out',
#   'of',
#   'airbnb'],
#  ['melania',
#   'trump',
#   'called',
#   'out',
#   'for',
#   'antibullying',
#   'campaign',
#   'that',
#   'ignores',
#   'her',
#   'husbands',
#   'actions'],
#  ['trevor',
#   'noah',
#   'watching',
#   'rudy',
#   'giuliani',
#   'is',
#   'like',
#   'smoking',
#   'weed',
#   'through',
#   'the',
#   'tv'],
#  ['janet',
#   'jackson',
#   'to',
#   'receive',
#   'icon',
#   'award',
#   'at',
#   '',
#   'billboard',
#   'music',
#   'awards'],
#  ['white',
#   'house',
#   'prepares',
#   'to',
#   'send',
#   'congress',
#   '',
#   'billion',
#   'spending',
#   'cuts',
#   'package'],
#  ['this',
#   'jared',
#   'kushnerbacked',
#   'bill',
#   'could',
#   'be',
#   's',
#   'last',
#   'shot',
#   'at',
#   'federal',
#   'prison',
#   'reform'],
#  ['george',
#   'zimmerman',
#   'accused',
#   'of',
#   'stalking',
#   'detective',
#   'working',
#   'on',
#   'trayvon',
#   'martin',
#   'film'],
#  ['passengers',
#   'lashing',
#   'out',
#   'at',
#   'scott',
#   'pruitt',
#   'justify',
#   'firstclass',
#   'travel',
#   'new',
#   'epa',
#   'memo',
#   'says'],
#  ['this',
#   'trump',
#   'country',
#   'house',
#   'district',
#   'just',
#   'became',
#   'a',
#   'key',
#   'progressive',
#   'battleground'],
#  ['mike',
#   'pences',
#   'brother',
#   'wins',
#   'primary',
#   'race',
#   'for',
#   'vice',
#   'presidents',
#   'former',
#   'house',
#   'seat'],
#  ['marines',
#   'investigating',
#   'avowed',
#   'white',
#   'supremacist',
#   'on',
#   'active',
#   'duty'],
#  ['trump',
#   'to',
#   'violate',
#   'iran',
#   'nuclear',
#   'deal',
#   'vows',
#   'to',
#   'reimpose',
#   'sanctions'],
#  ['us',
#   'olympic',
#   'committee',
#   'ignored',
#   'sexual',
#   'abuse',
#   'complaints',
#   'against',
#   'taekwondo',
#   'stars',
#   'lawsuit'],
#  ['blake',
#   'lively',
#   'brought',
#   'her',
#   'family',
#   'to',
#   'the',
#   'met',
#   'gala',
#   'without',
#   'you',
#   'even',
#   'noticing'],
#  ['bill',
#   'oreilly',
#   'offers',
#   'to',
#   'stand',
#   'next',
#   'to',
#   'sarah',
#   'sanders',
#   'to',
#   'handle',
#   'out',
#   'of',
#   'line',
#   'reporters'],
#  ['catholic',
#   'priest',
#   'praised',
#   'as',
#   'best',
#   'dressed',
#   'dude',
#   'at',
#   'met',
#   'gala',
#   'for',
#   'just',
#   'living',
#   'his',
#   'life'],
#  ['jimmy',
#   'kimmel',
#   'says',
#   'hideandseek',
#   'genius',
#   'dog',
#   'will',
#   'heal',
#   'our',
#   'nation'],
#  ['bank',
#   'of',
#   'america',
#   'appears',
#   'to',
#   'flip',
#   'on',
#   'firearm',
#   'promise',
#   'with',
#   'loan',
#   'to',
#   'remington'],
#  ['the',
#   'gentleman',
#   'caller',
#   'presents',
#   '',
#   'queer',
#   'icons',
#   'as',
#   'youve',
#   'never',
#   'seen',
#   'them',
#   'before'],
#  ['eric', 'schneiderman', 'has', 'always', 'been', 'a', 'con', 'man'],
#  ['christiane',
#   'amanpour',
#   'heading',
#   'up',
#   'new',
#   'pbs',
#   'show',
#   'replacing',
#   'charlie',
#   'rose'],
#  ['madonna',
#   'teases',
#   'new',
#   'song',
#   'at',
#   'surprise',
#   'met',
#   'gala',
#   'performance'],
#  ['iron',
#   'man',
#   'black',
#   'widow',
#   'captain',
#   'america',
#   'thor',
#   'and',
#   'hawkeye',
#   'got',
#   'matching',
#   'tattoos'],
#  ['michael',
#   'cohen',
#   'accepted',
#   '',
#   'from',
#   'firm',
#   'tied',
#   'to',
#   'russian',
#   'oligarch',
#   'reports'],
#  ['stephen',
#   'colbert',
#   'hits',
#   'rudy',
#   'giuliani',
#   'with',
#   'a',
#   'brutal',
#   'fact',
#   'check'],
#  ['katy',
#   'perry',
#   'sends',
#   'olive',
#   'branch',
#   'to',
#   'taylor',
#   'swift',
#   'and',
#   'the',
#   'world',
#   'rejoices'],
#  ['jada',
#   'pinkett',
#   'smith',
#   'gets',
#   'real',
#   'about',
#   'dating',
#   'will',
#   'smith',
#   'while',
#   'he',
#   'was',
#   'married'],
#  ['whoops',
#   'mark',
#   'hamill',
#   'just',
#   'spilled',
#   'the',
#   'beans',
#   'on',
#   'a',
#   'major',
#   'cameo',
#   'in',
#   'han',
#   'solo',
#   'movie'],
#  ['shawn',
#   'mendes',
#   'sweetly',
#   'attended',
#   'to',
#   'hailey',
#   'baldwins',
#   'gown',
#   'at',
#   'the',
#   'met',
#   'gala'],
#  ['orrin',
#   'hatch',
#   'is',
#   'sorry',
#   'he',
#   'suggested',
#   'trump',
#   'should',
#   'be',
#   'allowed',
#   'at',
#   'john',
#   'mccains',
#   'funeral'],
#  ['seth',
#   'meyers',
#   'has',
#   'perfect',
#   'line',
#   'to',
#   'confront',
#   'donald',
#   'trumps',
#   'lies'],
#  ['police',
#   'hope',
#   'to',
#   'use',
#   'dna',
#   'to',
#   'catch',
#   'the',
#   'zodiac',
#   'killer'],
#  ['lili',
#   'reinhart',
#   'and',
#   'cole',
#   'sprouse',
#   'finally',
#   'make',
#   'couple',
#   'debut',
#   'at',
#   'met',
#   'gala'],
#  ['how',
#   'sweetbitter',
#   'captures',
#   'the',
#   'grit',
#   'and',
#   'glamour',
#   'of',
#   'the',
#   'restaurant',
#   'world'],
#  ['mitch',
#   'mcconnell',
#   'bends',
#   'the',
#   'rules',
#   'again',
#   'to',
#   'confirm',
#   'trumps',
#   'judges'],
#  ['ryan', 'zinke', 'and', 'the', 'tale', 'of', 'two', 'fish'],
#  ['ny',
#   'attorney',
#   'general',
#   'eric',
#   'schneiderman',
#   'resigns',
#   'amid',
#   'abuse',
#   'allegations'],
#  ['sanctuary',
#   'cities',
#   'are',
#   'working',
#   'in',
#   'the',
#   'trump',
#   'era',
#   'but',
#   'at',
#   'a',
#   'surprising',
#   'cost'],
#  ['shepard',
#   'smith',
#   'you',
#   'cant',
#   'say',
#   'trump',
#   'pulled',
#   'out',
#   'of',
#   'iran',
#   'deal',
#   'he',
#   'made',
#   'decision',
#   'to',
#   'violate',
#   'it'],
#  ['stormy',
#   'daniels',
#   'finds',
#   'a',
#   'crunchy',
#   'new',
#   'way',
#   'to',
#   'chip',
#   'away',
#   'at',
#   'trump'],
#  ['these',
#   'rainbow',
#   'mountains',
#   'in',
#   'peru',
#   'look',
#   'like',
#   'theyre',
#   'straight',
#   'out',
#   'of',
#   'a',
#   'dr',
#   'seuss',
#   'book'],
#  ...]

# %% [markdown]
# # Analyse de la fréquence des mots

# %%
def compute_word_occurences(texts):
    """You have to define this function yourself. """
    
    words = itertools.chain.from_iterable(texts)#Mets toutes les listes dans une liste 
    
    word_count = pd.Series(words).value_counts()
    word_count = pd.DataFrame({"Word": word_count.index, "Count": word_count.values})

    return word_count

# %%
occurences = compute_word_occurences(splitted_text).head(1000)
occurences
# Out:
#         Word  Count
# 0        the  62071
# 1         to  50125
# 2             39884
# 3         of  31923
# 4          a  31613
# ..       ...    ...
# 995   movies    274
# 996    press    273
# 997   sunday    273
# 998  experts    273
# 999   breaks    273
#
# [1000 rows x 2 columns]

# %% [markdown]
# On observe que les premiers mots sont inutiles dans le traitement à venir, on catégorise ces mots comme étant des stopwords, on décide de les supprimer.

# %% [markdown]
# # Suppression des Stopwords
# NLTK est une plateforme de premier plan pour la création de programmes Python destinés à travailler avec des données sur le langage humain.
#
# Elle fournit des interfaces faciles à utiliser pour plus de 50 corpus et ressources lexicales telles que WordNet, ainsi qu'une suite de bibliothèques de traitement de texte pour la classification, la tokénisation, l'étymologie, le balisage, l'analyse syntaxique et le raisonnement sémantique, des wrappers pour les bibliothèques NLP industrielles, et un forum de discussion actif.
#
# NLTK a été qualifié de "merveilleux outil pour enseigner et travailler dans le domaine de la linguistique computationnelle en utilisant Python" et "d'incroyable bibliothèque pour jouer avec le langage naturel". Natural Language Processing with Python fournit une introduction pratique à la programmation pour le traitement du langage.

# %%
# Import stopwords with nltk.
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.corpus import stopwords
#Affichage des stopwords
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
stop = stopwords.words('english')

# %%
#On supprime nos stopwords du DataFrame Splitted text
the = [""," ","i", "me", "my", "myself", "we", "our","us", "ours", "ourselves", "you", "you're", "you've", "you'll", "you'd", "your", "yours", "yourself", "yourselves", "he", "him", "his", "himself", "she", "she's", "her", "hers", "herself", "it", "it's", "its", "itself", "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that","thats", "that'll", "these", "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "do", "does", "did", "doing", "a", "an", "the", "and", "but", 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't","the"]
test2=[]
for lists in splitted_text:
    for word in the:
        try:
            lists.remove(word)
        except Exception as e:
            e ="  "
splitted_text
# Out:
# [['mass', 'shootings', 'texas', 'last', 'week', 'tv'],
#  ['smith',
#   'joins',
#   'diplo',
#   'nicky',
#   'jam',
#   'world',
#   'cups',
#   'official',
#   'song'],
#  ['hugh', 'grant', 'marries', 'first', 'time', 'age'],
#  ['jim',
#   'carrey',
#   'blasts',
#   'castrato',
#   'adam',
#   'schiff',
#   'democrats',
#   'new',
#   'artwork'],
#  ['julianna',
#   'margulies',
#   'uses',
#   'donald',
#   'trump',
#   'poop',
#   'bags',
#   'pick',
#   'dog'],
#  ['morgan',
#   'freeman',
#   'devastated',
#   'sexual',
#   'harassment',
#   'claims',
#   'could',
#   'undermine',
#   'legacy'],
#  ['donald',
#   'trump',
#   'lovin',
#   'new',
#   'mcdonalds',
#   'jingle',
#   'tonight',
#   'show',
#   'bit'],
#  ['watch', 'amazon', 'prime', 'new', 'week'],
#  ['mike',
#   'myers',
#   'reveals',
#   'hed',
#   'like',
#   'fourth',
#   'austin',
#   'powers',
#   'film'],
#  ['watch', 'hulu', 'new', 'week'],
#  ['justin', 'timberlake', 'visits', 'texas', 'school', 'shooting', 'victims'],
#  ['south',
#   'korean',
#   'president',
#   'meets',
#   'north',
#   'koreas',
#   'kim',
#   'jong',
#   'un',
#   'talk',
#   'trump',
#   'summit'],
#  ['way',
#   'life',
#   'risk',
#   'remote',
#   'oystergrowing',
#   'region',
#   'called',
#   'robots'],
#  ['trumps',
#   'crackdown',
#   'immigrant',
#   'parents',
#   'puts',
#   'kids',
#   'already',
#   'strained',
#   'system'],
#  ['trumps',
#   'son',
#   'concerned',
#   'fbi',
#   'obtained',
#   'wiretaps',
#   'putin',
#   'ally',
#   'met',
#   'trump',
#   'jr'],
#  ['edward', 'snowden', 'theres', 'one', 'trump', 'loves', 'vladimir', 'putin'],
#  ['booyah',
#   'obama',
#   'photographer',
#   'hilariously',
#   'trolls',
#   'trumps',
#   'spy',
#   'claim'],
#  ['ireland',
#   'votes',
#   'repeal',
#   'abortion',
#   'amendment',
#   'landslide',
#   'referendum'],
#  ['ryan',
#   'zinke',
#   'looks',
#   'reel',
#   'back',
#   'critics',
#   'grand',
#   'pivot',
#   'to',
#   'conservation'],
#  ['trumps',
#   'scottish',
#   'golf',
#   'resort',
#   'pays',
#   'women',
#   'significantly',
#   'less',
#   'men',
#   'report'],
#  ['weird', 'fathers', 'day', 'gifts', 'dad', 'doesnt', 'know', 'wants', 'he'],
#  ['twitter', 'putstarwarsinotherfilms', 'universally', 'entertaining'],
#  ['mystery',
#   'wolflike',
#   'animal',
#   'reportedly',
#   'shot',
#   'montana',
#   'baffles',
#   'wildlife',
#   'officials'],
#  ['north', 'korea', 'still', 'open', 'talks', 'trump', 'cancels', 'summit'],
#  ['men',
#   'detonate',
#   'bomb',
#   'inside',
#   'indian',
#   'restaurant',
#   'near',
#   'toronto',
#   'authorities',
#   'say'],
#  ['thousands',
#   'travel',
#   'home',
#   'ireland',
#   'to',
#   'vote',
#   'abortion',
#   'access'],
#  ['irish',
#   'voters',
#   'set',
#   'liberalize',
#   'abortion',
#   'laws',
#   'landslide',
#   'exit',
#   'poll',
#   'signals'],
#  ['warriors',
#   'coach',
#   'steve',
#   'kerr',
#   'calls',
#   'nfl',
#   'ban',
#   'protests',
#   'fake',
#   'patriotism'],
#  ['historic',
#   'victory',
#   'barbados',
#   'elects',
#   'first',
#   'female',
#   'prime',
#   'minister'],
#  ['police',
#   'killed',
#   'least',
#   'black',
#   'americans',
#   'moment',
#   'colin',
#   'kaepernick',
#   'protested'],
#  ['jack', 'johnson', 'pardoned', 'taboo', 'sex', 'still', 'criminalized'],
#  ['bet', 'chairman', 'ceo', 'debra', 'lee', 'stepping'],
#  ['rachel', 'dolezal', 'faces', 'felony', 'charges', 'welfare', 'fraud'],
#  ['bishop',
#   'michael',
#   'curry',
#   'joins',
#   'christian',
#   'march',
#   'white',
#   'house',
#   'to',
#   'reclaim',
#   'jesus'],
#  ['kanye',
#   'west',
#   'spent',
#   'photo',
#   'whitney',
#   'houstons',
#   'bathroom',
#   'album',
#   'cover'],
#  ['morgan',
#   'freeman',
#   'dropped',
#   'marketing',
#   'campaigns',
#   'harassment',
#   'accusations'],
#  ['chinese',
#   'exclusion',
#   'act',
#   'help',
#   'understand',
#   'immigration',
#   'politics',
#   'today'],
#  ['trumps', 'new', 'magathemed', 'swimwear', 'sinks', 'twitter'],
#  ['seth',
#   'meyers',
#   'funny',
#   'regret',
#   'trump',
#   'cancels',
#   'north',
#   'korea',
#   'summit'],
#  ['colbert',
#   'wants',
#   'turn',
#   'nyc',
#   'subway',
#   'rides',
#   'new',
#   'terrible',
#   'punishment'],
#  ['man',
#   'faces',
#   'charges',
#   'pulling',
#   'knife',
#   'stun',
#   'gun',
#   'muslim',
#   'students',
#   'mcdonalds'],
#  ['jimmy',
#   'kimmel',
#   'knows',
#   'irans',
#   'supreme',
#   'leader',
#   'watches',
#   'tom',
#   'jerry'],
#  ['people', 'injured', 'indiana', 'school', 'shooting'],
#  ['people',
#   'rattled',
#   'much',
#   'nigerian',
#   'man',
#   'looks',
#   'like',
#   'chadwick',
#   'boseman'],
#  ['david', 'cross', 'proves', 'yet', 'hes', 'terrible', 'apologizing'],
#  ['sesame',
#   'street',
#   'creators',
#   'sue',
#   'makers',
#   'upcoming',
#   'adultthemed',
#   'puppet',
#   'film'],
#  ['missed', 'saddest', 'death', 'avengers', 'infinity', 'war'],
#  ['george',
#   'takei',
#   'accuser',
#   'walks',
#   'back',
#   'story',
#   'drugging',
#   'sexual',
#   'assault'],
#  ['samantha',
#   'bees',
#   'parents',
#   'think',
#   'america',
#   'basically',
#   'war',
#   'zone'],
#  ['pete',
#   'davidson',
#   'says',
#   'mental',
#   'illness',
#   'doesnt',
#   'ruin',
#   'romance'],
#  ['james', 'corden', 'adam', 'levine', 'get', 'pulled', 'carpool', 'karaoke'],
#  ['emilia', 'clarke', 'dishes', 'final', 'game', 'thrones', 'scene'],
#  ['hollywood', 'doesnt', 'need', 'difficult', 'men', 'make', 'great', 'tv'],
#  ['harvey',
#   'weinstein',
#   'accusers',
#   'say',
#   'never',
#   'thought',
#   'would',
#   'arrested'],
#  ['harvey', 'weinstein', 'turns', 'police', 'alleged', 'sex', 'crimes'],
#  ['john',
#   'mayers',
#   'weird',
#   'new',
#   'lowbudget',
#   'video',
#   'memeworthy',
#   'masterpiece'],
#  ['boba', 'fett', 'getting', 'star', 'wars', 'movie'],
#  ['trump', 'suggests', 'north', 'korea', 'summit', 'could', 'still', 'happen'],
#  ['roger',
#   'stone',
#   'pressed',
#   'damaging',
#   'emails',
#   'hillary',
#   'clinton',
#   'wikileaks',
#   'report'],
#  ['publix',
#   'suspends',
#   'contributions',
#   'nrabacked',
#   'politician',
#   'amid',
#   'protests'],
#  ['twitter',
#   'bots',
#   'may',
#   'delivered',
#   'donald',
#   'trumps',
#   'victory',
#   'research',
#   'paper',
#   'says'],
#  ['bag',
#   'wet',
#   'socks',
#   'apparently',
#   'living',
#   'white',
#   'house',
#   'press',
#   'briefing',
#   'room'],
#  ['member',
#   'farright',
#   'proud',
#   'boys',
#   'menaced',
#   'a',
#   'twitter',
#   'user',
#   'doorstep'],
#  ['things', 'nra', 'blamed', 'the', 'texas', 'school', 'shooting'],
#  ['heres', 'happens', 'catholic', 'hospital', 'wont', 'try', 'save'],
#  ['trumps',
#   'new',
#   'executive',
#   'orders',
#   'make',
#   'easier',
#   'fire',
#   'federal',
#   'workers'],
#  ['monsanto', 'bayer', 'set', 'merge', 'heres', 'care'],
#  ['joy', 'watching', 'harvey', 'weinsteins', 'perp', 'walk'],
#  ['funniest', 'tweets', 'women', 'week'],
#  ['queer',
#   'eye',
#   'star',
#   'bobby',
#   'berk',
#   'gave',
#   'desk',
#   'makeover',
#   'incredible'],
#  ['older', 'gay', 'men', 'try', 'new', 'gay', 'slang', 'hilarious', 'video'],
#  ['rupauls',
#   'drag',
#   'race',
#   'teaching',
#   'straight',
#   'people',
#   'queer',
#   'culture'],
#  ['fish', 'market', 'buys', 'freedom', 'fred', 'pound', 'octopus'],
#  ['north',
#   'korea',
#   'threatens',
#   'call',
#   'trump',
#   'summit',
#   'warns',
#   'nuclear',
#   'showdown'],
#  ['investigation', 'finds', 'russian', 'missile', 'shot', 'flight', 'mh'],
#  ['north',
#   'korea',
#   'demolishes',
#   'tunnels',
#   'nuclear',
#   'test',
#   'site',
#   'reports',
#   'say'],
#  ['kim',
#   'jong',
#   'un',
#   'baited',
#   'trump',
#   'canceling',
#   'north',
#   'korea',
#   'summit'],
#  ['michelle', 'obama', 'reveals', 'cover', 'upcoming', 'memoir', 'becoming'],
#  ['late',
#   'night',
#   'writers',
#   'breathless',
#   'royal',
#   'wedding',
#   'recap',
#   'one',
#   'need'],
#  ['morgan',
#   'freeman',
#   'accused',
#   'inappropriate',
#   'behavior',
#   'sexual',
#   'harassment'],
#  ['jets',
#   'chairman',
#   'christopher',
#   'johnson',
#   'wont',
#   'fine',
#   'players',
#   'anthem',
#   'protests'],
#  ['andy', 'cohen', 'taylor', 'swift', 'katy', 'perry', 'drama'],
#  ['infinity',
#   'war',
#   'writers',
#   'try',
#   'clear',
#   'marvels',
#   'problematic',
#   'timeline'],
#  ['david',
#   'blaine',
#   'chews',
#   'glass',
#   'lets',
#   'james',
#   'corden',
#   'puncture',
#   'cheek'],
#  ['amy', 'poehler', 'parks', 'recreation', 'revival', 'would', 'amazing'],
#  ['colbert',
#   'exposes',
#   'the\xa0biggest',
#   'flaw',
#   'trumps',
#   'latest',
#   'conspiracy',
#   'theory'],
#  ['seth',
#   'meyers',
#   'gives',
#   'donald',
#   'trump',
#   'valuable',
#   'marketing',
#   'advice'],
#  ['launches',
#   'auto',
#   'import',
#   'probe',
#   'china',
#   'vows',
#   'defend',
#   'interests'],
#  ['women', 'pulled', 'stops', 'land', 'dream', 'job'],
#  ['wife',
#   'asked',
#   'husband',
#   'fenty',
#   'highlighter',
#   'got',
#   'pack',
#   'highlighters',
#   'hairbrush'],
#  ['trump',
#   'roasted',
#   'rushing',
#   'defend',
#   'tomi',
#   'lahren',
#   'ignoring',
#   'real',
#   'victims'],
#  ['trump',
#   'abruptly',
#   'cancels',
#   'north',
#   'korea',
#   'summit',
#   'kim',
#   'jong',
#   'un'],
#  ['devin',
#   'nuneslinked',
#   'winery',
#   'faced',
#   'suit',
#   'alleged',
#   'coke',
#   'prostitute',
#   'yacht',
#   'party'],
#  ['immigrant',
#   'children',
#   'accuse',
#   'border',
#   'patrol',
#   'abuse',
#   'neglect',
#   'report',
#   'shows'],
#  ['irelands',
#   'historic',
#   'vote',
#   'legalizing',
#   'abortion',
#   'haunted',
#   'trump',
#   'brexit'],
#  ['trump',
#   'lawyer',
#   'attended',
#   'doj',
#   'meeting',
#   'confidential',
#   'fbi',
#   'informant'],
#  ['senate',
#   'advances',
#   'court',
#   'pick',
#   'said',
#   'planned',
#   'parenthood',
#   'kills',
#   'females',
#   'year'],
#  ['rudy',
#   'giuliani',
#   'trump',
#   'wont',
#   'interview',
#   'mueller',
#   'get',
#   'spygate',
#   'report'],
#  ['kentucky', 'attorney', 'running', 'judge', 'dies', 'day', 'primary', 'win'],
#  ['chrissy',
#   'teigen',
#   'taunts',
#   'donald',
#   'trump',
#   'twitter',
#   'blocking',
#   'ruling'],
#  ['koch', 'network', 'going', 'one', 'trumps', 'favorite', 'congressmen'],
#  ['trump', 'posthumously', 'pardons', 'boxer', 'jack', 'johnson'],
#  ['ellen',
#   'tears',
#   'ashton',
#   'kutcher',
#   'donates',
#   'million',
#   'wildlife',
#   'fund'],
#  ['ariana',
#   'grande',
#   'reveals',
#   'bee',
#   'tattoo',
#   'honor',
#   'manchester',
#   'attack'],
#  ['kim',
#   'kardashian',
#   'wished',
#   'kanye',
#   'west',
#   'happy',
#   'anniversary',
#   'fine',
#   'pretty',
#   'cute'],
#  ['chris',
#   'hemsworth',
#   'dances',
#   'wrecking',
#   'ball',
#   'kids',
#   'living',
#   'room'],
#  ['moses',
#   'farrow',
#   'defends',
#   'woody',
#   'allen',
#   'accuses',
#   'mia',
#   'farrow',
#   'abuse'],
#  ['gwyneth',
#   'paltrow',
#   'says',
#   'brad',
#   'pitt',
#   'threatened',
#   'kill',
#   'harvey',
#   'weinstein'],
#  ['stephen', 'king', 'reveals', 'donald', 'trump', 'blocked', 'twitter'],
#  ['fans',
#   'back',
#   'jessica',
#   'walter',
#   'addressed',
#   'verbal',
#   'harassment',
#   'jeffrey',
#   'tambor'],
#  ['jessica',
#   'walter',
#   'discusses',
#   'jeffrey',
#   'tambors',
#   'alleged',
#   'harassment',
#   'male',
#   'costars',
#   'brush'],
#  ['harvey', 'weinstein', 'expected', 'turn', 'to', 'nypd', 'sex', 'crimes'],
#  ['samantha', 'bee', 'torches', 'ice', 'lets', 'shut', 'fk'],
#  ['scott',
#   'pruitt',
#   'twice',
#   'introduced',
#   'antiabortion',
#   'bills',
#   'giving',
#   'men',
#   'property',
#   'rights',
#   'fetuses'],
#  ['twitter',
#   'critics',
#   'mercilessly',
#   'mock',
#   'trump',
#   'canceling',
#   'summit',
#   'kim'],
#  ['civil',
#   'rights',
#   'groups',
#   'rip',
#   'senate',
#   'bill',
#   'revising',
#   'sexual',
#   'harassment',
#   'policy'],
#  ['alabama',
#   'sues',
#   'exclude',
#   'undocumented',
#   'immigrants',
#   'census',
#   'count'],
#  ['cynthia',
#   'nixon',
#   'vows',
#   'keep',
#   'fighting',
#   'predictably',
#   'losing',
#   'party',
#   'endorsement'],
#  ['white',
#   'house',
#   'officials',
#   'reportedly',
#   'considered',
#   'ignoring',
#   'new',
#   'climate',
#   'research'],
#  ['read',
#   'trumps',
#   'letter',
#   'kim',
#   'jong',
#   'un',
#   'canceling',
#   'north',
#   'korea',
#   'summit'],
#  ['south',
#   'korea',
#   'responds',
#   'trumps',
#   'sudden',
#   'cancellation',
#   'kim',
#   'jong',
#   'un',
#   'summit'],
#  ['facebooks',
#   'new',
#   'ad',
#   'rules',
#   'prove',
#   'basically',
#   'charge',
#   'regulating',
#   'elections'],
#  ['border', 'agent', 'fatally', 'shoots', 'migrant', 'woman', 'texas'],
#  ['trump', 'opens', 'door', 'gun', 'industry', 'sell', 'firearms', 'abroad'],
#  ['stormy',
#   'daniels',
#   'day',
#   'declared',
#   'west',
#   'hollywood',
#   'adult',
#   'star',
#   'gets',
#   'key',
#   'city'],
#  ['youre', 'going', 'use', 'selfcheckout', 'machine', 'whether', 'like'],
#  ['ways', 'make', 'family', 'road', 'trips', 'easier', 'parents', 'whove'],
#  ['jake',
#   'tapper',
#   'shreds',
#   'donald',
#   'trump',
#   'long',
#   'list',
#   'conspiracy',
#   'theories'],
#  ['new', 'york', 'daily', 'news', 'rips', 'nfl', 'anthem', 'kneeling', 'ban'],
#  ['judge',
#   'ruled',
#   'one',
#   'immigrant',
#   'a',
#   'right',
#   'a',
#   'hearing',
#   'others'],
#  ['house',
#   'democrats',
#   'offer',
#   'internships',
#   'students',
#   'affected',
#   'gun',
#   'violence'],
#  ['tig', 'notaro', 'tells', 'ellen', 'degeneres', 'sons', 'passion', 'trash'],
#  ['stormy',
#   'daniels',
#   'thanks',
#   'wonderful',
#   'gay',
#   'dads',
#   'west',
#   'hollywood',
#   'hands',
#   'keys',
#   'city'],
#  ['believe', 'queer', 'eye', 'season', 'drops', 'next', 'month'],
#  ['gay',
#   'man',
#   'denied',
#   'marriage',
#   'license',
#   'kim',
#   'davis',
#   'loses',
#   'bid',
#   'unseat'],
#  ['anna', 'kournikova', 'dancing', 'bouncing', 'baby', 'cutest', 'thing'],
#  ['trump',
#   'says',
#   'nfl',
#   'players',
#   'unwilling',
#   'stand',
#   'anthem',
#   'maybe',
#   'shouldnt',
#   'country'],
#  ['facebook',
#   'accused',
#   'reading',
#   'texts',
#   'accessing',
#   'microphones',
#   'lawsuit'],
#  ['selfdriving', 'uber', 'fatal', 'accident', 'seconds', 'react', 'crash'],
#  ['amazon', 'admits', 'alexa', 'device', 'eavesdropped', 'portland', 'family'],
#  ['man', 'discovers', 'handgun', 'impaled', 'front', 'bumper', 'car'],
#  ['rescue',
#   'cat',
#   'hilarious',
#   'wideeyed',
#   'expression',
#   'scan',
#   'confirms',
#   'pregnant'],
#  ['weirdest', 'promposals', 'include', 'teen', 'faked', 'birth'],
#  ['trump', 'american', 'far', 'right', 'stoke', 'hate', 'canada'],
#  ['farright',
#   'antiestablishment',
#   'parties',
#   'set',
#   'form',
#   'italys',
#   'new',
#   'government'],
#  ['sarah',
#   'silverman',
#   'sees',
#   'reason',
#   'louis',
#   'ck',
#   'cant',
#   'continue',
#   'artist'],
#  ['southern',
#   'baptist',
#   'leader',
#   'said',
#   'abused',
#   'women',
#   'pray',
#   'removed',
#   'post'],
#  ['americans', 'ever', 'support', 'samesex', 'marriage'],
#  ['brynn', 'cartelli', 'becomes', 'youngestever', 'winner', 'voice'],
#  ['betsy',
#   'devos',
#   'stirs',
#   'uproar',
#   'saying',
#   'schools',
#   'call',
#   'ice',
#   'undocumented',
#   'kids'],
#  ['sandy',
#   'hook',
#   'families',
#   'fbi',
#   'agent',
#   'sue',
#   'alex',
#   'jones',
#   'defamation'],
#  ['high',
#   'school',
#   'teacher',
#   'defeats',
#   'kentucky',
#   'house',
#   'majority',
#   'leader',
#   'gop',
#   'primary'],
#  ['lupe',
#   'valdez',
#   'makes',
#   'history',
#   'texas',
#   'winning',
#   'democratic',
#   'nod',
#   'governor'],
#  ['report',
#   'michael',
#   'cohens',
#   'business',
#   'partner',
#   'cooperating',
#   'prosecutors'],
#  ['brandi',
#   'chastain',
#   'totally',
#   'agrees',
#   'hall',
#   'fame',
#   'plaque',
#   'looks',
#   'nothing',
#   'like',
#   'her'],
#  ['scientists',
#   'turn',
#   'dna',
#   'technology',
#   'to',
#   'search',
#   'loch',
#   'ness',
#   'monster'],
#  ['late',
#   'night',
#   'writer',
#   'vows',
#   'take',
#   'red',
#   'hats',
#   'back',
#   'trump',
#   'supporters'],
#  ['julia',
#   'louisdreyfus',
#   'receive',
#   'mark',
#   'twain',
#   'prize',
#   'american',
#   'humor'],
#  ['michelle',
#   'obama',
#   'shares',
#   'intimate',
#   'wedding',
#   'photo',
#   'tribute',
#   'husband',
#   'barack'],
#  ['spot',
#   'trevor',
#   'noah',
#   'black',
#   'panther',
#   'daily',
#   'show',
#   'hosts',
#   'stealth',
#   'cameo',
#   'revealed'],
#  ['donald',
#   'glover',
#   'fans',
#   'execute',
#   'stunning',
#   'coup',
#   'donald',
#   'trumpthemed',
#   'reddit',
#   'forum'],
#  ['ti',
#   'calls',
#   'boycott',
#   'restaurant',
#   'offduty',
#   'cop',
#   'allegedly',
#   'assaults',
#   'black',
#   'women'],
#  ['survivor',
#   'rwandan',
#   'genocide',
#   'countrys',
#   'first',
#   'female',
#   'neurosurgeon'],
#  ['stacey', 'abrams', 'wins', 'democratic', 'primary', 'georgia', 'governor'],
#  ['trevor',
#   'noah',
#   'reveals',
#   'question',
#   'hed',
#   'ask',
#   'donald',
#   'trump',
#   'else',
#   'dared'],
#  ['michelle',
#   'obama',
#   'reflects',
#   'scary',
#   'time',
#   'princeton',
#   'sweet',
#   'throwback',
#   'snap'],
#  ['reasons', 'started', 'conversation', 'whos', 'responsible', 'finishing'],
#  ['lourdes',
#   'leon',
#   'gives',
#   'major',
#   'madonna',
#   'vibes',
#   'moody',
#   'new',
#   'ad',
#   'campaign',
#   'pics'],
#  ['ways', 'netflix', 'tricks', 'watching', 'shows', 'movies'],
#  ['brad',
#   'pitt',
#   'made',
#   'ryan',
#   'reynolds',
#   'one',
#   'demeaning',
#   'thing',
#   'exchange',
#   'deadpool',
#   'cameo'],
#  ['robert', 'de', 'niro', 'bans', 'trump', 'every', 'nobu', 'restaurant'],
#  ['ariana',
#   'grande',
#   'shuts',
#   'fan',
#   'blaming',
#   'heartbreaking',
#   'mac',
#   'miller',
#   'split'],
#  ['parents',
#   'slam',
#   'show',
#   'dogs',
#   'scenes',
#   'grooming',
#   'children',
#   'sexual',
#   'abuse'],
#  ['dave',
#   'grohl',
#   'wants',
#   'apologize',
#   'to',
#   'world',
#   'massive',
#   'jerk',
#   'trump'],
#  ['emilia',
#   'clarke',
#   'introduced',
#   'prince',
#   'william',
#   'pretty',
#   'embarrassing',
#   'way'],
#  ['sarah',
#   'paulson',
#   'takes',
#   'impressions',
#   'next',
#   'level',
#   'tonight',
#   'show'],
#  ['bs', 'still', 'ready', 'party', 'taken', 'seriously'],
#  ['gina',
#   'ortiz',
#   'jones',
#   'wins',
#   'democratic',
#   'runoff',
#   'texas',
#   'congressional',
#   'race'],
#  ['fighter',
#   'pilot',
#   'amy',
#   'mcgrath',
#   'wins',
#   'democratic',
#   'primary',
#   'kentucky',
#   'swing',
#   'district'],
#  ['trump', 'rallies', 'conservatives', 'promise', 'abortion', 'curbs'],
#  ['aclu', 'suing', 'strike', 'ohios', 'congressional', 'map'],
#  ['latest',
#   'school',
#   'shooting',
#   'hasnt',
#   'really',
#   'stirred',
#   'gun',
#   'debate'],
#  ['donald',
#   'trump',
#   'tweet',
#   'rescues',
#   'roseanne',
#   'family',
#   'season',
#   'finale'],
#  ['ellen', 'grills', 'mark', 'wahlberg', 'shirtless', 'instagram', 'selfies'],
#  ['idris', 'elba', 'star', 'new', 'hunchback', 'notre', 'dame', 'netflix'],
#  ['maryland',
#   'police',
#   'charge',
#   'church',
#   'leaders',
#   'past',
#   'abuse',
#   'atrisk',
#   'teen',
#   'girls'],
#  ['nfl', 'bans', 'kneeling', 'national', 'anthem'],
#  ['conan', 'obrien', 'muscles', 'royal', 'wedding', 'spoof', 'ads'],
#  ['house', 'republicans', 'report', 'progress', 'immigration', 'deal'],
#  ['democrats',
#   'werent',
#   'invited',
#   'review',
#   'classified',
#   'documents',
#   'fbi',
#   'informant'],
#  ['gop',
#   'candidate',
#   'pointed',
#   'gun',
#   'teenager',
#   'advances',
#   'georgia',
#   'governor',
#   'primary',
#   'runoff'],
#  ['walking',
#   'definition',
#   'entitled',
#   'millennial',
#   'swears',
#   'hes',
#   'an',
#   'entitled',
#   'millennial'],
#  ['democrats',
#   'push',
#   'included',
#   'classified',
#   'briefing',
#   'fbi',
#   'informant'],
#  ['machines',
#   'dont',
#   'always',
#   'steal',
#   'jobs',
#   'increasingly',
#   'rob',
#   'our',
#   'work',
#   'humanity'],
#  ['trump',
#   'praises',
#   'tomi',
#   'lahren',
#   'restaurant',
#   'crowd',
#   'tosses',
#   'water',
#   'insults'],
#  ['sarah', 'sanders', 'bothers', 'called', 'liar'],
#  ['trump',
#   'blocking',
#   'people',
#   'twitter',
#   'unconstitutional',
#   'judge',
#   'rules'],
#  ['mostly',
#   'nonchristian',
#   'militia',
#   'iraqi',
#   'christians',
#   'parliamentary',
#   'seats',
#   'christians',
#   'want',
#   'trump',
#   'intervene'],
#  ['tulsi',
#   'gabbards',
#   'syria',
#   'views',
#   'cost',
#   'support',
#   'hawaii',
#   'teachers',
#   'union'],
#  ['jared', 'kushner', 'received', 'security', 'clearance', 'reports'],
#  ['arizona',
#   'gop',
#   'congressional',
#   'candidate',
#   'compares',
#   'abortion',
#   'holocaust'],
#  ['gun',
#   'reform',
#   'advocate',
#   'lucy',
#   'mcbath',
#   'heads',
#   'runoff',
#   'georgia',
#   'house',
#   'seat'],
#  ['star',
#   'wars',
#   'burlesque',
#   'show',
#   'storms',
#   'west',
#   'coast',
#   'sexy',
#   'stormtroopers'],
#  ['establishmentbacked',
#   'moderate',
#   'wins',
#   'heated',
#   'democratic',
#   'house',
#   'primary',
#   'texas'],
#  ['senators', 'unveil', 'bill', 'crack', 'sexual', 'harassment'],
#  ['trips', 'take', 'new', 'york', 'city', 'long', 'weekend'],
#  ['disney',
#   'reveals',
#   'opening',
#   'seasons',
#   'star',
#   'wars',
#   'theme',
#   'park',
#   'lands'],
#  ['latest', 'entries', 'comedy', 'wildlife', 'photo', 'awards', 'cheer'],
#  ['bad', 'lip', 'reading', 'reveals', 'really', 'said', 'royal', 'wedding'],
#  ['australian',
#   'archbishop',
#   'convicted',
#   'covering',
#   'child',
#   'sex',
#   'abuse'],
#  ['commander',
#   'says',
#   'irans',
#   'people',
#   'respond',
#   'pompeos',
#   'threats',
#   'punch',
#   'mouth'],
#  ['mark',
#   'zuckerberg',
#   'extends',
#   'facebook',
#   'apology',
#   'tour',
#   'european',
#   'gig'],
#  ['ariana',
#   'grande',
#   'tweets',
#   'message',
#   'support',
#   'manchester',
#   'bombing',
#   'anniversary'],
#  ['katy', 'perry', 'says', 'shes', 'single', 'american', 'idol'],
#  ['call', 'cops', 'watch', 'powerful', 'monologue', 'on', 'racism'],
#  ['amazon',
#   'selling',
#   'cops',
#   'facial',
#   'recognition',
#   'tool',
#   'bad',
#   'potentially',
#   'racist',
#   'move'],
#  ['miley',
#   'cyrus',
#   'comes',
#   'like',
#   'wrecking',
#   'ball',
#   'prank',
#   'a',
#   'sleeping',
#   'jimmy',
#   'kimmel'],
#  ['vanessa',
#   'bayer',
#   'feared',
#   'porn',
#   'stars',
#   'skit',
#   'donald',
#   'trump',
#   'snl'],
#  ['adam', 'rippon', 'wins', 'dancing', 'stars', 'destined'],
#  ['emilia', 'clarke', 'never', 'try', 'imitate', 'chewbacca', 'ever'],
#  ['maddie',
#   'poppe',
#   'wins',
#   'american',
#   'idol',
#   'runnerup',
#   'reveals',
#   'theyre',
#   'dating'],
#  ['colbert',
#   'cant',
#   'resist',
#   'turning',
#   'trumps',
#   'nickname',
#   'pee',
#   'tape',
#   'joke'],
#  ['seth',
#   'meyers',
#   'forced',
#   'tweak',
#   'donald',
#   'trumps',
#   'latest',
#   'twitter',
#   'rant',
#   'time'],
#  ['boy', 'says', 'teacher', 'told', 'fault', 'police', 'shoot', 'him', 'age'],
#  ['cops', 'accused', 'racism', 'detaining', 'black', 'man', 'vegetation'],
#  ['white',
#   'cop',
#   'shouts',
#   'black',
#   'suspect',
#   'pretend',
#   'like',
#   'going',
#   'shoot'],
#  ['florida',
#   'police',
#   'report',
#   'dead',
#   'standoff',
#   'panama',
#   'city',
#   'apartment',
#   'complex'],
#  ['donald', 'glover', 'board', 'lando', 'calrissians', 'pansexuality', 'solo'],
#  ['charlize', 'theron', 'play', 'megyn', 'kelly', 'film', 'roger', 'ailes'],
#  ['shoppers',
#   'boycott',
#   'publix',
#   'stores',
#   'donations',
#   'nrabacked',
#   'candidate'],
#  ['bill',
#   'de',
#   'blasio',
#   'tells',
#   'nypd',
#   'stop',
#   'arresting',
#   'people',
#   'smoking',
#   'pot',
#   'street'],
#  ['dhs',
#   'head',
#   'says',
#   'shes',
#   'still',
#   'somehow',
#   'unaware',
#   'intel',
#   'russia',
#   'interference',
#   'boost',
#   'trump'],
#  ['lawmaker',
#   'introduces',
#   'crowdfunding',
#   'bill',
#   'pay',
#   'trumps',
#   'border',
#   'wall'],
#  ['gop',
#   'lawmakers',
#   'soon',
#   'allowed',
#   'review',
#   'classified',
#   'info',
#   'russia',
#   'investigation'],
#  ['james',
#   'corden',
#   'reveals',
#   'worst',
#   'part',
#   'royal',
#   'wedding',
#   'ceremony'],
#  ['ariana',
#   'grande',
#   'reportedly',
#   'dating',
#   'snl',
#   'star',
#   'pete',
#   'davidson'],
#  ['jim',
#   'carrey',
#   'pens',
#   'new',
#   'pledge',
#   'allegiance',
#   'students',
#   'bulletriddled',
#   'schools'],
#  ['ellen', 'gets', 'david', 'spade', 'open', 'dating', 'younger', 'women'],
#  ['ceasefire',
#   'jimmy',
#   'kimmel',
#   'shreds',
#   'sean',
#   'hannity',
#   'dummies',
#   'fox',
#   'friends'],
#  ['spoof',
#   'royal',
#   'wedding',
#   'video',
#   'sees',
#   'ceremony',
#   'taking',
#   'different',
#   'turn'],
#  ['georgia', 'gop', 'governors', 'primary', 'focuses', 'guns', 'immigration'],
#  ['glaads',
#   'movie',
#   'report',
#   'finds',
#   'troubling',
#   'drop',
#   'lgbtq',
#   'representation'],
#  ['sephora',
#   'offers',
#   'instore',
#   'beauty',
#   'classes',
#   'trans',
#   'nonbinary',
#   'community'],
#  ['georgia',
#   'governors',
#   'primary',
#   'highlights',
#   'competing',
#   'visions',
#   'democratic',
#   'party'],
#  ['california',
#   'moves',
#   'let',
#   'schools',
#   'coworkers',
#   'red',
#   'flag',
#   'dangerous',
#   'gun',
#   'owners'],
#  ['talking',
#   'grievance',
#   'health',
#   'care',
#   'outsider',
#   'kentucky',
#   'dem',
#   'found',
#   'inside',
#   'track'],
#  ['problems', 'commemorative', 'trumpkim', 'jong', 'un', 'coin'],
#  ['giulianis', 'new', 'stance', 'russian', 'collusion', 'illegal'],
#  ['onion',
#   'hilariously',
#   'trolls',
#   'michael',
#   'cohen',
#   'ceaseanddesist',
#   'note'],
#  ['democrats',
#   'want',
#   'boost',
#   'school',
#   'funding',
#   'to',
#   'address',
#   'teacher',
#   'walkouts'],
#  ['emails', 'lawmakers', 'shrug', 'trumps', 'lax', 'cellphone', 'security'],
#  ['try', 'stink', 'bugflavored', 'jelly', 'bellys', 'dont'],
#  ['power',
#   'outage',
#   'triggers',
#   'extreme',
#   'zombie',
#   'activity',
#   'alert',
#   'florida',
#   'city'],
#  ['congress', 'wall', 'street', 'favor', 'banks', 'post', 'record', 'profits'],
#  ['white', 'house', 'sinkhole', 'probably', 'metaphor', 'something'],
#  ['reporter',
#   'shoved',
#   'others',
#   'barred',
#   'epa',
#   'meeting',
#   'water',
#   'contaminants'],
#  ['garry',
#   'kasparov',
#   'donald',
#   'trump',
#   'russian',
#   'connections',
#   'aeroflot'],
#  ['lonely',
#   'planets',
#   'top',
#   'european',
#   'destinations',
#   'take',
#   'aim',
#   'overtourism'],
#  ['attorney',
#   'aaron',
#   'schlossberg',
#   'insists',
#   'antispanish',
#   'rant',
#   'person'],
#  ['minutes',
#   'reporter',
#   'reveals',
#   'trumps',
#   'chilling',
#   'reason',
#   'slamming',
#   'press'],
#  ['trump',
#   'reportedly',
#   'rejects',
#   'phone',
#   'security',
#   'measures',
#   'inconvenient'],
#  ['federal',
#   'court',
#   'sides',
#   'transgender',
#   'teen',
#   'gavin',
#   'grimm',
#   'bathroom',
#   'fight'],
#  ['extrump',
#   'adviser',
#   'calls',
#   'presidents',
#   'claims',
#   'informant',
#   'spied',
#   'campaign',
#   'embarrassing'],
#  ['vietnam', 'test', 'happens', 'abandons', 'climate', 'diplomacy'],
#  ['onethird',
#   'americans',
#   'think',
#   'trump',
#   'successfully',
#   'draining',
#   'swamp'],
#  ['msnbc',
#   'host',
#   'hugh',
#   'hewitt',
#   'suggests',
#   'trench',
#   'coat',
#   'control',
#   'gun',
#   'control'],
#  ['bishop',
#   'michael',
#   'curry',
#   'harry',
#   'meghans',
#   'love',
#   'brought',
#   'different',
#   'worlds',
#   'together'],
#  ['sarah',
#   'paulson',
#   'unapologetic',
#   'year',
#   'age',
#   'gap',
#   'girlfriend',
#   'holland',
#   'taylor'],
#  ['texans',
#   'sides',
#   'gun',
#   'debate',
#   'agree',
#   'on',
#   'safe',
#   'storage',
#   'on',
#   'support'],
#  ['family',
#   'gay',
#   'man',
#   'found',
#   'critically',
#   'injured',
#   'near',
#   'amtrak',
#   'route',
#   'wants',
#   'answers'],
#  ['caitlyn',
#   'jenner',
#   'trump',
#   'worst',
#   'president',
#   'ever',
#   'lgbtq',
#   'rights'],
#  ['boy',
#   'scout',
#   'allegedly',
#   'booted',
#   'store',
#   'company',
#   'wont',
#   'support',
#   'homos'],
#  ['instagram', 'adding', 'mute', 'button', 'sake', 'sanity'],
#  ['publix', 'censors', 'teens', 'summa', 'cum', 'laude', 'graduation', 'cake'],
#  ['say', 'sexist', 'passengers', 'female', 'pilot', 'perfect', 'response'],
#  ['times',
#   'takes',
#   'aim',
#   'mcdonalds',
#   'walmart',
#   'sexual',
#   'harassment',
#   'complaints'],
#  ['venezuelas',
#   'socialist',
#   'leader',
#   'nicolas',
#   'maduro',
#   'reelected',
#   'amid',
#   'allegations',
#   'irregularities'],
#  ['iran',
#   'says',
#   'europes',
#   'support',
#   'nuclear',
#   'deal',
#   'isnt',
#   'enough',
#   'americas',
#   'withdrawal'],
#  ['farright', 'mob', 'attacks', 'yearold', 'liberal', 'greek', 'mayor'],
#  ['shawn',
#   'mendes',
#   'khalid',
#   'perform',
#   'parkland',
#   'survivors',
#   'billboard',
#   'music',
#   'awards'],
#  ['tamir',
#   'rices',
#   'mother',
#   'opening',
#   'youth',
#   'center',
#   'honor',
#   'sons',
#   'memory'],
#  ['judge',
#   'orders',
#   'texas',
#   'make',
#   'voter',
#   'registration',
#   'easier',
#   'updating',
#   'dmv',
#   'info'],
#  ['kelly',
#   'clarkson',
#   'calls',
#   'moments',
#   'action',
#   'honor',
#   'of',
#   'texas',
#   'shooting',
#   'victims',
#   'billboard',
#   'awards'],
#  ['kendrick', 'lamar', 'stops', 'white', 'fan', 'rapping', 'nword', 'onstage'],
#  ['gay',
#   'man',
#   'says',
#   'pope',
#   'francis',
#   'told',
#   'god',
#   'made',
#   'like',
#   'loves',
#   'you',
#   'like',
#   'that'],
#  ['unusual', 'asteroid', 'could', 'interstellar', 'guest', 'solar', 'system'],
#  ['started',
#   'suicide',
#   'prevention',
#   'site',
#   'age',
#   'still',
#   'going',
#   'strong'],
#  ['roger',
#   'stone',
#   'says',
#   'hes',
#   'prepared',
#   'conjured',
#   'mueller',
#   'indictment'],
#  ['hillary', 'clinton', 'endorse', 'andrew', 'cuomos', 'reelection'],
#  ['supreme', 'court', 'made', 'lot', 'harder', 'sue', 'employer'],
#  ['blake',
#   'farenthold',
#   'may',
#   'hired',
#   'illegally',
#   'new',
#   'lobbyist',
#   'job'],
#  ['bill',
#   'konigsberg',
#   'explores',
#   'new',
#   'side',
#   'gay',
#   'experience',
#   'latest',
#   'book'],
#  ['alone',
#   'game',
#   'shows',
#   'biggest',
#   'hurdles',
#   'lgbtq',
#   'athletes',
#   'exist',
#   'field'],
#  ['chrissy',
#   'teigen',
#   'somehow',
#   'gets',
#   'even',
#   'real',
#   'life',
#   'childbirth'],
#  ['suits',
#   'creator',
#   'pens',
#   'heartfelt',
#   'open',
#   'letter',
#   'attending',
#   'royal',
#   'wedding'],
#  ['movies', 'coming', 'netflix', 'week'],
#  ['obamas', 'coming', 'netflix', 'queue'],
#  ['sorry',
#   'ben',
#   'affleck',
#   'make',
#   'way',
#   'justin',
#   'therouxs',
#   'giant',
#   'rat',
#   'tattoo'],
#  ['hillary',
#   'clinton',
#   'tips',
#   'russian',
#   'hat',
#   'trump',
#   'yale',
#   'commencement',
#   'speech'],
#  ['giuliani',
#   'says',
#   'mueller',
#   'cant',
#   'talk',
#   'trump',
#   'trump',
#   'hears',
#   'fbi',
#   'source'],
#  ['democrats', 'plan', 'big', 'anticorruption', 'theme', 'midterms'],
#  ['kelly',
#   'clarkson',
#   'rejects',
#   'moment',
#   'silence',
#   'calls',
#   'change',
#   'billboard',
#   'music',
#   'awards'],
#  ['asked', 'american', 'public', 'settle', 'internets', 'dumbest', 'debates'],
#  ['fox',
#   'news',
#   'viewers',
#   'really',
#   'dont',
#   'like',
#   'lifelong',
#   'republican',
#   'robert',
#   'mueller'],
#  ['trump',
#   'team',
#   'moves',
#   'lift',
#   'ban',
#   'extreme',
#   'hunting',
#   'tactics',
#   'alaska'],
#  ['howard',
#   'stern',
#   'tells',
#   'trump',
#   'sexualized',
#   'ivanka',
#   'makes',
#   'david',
#   'letterman',
#   'cringe'],
#  ['supreme',
#   'court',
#   'helping',
#   'companies',
#   'get',
#   'away',
#   'sexual',
#   'harassment'],
#  ['deadpool',
#   'steals',
#   'spot',
#   'box',
#   'office',
#   'avengers',
#   'infinity',
#   'war'],
#  ['westworld', 'subtly', 'tease', 'baby', 'theory'],
#  ['donald',
#   'glover',
#   'tells',
#   'ellen',
#   'full',
#   'circle',
#   'star',
#   'wars',
#   'moment',
#   'his',
#   'son'],
#  ['marvel', 'exec', 'tried', 'stop', 'jarring', 'infinity', 'war', 'death'],
#  ['jake', 'gyllenhaal', 'set', 'star', 'villain', 'spiderman', 'sequel'],
#  ['janet',
#   'jackson',
#   'becomes',
#   'first',
#   'black',
#   'woman',
#   'receive',
#   'billboard',
#   'icon',
#   'award'],
#  ['isnt',
#   'pakistan',
#   'bitch',
#   'video',
#   'captures',
#   'drivers',
#   'racist',
#   'rant'],
#  ['grey',
#   'gardens',
#   'ladies',
#   'unwitting',
#   'godmothers',
#   'reality',
#   'tv',
#   'archetypes'],
#  ['yearold', 'boy', 'superhero', 'alabamas', 'homeless', 'population'],
#  ['john', 'oliver', 'best', 'time', 'mocking', 'royal', 'wedding'],
#  ['john',
#   'oliver',
#   'needles',
#   'dangerously',
#   'unregulated',
#   'rehab',
#   'industry'],
#  ['jemele', 'hill', 'honored', 'nabjs', 'journalist', 'year'],
#  ['french', 'digital', 'minister', 'comes', 'gay', 'fight', 'homophobia'],
#  ['belgian',
#   'transgender',
#   'ballet',
#   'drama',
#   'wins',
#   'big',
#   'cannes',
#   'film',
#   'festival'],
#  ['yearold',
#   'gay',
#   'man',
#   'proves',
#   'youre',
#   'never',
#   'old',
#   'attend',
#   'first',
#   'pride'],
#  ['super',
#   'pacs',
#   'meddled',
#   'west',
#   'virginias',
#   'senate',
#   'primary',
#   'didnt',
#   'receive',
#   'penny',
#   'west',
#   'virginians'],
#  ['airline',
#   'passenger',
#   'arrested',
#   'allegedly',
#   'harassing',
#   'woman',
#   'peeing',
#   'seat'],
#  ['mike', 'pompeo', 'promises', 'crush', 'iran', 'achieve', 'better', 'deal'],
#  ['majestic', 'islands', 'europe', 'tourists', 'dont', 'know', 'yet'],
#  ['cuba',
#   'confirms',
#   'killed',
#   'countrys',
#   'deadliest',
#   'plane',
#   'crash',
#   'since'],
#  ['china',
#   'putting',
#   'trade',
#   'war',
#   'hold',
#   'treasurys',
#   'steve',
#   'mnuchin',
#   'says'],
#  ['trumps', 'top', 'economic', 'adviser', 'says', 'amazon', 'threats', 'lane'],
#  ['dems',
#   'trump',
#   'admin',
#   'find',
#   'common',
#   'ground',
#   'helping',
#   'victims',
#   'myanmars',
#   'genocide'],
#  ['giuliani',
#   'says',
#   'mueller',
#   'wrap',
#   'trump',
#   'obstruction',
#   'probe',
#   'september',
#   'report'],
#  ['german',
#   'broadcaster',
#   'criticized',
#   'racist',
#   'coverage',
#   'royal',
#   'wedding'],
#  ['kathryn', 'newton', 'boldest', 'teen', 'tv', 'ready', 'grow'],
#  ['stephanie', 'kelton', 'biggest', 'idea', 'washington'],
#  ['texas',
#   'govs',
#   'campaign',
#   'cancels',
#   'shotgun',
#   'giveaway',
#   'santa',
#   'fe',
#   'school',
#   'shooting'],
#  ['tina',
#   'feys',
#   'sarah',
#   'palin',
#   'leads',
#   'snl',
#   'chorus',
#   'lamenting',
#   'trump'],
#  ['day',
#   'american',
#   'gushing',
#   'snl',
#   'goes',
#   'smart',
#   'aleck',
#   'royal',
#   'wedding'],
#  ['starbucks',
#   'says',
#   'anyone',
#   'sit',
#   'cafes',
#   'even',
#   'without',
#   'buying',
#   'anything'],
#  ['alec',
#   'baldwins',
#   'trump',
#   'faces',
#   'ominous',
#   'sopranos',
#   'scenario',
#   'snl',
#   'finale'],
#  ['asia',
#   'argentos',
#   'fiery',
#   'speech',
#   'closes',
#   'cannes',
#   'raped',
#   'harvey',
#   'weinstein'],
#  ['tina', 'fey', 'tries', 'mean', 'girls', 'musical', 'snl'],
#  ['parents',
#   'school',
#   'shooting',
#   'victims',
#   'decry',
#   'moronic',
#   'gop',
#   'platitudes'],
#  ['trump', 'real', 'americans', 'get', 'tough', 'russia', 'probe'],
#  ['chrissy',
#   'teigen',
#   'john',
#   'legend',
#   'announce',
#   'name',
#   'baby',
#   'boy',
#   'adorable',
#   'photo'],
#  ['texas', 'lt', 'gov', 'dan', 'patrick', 'touts', 'need', 'arm', 'teachers'],
#  ['david',
#   'hogg',
#   'calls',
#   'media',
#   'stop',
#   'naming',
#   'santa',
#   'fe',
#   'school',
#   'shooter'],
#  ['trump', 'sets', 'showdown', 'doj', 'claims', 'campaign', 'surveillance'],
#  ['jim',
#   'carreys',
#   'latest',
#   'painting',
#   'slams',
#   'kent',
#   'state',
#   'goldilocks',
#   'ar'],
#  ['oliver', 'north', 'blames', 'school', 'shootings', 'ritalin'],
#  ['jimmy',
#   'kimmel',
#   'tricks',
#   'royal',
#   'fans',
#   'reviewing',
#   'wedding',
#   'big',
#   'day'],
#  ['jimmy', 'fallon', 'reveals', 'viewers', 'biggest', 'wedding', 'fails'],
#  ['protesters',
#   'throw',
#   'fiesta',
#   'razz',
#   'lawyer',
#   'ranted',
#   'spanish',
#   'speakers'],
#  ['watch', 'amazon', 'prime', 'new', 'week'],
#  ['ferrell',
#   'molly',
#   'shannon',
#   'cover',
#   'royal',
#   'wedding',
#   'cord',
#   'and',
#   'tish'],
#  ['artist', 'formerly', 'known', 'cedric', 'entertainer', 'arrived'],
#  ['mark', 'kelly', 'trump', 'rolled', 'nra', 'nothing', 'guns', 'parkland'],
#  ['gop',
#   'candidate',
#   'set',
#   'trust',
#   'pays',
#   'kids',
#   'marrying',
#   'white',
#   'people'],
#  ['houston',
#   'police',
#   'chief',
#   'says',
#   'hes',
#   'sick',
#   'inaction',
#   'gun',
#   'control'],
#  ['history', 'national', 'anthem', 'sports'],
#  ['bbc',
#   'trolls',
#   'president',
#   'trump',
#   'bigly',
#   'huge',
#   'royal',
#   'wedding',
#   'crowd'],
#  ['victims', 'santa', 'fe', 'high', 'school', 'shooting'],
#  ['ceo',
#   'took',
#   'pay',
#   'cut',
#   'give',
#   'employees',
#   'a',
#   'year',
#   'hes',
#   'battling',
#   'amazon'],
#  ['trump',
#   'jr',
#   'met',
#   'emissary',
#   'gulf',
#   'princes',
#   'offering',
#   'help',
#   'with',
#   'campaign',
#   'report'],
#  ['trump',
#   'misspells',
#   'melanias',
#   'name',
#   'welcome',
#   'home',
#   'tweet',
#   'twitter',
#   'roars'],
#  ['jimmy',
#   'kimmel',
#   'shreds',
#   'cowardly',
#   'trump',
#   'lawmakers',
#   'texas',
#   'school',
#   'shooting'],
#  ['bill', 'maher', 'reveals', 'things', 'dont', 'know', 'michael', 'cohen'],
#  ['watch', 'hulu', 'new', 'week'],
#  ['students',
#   'stage',
#   'sitin',
#   'gun',
#   'control',
#   'outside',
#   'paul',
#   'ryans',
#   'office',
#   'get',
#   'arrested'],
#  ['trump',
#   'knew',
#   'scary',
#   'amount',
#   'appearance',
#   'bill',
#   'gates',
#   'daughter'],
#  ['exrussian',
#   'spy',
#   'sergei',
#   'skripal',
#   'discharged',
#   'uk',
#   'hospital',
#   'poisoning',
#   'incident'],
#  ['cuba', 'plane', 'crash', 'reportedly', 'kills'],
#  ['trump',
#   'reassures',
#   'north',
#   'korea',
#   'threatens',
#   'total',
#   'decimation',
#   'without',
#   'deal'],
#  ['ariana',
#   'grande',
#   'gives',
#   'fans',
#   'singing',
#   'one',
#   'last',
#   'time',
#   'surprise',
#   'lives'],
#  ['cambridge',
#   'analytica',
#   'files',
#   'chapter',
#   'bankruptcy',
#   'facebook',
#   'privacy',
#   'row'],
#  ['santa',
#   'fe',
#   'high',
#   'schoolers',
#   'held',
#   'gun',
#   'violence',
#   'protest',
#   'month',
#   'shooting'],
#  ['michelle',
#   'wolfs',
#   'netflix',
#   'trailer',
#   'gives',
#   'closer',
#   'look',
#   'new',
#   'show'],
#  ['jeff',
#   'sessions',
#   'uses',
#   'exceptional',
#   'power',
#   'immigration',
#   'courts',
#   'limit',
#   'judges',
#   'authority'],
#  ['gop',
#   'rep',
#   'introduces',
#   'bill',
#   'would',
#   'demand',
#   'white',
#   'house',
#   'apologize',
#   'mccain'],
#  ['colbert',
#   'super',
#   'graphic',
#   'way',
#   'describing',
#   'deep',
#   'muellers',
#   'probe',
#   'goes'],
#  ['jack', 'osbournes', 'wife', 'files', 'divorce'],
#  ['meek', 'mill', 'backs', 'trump', 'event', 'prison', 'reform'],
#  ['new',
#   'trump',
#   'rule',
#   'would',
#   'cut',
#   'federal',
#   'funds',
#   'clinics',
#   'providing',
#   'abortions'],
#  ['twitter',
#   'users',
#   'joke',
#   'trump',
#   'wants',
#   'prison',
#   'reform',
#   'hes',
#   'headed'],
#  ['every',
#   'single',
#   'chilean',
#   'bishop',
#   'offers',
#   'resign',
#   'countrys',
#   'sex',
#   'abuse',
#   'scandal'],
#  ['ariana',
#   'grande',
#   'calls',
#   'manchester',
#   'attack',
#   'worst',
#   'humanity',
#   'one',
#   'year',
#   'later'],
#  ['chrissy',
#   'teigen',
#   'spills',
#   'first',
#   'details',
#   'new',
#   'baby',
#   'boy',
#   'love'],
#  ['alec', 'baldwin', 'wife', 'hilaria', 'welcome', 'another', 'baby', 'boy'],
#  ['kate', 'mckinnon', 'breaks', 'another', 'impression', 'rudy', 'giuliani'],
#  ['smallvilles',
#   'allison',
#   'mack',
#   'get',
#   'involved',
#   'sex',
#   'cult',
#   'first',
#   'place'],
#  ['trump',
#   'white',
#   'house',
#   'kills',
#   'yannylaurel',
#   'debate',
#   'ridiculous',
#   'clip'],
#  ['jennifer',
#   'aniston',
#   'play',
#   'lesbian',
#   'president',
#   'netflixs',
#   'first',
#   'ladies'],
#  ['break', 'book', 'shadows', 'charmed', 'reboot', 'trailer'],
#  ['former',
#   'dave',
#   'matthews',
#   'band',
#   'violinist',
#   'boyd',
#   'tinsley',
#   'accused',
#   'sexual',
#   'misconduct'],
#  ['many', 'people', 'cant', 'name', 'single', 'book', 'jimmy', 'kimmel'],
#  ['ellen',
#   'degeneres',
#   'hilariously',
#   'explains',
#   'saved',
#   'meghan',
#   'markles',
#   'life'],
#  ['lawyer',
#   'ranted',
#   'spanishspeakers',
#   'faces',
#   'office',
#   'eviction',
#   'disciplinary',
#   'complaint'],
#  ['hannity',
#   'flips',
#   'mueller',
#   'probe',
#   'direct',
#   'threat',
#   'american',
#   'republic'],
#  ['top',
#   'democrats',
#   'want',
#   'answers',
#   'global',
#   'health',
#   'security',
#   'heads',
#   'sudden',
#   'departure'],
#  ['gun',
#   'owners',
#   'nongun',
#   'owners',
#   'actually',
#   'agree',
#   'lot',
#   'gun',
#   'reforms'],
#  ['twitter',
#   'users',
#   'pan',
#   'ted',
#   'cruz',
#   'tweets',
#   'prayers',
#   'santa',
#   'fe',
#   'school',
#   'shooting',
#   'victims'],
#  ['states', 'ban', 'bump', 'stocks', 'enforce', 'law'],
#  ['liberal', 'billionaire', 'tom', 'steyer', 'base'],
#  ['sen',
#   'dean',
#   'hellers',
#   'campaign',
#   'paid',
#   'social',
#   'media',
#   'influencer',
#   'son'],
#  ['interior',
#   'dept',
#   'dodges',
#   'watchdogs',
#   'questions',
#   'zinkes',
#   'call',
#   'alaska',
#   'senators'],
#  ['blake',
#   'lively',
#   'teases',
#   'ryan',
#   'reynolds',
#   'hugh',
#   'jackmans',
#   'bromance'],
#  ['happytime', 'murders', 'adultthemed', 'movie', 'puppets'],
#  ['photo',
#   'daniel',
#   'radcliffe',
#   'holding',
#   'guns',
#   'crazy',
#   'slippers',
#   'becomes',
#   'magical',
#   'meme'],
#  ['bill',
#   'gates',
#   'says',
#   'trump',
#   'didnt',
#   'know',
#   'difference',
#   'hpv',
#   'hiv'],
#  ['bachelorette', 'bios', 'are', 'terrible'],
#  ['steven',
#   'tyler',
#   'admits',
#   'hitting',
#   'daughter',
#   'livs',
#   'famous',
#   'pal',
#   'watched'],
#  ['hospice',
#   'overdosed',
#   'patients',
#   'hasten',
#   'deaths',
#   'former',
#   'health',
#   'care',
#   'executive',
#   'admits'],
#  ['kimmel',
#   'brings',
#   'house',
#   'giving',
#   'trumps',
#   'latest',
#   'tweet',
#   'new',
#   'ending'],
#  ['former',
#   'wwf',
#   'wrestler',
#   'severely',
#   'beaten',
#   'outside',
#   'california',
#   'home'],
#  ['robert',
#   'wilkie',
#   'picked',
#   'new',
#   'va',
#   'secretary',
#   'surprise',
#   'announcement'],
#  ['trumps',
#   'new',
#   'domestic',
#   'gag',
#   'rule',
#   'would',
#   'strip',
#   'funds',
#   'planned',
#   'parenthood'],
#  ['rudy',
#   'giuliani',
#   'reverses',
#   'trump',
#   'teams',
#   'position',
#   'says',
#   'president',
#   'obstruct',
#   'justice'],
#  ['social', 'anxiety', 'doesnt', 'get', 'attention', 'deserves'],
#  ['deadpool', 'already', 'breaking', 'box', 'office', 'records'],
#  ['obamacare', 'premiums', 'way', 'higher', 'next', 'year', 'didnt', 'be'],
#  ['comprehensive',
#   'list',
#   'everything',
#   'jr',
#   'doesnt',
#   'know',
#   'infamous',
#   'meeting'],
#  ['report',
#   'manaforts',
#   'former',
#   'soninlaw',
#   'cuts',
#   'plea',
#   'deal',
#   'cooperate',
#   'government'],
#  ['trump',
#   'briefly',
#   'responds',
#   'santa',
#   'fe',
#   'school',
#   'shooting',
#   'pivoting'],
#  ['late', 'night', 'writer', 'shreds', 'roseanne', 'better', 'ever', 'racist'],
#  ['trumps',
#   'nasa',
#   'chief',
#   'apparently',
#   'changed',
#   'tune',
#   'climate',
#   'change'],
#  ['freedom',
#   'caucus',
#   'sinks',
#   'key',
#   'part',
#   'paul',
#   'ryans',
#   'welfare',
#   'reform',
#   'agenda'],
#  ['transphobic',
#   'congressional',
#   'hopeful',
#   'berates',
#   'person',
#   'inside',
#   'public',
#   'restroom'],
#  ['singer', 'ryan', 'amador', 'says', 'loverboy', 'second', 'coming'],
#  ['newest', 'head', 'cracker', 'hear', 'brainstorm', 'green', 'needle'],
#  ['meditation', 'like', 'humans', 'way', 'clearing', 'browser', 'cache'],
#  ['funniest', 'tweets', 'women', 'week'],
#  ['italy',
#   'looks',
#   'befriend',
#   'russia',
#   'populist',
#   'parties',
#   'try',
#   'to',
#   'form',
#   'government'],
#  ['business',
#   'groups',
#   'might',
#   'quietly',
#   'killing',
#   'bill',
#   'would',
#   'bring',
#   'sexual',
#   'abuse',
#   'claims',
#   'light'],
#  ['kushner',
#   'family',
#   'reportedly',
#   'close',
#   'getting',
#   'bailout',
#   'flagship',
#   'tower'],
#  ['trump',
#   'says',
#   'hell',
#   'give',
#   'charity',
#   'royal',
#   'wedding',
#   'well',
#   'see'],
#  ['federal',
#   'prosecutors',
#   'still',
#   'trying',
#   'turn',
#   'trump',
#   'inauguration',
#   'protesters',
#   'felons'],
#  ['republican', 'immigration', 'fight', 'derails', 'food', 'stamp', 'bill'],
#  ['retiring',
#   'lawmakers',
#   'added',
#   'million',
#   'campaign',
#   'treasuries',
#   'since',
#   'last',
#   'election'],
#  ['facing',
#   'farm',
#   'bill',
#   'vote',
#   'problems',
#   'gop',
#   'leaders',
#   'may',
#   'make',
#   'deal'],
#  ['methodists',
#   'surprise',
#   'gay',
#   'minister',
#   'worlds',
#   'best',
#   'pastor',
#   'certificates',
#   'theft',
#   'diploma'],
#  ['china',
#   'marks',
#   'another',
#   'milestone',
#   'quest',
#   'become',
#   'space',
#   'superpower'],
#  ['stephen',
#   'colbert',
#   'wants',
#   'mueller',
#   'give',
#   'trump',
#   'special',
#   'anniversary',
#   'gift'],
#  ['trumps',
#   'stormy',
#   'daniels',
#   'disclosure',
#   'still',
#   'leaves',
#   'questions',
#   'payments',
#   'cohen'],
#  ['please', 'enjoy', 'animated', 'history', 'tina', 'fey', 'snl', 'return'],
#  ['controversial',
#   'way',
#   'california',
#   'schools',
#   'handling',
#   'students',
#   'misbehavior'],
#  ['deaf',
#   'activist',
#   'points',
#   'marvels',
#   'diversity',
#   'problem',
#   'isnt',
#   'race'],
#  ['magnum', 'pi', 'trailer', 'lots', 'close', 'shaves', 'big', 'mustache'],
#  ['gina', 'haspel', 'confirmed', 'cia', 'director', 'aid', 'democrats'],
#  ['boulder',
#   'city',
#   'council',
#   'unanimously',
#   'votes',
#   'ban',
#   'assault',
#   'weapons',
#   'highcapacity',
#   'magazines'],
#  ['chrissy', 'teigen', 'john', 'legend', 'welcome', 'baby', 'boy'],
#  ['terrifying', 'clip', 'shows', 'never', 'run', 'tree', 'thunderstorms'],
#  ['mitch',
#   'mcconnell',
#   'taps',
#   'antilgbtq',
#   'bigot',
#   'religious',
#   'freedom',
#   'panel'],
#  ['seth',
#   'meyers',
#   'gives',
#   'donald',
#   'trump',
#   'unexpected',
#   'advice',
#   'north',
#   'korea'],
#  ['devin',
#   'nunes',
#   'fundraising',
#   'fbi',
#   'attacks',
#   'tells',
#   'potential',
#   'donors',
#   'trump',
#   'says',
#   'hes',
#   'hero'],
#  ['former',
#   'mexican',
#   'president',
#   'warns',
#   'donald',
#   'trump',
#   'youve',
#   'got',
#   'get',
#   'st',
#   'together'],
#  ['fox',
#   'news',
#   'first',
#   'female',
#   'ceo',
#   'named',
#   'sexual',
#   'harassment',
#   'complaints'],
#  ['battle', 'save', 'dying', 'soil'],
#  ['latino',
#   'man',
#   'insulted',
#   'starbucks',
#   'barista',
#   'writes',
#   'slur',
#   'cup'],
#  ['snl',
#   'cast',
#   'member',
#   'claims',
#   'trump',
#   'faked',
#   'bizarre',
#   'phone',
#   'call',
#   'rehearsals'],
#  ['jimmy',
#   'kimmel',
#   'comes',
#   'clean',
#   'may',
#   'owe',
#   'donald',
#   'trump',
#   'apology'],
#  ['trevor',
#   'noah',
#   'skewers',
#   'betsy',
#   'devos',
#   'fake',
#   'forprofit',
#   'university',
#   'ad'],
#  ['serena', 'williams', 'explains', 'father', 'didnt', 'walk', 'her', 'aisle'],
#  ['star',
#   'wars',
#   'writer',
#   'confirms',
#   'donald',
#   'glovers',
#   'character',
#   'pansexual',
#   'solo'],
#  ['medical',
#   'professionals',
#   'factcheck',
#   'greys',
#   'anatomy',
#   'sex',
#   'scenes'],
#  ['amy',
#   'schumer',
#   'nails',
#   'meghan',
#   'markles',
#   'fairytale',
#   'wedding',
#   'actually',
#   'sucks'],
#  ['michael',
#   'keaton',
#   'ends',
#   'kent',
#   'state',
#   'commencement',
#   'speech',
#   'im',
#   'batman'],
#  ['______', 'black', 'profiled', 'share', 'story'],
#  ['black',
#   'actresses',
#   'cannes',
#   'protest',
#   'racism',
#   'french',
#   'film',
#   'industry'],
#  ['michael',
#   'b',
#   'jordan',
#   'denies',
#   'rumors',
#   'doesnt',
#   'date',
#   'black',
#   'women'],
#  ['scam',
#   'pacs',
#   'ripped',
#   'conservatives',
#   'propolice',
#   'antiabortion',
#   'messages',
#   'prosecutors'],
#  ['mtv',
#   'suspends',
#   'catfish',
#   'probes',
#   'nev',
#   'schulman',
#   'sexual',
#   'misconduct',
#   'claims'],
#  ['trumps',
#   'ice',
#   'increasingly',
#   'arresting',
#   'immigrants',
#   'without',
#   'criminal',
#   'convictions'],
#  ['special',
#   'counsel',
#   'hits',
#   'roger',
#   'stones',
#   'social',
#   'media',
#   'advisor',
#   'subpoenas'],
#  ['whitney',
#   'houston',
#   'sexually',
#   'abused',
#   'dee',
#   'dee',
#   'warwick',
#   'cannes',
#   'documentary'],
#  ['patton', 'oswalts', 'joker', 'theory', 'change', 'watch', 'dark', 'knight'],
#  ['josh',
#   'holt',
#   'american',
#   'captive',
#   'venezuela',
#   'begs',
#   'help',
#   'in',
#   'prison',
#   'videos'],
#  ['obama',
#   'photographer',
#   'taunts',
#   'donald',
#   'trump',
#   'calling',
#   'immigrants',
#   'animals'],
#  ['backstreet',
#   'boys',
#   'release',
#   'new',
#   'song',
#   'dont',
#   'go',
#   'breaking',
#   'heart'],
#  ['prince',
#   'knight',
#   'puts',
#   'gayinclusive',
#   'twist',
#   'traditional',
#   'fairy',
#   'tales'],
#  ['gay',
#   'conversion',
#   'therapy',
#   'survivor',
#   'recalls',
#   'month',
#   'nightmare',
#   'powerful',
#   'video'],
#  ['gq',
#   'expertly',
#   'spoofs',
#   'vanity',
#   'fair',
#   'annual',
#   'comedy',
#   'issue',
#   'cover'],
#  ['rudy', 'giuliani', 'offers', 'headspinning', 'new', 'defense', 'trump'],
#  ['cynthia',
#   'nixons',
#   'fix',
#   'subway',
#   'ads',
#   'shred',
#   'cuomos',
#   'mta',
#   'commuters',
#   'rejoice'],
#  ['farm', 'bill', 'could', 'huge', 'blow', 'animals'],
#  ['emails',
#   'show',
#   'interior',
#   'expected',
#   'learn',
#   'nothing',
#   'public',
#   'input',
#   'bears',
#   'ears',
#   'review'],
#  ['whistleblower',
#   'leaked',
#   'michael',
#   'cohens',
#   'financials',
#   'potential',
#   'coverup',
#   'report'],
#  ['kidnapper', 'accused', 'using', 'alligator', 'hold', 'man', 'captive'],
#  ['miss', 'america', 'pageant', 'headed', 'women', 'email', 'scandal'],
#  ['north',
#   'korea',
#   'threatens',
#   'reconsider',
#   'trump',
#   'summit',
#   'cancels',
#   'south',
#   'korea',
#   'talks'],
#  ['chemical', 'weapons', 'likely', 'used', 'syria', 'watchdog', 'finds'],
#  ['hundreds',
#   'israel',
#   'beyond',
#   'protest',
#   'killings',
#   'palestinians',
#   'gaza',
#   'border'],
#  ['researchers', 'uncover', 'secret', 'pages', 'diary', 'anne', 'frank'],
#  ['stephen',
#   'piscotty',
#   'returns',
#   'bereavement',
#   'hit',
#   'momtribute',
#   'home',
#   'run'],
#  ['senate',
#   'intelligence',
#   'committee',
#   'backs',
#   'gina',
#   'haspel',
#   'lead',
#   'cia'],
#  ['pennsylvanias', 'congressional', 'delegation', 'longer', 'men'],
#  ['lando',
#   'calrissian',
#   'star',
#   'wars',
#   'spinoff',
#   'starring',
#   'donald',
#   'glover',
#   'isnt',
#   'happening'],
#  ['fake',
#   'donald',
#   'trump',
#   'sean',
#   'hannity',
#   'pillow',
#   'talk',
#   'late',
#   'show'],
#  ['rapper',
#   'ti',
#   'arrested',
#   'disorderly',
#   'conduct',
#   'public',
#   'drunkenness'],
#  ['conservatives',
#   'cook',
#   'farm',
#   'bill',
#   'gambit',
#   'get',
#   'vote',
# ...
#  ['tom',
#   'hardy',
#   'completely',
#   'unrecognizable',
#   'al',
#   'capone',
#   'new',
#   'movie'],
#  ['woman',
#   'alleges',
#   'rapper',
#   'young',
#   'lo',
#   'raped',
#   'trapped',
#   'chris',
#   'browns',
#   'home'],
#  ['republicans', 'fill', 'court', 'seat', 'denied', 'obama', 'years'],
#  ['sc',
#   'man',
#   'wanted',
#   'white',
#   'supremacists',
#   'kill',
#   'black',
#   'neighbor',
#   'burn',
#   'cross',
#   'yard',
#   'fbi'],
#  ['trump', 'announces', 'details', 'meeting', 'kim', 'jong', 'un'],
#  ['samantha',
#   'bee',
#   'delivers',
#   'blistering',
#   'takedown',
#   'former',
#   'ny',
#   'ag',
#   'eric',
#   'schneiderman'],
#  ['jim',
#   'carreys',
#   'scathing',
#   'portrait',
#   'trump',
#   'joker',
#   'give',
#   'nightmares'],
#  ['michelle', 'wolf', 'renews', 'hostilities', 'sarah', 'huckabee', 'sanders'],
#  ['fans', 'erupt', 'fate', 'elias', 'koteas', 'olinsky', 'chicago', 'pd'],
#  ['people',
#   'street',
#   'apologize',
#   'old',
#   'teachers',
#   'on',
#   'jimmy',
#   'kimmel',
#   'live'],
#  ['stephen',
#   'colbert',
#   'porn',
#   'star',
#   'math',
#   'michael',
#   'cohen',
#   'donald',
#   'trump'],
#  ['pollen', 'bomb', 'every', 'allergy', 'sufferers', 'worst', 'nightmare'],
#  ['jennifer',
#   'lopez',
#   'dances',
#   'least',
#   'danceable',
#   'songs',
#   'tonight',
#   'show'],
#  ['white',
#   'yale',
#   'student',
#   'calls',
#   'cops',
#   'black',
#   'schoolmate',
#   'napping',
#   'dorm',
#   'common',
#   'room'],
#  ['rudy', 'giuliani', 'quits', 'law', 'firm', 'wild', 'week', 'interviews'],
#  ['teddy',
#   'geiger',
#   'makes',
#   'first',
#   'public',
#   'appearance',
#   'since',
#   'coming',
#   'transgender'],
#  ['ariana', 'grande', 'mac', 'miller', 'reportedly', 'break'],
#  ['avengers',
#   'leaks',
#   'get',
#   'support',
#   'yearold',
#   'interview',
#   'marvel',
#   'directors'],
#  ['theres',
#   'good',
#   'excuse',
#   'racist',
#   'impact',
#   'michigans',
#   'medicaid',
#   'proposal'],
#  ['fcc', 'complaints', 'minutes', 'interview', 'stormy', 'daniels'],
#  ['americans',
#   'jailed',
#   'n',
#   'korea',
#   'home',
#   'trump',
#   'may',
#   'made',
#   'others',
#   'situation',
#   'worse'],
#  ['alex',
#   'strangelove',
#   'gay',
#   'teen',
#   'comedy',
#   'doesnt',
#   'turn',
#   'away',
#   'sex'],
#  ['woman', 'says', 'took', 'home', 'kittens', 'find', 'bobcats'],
#  ['video',
#   'bear',
#   'eating',
#   'ice',
#   'cream',
#   'dairy',
#   'queen',
#   'leads',
#   'charges',
#   'zoo',
#   'owners'],
#  ['iranian',
#   'lawmakers',
#   'mock',
#   'trumps',
#   'mental',
#   'capacity',
#   'burn',
#   'flag',
#   'us',
#   'pulls',
#   'nuke',
#   'deal'],
#  ['europeans', 'scramble', 'save', 'iran', 'deal', 'trump', 'withdraws'],
#  ['north',
#   'korea',
#   'releases',
#   'american',
#   'political',
#   'prisoners',
#   'advance',
#   'historic',
#   'summit'],
#  ['establishment',
#   'gop',
#   'notches',
#   'win',
#   'ohio',
#   'primary',
#   'vacant',
#   'house',
#   'seat'],
#  ['eric',
#   'schneiderman',
#   'praised',
#   'movement',
#   'days',
#   'abuse',
#   'allegations',
#   'emerged'],
#  ['trevor',
#   'noah',
#   'unloads',
#   'supposed',
#   'advocate',
#   'women',
#   'eric',
#   'schneiderman'],
#  ['year',
#   'comeys',
#   'firing',
#   'scope',
#   'mueller',
#   'probe',
#   'expands',
#   'lawyers',
#   'shell',
#   'company'],
#  ['trumpinspired',
#   'businessman',
#   'wins',
#   'indianas',
#   'gop',
#   'senate',
#   'primary'],
#  ['gop',
#   'rival',
#   'says',
#   'tammy',
#   'baldwin',
#   'team',
#   'terrorists',
#   'silence',
#   'on',
#   'trump',
#   'cia',
#   'pick'],
#  ['jobs', 'program', 'might', 'get', 'people', 'back', 'work'],
#  ['jim', 'parsons', 'yes', 'still', 'need', 'queer', 'stories', 'onscreen'],
#  ['trump',
#   'accuser',
#   'wins',
#   'democratic',
#   'nomination',
#   'ohio',
#   'legislature'],
#  ['mastermind',
#   'waterboarded',
#   'cia',
#   'information',
#   'share',
#   'gina',
#   'haspel'],
#  ['conservative',
#   'senate',
#   'democrat',
#   'backs',
#   'trumps',
#   'agenda',
#   'defeats',
#   'progressive',
#   'challenger'],
#  ['taylor',
#   'swift',
#   'mightve',
#   'made',
#   'katy',
#   'perry',
#   'kimye',
#   'feud',
#   'lives'],
#  ['kim',
#   'kardashian',
#   'make',
#   'history',
#   'fashion',
#   'councils',
#   'first',
#   'influencer',
#   'award'],
#  ['nbc',
#   'says',
#   'believes',
#   'matt',
#   'lauers',
#   'accusers',
#   'monthslong',
#   'investigation'],
#  ['russians', 'ability', 'change', 'voter', 'data', 'didnt', 'report', 'says'],
#  ['elizabeth',
#   'warrens',
#   'pick',
#   'wins',
#   'ohios',
#   'democratic',
#   'gubernatorial',
#   'primary'],
#  ['kkk',
#   'leader',
#   'found',
#   'guilty',
#   'firing',
#   'gun',
#   'charlottesville',
#   'rally'],
#  ['protesters',
#   'decrying',
#   'torture',
#   'dragged',
#   'gina',
#   'haspel',
#   'senate',
#   'hearing'],
#  ['att',
#   'hired',
#   'firm',
#   'linked',
#   'michael',
#   'cohen',
#   'to',
#   'get',
#   'inside',
#   'scoop',
#   'trump'],
#  ['rnc',
#   'selling',
#   'sickening',
#   'donald',
#   'trumpthemed',
#   'merch',
#   'ahead',
#   'mothers',
#   'day'],
#  ['blankenships',
#   'defeat',
#   'relief',
#   'families',
#   'upper',
#   'big',
#   'branch',
#   'miners'],
#  ['colbert', 'shreds', 'trump', 'broken', 'promises', 'talking'],
#  ['new', 'ambassador', 'germany', 'offends', 'hosts', 'hours', 'first', 'day'],
#  ['jordan', 'peeles', 'new', 'nightmare', 'coming', 'next', 'year'],
#  ['backstreet', 'boys', 'dressed', 'spice', 'girls', 'larger', 'life'],
#  ['seth',
#   'meyers',
#   'decodes',
#   'teen',
#   'slang',
#   'reveals',
#   'giuliani',
#   'really',
#   'means'],
#  ['heres', 'look', 'orlandos', 'interim', 'pulse', 'nightclub', 'memorial'],
#  ['trevor',
#   'noah',
#   'turns',
#   'donald',
#   'trumps',
#   'knives',
#   'comment',
#   'reggae',
#   'magic'],
#  ['senators',
#   'force',
#   'vote',
#   'may',
#   'ultimately',
#   'reverse',
#   'fcc',
#   'restore',
#   'net',
#   'neutrality'],
#  ['ny',
#   'legislature',
#   'plan',
#   'place',
#   'consider',
#   'replacements',
#   'eric',
#   'schneiderman'],
#  ['former',
#   'ambassadors',
#   'write',
#   'letter',
#   'opposing',
#   'gina',
#   'haspel',
#   'nomination'],
#  ['california',
#   'authority',
#   'says',
#   'states',
#   'new',
#   'homes',
#   'must',
#   'solar',
#   'powered'],
#  ['ny',
#   'governor',
#   'assigns',
#   'investigation',
#   'eric',
#   'schneiderman',
#   'abuse',
#   'allegations'],
#  ['refugee',
#   'caravan',
#   'became',
#   'scapegoat',
#   'trumps',
#   'border',
#   'crackdown'],
#  ['pennsylvania',
#   'becomes',
#   'latest',
#   'state',
#   'fund',
#   'urban',
#   'gun',
#   'violence',
#   'prevention'],
#  ['denver', 'mayors', 'son', 'caught', 'tape', 'berating', 'cop', 'faggot'],
#  ['progressive', 'prosecutors', 'win', 'primaries', 'north', 'carolina'],
#  ['att', 'novartis', 'get', 'money', 'paid', 'trumps', 'lawyer'],
#  ['hypocrisy',
#   'melania',
#   'trumps',
#   'online',
#   'safety',
#   'booklet',
#   'pointed',
#   'page',
#   'page'],
#  ['uninsured', 'rate', 'worsening', 'years', 'obamacares', 'gains'],
#  ['bernie', 'sanders', 'plan', 'revive', 'labor', 'unions'],
#  ['jim',
#   'carrey',
#   'bestows',
#   'scott',
#   'pruitt',
#   'savage',
#   'nickname',
#   'latest',
#   'painting'],
#  ['male', 'allies', 'become', 'abusers'],
#  ['mormon', 'church', 'end', 'centurylong', 'relationship', 'boy', 'scouts'],
#  ['snack', 'addiction', 'killing', 'orangutans'],
#  ['trumps',
#   'pick',
#   'cia',
#   'director',
#   'wont',
#   'say',
#   'torture',
#   'program',
#   'morally',
#   'wrong'],
#  ['anderson',
#   'cooper',
#   'burns',
#   'moronic',
#   'michael',
#   'cohen',
#   'russia',
#   'cash',
#   'claims'],
#  ['pinata',
#   'maker',
#   'apologizes',
#   'hanging',
#   'black',
#   'figures',
#   'likeness',
#   'lynchings'],
#  ['caliphate', 'trump', 'planet', 'ruins'],
#  ['gay',
#   'marriage',
#   'opponent',
#   'ousted',
#   'a',
#   'gop',
#   'incumbent',
#   'north',
#   'carolina'],
#  ['espn', 'eliminates', 'public', 'editor', 'role', 'calling', 'outdated'],
#  ['michael',
#   'cohen',
#   'selling',
#   'access',
#   'trump',
#   'says',
#   'group',
#   'paid',
#   'shell',
#   'company'],
#  ['mitch',
#   'mcconnell',
#   'mocks',
#   'blankenship',
#   'twitter',
#   'big',
#   'cloud',
#   'cocaine'],
#  ['exconvict',
#   'blankenship',
#   'loses',
#   'patrick',
#   'morrisey',
#   'west',
#   'virginia',
#   'senate',
#   'race'],
#  ['ohio', 'voters', 'pass', 'gerrymandering', 'reform', 'measure'],
#  ['trumps', 'iran', 'deal', 'exit', 'win', 'russia'],
#  ['cynthia',
#   'nixon',
#   'wants',
#   'new',
#   'yorkers',
#   'vote',
#   'homo',
#   'for',
#   'cuomo'],
#  ['ontario', 'canada', 'issued', 'first', 'nonbinary', 'birth', 'certificate'],
#  ['child',
#   'sexual',
#   'predator',
#   'roman',
#   'polanski',
#   'calls',
#   'movement',
#   'total',
#   'hypocrisy'],
#  ['america',
#   'producer',
#   'reveals',
#   'new',
#   'details',
#   'childish',
#   'gambinos',
#   'viral',
#   'video'],
#  ['terry',
#   'crews',
#   'black',
#   'men',
#   'arent',
#   'allowed',
#   'victims',
#   'theyre',
#   'dead'],
#  ['donald', 'glovers', 'america', 'eyes', 'jim', 'crow', 'historian'],
#  ['fox',
#   'news',
#   'judicial',
#   'analyst',
#   'issues',
#   'dark',
#   'warning',
#   'trump',
#   'michael',
#   'cohen'],
#  ['black',
#   'women',
#   'bishops',
#   'making',
#   'history',
#   'predominantly',
#   'white',
#   'church'],
#  ['geena', 'davis', 'th', 'husband', 'reza', 'jarrahy', 'divorcing'],
#  ['pauley', 'perrettes', 'abby', 'heartwrenching', 'farewell', 'ncis'],
#  ['lethal',
#   'weapon',
#   'fires',
#   'clayne',
#   'crawford',
#   'character',
#   'gets',
#   'shot'],
#  ['selena', 'gomez', 'pokes', 'fun', 'met', 'gala', 'spray', 'tan', 'mishap'],
#  ['protest',
#   'leader',
#   'nikol',
#   'pashinian',
#   'elected',
#   'prime',
#   'minister',
#   'armenia'],
#  ['kim', 'jong', 'un', 'secretly', 'met', 'xi', 'jinping'],
#  ['netanyahus',
#   'bombastic',
#   'iran',
#   'claims',
#   'found',
#   'perfect',
#   'audience',
#   'trump'],
#  ['netanyahus',
#   'chef',
#   'blasted',
#   'serving',
#   'japans',
#   'prime',
#   'minister',
#   'dessert',
#   'shoe'],
#  ['world',
#   'leaders',
#   'condemn',
#   'trump',
#   'withdrawing',
#   'iran',
#   'nuclear',
#   'deal'],
#  ['senate',
#   'republicans',
#   'shun',
#   'blankenship',
#   'day',
#   'west',
#   'virginia',
#   'primary'],
#  ['new',
#   'yorks',
#   'harvey',
#   'weinstein',
#   'probe',
#   'set',
#   'continue',
#   'despite',
#   'attorney',
#   'generals',
#   'exit'],
#  ['trump', 'announce', 'whether', 'break', 'iran', 'nuclear', 'deal'],
#  ['politicians',
#   'call',
#   'schneiderman',
#   'resign',
#   'physical',
#   'abuse',
#   'allegations'],
#  ['joe',
#   'scarborough',
#   'trumps',
#   'legal',
#   'strategy',
#   'like',
#   'monkey',
#   'throwing',
#   'poo',
#   'wall'],
#  ['kirsten', 'dunst', 'jesse', 'plemons', 'welcome', 'baby', 'boy'],
#  ['holy', 'matrimony', 'proposal', 'met', 'gala'],
#  ['nordstrom',
#   'rack',
#   'president',
#   'apologizes',
#   'store',
#   'accuses',
#   'three',
#   'black',
#   'men',
#   'theft'],
#  ['giuliani',
#   'says',
#   'trump',
#   'lawyer',
#   'michael',
#   'cohen',
#   'incriminating',
#   'information',
#   'president'],
#  ['lena', 'waithe', 'stuns', 'met', 'gala', 'queer', 'superhero'],
#  ['r',
#   'kelly',
#   'accusers',
#   'say',
#   'ask',
#   'permission',
#   'to',
#   'use',
#   'bathroom'],
#  ['trump',
#   'reportedly',
#   'tells',
#   'macron',
#   'hes',
#   'pulling',
#   'iran',
#   'nuclear',
#   'deal'],
#  ['deportation', 'crackdown', 'hurting', 'immigrant', 'victims', 'crime'],
#  ['seth',
#   'meyers',
#   'says',
#   'michael',
#   'cohen',
#   'tried',
#   'get',
#   'to',
#   'apologize',
#   'onair',
#   'to',
#   'trump'],
#  ['blessing', 'best', 'met', 'gala', 'tweets'],
#  ['farm', 'bill', 'would', 'cut', 'food', 'stamps', 'friendly', 'farmers'],
#  ['know', 'iran', 'nuclear', 'deal'],
#  ['derby', 'day', 'bet', 'wins', 'thrilled', 'texas', 'woman', 'million'],
#  ['democratic',
#   'meddling',
#   'west',
#   'virginia',
#   'things',
#   'watch',
#   'election',
#   'day'],
#  ['cynthia',
#   'erivos',
#   'met',
#   'gala',
#   'nails',
#   'featured',
#   'sistine',
#   'chapel',
#   'painting',
#   'black',
#   'women'],
#  ['keanu',
#   'reeves',
#   'alex',
#   'winter',
#   'coming',
#   'back',
#   'bill',
#   'ted',
#   'years'],
#  ['solanges', 'durag', 'true', 'mvp', 'met', 'gala'],
#  ['top',
#   'house',
#   'republican',
#   'threatens',
#   'subpoena',
#   'trump',
#   'doj',
#   'official',
#   'census',
#   'citizenship',
#   'request'],
#  ['jimmy',
#   'kimmel',
#   'tries',
#   'hard',
#   'make',
#   'sense',
#   'rudys',
#   'latest',
#   'trump',
#   'defense',
#   'gives'],
#  ['religious', 'imagery', 'stitched', 'throughout', 'met', 'gala'],
#  ['bob',
#   'marleys',
#   'granddaughter',
#   'says',
#   'cops',
#   'racially',
#   'profiled',
#   'checking',
#   'airbnb'],
#  ['melania',
#   'trump',
#   'called',
#   'antibullying',
#   'campaign',
#   'ignores',
#   'husbands',
#   'actions'],
#  ['trevor',
#   'noah',
#   'watching',
#   'rudy',
#   'giuliani',
#   'like',
#   'smoking',
#   'weed',
#   'tv'],
#  ['janet',
#   'jackson',
#   'receive',
#   'icon',
#   'award',
#   'billboard',
#   'music',
#   'awards'],
#  ['white',
#   'house',
#   'prepares',
#   'send',
#   'congress',
#   'billion',
#   'spending',
#   'cuts',
#   'package'],
#  ['jared',
#   'kushnerbacked',
#   'bill',
#   'could',
#   'last',
#   'shot',
#   'federal',
#   'prison',
#   'reform'],
#  ['george',
#   'zimmerman',
#   'accused',
#   'stalking',
#   'detective',
#   'working',
#   'trayvon',
#   'martin',
#   'film'],
#  ['passengers',
#   'lashing',
#   'scott',
#   'pruitt',
#   'justify',
#   'firstclass',
#   'travel',
#   'new',
#   'epa',
#   'memo',
#   'says'],
#  ['trump',
#   'country',
#   'house',
#   'district',
#   'became',
#   'key',
#   'progressive',
#   'battleground'],
#  ['mike',
#   'pences',
#   'brother',
#   'wins',
#   'primary',
#   'race',
#   'vice',
#   'presidents',
#   'former',
#   'house',
#   'seat'],
#  ['marines',
#   'investigating',
#   'avowed',
#   'white',
#   'supremacist',
#   'active',
#   'duty'],
#  ['trump',
#   'violate',
#   'iran',
#   'nuclear',
#   'deal',
#   'vows',
#   'to',
#   'reimpose',
#   'sanctions'],
#  ['olympic',
#   'committee',
#   'ignored',
#   'sexual',
#   'abuse',
#   'complaints',
#   'taekwondo',
#   'stars',
#   'lawsuit'],
#  ['blake',
#   'lively',
#   'brought',
#   'family',
#   'met',
#   'gala',
#   'without',
#   'even',
#   'noticing'],
#  ['bill',
#   'oreilly',
#   'offers',
#   'stand',
#   'next',
#   'to',
#   'sarah',
#   'sanders',
#   'to',
#   'handle',
#   'line',
#   'reporters'],
#  ['catholic',
#   'priest',
#   'praised',
#   'best',
#   'dressed',
#   'dude',
#   'met',
#   'gala',
#   'living',
#   'life'],
#  ['jimmy', 'kimmel', 'says', 'hideandseek', 'genius', 'dog', 'heal', 'nation'],
#  ['bank',
#   'america',
#   'appears',
#   'flip',
#   'firearm',
#   'promise',
#   'loan',
#   'to',
#   'remington'],
#  ['gentleman',
#   'caller',
#   'presents',
#   'queer',
#   'icons',
#   'youve',
#   'never',
#   'seen'],
#  ['eric', 'schneiderman', 'always', 'con', 'man'],
#  ['christiane',
#   'amanpour',
#   'heading',
#   'new',
#   'pbs',
#   'show',
#   'replacing',
#   'charlie',
#   'rose'],
#  ['madonna',
#   'teases',
#   'new',
#   'song',
#   'surprise',
#   'met',
#   'gala',
#   'performance'],
#  ['iron',
#   'man',
#   'black',
#   'widow',
#   'captain',
#   'america',
#   'thor',
#   'hawkeye',
#   'got',
#   'matching',
#   'tattoos'],
#  ['michael',
#   'cohen',
#   'accepted',
#   'firm',
#   'tied',
#   'russian',
#   'oligarch',
#   'reports'],
#  ['stephen', 'colbert', 'hits', 'rudy', 'giuliani', 'brutal', 'fact', 'check'],
#  ['katy',
#   'perry',
#   'sends',
#   'olive',
#   'branch',
#   'taylor',
#   'swift',
#   'world',
#   'rejoices'],
#  ['jada', 'pinkett', 'smith', 'gets', 'real', 'dating', 'smith', 'married'],
#  ['whoops',
#   'mark',
#   'hamill',
#   'spilled',
#   'beans',
#   'major',
#   'cameo',
#   'han',
#   'solo',
#   'movie'],
#  ['shawn',
#   'mendes',
#   'sweetly',
#   'attended',
#   'hailey',
#   'baldwins',
#   'gown',
#   'met',
#   'gala'],
#  ['orrin',
#   'hatch',
#   'sorry',
#   'suggested',
#   'trump',
#   'allowed',
#   'john',
#   'mccains',
#   'funeral'],
#  ['seth', 'meyers', 'perfect', 'line', 'confront', 'donald', 'trumps', 'lies'],
#  ['police', 'hope', 'use', 'dna', 'to', 'catch', 'zodiac', 'killer'],
#  ['lili',
#   'reinhart',
#   'cole',
#   'sprouse',
#   'finally',
#   'make',
#   'couple',
#   'debut',
#   'met',
#   'gala'],
#  ['sweetbitter', 'captures', 'grit', 'glamour', 'restaurant', 'world'],
#  ['mitch', 'mcconnell', 'bends', 'rules', 'confirm', 'trumps', 'judges'],
#  ['ryan', 'zinke', 'tale', 'two', 'fish'],
#  ['ny',
#   'attorney',
#   'general',
#   'eric',
#   'schneiderman',
#   'resigns',
#   'amid',
#   'abuse',
#   'allegations'],
#  ['sanctuary', 'cities', 'working', 'trump', 'era', 'surprising', 'cost'],
#  ['shepard',
#   'smith',
#   'cant',
#   'say',
#   'trump',
#   'pulled',
#   'iran',
#   'deal',
#   'made',
#   'decision',
#   'violate'],
#  ['stormy',
#   'daniels',
#   'finds',
#   'crunchy',
#   'new',
#   'way',
#   'chip',
#   'away',
#   'trump'],
#  ['rainbow',
#   'mountains',
#   'peru',
#   'look',
#   'like',
#   'theyre',
#   'straight',
#   'dr',
#   'seuss',
#   'book'],
#  ...]

# %%
occurences = compute_word_occurences(splitted_text).head(1000)
occurences
# Out:
#        Word  Count
# 0    photos  10277
# 1     trump   9569
# 2       new   8554
# 3     video   5770
# 4    donald   4589
# ..      ...    ...
# 995   vegas    253
# 996   actor    253
# 997  center    252
# 998  longer    252
# 999   crash    252
#
# [1000 rows x 2 columns]

# %% [markdown]
# On observe que nous avons en première place des espaces, nous les supprimons afin de ne plus les traiter.

# %%
space = [""," "]
for lists in splitted_text:
    for word in space:
        try:
            lists.remove(word)
        except Exception as e:
            e ="  "
splitted_text
# Out:
# [['there',
#   'were',
#   'mass',
#   'shootings',
#   'in',
#   'texas',
#   'last',
#   'week',
#   'but',
#   'only',
#   'on',
#   'tv'],
#  ['will',
#   'smith',
#   'joins',
#   'diplo',
#   'and',
#   'nicky',
#   'jam',
#   'for',
#   'the',
#   'world',
#   'cups',
#   'official',
#   'song'],
#  ['hugh', 'grant', 'marries', 'for', 'the', 'first', 'time', 'at', 'age'],
#  ['jim',
#   'carrey',
#   'blasts',
#   'castrato',
#   'adam',
#   'schiff',
#   'and',
#   'democrats',
#   'in',
#   'new',
#   'artwork'],
#  ['julianna',
#   'margulies',
#   'uses',
#   'donald',
#   'trump',
#   'poop',
#   'bags',
#   'to',
#   'pick',
#   'up',
#   'after',
#   'her',
#   'dog'],
#  ['morgan',
#   'freeman',
#   'devastated',
#   'that',
#   'sexual',
#   'harassment',
#   'claims',
#   'could',
#   'undermine',
#   'legacy'],
#  ['donald',
#   'trump',
#   'is',
#   'lovin',
#   'new',
#   'mcdonalds',
#   'jingle',
#   'in',
#   'tonight',
#   'show',
#   'bit'],
#  ['what',
#   'to',
#   'watch',
#   'on',
#   'amazon',
#   'prime',
#   'thats',
#   'new',
#   'this',
#   'week'],
#  ['mike',
#   'myers',
#   'reveals',
#   'hed',
#   'like',
#   'to',
#   'do',
#   'a',
#   'fourth',
#   'austin',
#   'powers',
#   'film'],
#  ['what', 'to', 'watch', 'on', 'hulu', 'thats', 'new', 'this', 'week'],
#  ['justin', 'timberlake', 'visits', 'texas', 'school', 'shooting', 'victims'],
#  ['south',
#   'korean',
#   'president',
#   'meets',
#   'north',
#   'koreas',
#   'kim',
#   'jong',
#   'un',
#   'to',
#   'talk',
#   'trump',
#   'summit'],
#  ['with',
#   'its',
#   'way',
#   'of',
#   'life',
#   'at',
#   'risk',
#   'this',
#   'remote',
#   'oystergrowing',
#   'region',
#   'called',
#   'in',
#   'robots'],
#  ['trumps',
#   'crackdown',
#   'on',
#   'immigrant',
#   'parents',
#   'puts',
#   'more',
#   'kids',
#   'in',
#   'an',
#   'already',
#   'strained',
#   'system'],
#  ['trumps',
#   'son',
#   'should',
#   'be',
#   'concerned',
#   'fbi',
#   'obtained',
#   'wiretaps',
#   'of',
#   'putin',
#   'ally',
#   'who',
#   'met',
#   'with',
#   'trump',
#   'jr'],
#  ['edward',
#   'snowden',
#   'theres',
#   'no',
#   'one',
#   'trump',
#   'loves',
#   'more',
#   'than',
#   'vladimir',
#   'putin'],
#  ['booyah',
#   'obama',
#   'photographer',
#   'hilariously',
#   'trolls',
#   'trumps',
#   'spy',
#   'claim'],
#  ['ireland',
#   'votes',
#   'to',
#   'repeal',
#   'abortion',
#   'amendment',
#   'in',
#   'landslide',
#   'referendum'],
#  ['ryan',
#   'zinke',
#   'looks',
#   'to',
#   'reel',
#   'back',
#   'some',
#   'critics',
#   'with',
#   'grand',
#   'pivot',
#   'to',
#   'conservation'],
#  ['trumps',
#   'scottish',
#   'golf',
#   'resort',
#   'pays',
#   'women',
#   'significantly',
#   'less',
#   'than',
#   'men',
#   'report'],
#  ['weird',
#   'fathers',
#   'day',
#   'gifts',
#   'your',
#   'dad',
#   'doesnt',
#   'know',
#   'he',
#   'wants',
#   'but',
#   'he',
#   'does'],
#  ['twitter',
#   'putstarwarsinotherfilms',
#   'and',
#   'it',
#   'was',
#   'universally',
#   'entertaining'],
#  ['mystery',
#   'wolflike',
#   'animal',
#   'reportedly',
#   'shot',
#   'in',
#   'montana',
#   'baffles',
#   'wildlife',
#   'officials'],
#  ['north',
#   'korea',
#   'still',
#   'open',
#   'to',
#   'talks',
#   'after',
#   'trump',
#   'cancels',
#   'summit'],
#  ['men',
#   'detonate',
#   'bomb',
#   'inside',
#   'indian',
#   'restaurant',
#   'near',
#   'toronto',
#   'authorities',
#   'say'],
#  ['thousands',
#   'travel',
#   'home',
#   'to',
#   'ireland',
#   'to',
#   'vote',
#   'on',
#   'abortion',
#   'access'],
#  ['irish',
#   'voters',
#   'set',
#   'to',
#   'liberalize',
#   'abortion',
#   'laws',
#   'in',
#   'landslide',
#   'exit',
#   'poll',
#   'signals'],
#  ['warriors',
#   'coach',
#   'steve',
#   'kerr',
#   'calls',
#   'nfl',
#   'ban',
#   'on',
#   'protests',
#   'fake',
#   'patriotism'],
#  ['in',
#   'historic',
#   'victory',
#   'barbados',
#   'elects',
#   'first',
#   'female',
#   'prime',
#   'minister'],
#  ['police',
#   'killed',
#   'at',
#   'least',
#   'black',
#   'americans',
#   'from',
#   'the',
#   'moment',
#   'colin',
#   'kaepernick',
#   'protested'],
#  ['jack',
#   'johnson',
#   'was',
#   'pardoned',
#   'but',
#   'taboo',
#   'sex',
#   'is',
#   'still',
#   'being',
#   'criminalized'],
#  ['bet', 'chairman', 'and', 'ceo', 'debra', 'lee', 'is', 'stepping', 'down'],
#  ['rachel',
#   'dolezal',
#   'faces',
#   'felony',
#   'charges',
#   'for',
#   'welfare',
#   'fraud'],
#  ['bishop',
#   'michael',
#   'curry',
#   'joins',
#   'christian',
#   'march',
#   'to',
#   'white',
#   'house',
#   'to',
#   'reclaim',
#   'jesus'],
#  ['kanye',
#   'west',
#   'spent',
#   'on',
#   'photo',
#   'of',
#   'whitney',
#   'houstons',
#   'bathroom',
#   'for',
#   'album',
#   'cover'],
#  ['morgan',
#   'freeman',
#   'dropped',
#   'from',
#   'marketing',
#   'campaigns',
#   'after',
#   'harassment',
#   'accusations'],
#  ['how',
#   'the',
#   'chinese',
#   'exclusion',
#   'act',
#   'can',
#   'help',
#   'us',
#   'understand',
#   'immigration',
#   'politics',
#   'today'],
#  ['trumps', 'new', 'magathemed', 'swimwear', 'sinks', 'on', 'twitter'],
#  ['seth',
#   'meyers',
#   'has',
#   'funny',
#   'regret',
#   'after',
#   'trump',
#   'cancels',
#   'north',
#   'korea',
#   'summit'],
#  ['colbert',
#   'wants',
#   'to',
#   'turn',
#   'nyc',
#   'subway',
#   'rides',
#   'into',
#   'a',
#   'new',
#   'and',
#   'terrible',
#   'punishment'],
#  ['man',
#   'faces',
#   'charges',
#   'after',
#   'pulling',
#   'knife',
#   'stun',
#   'gun',
#   'on',
#   'muslim',
#   'students',
#   'at',
#   'mcdonalds'],
#  ['jimmy',
#   'kimmel',
#   'knows',
#   'why',
#   'irans',
#   'supreme',
#   'leader',
#   'watches',
#   'tom',
#   'and',
#   'jerry'],
#  ['people', 'injured', 'in', 'indiana', 'school', 'shooting'],
#  ['people',
#   'are',
#   'rattled',
#   'by',
#   'how',
#   'much',
#   'this',
#   'nigerian',
#   'man',
#   'looks',
#   'like',
#   'chadwick',
#   'boseman'],
#  ['david',
#   'cross',
#   'proves',
#   'yet',
#   'again',
#   'that',
#   'hes',
#   'terrible',
#   'at',
#   'apologizing'],
#  ['sesame',
#   'street',
#   'creators',
#   'sue',
#   'makers',
#   'of',
#   'upcoming',
#   'adultthemed',
#   'puppet',
#   'film'],
#  ['what',
#   'you',
#   'missed',
#   'about',
#   'the',
#   'saddest',
#   'death',
#   'in',
#   'avengers',
#   'infinity',
#   'war'],
#  ['george',
#   'takei',
#   'accuser',
#   'walks',
#   'back',
#   'story',
#   'of',
#   'drugging',
#   'and',
#   'sexual',
#   'assault'],
#  ['samantha',
#   'bees',
#   'parents',
#   'think',
#   'america',
#   'is',
#   'basically',
#   'a',
#   'war',
#   'zone'],
#  ['pete',
#   'davidson',
#   'says',
#   'his',
#   'mental',
#   'illness',
#   'doesnt',
#   'ruin',
#   'romance'],
#  ['james',
#   'corden',
#   'and',
#   'adam',
#   'levine',
#   'get',
#   'pulled',
#   'over',
#   'during',
#   'carpool',
#   'karaoke'],
#  ['emilia',
#   'clarke',
#   'dishes',
#   'on',
#   'her',
#   'final',
#   'game',
#   'of',
#   'thrones',
#   'scene'],
#  ['hollywood',
#   'doesnt',
#   'need',
#   'difficult',
#   'men',
#   'to',
#   'make',
#   'great',
#   'tv'],
#  ['harvey',
#   'weinstein',
#   'accusers',
#   'say',
#   'they',
#   'never',
#   'thought',
#   'he',
#   'would',
#   'be',
#   'arrested'],
#  ['harvey',
#   'weinstein',
#   'turns',
#   'himself',
#   'in',
#   'to',
#   'police',
#   'for',
#   'alleged',
#   'sex',
#   'crimes'],
#  ['john',
#   'mayers',
#   'weird',
#   'new',
#   'lowbudget',
#   'video',
#   'is',
#   'a',
#   'memeworthy',
#   'masterpiece'],
#  ['now',
#   'boba',
#   'fett',
#   'is',
#   'getting',
#   'his',
#   'own',
#   'star',
#   'wars',
#   'movie'],
#  ['trump', 'suggests', 'north', 'korea', 'summit', 'could', 'still', 'happen'],
#  ['roger',
#   'stone',
#   'pressed',
#   'for',
#   'damaging',
#   'emails',
#   'about',
#   'hillary',
#   'clinton',
#   'from',
#   'wikileaks',
#   'report'],
#  ['publix',
#   'suspends',
#   'contributions',
#   'to',
#   'nrabacked',
#   'politician',
#   'amid',
#   'protests'],
#  ['twitter',
#   'bots',
#   'may',
#   'have',
#   'delivered',
#   'donald',
#   'trumps',
#   'victory',
#   'research',
#   'paper',
#   'says'],
#  ['a',
#   'bag',
#   'of',
#   'wet',
#   'socks',
#   'is',
#   'apparently',
#   'living',
#   'in',
#   'the',
#   'white',
#   'house',
#   'press',
#   'briefing',
#   'room'],
#  ['a',
#   'member',
#   'of',
#   'the',
#   'farright',
#   'proud',
#   'boys',
#   'menaced',
#   'a',
#   'twitter',
#   'user',
#   'on',
#   'his',
#   'doorstep'],
#  ['all',
#   'the',
#   'things',
#   'the',
#   'nra',
#   'has',
#   'blamed',
#   'for',
#   'the',
#   'texas',
#   'school',
#   'shooting'],
#  ['heres',
#   'what',
#   'happens',
#   'when',
#   'a',
#   'catholic',
#   'hospital',
#   'wont',
#   'try',
#   'to',
#   'save',
#   'you'],
#  ['trumps',
#   'new',
#   'executive',
#   'orders',
#   'make',
#   'it',
#   'easier',
#   'to',
#   'fire',
#   'federal',
#   'workers'],
#  ['monsanto',
#   'and',
#   'bayer',
#   'are',
#   'set',
#   'to',
#   'merge',
#   'heres',
#   'why',
#   'you',
#   'should',
#   'care'],
#  ['the', 'joy', 'of', 'watching', 'harvey', 'weinsteins', 'perp', 'walk'],
#  ['the', 'funniest', 'tweets', 'from', 'women', 'this', 'week'],
#  ['queer',
#   'eye',
#   'star',
#   'bobby',
#   'berk',
#   'gave',
#   'me',
#   'a',
#   'desk',
#   'makeover',
#   'and',
#   'it',
#   'was',
#   'incredible'],
#  ['older',
#   'gay',
#   'men',
#   'try',
#   'out',
#   'new',
#   'gay',
#   'slang',
#   'in',
#   'this',
#   'hilarious',
#   'video'],
#  ['how',
#   'rupauls',
#   'drag',
#   'race',
#   'is',
#   'teaching',
#   'straight',
#   'people',
#   'about',
#   'queer',
#   'culture'],
#  ['fish',
#   'market',
#   'buys',
#   'freedom',
#   'for',
#   'fred',
#   'the',
#   'pound',
#   'octopus'],
#  ['north',
#   'korea',
#   'threatens',
#   'again',
#   'to',
#   'call',
#   'off',
#   'trump',
#   'summit',
#   'warns',
#   'of',
#   'nuclear',
#   'showdown'],
#  ['investigation',
#   'finds',
#   'russian',
#   'missile',
#   'shot',
#   'down',
#   'flight',
#   'mh'],
#  ['north',
#   'korea',
#   'demolishes',
#   'tunnels',
#   'at',
#   'nuclear',
#   'test',
#   'site',
#   'reports',
#   'say'],
#  ['how',
#   'kim',
#   'jong',
#   'un',
#   'baited',
#   'trump',
#   'into',
#   'canceling',
#   'the',
#   'north',
#   'korea',
#   'summit'],
#  ['michelle',
#   'obama',
#   'reveals',
#   'cover',
#   'for',
#   'upcoming',
#   'memoir',
#   'becoming'],
#  ['late',
#   'night',
#   'writers',
#   'breathless',
#   'royal',
#   'wedding',
#   'recap',
#   'is',
#   'the',
#   'only',
#   'one',
#   'you',
#   'need'],
#  ['morgan',
#   'freeman',
#   'accused',
#   'of',
#   'inappropriate',
#   'behavior',
#   'and',
#   'sexual',
#   'harassment'],
#  ['jets',
#   'chairman',
#   'christopher',
#   'johnson',
#   'wont',
#   'fine',
#   'players',
#   'for',
#   'anthem',
#   'protests'],
#  ['andy',
#   'cohen',
#   'and',
#   'taylor',
#   'swift',
#   'are',
#   'over',
#   'their',
#   'katy',
#   'perry',
#   'drama'],
#  ['infinity',
#   'war',
#   'writers',
#   'try',
#   'to',
#   'clear',
#   'up',
#   'marvels',
#   'problematic',
#   'timeline'],
#  ['david',
#   'blaine',
#   'chews',
#   'glass',
#   'and',
#   'lets',
#   'james',
#   'corden',
#   'puncture',
#   'his',
#   'cheek'],
#  ['amy',
#   'poehler',
#   'a',
#   'parks',
#   'and',
#   'recreation',
#   'revival',
#   'would',
#   'be',
#   'amazing'],
#  ['colbert',
#   'exposes',
#   'the\xa0biggest',
#   'flaw',
#   'in',
#   'trumps',
#   'latest',
#   'conspiracy',
#   'theory'],
#  ['seth',
#   'meyers',
#   'gives',
#   'donald',
#   'trump',
#   'some',
#   'valuable',
#   'marketing',
#   'advice'],
#  ['us',
#   'launches',
#   'auto',
#   'import',
#   'probe',
#   'china',
#   'vows',
#   'to',
#   'defend',
#   'its',
#   'interests'],
#  ['this',
#   'women',
#   'pulled',
#   'out',
#   'all',
#   'the',
#   'stops',
#   'to',
#   'land',
#   'her',
#   'dream',
#   'job'],
#  ['wife',
#   'asked',
#   'husband',
#   'for',
#   'fenty',
#   'highlighter',
#   'and',
#   'got',
#   'a',
#   'pack',
#   'of',
#   'highlighters',
#   'hairbrush'],
#  ['trump',
#   'roasted',
#   'for',
#   'rushing',
#   'to',
#   'defend',
#   'tomi',
#   'lahren',
#   'while',
#   'ignoring',
#   'real',
#   'victims'],
#  ['trump',
#   'abruptly',
#   'cancels',
#   'north',
#   'korea',
#   'summit',
#   'with',
#   'kim',
#   'jong',
#   'un'],
#  ['devin',
#   'nuneslinked',
#   'winery',
#   'faced',
#   'suit',
#   'over',
#   'alleged',
#   'coke',
#   'and',
#   'prostitute',
#   'yacht',
#   'party'],
#  ['immigrant',
#   'children',
#   'accuse',
#   'border',
#   'patrol',
#   'of',
#   'abuse',
#   'and',
#   'neglect',
#   'report',
#   'shows'],
#  ['irelands',
#   'historic',
#   'vote',
#   'on',
#   'legalizing',
#   'abortion',
#   'is',
#   'haunted',
#   'by',
#   'trump',
#   'and',
#   'brexit'],
#  ['trump',
#   'lawyer',
#   'attended',
#   'doj',
#   'meeting',
#   'on',
#   'confidential',
#   'fbi',
#   'informant'],
#  ['senate',
#   'advances',
#   'court',
#   'pick',
#   'who',
#   'said',
#   'planned',
#   'parenthood',
#   'kills',
#   'over',
#   'females',
#   'a',
#   'year'],
#  ['rudy',
#   'giuliani',
#   'trump',
#   'wont',
#   'interview',
#   'with',
#   'mueller',
#   'until',
#   'we',
#   'get',
#   'spygate',
#   'report'],
#  ['kentucky',
#   'attorney',
#   'running',
#   'for',
#   'judge',
#   'dies',
#   'day',
#   'after',
#   'primary',
#   'win'],
#  ['chrissy',
#   'teigen',
#   'taunts',
#   'donald',
#   'trump',
#   'over',
#   'twitter',
#   'blocking',
#   'ruling'],
#  ['the',
#   'koch',
#   'network',
#   'is',
#   'going',
#   'after',
#   'one',
#   'of',
#   'trumps',
#   'favorite',
#   'congressmen'],
#  ['trump', 'posthumously', 'pardons', 'boxer', 'jack', 'johnson'],
#  ['ellen',
#   'tears',
#   'up',
#   'when',
#   'ashton',
#   'kutcher',
#   'donates',
#   'million',
#   'to',
#   'her',
#   'wildlife',
#   'fund'],
#  ['ariana',
#   'grande',
#   'reveals',
#   'bee',
#   'tattoo',
#   'in',
#   'honor',
#   'of',
#   'the',
#   'manchester',
#   'attack'],
#  ['kim',
#   'kardashian',
#   'wished',
#   'kanye',
#   'west',
#   'a',
#   'happy',
#   'anniversary',
#   'and',
#   'fine',
#   'its',
#   'pretty',
#   'cute'],
#  ['chris',
#   'hemsworth',
#   'dances',
#   'wrecking',
#   'ball',
#   'with',
#   'his',
#   'kids',
#   'in',
#   'the',
#   'living',
#   'room'],
#  ['moses',
#   'farrow',
#   'defends',
#   'woody',
#   'allen',
#   'and',
#   'accuses',
#   'mia',
#   'farrow',
#   'of',
#   'abuse'],
#  ['gwyneth',
#   'paltrow',
#   'says',
#   'brad',
#   'pitt',
#   'threatened',
#   'to',
#   'kill',
#   'harvey',
#   'weinstein'],
#  ['stephen',
#   'king',
#   'reveals',
#   'why',
#   'donald',
#   'trump',
#   'blocked',
#   'him',
#   'on',
#   'twitter'],
#  ['fans',
#   'back',
#   'jessica',
#   'walter',
#   'after',
#   'she',
#   'addressed',
#   'verbal',
#   'harassment',
#   'by',
#   'jeffrey',
#   'tambor'],
#  ['jessica',
#   'walter',
#   'discusses',
#   'jeffrey',
#   'tambors',
#   'alleged',
#   'harassment',
#   'while',
#   'male',
#   'costars',
#   'brush',
#   'it',
#   'off'],
#  ['harvey',
#   'weinstein',
#   'expected',
#   'to',
#   'turn',
#   'himself',
#   'in',
#   'to',
#   'the',
#   'nypd',
#   'for',
#   'sex',
#   'crimes'],
#  ['samantha',
#   'bee',
#   'torches',
#   'ice',
#   'lets',
#   'shut',
#   'it',
#   'the',
#   'fk',
#   'down'],
#  ['scott',
#   'pruitt',
#   'twice',
#   'introduced',
#   'antiabortion',
#   'bills',
#   'giving',
#   'men',
#   'property',
#   'rights',
#   'over',
#   'fetuses'],
#  ['twitter',
#   'critics',
#   'mercilessly',
#   'mock',
#   'trump',
#   'for',
#   'canceling',
#   'summit',
#   'with',
#   'kim'],
#  ['civil',
#   'rights',
#   'groups',
#   'rip',
#   'senate',
#   'bill',
#   'revising',
#   'its',
#   'own',
#   'sexual',
#   'harassment',
#   'policy'],
#  ['alabama',
#   'sues',
#   'to',
#   'exclude',
#   'undocumented',
#   'immigrants',
#   'from',
#   'census',
#   'count'],
#  ['cynthia',
#   'nixon',
#   'vows',
#   'to',
#   'keep',
#   'fighting',
#   'after',
#   'predictably',
#   'losing',
#   'party',
#   'endorsement'],
#  ['white',
#   'house',
#   'officials',
#   'reportedly',
#   'considered',
#   'just',
#   'ignoring',
#   'new',
#   'climate',
#   'research'],
#  ['read',
#   'trumps',
#   'letter',
#   'to',
#   'kim',
#   'jong',
#   'un',
#   'canceling',
#   'north',
#   'korea',
#   'summit'],
#  ['south',
#   'korea',
#   'responds',
#   'to',
#   'trumps',
#   'sudden',
#   'cancellation',
#   'of',
#   'kim',
#   'jong',
#   'un',
#   'summit'],
#  ['facebooks',
#   'new',
#   'ad',
#   'rules',
#   'prove',
#   'its',
#   'basically',
#   'in',
#   'charge',
#   'of',
#   'regulating',
#   'elections',
#   'now'],
#  ['border', 'agent', 'fatally', 'shoots', 'migrant', 'woman', 'in', 'texas'],
#  ['trump',
#   'opens',
#   'door',
#   'for',
#   'us',
#   'gun',
#   'industry',
#   'to',
#   'sell',
#   'more',
#   'firearms',
#   'abroad'],
#  ['stormy',
#   'daniels',
#   'day',
#   'declared',
#   'in',
#   'west',
#   'hollywood',
#   'as',
#   'adult',
#   'star',
#   'gets',
#   'key',
#   'to',
#   'city'],
#  ['youre',
#   'going',
#   'to',
#   'use',
#   'that',
#   'selfcheckout',
#   'machine',
#   'whether',
#   'you',
#   'like',
#   'it',
#   'or',
#   'not'],
#  ['ways',
#   'to',
#   'make',
#   'family',
#   'road',
#   'trips',
#   'easier',
#   'from',
#   'parents',
#   'whove',
#   'been',
#   'there'],
#  ['jake',
#   'tapper',
#   'shreds',
#   'donald',
#   'trump',
#   'with',
#   'a',
#   'long',
#   'list',
#   'of',
#   'his',
#   'conspiracy',
#   'theories'],
#  ['new',
#   'york',
#   'daily',
#   'news',
#   'rips',
#   'nfl',
#   'over',
#   'anthem',
#   'kneeling',
#   'ban'],
#  ['a',
#   'judge',
#   'ruled',
#   'one',
#   'immigrant',
#   'had',
#   'a',
#   'right',
#   'to',
#   'a',
#   'hearing',
#   'what',
#   'about',
#   'all',
#   'the',
#   'others'],
#  ['house',
#   'democrats',
#   'offer',
#   'internships',
#   'for',
#   'students',
#   'affected',
#   'by',
#   'gun',
#   'violence'],
#  ['tig',
#   'notaro',
#   'tells',
#   'ellen',
#   'degeneres',
#   'about',
#   'her',
#   'sons',
#   'passion',
#   'for',
#   'trash'],
#  ['stormy',
#   'daniels',
#   'thanks',
#   'wonderful',
#   'gay',
#   'dads',
#   'as',
#   'west',
#   'hollywood',
#   'hands',
#   'her',
#   'keys',
#   'to',
#   'city'],
#  ['can', 'you', 'believe', 'queer', 'eye', 'season', 'drops', 'next', 'month'],
#  ['gay',
#   'man',
#   'denied',
#   'marriage',
#   'license',
#   'by',
#   'kim',
#   'davis',
#   'loses',
#   'bid',
#   'to',
#   'unseat',
#   'her'],
#  ['anna',
#   'kournikova',
#   'dancing',
#   'with',
#   'her',
#   'bouncing',
#   'baby',
#   'is',
#   'the',
#   'cutest',
#   'thing'],
#  ['trump',
#   'says',
#   'nfl',
#   'players',
#   'unwilling',
#   'to',
#   'stand',
#   'for',
#   'anthem',
#   'maybe',
#   'shouldnt',
#   'be',
#   'in',
#   'the',
#   'country'],
#  ['facebook',
#   'accused',
#   'of',
#   'reading',
#   'texts',
#   'and',
#   'accessing',
#   'microphones',
#   'in',
#   'lawsuit'],
#  ['selfdriving',
#   'uber',
#   'in',
#   'fatal',
#   'accident',
#   'had',
#   'seconds',
#   'to',
#   'react',
#   'before',
#   'crash'],
#  ['amazon',
#   'admits',
#   'alexa',
#   'device',
#   'eavesdropped',
#   'on',
#   'portland',
#   'family'],
#  ['man',
#   'discovers',
#   'handgun',
#   'impaled',
#   'in',
#   'front',
#   'bumper',
#   'of',
#   'car'],
#  ['rescue',
#   'cat',
#   'has',
#   'hilarious',
#   'wideeyed',
#   'expression',
#   'after',
#   'scan',
#   'confirms',
#   'she',
#   'is',
#   'pregnant'],
#  ['weirdest',
#   'promposals',
#   'of',
#   'include',
#   'teen',
#   'who',
#   'faked',
#   'his',
#   'own',
#   'birth'],
#  ['trump',
#   'and',
#   'the',
#   'american',
#   'far',
#   'right',
#   'stoke',
#   'hate',
#   'in',
#   'canada'],
#  ['farright',
#   'and',
#   'antiestablishment',
#   'parties',
#   'set',
#   'to',
#   'form',
#   'italys',
#   'new',
#   'government'],
#  ['sarah',
#   'silverman',
#   'sees',
#   'no',
#   'reason',
#   'why',
#   'louis',
#   'ck',
#   'cant',
#   'continue',
#   'being',
#   'an',
#   'artist'],
#  ['southern',
#   'baptist',
#   'leader',
#   'who',
#   'said',
#   'abused',
#   'women',
#   'should',
#   'just',
#   'pray',
#   'is',
#   'removed',
#   'from',
#   'post'],
#  ['more', 'americans', 'than', 'ever', 'support', 'samesex', 'marriage'],
#  ['brynn',
#   'cartelli',
#   'becomes',
#   'youngestever',
#   'winner',
#   'of',
#   'the',
#   'voice'],
#  ['betsy',
#   'devos',
#   'stirs',
#   'uproar',
#   'by',
#   'saying',
#   'schools',
#   'can',
#   'call',
#   'ice',
#   'on',
#   'undocumented',
#   'kids'],
#  ['sandy',
#   'hook',
#   'families',
#   'fbi',
#   'agent',
#   'sue',
#   'alex',
#   'jones',
#   'for',
#   'defamation'],
#  ['high',
#   'school',
#   'teacher',
#   'defeats',
#   'kentucky',
#   'house',
#   'majority',
#   'leader',
#   'in',
#   'gop',
#   'primary'],
#  ['lupe',
#   'valdez',
#   'makes',
#   'history',
#   'in',
#   'texas',
#   'by',
#   'winning',
#   'democratic',
#   'nod',
#   'for',
#   'governor'],
#  ['report',
#   'michael',
#   'cohens',
#   'business',
#   'partner',
#   'cooperating',
#   'with',
#   'prosecutors'],
#  ['brandi',
#   'chastain',
#   'totally',
#   'agrees',
#   'her',
#   'hall',
#   'of',
#   'fame',
#   'plaque',
#   'looks',
#   'nothing',
#   'like',
#   'her'],
#  ['scientists',
#   'turn',
#   'to',
#   'dna',
#   'technology',
#   'to',
#   'search',
#   'for',
#   'loch',
#   'ness',
#   'monster'],
#  ['late',
#   'night',
#   'writer',
#   'vows',
#   'to',
#   'take',
#   'red',
#   'hats',
#   'back',
#   'from',
#   'trump',
#   'supporters'],
#  ['julia',
#   'louisdreyfus',
#   'to',
#   'receive',
#   'mark',
#   'twain',
#   'prize',
#   'for',
#   'american',
#   'humor'],
#  ['michelle',
#   'obama',
#   'shares',
#   'intimate',
#   'wedding',
#   'photo',
#   'in',
#   'tribute',
#   'to',
#   'husband',
#   'barack'],
#  ['did',
#   'you',
#   'spot',
#   'trevor',
#   'noah',
#   'in',
#   'black',
#   'panther',
#   'the',
#   'daily',
#   'show',
#   'hosts',
#   'stealth',
#   'cameo',
#   'revealed'],
#  ['donald',
#   'glover',
#   'fans',
#   'execute',
#   'stunning',
#   'coup',
#   'on',
#   'donald',
#   'trumpthemed',
#   'reddit',
#   'forum'],
#  ['ti',
#   'calls',
#   'for',
#   'boycott',
#   'of',
#   'restaurant',
#   'after',
#   'offduty',
#   'cop',
#   'allegedly',
#   'assaults',
#   'black',
#   'women'],
#  ['survivor',
#   'of',
#   'rwandan',
#   'genocide',
#   'to',
#   'be',
#   'countrys',
#   'first',
#   'female',
#   'neurosurgeon'],
#  ['stacey',
#   'abrams',
#   'wins',
#   'democratic',
#   'primary',
#   'for',
#   'georgia',
#   'governor'],
#  ['trevor',
#   'noah',
#   'reveals',
#   'the',
#   'question',
#   'hed',
#   'ask',
#   'donald',
#   'trump',
#   'that',
#   'no',
#   'else',
#   'has',
#   'dared',
#   'to'],
#  ['michelle',
#   'obama',
#   'reflects',
#   'on',
#   'scary',
#   'time',
#   'at',
#   'princeton',
#   'with',
#   'sweet',
#   'throwback',
#   'snap'],
#  ['reasons',
#   'why',
#   'started',
#   'a',
#   'conversation',
#   'whos',
#   'responsible',
#   'for',
#   'finishing',
#   'it'],
#  ['lourdes',
#   'leon',
#   'gives',
#   'us',
#   'major',
#   'madonna',
#   'vibes',
#   'in',
#   'moody',
#   'new',
#   'ad',
#   'campaign',
#   'pics'],
#  ['ways',
#   'netflix',
#   'tricks',
#   'you',
#   'into',
#   'watching',
#   'more',
#   'shows',
#   'and',
#   'movies'],
#  ['brad',
#   'pitt',
#   'made',
#   'ryan',
#   'reynolds',
#   'do',
#   'one',
#   'demeaning',
#   'thing',
#   'in',
#   'exchange',
#   'for',
#   'deadpool',
#   'cameo'],
#  ['robert',
#   'de',
#   'niro',
#   'bans',
#   'trump',
#   'from',
#   'every',
#   'nobu',
#   'restaurant'],
#  ['ariana',
#   'grande',
#   'shuts',
#   'down',
#   'fan',
#   'blaming',
#   'her',
#   'for',
#   'heartbreaking',
#   'mac',
#   'miller',
#   'split'],
#  ['parents',
#   'slam',
#   'show',
#   'dogs',
#   'scenes',
#   'as',
#   'grooming',
#   'children',
#   'for',
#   'sexual',
#   'abuse'],
#  ['dave',
#   'grohl',
#   'wants',
#   'to',
#   'apologize',
#   'to',
#   'the',
#   'world',
#   'for',
#   'massive',
#   'jerk',
#   'trump'],
#  ['emilia',
#   'clarke',
#   'introduced',
#   'herself',
#   'to',
#   'prince',
#   'william',
#   'in',
#   'a',
#   'pretty',
#   'embarrassing',
#   'way'],
#  ['sarah',
#   'paulson',
#   'takes',
#   'impressions',
#   'to',
#   'next',
#   'level',
#   'on',
#   'tonight',
#   'show'],
#  ['the',
#   'bs',
#   'are',
#   'still',
#   'ready',
#   'to',
#   'party',
#   'and',
#   'be',
#   'taken',
#   'seriously'],
#  ['gina',
#   'ortiz',
#   'jones',
#   'wins',
#   'democratic',
#   'runoff',
#   'in',
#   'texas',
#   'congressional',
#   'race'],
#  ['fighter',
#   'pilot',
#   'amy',
#   'mcgrath',
#   'wins',
#   'democratic',
#   'primary',
#   'in',
#   'kentucky',
#   'swing',
#   'district'],
#  ['trump',
#   'rallies',
#   'conservatives',
#   'with',
#   'promise',
#   'of',
#   'more',
#   'abortion',
#   'curbs'],
#  ['the',
#   'aclu',
#   'is',
#   'suing',
#   'to',
#   'strike',
#   'down',
#   'ohios',
#   'congressional',
#   'map'],
#  ['the',
#   'latest',
#   'school',
#   'shooting',
#   'hasnt',
#   'really',
#   'stirred',
#   'the',
#   'gun',
#   'debate'],
#  ['donald',
#   'trump',
#   'tweet',
#   'rescues',
#   'roseanne',
#   'and',
#   'family',
#   'in',
#   'season',
#   'finale'],
#  ['ellen',
#   'grills',
#   'mark',
#   'wahlberg',
#   'about',
#   'his',
#   'shirtless',
#   'instagram',
#   'selfies'],
#  ['idris',
#   'elba',
#   'to',
#   'star',
#   'as',
#   'the',
#   'new',
#   'hunchback',
#   'of',
#   'notre',
#   'dame',
#   'for',
#   'netflix'],
#  ['maryland',
#   'police',
#   'charge',
#   'church',
#   'leaders',
#   'with',
#   'past',
#   'abuse',
#   'of',
#   'atrisk',
#   'teen',
#   'girls'],
#  ['nfl', 'bans', 'kneeling', 'during', 'the', 'national', 'anthem'],
#  ['conan',
#   'obrien',
#   'muscles',
#   'in',
#   'on',
#   'the',
#   'royal',
#   'wedding',
#   'with',
#   'his',
#   'own',
#   'spoof',
#   'ads'],
#  ['house',
#   'republicans',
#   'report',
#   'progress',
#   'on',
#   'an',
#   'immigration',
#   'deal'],
#  ['democrats',
#   'werent',
#   'invited',
#   'to',
#   'review',
#   'classified',
#   'documents',
#   'on',
#   'fbi',
#   'informant'],
#  ['gop',
#   'candidate',
#   'who',
#   'pointed',
#   'gun',
#   'at',
#   'teenager',
#   'advances',
#   'to',
#   'georgia',
#   'governor',
#   'primary',
#   'runoff'],
#  ['walking',
#   'definition',
#   'of',
#   'an',
#   'entitled',
#   'millennial',
#   'swears',
#   'hes',
#   'not',
#   'an',
#   'entitled',
#   'millennial'],
#  ['democrats',
#   'push',
#   'to',
#   'be',
#   'included',
#   'in',
#   'classified',
#   'briefing',
#   'on',
#   'fbi',
#   'informant'],
#  ['machines',
#   'dont',
#   'always',
#   'steal',
#   'our',
#   'jobs',
#   'increasingly',
#   'they',
#   'rob',
#   'our',
#   'work',
#   'of',
#   'humanity'],
#  ['trump',
#   'praises',
#   'tomi',
#   'lahren',
#   'after',
#   'restaurant',
#   'crowd',
#   'tosses',
#   'water',
#   'insults'],
#  ['sarah', 'sanders', 'it', 'bothers', 'me', 'being', 'called', 'a', 'liar'],
#  ['trump',
#   'blocking',
#   'people',
#   'on',
#   'twitter',
#   'is',
#   'unconstitutional',
#   'judge',
#   'rules'],
#  ['a',
#   'mostly',
#   'nonchristian',
#   'militia',
#   'won',
#   'of',
#   'iraqi',
#   'christians',
#   'parliamentary',
#   'seats',
#   'now',
#   'christians',
#   'want',
#   'trump',
#   'to',
#   'intervene'],
#  ['tulsi',
#   'gabbards',
#   'syria',
#   'views',
#   'cost',
#   'her',
#   'support',
#   'of',
#   'hawaii',
#   'teachers',
#   'union'],
#  ['jared', 'kushner', 'received', 'his', 'security', 'clearance', 'reports'],
#  ['arizona',
#   'gop',
#   'congressional',
#   'candidate',
#   'compares',
#   'abortion',
#   'to',
#   'holocaust'],
#  ['gun',
#   'reform',
#   'advocate',
#   'lucy',
#   'mcbath',
#   'heads',
#   'to',
#   'runoff',
#   'for',
#   'georgia',
#   'house',
#   'seat'],
#  ['star',
#   'wars',
#   'burlesque',
#   'show',
#   'storms',
#   'west',
#   'coast',
#   'with',
#   'sexy',
#   'stormtroopers'],
#  ['establishmentbacked',
#   'moderate',
#   'wins',
#   'heated',
#   'democratic',
#   'house',
#   'primary',
#   'in',
#   'texas'],
#  ['senators',
#   'unveil',
#   'bill',
#   'to',
#   'crack',
#   'down',
#   'on',
#   'their',
#   'sexual',
#   'harassment'],
#  ['trips',
#   'to',
#   'take',
#   'from',
#   'new',
#   'york',
#   'city',
#   'on',
#   'a',
#   'long',
#   'weekend'],
#  ['disney',
#   'reveals',
#   'opening',
#   'seasons',
#   'for',
#   'star',
#   'wars',
#   'theme',
#   'park',
#   'lands'],
#  ['the',
#   'latest',
#   'entries',
#   'from',
#   'the',
#   'comedy',
#   'wildlife',
#   'photo',
#   'awards',
#   'will',
#   'cheer',
#   'you',
#   'up'],
#  ['bad',
#   'lip',
#   'reading',
#   'reveals',
#   'what',
#   'was',
#   'really',
#   'said',
#   'at',
#   'the',
#   'royal',
#   'wedding'],
#  ['australian',
#   'archbishop',
#   'convicted',
#   'of',
#   'covering',
#   'up',
#   'child',
#   'sex',
#   'abuse'],
#  ['commander',
#   'says',
#   'irans',
#   'people',
#   'will',
#   'respond',
#   'to',
#   'pompeos',
#   'threats',
#   'with',
#   'a',
#   'punch',
#   'in',
#   'the',
#   'mouth'],
#  ['mark',
#   'zuckerberg',
#   'extends',
#   'facebook',
#   'apology',
#   'tour',
#   'with',
#   'european',
#   'gig'],
#  ['ariana',
#   'grande',
#   'tweets',
#   'message',
#   'of',
#   'support',
#   'on',
#   'manchester',
#   'bombing',
#   'anniversary'],
#  ['katy', 'perry', 'says', 'shes', 'not', 'single', 'on', 'american', 'idol'],
#  ['before',
#   'you',
#   'call',
#   'the',
#   'cops',
#   'on',
#   'him',
#   'watch',
#   'his',
#   'powerful',
#   'monologue',
#   'on',
#   'racism'],
#  ['amazon',
#   'is',
#   'selling',
#   'cops',
#   'its',
#   'facial',
#   'recognition',
#   'tool',
#   'thats',
#   'a',
#   'bad',
#   'potentially',
#   'racist',
#   'move'],
#  ['miley',
#   'cyrus',
#   'comes',
#   'in',
#   'like',
#   'a',
#   'wrecking',
#   'ball',
#   'to',
#   'prank',
#   'a',
#   'sleeping',
#   'jimmy',
#   'kimmel'],
#  ['vanessa',
#   'bayer',
#   'feared',
#   'doing',
#   'the',
#   'porn',
#   'stars',
#   'skit',
#   'with',
#   'donald',
#   'trump',
#   'on',
#   'snl'],
#  ['adam',
#   'rippon',
#   'wins',
#   'dancing',
#   'with',
#   'the',
#   'stars',
#   'because',
#   'it',
#   'was',
#   'destined'],
#  ['emilia',
#   'clarke',
#   'should',
#   'never',
#   'try',
#   'to',
#   'imitate',
#   'chewbacca',
#   'ever',
#   'again'],
#  ['maddie',
#   'poppe',
#   'wins',
#   'american',
#   'idol',
#   'after',
#   'runnerup',
#   'reveals',
#   'theyre',
#   'dating'],
#  ['colbert',
#   'just',
#   'cant',
#   'resist',
#   'turning',
#   'trumps',
#   'nickname',
#   'into',
#   'a',
#   'pee',
#   'tape',
#   'joke'],
#  ['seth',
#   'meyers',
#   'is',
#   'forced',
#   'to',
#   'tweak',
#   'donald',
#   'trumps',
#   'latest',
#   'twitter',
#   'rant',
#   'for',
#   'time'],
#  ['boy',
#   'says',
#   'teacher',
#   'told',
#   'him',
#   'it',
#   'will',
#   'be',
#   'his',
#   'fault',
#   'when',
#   'police',
#   'shoot',
#   'him',
#   'at',
#   'age'],
#  ['cops',
#   'accused',
#   'of',
#   'racism',
#   'after',
#   'detaining',
#   'black',
#   'man',
#   'over',
#   'vegetation'],
#  ['white',
#   'cop',
#   'shouts',
#   'at',
#   'black',
#   'suspect',
#   'pretend',
#   'like',
#   'were',
#   'going',
#   'to',
#   'shoot',
#   'you'],
#  ['florida',
#   'police',
#   'report',
#   'dead',
#   'after',
#   'standoff',
#   'at',
#   'panama',
#   'city',
#   'apartment',
#   'complex'],
#  ['donald',
#   'glover',
#   'is',
#   'on',
#   'board',
#   'with',
#   'lando',
#   'calrissians',
#   'pansexuality',
#   'in',
#   'solo'],
#  ['charlize',
#   'theron',
#   'to',
#   'play',
#   'megyn',
#   'kelly',
#   'in',
#   'film',
#   'about',
#   'roger',
#   'ailes'],
#  ['shoppers',
#   'boycott',
#   'publix',
#   'over',
#   'stores',
#   'donations',
#   'to',
#   'nrabacked',
#   'candidate'],
#  ['bill',
#   'de',
#   'blasio',
#   'tells',
#   'nypd',
#   'to',
#   'stop',
#   'arresting',
#   'people',
#   'for',
#   'smoking',
#   'pot',
#   'on',
#   'the',
#   'street'],
#  ['dhs',
#   'head',
#   'says',
#   'shes',
#   'still',
#   'somehow',
#   'unaware',
#   'of',
#   'intel',
#   'on',
#   'russia',
#   'interference',
#   'to',
#   'boost',
#   'trump'],
#  ['lawmaker',
#   'introduces',
#   'crowdfunding',
#   'bill',
#   'to',
#   'pay',
#   'for',
#   'trumps',
#   'border',
#   'wall'],
#  ['gop',
#   'lawmakers',
#   'will',
#   'soon',
#   'be',
#   'allowed',
#   'to',
#   'review',
#   'classified',
#   'info',
#   'on',
#   'russia',
#   'investigation'],
#  ['james',
#   'corden',
#   'reveals',
#   'the',
#   'worst',
#   'part',
#   'of',
#   'the',
#   'royal',
#   'wedding',
#   'ceremony'],
#  ['ariana',
#   'grande',
#   'reportedly',
#   'dating',
#   'snl',
#   'star',
#   'pete',
#   'davidson'],
#  ['jim',
#   'carrey',
#   'pens',
#   'new',
#   'pledge',
#   'of',
#   'allegiance',
#   'for',
#   'students',
#   'in',
#   'bulletriddled',
#   'schools'],
#  ['ellen',
#   'gets',
#   'david',
#   'spade',
#   'to',
#   'open',
#   'up',
#   'about',
#   'dating',
#   'younger',
#   'women'],
#  ['ceasefire',
#   'over',
#   'jimmy',
#   'kimmel',
#   'shreds',
#   'sean',
#   'hannity',
#   'and',
#   'those',
#   'dummies',
#   'on',
#   'fox',
#   'friends'],
#  ['spoof',
#   'royal',
#   'wedding',
#   'video',
#   'sees',
#   'ceremony',
#   'taking',
#   'a',
#   'very',
#   'different',
#   'turn'],
#  ['the',
#   'georgia',
#   'gop',
#   'governors',
#   'primary',
#   'focuses',
#   'on',
#   'guns',
#   'and',
#   'immigration'],
#  ['glaads',
#   'movie',
#   'report',
#   'finds',
#   'troubling',
#   'drop',
#   'in',
#   'lgbtq',
#   'representation'],
#  ['sephora',
#   'now',
#   'offers',
#   'instore',
#   'beauty',
#   'classes',
#   'for',
#   'trans',
#   'nonbinary',
#   'community'],
#  ['georgia',
#   'governors',
#   'primary',
#   'highlights',
#   'competing',
#   'visions',
#   'for',
#   'the',
#   'democratic',
#   'party'],
#  ['california',
#   'moves',
#   'to',
#   'let',
#   'schools',
#   'coworkers',
#   'red',
#   'flag',
#   'dangerous',
#   'gun',
#   'owners'],
#  ['talking',
#   'grievance',
#   'and',
#   'health',
#   'care',
#   'an',
#   'outsider',
#   'kentucky',
#   'dem',
#   'found',
#   'the',
#   'inside',
#   'track'],
#  ['there',
#   'are',
#   'some',
#   'problems',
#   'with',
#   'this',
#   'commemorative',
#   'trumpkim',
#   'jong',
#   'un',
#   'coin'],
#  ['giulianis',
#   'new',
#   'stance',
#   'on',
#   'russian',
#   'collusion',
#   'so',
#   'what',
#   'its',
#   'not',
#   'illegal'],
#  ['the',
#   'onion',
#   'hilariously',
#   'trolls',
#   'michael',
#   'cohen',
#   'with',
#   'his',
#   'own',
#   'ceaseanddesist',
#   'note'],
#  ['democrats',
#   'want',
#   'to',
#   'boost',
#   'school',
#   'funding',
#   'to',
#   'address',
#   'teacher',
#   'walkouts'],
#  ['but',
#   'her',
#   'emails',
#   'lawmakers',
#   'shrug',
#   'off',
#   'trumps',
#   'lax',
#   'cellphone',
#   'security'],
#  ['we',
#   'try',
#   'stink',
#   'bugflavored',
#   'jelly',
#   'bellys',
#   'so',
#   'you',
#   'dont',
#   'have',
#   'to'],
#  ['power',
#   'outage',
#   'triggers',
#   'extreme',
#   'zombie',
#   'activity',
#   'alert',
#   'in',
#   'florida',
#   'city'],
#  ['congress',
#   'does',
#   'wall',
#   'street',
#   'a',
#   'favor',
#   'as',
#   'banks',
#   'post',
#   'record',
#   'profits'],
#  ['white', 'house', 'sinkhole', 'probably', 'metaphor', 'for', 'something'],
#  ['reporter',
#   'shoved',
#   'others',
#   'barred',
#   'from',
#   'epa',
#   'meeting',
#   'on',
#   'water',
#   'contaminants'],
#  ['garry',
#   'kasparov',
#   'donald',
#   'trump',
#   'has',
#   'more',
#   'russian',
#   'connections',
#   'than',
#   'aeroflot'],
#  ['lonely',
#   'planets',
#   'top',
#   'european',
#   'destinations',
#   'of',
#   'take',
#   'aim',
#   'at',
#   'overtourism'],
#  ['attorney',
#   'aaron',
#   'schlossberg',
#   'insists',
#   'antispanish',
#   'rant',
#   'is',
#   'not',
#   'the',
#   'person',
#   'i',
#   'am'],
#  ['minutes',
#   'reporter',
#   'reveals',
#   'trumps',
#   'chilling',
#   'reason',
#   'for',
#   'slamming',
#   'the',
#   'press'],
#  ['trump',
#   'reportedly',
#   'rejects',
#   'phone',
#   'security',
#   'measures',
#   'as',
#   'too',
#   'inconvenient'],
#  ['federal',
#   'court',
#   'sides',
#   'with',
#   'transgender',
#   'teen',
#   'gavin',
#   'grimm',
#   'in',
#   'bathroom',
#   'fight'],
#  ['extrump',
#   'adviser',
#   'calls',
#   'presidents',
#   'claims',
#   'that',
#   'informant',
#   'spied',
#   'on',
#   'campaign',
#   'embarrassing'],
#  ['vietnam',
#   'is',
#   'a',
#   'test',
#   'for',
#   'what',
#   'happens',
#   'when',
#   'the',
#   'us',
#   'abandons',
#   'climate',
#   'diplomacy'],
#  ['just',
#   'onethird',
#   'of',
#   'americans',
#   'think',
#   'trump',
#   'is',
#   'successfully',
#   'draining',
#   'the',
#   'swamp'],
#  ['msnbc',
#   'host',
#   'hugh',
#   'hewitt',
#   'suggests',
#   'trench',
#   'coat',
#   'control',
#   'not',
#   'gun',
#   'control'],
#  ['bishop',
#   'michael',
#   'curry',
#   'harry',
#   'and',
#   'meghans',
#   'love',
#   'brought',
#   'different',
#   'worlds',
#   'together'],
#  ['sarah',
#   'paulson',
#   'is',
#   'unapologetic',
#   'about',
#   'year',
#   'age',
#   'gap',
#   'with',
#   'girlfriend',
#   'holland',
#   'taylor'],
#  ['texans',
#   'on',
#   'both',
#   'sides',
#   'of',
#   'gun',
#   'debate',
#   'agree',
#   'on',
#   'safe',
#   'storage',
#   'but',
#   'not',
#   'on',
#   'how',
#   'to',
#   'support',
#   'it'],
#  ['family',
#   'of',
#   'gay',
#   'man',
#   'found',
#   'critically',
#   'injured',
#   'near',
#   'amtrak',
#   'route',
#   'wants',
#   'answers'],
#  ['caitlyn',
#   'jenner',
#   'trump',
#   'is',
#   'the',
#   'worst',
#   'president',
#   'we',
#   'have',
#   'ever',
#   'had',
#   'on',
#   'lgbtq',
#   'rights'],
#  ['boy',
#   'scout',
#   'allegedly',
#   'booted',
#   'from',
#   'store',
#   'because',
#   'company',
#   'wont',
#   'support',
#   'homos'],
#  ['instagram',
#   'is',
#   'adding',
#   'a',
#   'mute',
#   'button',
#   'for',
#   'the',
#   'sake',
#   'of',
#   'your',
#   'sanity'],
#  ['publix', 'censors', 'teens', 'summa', 'cum', 'laude', 'graduation', 'cake'],
#  ['what',
#   'do',
#   'you',
#   'say',
#   'to',
#   'sexist',
#   'passengers',
#   'this',
#   'female',
#   'pilot',
#   'has',
#   'the',
#   'perfect',
#   'response'],
#  ['times',
#   'up',
#   'takes',
#   'aim',
#   'at',
#   'mcdonalds',
#   'walmart',
#   'over',
#   'sexual',
#   'harassment',
#   'complaints'],
#  ['venezuelas',
#   'socialist',
#   'leader',
#   'nicolas',
#   'maduro',
#   'reelected',
#   'amid',
#   'allegations',
#   'of',
#   'irregularities'],
#  ['iran',
#   'says',
#   'europes',
#   'support',
#   'for',
#   'nuclear',
#   'deal',
#   'isnt',
#   'enough',
#   'after',
#   'americas',
#   'withdrawal'],
#  ['farright', 'mob', 'attacks', 'yearold', 'liberal', 'greek', 'mayor'],
#  ['shawn',
#   'mendes',
#   'and',
#   'khalid',
#   'perform',
#   'with',
#   'parkland',
#   'survivors',
#   'at',
#   'billboard',
#   'music',
#   'awards'],
#  ['tamir',
#   'rices',
#   'mother',
#   'is',
#   'opening',
#   'a',
#   'youth',
#   'center',
#   'to',
#   'honor',
#   'her',
#   'sons',
#   'memory'],
#  ['judge',
#   'orders',
#   'texas',
#   'to',
#   'make',
#   'voter',
#   'registration',
#   'easier',
#   'when',
#   'updating',
#   'dmv',
#   'info'],
#  ['kelly',
#   'clarkson',
#   'calls',
#   'for',
#   'moments',
#   'of',
#   'action',
#   'in',
#   'honor',
#   'of',
#   'texas',
#   'shooting',
#   'victims',
#   'at',
#   'billboard',
#   'awards'],
#  ['kendrick', 'lamar', 'stops', 'white', 'fan', 'rapping', 'nword', 'onstage'],
#  ['gay',
#   'man',
#   'says',
#   'pope',
#   'francis',
#   'told',
#   'him',
#   'god',
#   'made',
#   'you',
#   'like',
#   'that',
#   'and',
#   'loves',
#   'you',
#   'like',
#   'that'],
#  ['unusual',
#   'asteroid',
#   'could',
#   'be',
#   'an',
#   'interstellar',
#   'guest',
#   'to',
#   'our',
#   'solar',
#   'system'],
#  ['she',
#   'started',
#   'a',
#   'suicide',
#   'prevention',
#   'site',
#   'at',
#   'age',
#   'its',
#   'still',
#   'going',
#   'strong'],
#  ['roger',
#   'stone',
#   'says',
#   'hes',
#   'prepared',
#   'for',
#   'conjured',
#   'up',
#   'mueller',
#   'indictment'],
#  ['hillary', 'clinton', 'to', 'endorse', 'andrew', 'cuomos', 'reelection'],
#  ['the',
#   'supreme',
#   'court',
#   'just',
#   'made',
#   'it',
#   'a',
#   'lot',
#   'harder',
#   'for',
#   'you',
#   'to',
#   'sue',
#   'your',
#   'employer'],
#  ['blake',
#   'farenthold',
#   'may',
#   'have',
#   'been',
#   'hired',
#   'illegally',
#   'at',
#   'his',
#   'new',
#   'lobbyist',
#   'job'],
#  ['bill',
#   'konigsberg',
#   'explores',
#   'a',
#   'new',
#   'side',
#   'of',
#   'the',
#   'gay',
#   'experience',
#   'in',
#   'his',
#   'latest',
#   'book'],
#  ['alone',
#   'in',
#   'the',
#   'game',
#   'shows',
#   'biggest',
#   'hurdles',
#   'for',
#   'lgbtq',
#   'athletes',
#   'exist',
#   'off',
#   'the',
#   'field'],
#  ['chrissy',
#   'teigen',
#   'somehow',
#   'gets',
#   'even',
#   'more',
#   'real',
#   'about',
#   'life',
#   'after',
#   'childbirth'],
#  ['suits',
#   'creator',
#   'pens',
#   'heartfelt',
#   'open',
#   'letter',
#   'about',
#   'attending',
#   'royal',
#   'wedding'],
#  ['here', 'are', 'the', 'movies', 'coming', 'to', 'netflix', 'this', 'week'],
#  ['the', 'obamas', 'are', 'coming', 'to', 'your', 'netflix', 'queue'],
#  ['sorry',
#   'ben',
#   'affleck',
#   'make',
#   'way',
#   'for',
#   'justin',
#   'therouxs',
#   'giant',
#   'rat',
#   'tattoo'],
#  ['hillary',
#   'clinton',
#   'tips',
#   'a',
#   'russian',
#   'hat',
#   'at',
#   'trump',
#   'during',
#   'yale',
#   'commencement',
#   'speech'],
#  ['giuliani',
#   'says',
#   'mueller',
#   'cant',
#   'talk',
#   'to',
#   'trump',
#   'until',
#   'trump',
#   'hears',
#   'more',
#   'about',
#   'fbi',
#   'source'],
#  ['democrats', 'plan', 'big', 'anticorruption', 'theme', 'for', 'midterms'],
#  ['kelly',
#   'clarkson',
#   'rejects',
#   'moment',
#   'of',
#   'silence',
#   'calls',
#   'for',
#   'change',
#   'at',
#   'billboard',
#   'music',
#   'awards'],
#  ['we',
#   'asked',
#   'the',
#   'american',
#   'public',
#   'to',
#   'settle',
#   'of',
#   'the',
#   'internets',
#   'dumbest',
#   'debates'],
#  ['fox',
#   'news',
#   'viewers',
#   'really',
#   'dont',
#   'like',
#   'lifelong',
#   'republican',
#   'robert',
#   'mueller'],
#  ['trump',
#   'team',
#   'moves',
#   'to',
#   'lift',
#   'ban',
#   'on',
#   'extreme',
#   'hunting',
#   'tactics',
#   'in',
#   'alaska'],
#  ['howard',
#   'stern',
#   'tells',
#   'how',
#   'trump',
#   'sexualized',
#   'ivanka',
#   'and',
#   'makes',
#   'david',
#   'letterman',
#   'cringe'],
#  ['the',
#   'supreme',
#   'court',
#   'is',
#   'helping',
#   'companies',
#   'get',
#   'away',
#   'with',
#   'sexual',
#   'harassment'],
#  ['deadpool',
#   'steals',
#   'no',
#   'spot',
#   'at',
#   'the',
#   'box',
#   'office',
#   'from',
#   'avengers',
#   'infinity',
#   'war'],
#  ['did', 'westworld', 'subtly', 'tease', 'that', 'baby', 'theory'],
#  ['donald',
#   'glover',
#   'tells',
#   'ellen',
#   'about',
#   'his',
#   'full',
#   'circle',
#   'star',
#   'wars',
#   'moment',
#   'with',
#   'his',
#   'son'],
#  ['a',
#   'marvel',
#   'exec',
#   'tried',
#   'to',
#   'stop',
#   'the',
#   'most',
#   'jarring',
#   'infinity',
#   'war',
#   'death'],
#  ['jake',
#   'gyllenhaal',
#   'set',
#   'to',
#   'star',
#   'as',
#   'villain',
#   'in',
#   'spiderman',
#   'sequel'],
#  ['janet',
#   'jackson',
#   'becomes',
#   'first',
#   'black',
#   'woman',
#   'to',
#   'receive',
#   'billboard',
#   'icon',
#   'award'],
#  ['this',
#   'isnt',
#   'pakistan',
#   'bitch',
#   'video',
#   'captures',
#   'drivers',
#   'racist',
#   'rant'],
#  ['the',
#   'grey',
#   'gardens',
#   'ladies',
#   'were',
#   'the',
#   'unwitting',
#   'godmothers',
#   'of',
#   'reality',
#   'tv',
#   'archetypes'],
#  ['yearold',
#   'boy',
#   'is',
#   'a',
#   'superhero',
#   'to',
#   'alabamas',
#   'homeless',
#   'population'],
#  ['john',
#   'oliver',
#   'has',
#   'the',
#   'best',
#   'time',
#   'mocking',
#   'the',
#   'royal',
#   'wedding'],
#  ['john',
#   'oliver',
#   'needles',
#   'the',
#   'dangerously',
#   'unregulated',
#   'rehab',
#   'industry'],
#  ['jemele',
#   'hill',
#   'honored',
#   'as',
#   'nabjs',
#   'journalist',
#   'of',
#   'the',
#   'year'],
#  ['french',
#   'digital',
#   'minister',
#   'comes',
#   'out',
#   'as',
#   'gay',
#   'to',
#   'fight',
#   'homophobia'],
#  ['belgian',
#   'transgender',
#   'ballet',
#   'drama',
#   'wins',
#   'big',
#   'at',
#   'cannes',
#   'film',
#   'festival'],
#  ['yearold',
#   'gay',
#   'man',
#   'proves',
#   'youre',
#   'never',
#   'too',
#   'old',
#   'to',
#   'attend',
#   'your',
#   'first',
#   'pride'],
#  ['super',
#   'pacs',
#   'that',
#   'meddled',
#   'in',
#   'west',
#   'virginias',
#   'senate',
#   'primary',
#   'didnt',
#   'receive',
#   'a',
#   'penny',
#   'from',
#   'west',
#   'virginians'],
#  ['airline',
#   'passenger',
#   'arrested',
#   'after',
#   'allegedly',
#   'harassing',
#   'woman',
#   'and',
#   'peeing',
#   'on',
#   'seat'],
#  ['mike',
#   'pompeo',
#   'promises',
#   'to',
#   'crush',
#   'iran',
#   'and',
#   'achieve',
#   'a',
#   'better',
#   'deal'],
#  ['majestic',
#   'islands',
#   'in',
#   'europe',
#   'that',
#   'most',
#   'tourists',
#   'dont',
#   'know',
#   'about',
#   'yet'],
#  ['cuba',
#   'confirms',
#   'killed',
#   'in',
#   'countrys',
#   'deadliest',
#   'plane',
#   'crash',
#   'since'],
#  ['us',
#   'china',
#   'putting',
#   'trade',
#   'war',
#   'on',
#   'hold',
#   'treasurys',
#   'steve',
#   'mnuchin',
#   'says'],
#  ['trumps',
#   'top',
#   'economic',
#   'adviser',
#   'says',
#   'amazon',
#   'threats',
#   'are',
#   'not',
#   'in',
#   'my',
#   'lane'],
#  ['dems',
#   'trump',
#   'admin',
#   'find',
#   'common',
#   'ground',
#   'helping',
#   'victims',
#   'of',
#   'myanmars',
#   'genocide'],
#  ['giuliani',
#   'says',
#   'mueller',
#   'will',
#   'wrap',
#   'up',
#   'trump',
#   'obstruction',
#   'probe',
#   'by',
#   'september',
#   'report'],
#  ['german',
#   'broadcaster',
#   'criticized',
#   'for',
#   'racist',
#   'coverage',
#   'of',
#   'royal',
#   'wedding'],
#  ['kathryn',
#   'newton',
#   'the',
#   'boldest',
#   'teen',
#   'on',
#   'tv',
#   'is',
#   'ready',
#   'to',
#   'grow',
#   'up'],
#  ['stephanie', 'kelton', 'has', 'the', 'biggest', 'idea', 'in', 'washington'],
#  ['texas',
#   'govs',
#   'campaign',
#   'cancels',
#   'shotgun',
#   'giveaway',
#   'after',
#   'santa',
#   'fe',
#   'school',
#   'shooting'],
#  ['tina',
#   'feys',
#   'sarah',
#   'palin',
#   'leads',
#   'snl',
#   'chorus',
#   'lamenting',
#   'what',
#   'i',
#   'did',
#   'for',
#   'trump'],
#  ['after',
#   'day',
#   'of',
#   'american',
#   'gushing',
#   'snl',
#   'goes',
#   'smart',
#   'aleck',
#   'on',
#   'the',
#   'royal',
#   'wedding'],
#  ['starbucks',
#   'says',
#   'anyone',
#   'can',
#   'now',
#   'sit',
#   'in',
#   'its',
#   'cafes',
#   'even',
#   'without',
#   'buying',
#   'anything'],
#  ['alec',
#   'baldwins',
#   'trump',
#   'faces',
#   'ominous',
#   'sopranos',
#   'scenario',
#   'in',
#   'snl',
#   'finale'],
#  ['asia',
#   'argentos',
#   'fiery',
#   'speech',
#   'closes',
#   'cannes',
#   'i',
#   'was',
#   'raped',
#   'by',
#   'harvey',
#   'weinstein',
#   'here'],
#  ['tina',
#   'fey',
#   'tries',
#   'out',
#   'for',
#   'mean',
#   'girls',
#   'the',
#   'musical',
#   'on',
#   'snl'],
#  ['parents',
#   'of',
#   'school',
#   'shooting',
#   'victims',
#   'decry',
#   'moronic',
#   'gop',
#   'platitudes'],
#  ['trump',
#   'real',
#   'americans',
#   'should',
#   'get',
#   'tough',
#   'on',
#   'russia',
#   'probe'],
#  ['chrissy',
#   'teigen',
#   'john',
#   'legend',
#   'announce',
#   'name',
#   'of',
#   'baby',
#   'boy',
#   'with',
#   'adorable',
#   'photo'],
#  ['texas',
#   'lt',
#   'gov',
#   'dan',
#   'patrick',
#   'touts',
#   'need',
#   'to',
#   'arm',
#   'teachers'],
#  ['david',
#   'hogg',
#   'calls',
#   'on',
#   'media',
#   'to',
#   'stop',
#   'naming',
#   'santa',
#   'fe',
#   'school',
#   'shooter'],
#  ['trump',
#   'sets',
#   'up',
#   'showdown',
#   'with',
#   'doj',
#   'over',
#   'claims',
#   'of',
#   'campaign',
#   'surveillance'],
#  ['jim',
#   'carreys',
#   'latest',
#   'painting',
#   'slams',
#   'kent',
#   'state',
#   'goldilocks',
#   'and',
#   'her',
#   'ar'],
#  ['oliver', 'north', 'blames', 'school', 'shootings', 'on', 'ritalin'],
#  ['jimmy',
#   'kimmel',
#   'tricks',
#   'royal',
#   'fans',
#   'into',
#   'reviewing',
#   'the',
#   'wedding',
#   'before',
#   'the',
#   'big',
#   'day'],
#  ['jimmy',
#   'fallon',
#   'reveals',
#   'his',
#   'viewers',
#   'biggest',
#   'wedding',
#   'fails'],
#  ['protesters',
#   'throw',
#   'a',
#   'fiesta',
#   'to',
#   'razz',
#   'lawyer',
#   'who',
#   'ranted',
#   'at',
#   'spanish',
#   'speakers'],
#  ['what',
#   'to',
#   'watch',
#   'on',
#   'amazon',
#   'prime',
#   'thats',
#   'new',
#   'this',
#   'week'],
#  ['will',
#   'ferrell',
#   'and',
#   'molly',
#   'shannon',
#   'cover',
#   'the',
#   'royal',
#   'wedding',
#   'as',
#   'cord',
#   'and',
#   'tish'],
#  ['the',
#   'artist',
#   'formerly',
#   'known',
#   'as',
#   'cedric',
#   'the',
#   'entertainer',
#   'has',
#   'arrived'],
#  ['mark',
#   'kelly',
#   'trump',
#   'rolled',
#   'over',
#   'for',
#   'nra',
#   'did',
#   'nothing',
#   'about',
#   'guns',
#   'after',
#   'parkland'],
#  ['gop',
#   'candidate',
#   'set',
#   'up',
#   'trust',
#   'that',
#   'pays',
#   'his',
#   'kids',
#   'for',
#   'marrying',
#   'white',
#   'people'],
#  ['houston',
#   'police',
#   'chief',
#   'says',
#   'hes',
#   'sick',
#   'of',
#   'inaction',
#   'on',
#   'gun',
#   'control'],
#  ['the', 'history', 'of', 'the', 'national', 'anthem', 'in', 'sports'],
#  ['bbc',
#   'trolls',
#   'president',
#   'trump',
#   'with',
#   'bigly',
#   'huge',
#   'royal',
#   'wedding',
#   'crowd'],
#  ['these',
#   'are',
#   'the',
#   'victims',
#   'of',
#   'the',
#   'santa',
#   'fe',
#   'high',
#   'school',
#   'shooting'],
#  ['this',
#   'ceo',
#   'took',
#   'a',
#   'pay',
#   'cut',
#   'to',
#   'give',
#   'employees',
#   'a',
#   'year',
#   'now',
#   'hes',
#   'battling',
#   'amazon'],
#  ['trump',
#   'jr',
#   'met',
#   'with',
#   'emissary',
#   'for',
#   'gulf',
#   'princes',
#   'offering',
#   'help',
#   'with',
#   'campaign',
#   'in',
#   'report'],
#  ['trump',
#   'misspells',
#   'melanias',
#   'name',
#   'in',
#   'welcome',
#   'home',
#   'tweet',
#   'twitter',
#   'roars'],
#  ['jimmy',
#   'kimmel',
#   'shreds',
#   'cowardly',
#   'trump',
#   'lawmakers',
#   'after',
#   'texas',
#   'school',
#   'shooting'],
#  ['bill',
#   'maher',
#   'reveals',
#   'things',
#   'you',
#   'dont',
#   'know',
#   'about',
#   'michael',
#   'cohen'],
#  ['what', 'to', 'watch', 'on', 'hulu', 'thats', 'new', 'this', 'week'],
#  ['students',
#   'stage',
#   'sitin',
#   'for',
#   'gun',
#   'control',
#   'outside',
#   'paul',
#   'ryans',
#   'office',
#   'get',
#   'arrested'],
#  ['trump',
#   'knew',
#   'a',
#   'scary',
#   'amount',
#   'about',
#   'the',
#   'appearance',
#   'of',
#   'bill',
#   'gates',
#   'daughter'],
#  ['exrussian',
#   'spy',
#   'sergei',
#   'skripal',
#   'discharged',
#   'from',
#   'uk',
#   'hospital',
#   'after',
#   'poisoning',
#   'incident'],
#  ['cuba', 'plane', 'crash', 'reportedly', 'kills', 'over'],
#  ['trump',
#   'reassures',
#   'north',
#   'korea',
#   'but',
#   'threatens',
#   'total',
#   'decimation',
#   'without',
#   'a',
#   'deal'],
#  ['ariana',
#   'grande',
#   'gives',
#   'fans',
#   'singing',
#   'one',
#   'last',
#   'time',
#   'the',
#   'surprise',
#   'of',
#   'their',
#   'lives'],
#  ['cambridge',
#   'analytica',
#   'files',
#   'for',
#   'chapter',
#   'bankruptcy',
#   'after',
#   'facebook',
#   'privacy',
#   'row'],
#  ['santa',
#   'fe',
#   'high',
#   'schoolers',
#   'held',
#   'gun',
#   'violence',
#   'protest',
#   'month',
#   'before',
#   'shooting'],
#  ['michelle',
#   'wolfs',
#   'netflix',
#   'trailer',
#   'gives',
#   'us',
#   'a',
#   'closer',
#   'look',
#   'at',
#   'her',
#   'new',
#   'show'],
#  ['jeff',
#   'sessions',
#   'uses',
#   'exceptional',
#   'power',
#   'over',
#   'immigration',
#   'courts',
#   'to',
#   'limit',
#   'judges',
#   'authority'],
#  ['gop',
#   'rep',
#   'introduces',
#   'bill',
#   'that',
#   'would',
#   'demand',
#   'white',
#   'house',
#   'apologize',
#   'to',
#   'mccain'],
#  ['colbert',
#   'has',
#   'a',
#   'super',
#   'graphic',
#   'way',
#   'of',
#   'describing',
#   'how',
#   'deep',
#   'muellers',
#   'probe',
#   'goes',
#   'now'],
#  ['jack', 'osbournes', 'wife', 'files', 'for', 'divorce'],
#  ['meek',
#   'mill',
#   'backs',
#   'out',
#   'of',
#   'trump',
#   'event',
#   'on',
#   'prison',
#   'reform'],
#  ['new',
#   'trump',
#   'rule',
#   'would',
#   'cut',
#   'federal',
#   'funds',
#   'from',
#   'clinics',
#   'providing',
#   'abortions'],
#  ['twitter',
#   'users',
#   'joke',
#   'trump',
#   'wants',
#   'prison',
#   'reform',
#   'because',
#   'thats',
#   'where',
#   'hes',
#   'headed'],
#  ['every',
#   'single',
#   'chilean',
#   'bishop',
#   'offers',
#   'to',
#   'resign',
#   'over',
#   'countrys',
#   'sex',
#   'abuse',
#   'scandal'],
#  ['ariana',
#   'grande',
#   'calls',
#   'manchester',
#   'attack',
#   'the',
#   'worst',
#   'of',
#   'humanity',
#   'one',
#   'year',
#   'later'],
#  ['chrissy',
#   'teigen',
#   'spills',
#   'first',
#   'details',
#   'about',
#   'new',
#   'baby',
#   'boy',
#   'we',
#   'are',
#   'in',
#   'love'],
#  ['alec',
#   'baldwin',
#   'and',
#   'wife',
#   'hilaria',
#   'welcome',
#   'another',
#   'baby',
#   'boy'],
#  ['kate',
#   'mckinnon',
#   'breaks',
#   'out',
#   'another',
#   'impression',
#   'of',
#   'rudy',
#   'giuliani'],
#  ['how',
#   'did',
#   'smallvilles',
#   'allison',
#   'mack',
#   'get',
#   'involved',
#   'with',
#   'a',
#   'sex',
#   'cult',
#   'in',
#   'the',
#   'first',
# ...
#   'for',
#   'ohio',
#   'legislature'],
#  ['mastermind',
#   'waterboarded',
#   'by',
#   'cia',
#   'has',
#   'information',
#   'to',
#   'share',
#   'about',
#   'gina',
#   'haspel'],
#  ['conservative',
#   'senate',
#   'democrat',
#   'who',
#   'backs',
#   'trumps',
#   'agenda',
#   'defeats',
#   'progressive',
#   'challenger'],
#  ['taylor',
#   'swift',
#   'mightve',
#   'made',
#   'up',
#   'with',
#   'katy',
#   'perry',
#   'but',
#   'her',
#   'kimye',
#   'feud',
#   'lives',
#   'on'],
#  ['kim',
#   'kardashian',
#   'to',
#   'make',
#   'history',
#   'with',
#   'fashion',
#   'councils',
#   'first',
#   'influencer',
#   'award'],
#  ['nbc',
#   'says',
#   'it',
#   'believes',
#   'matt',
#   'lauers',
#   'accusers',
#   'after',
#   'monthslong',
#   'investigation'],
#  ['russians',
#   'had',
#   'ability',
#   'to',
#   'change',
#   'voter',
#   'data',
#   'but',
#   'didnt',
#   'report',
#   'says'],
#  ['elizabeth',
#   'warrens',
#   'pick',
#   'wins',
#   'ohios',
#   'democratic',
#   'gubernatorial',
#   'primary'],
#  ['kkk',
#   'leader',
#   'found',
#   'guilty',
#   'of',
#   'firing',
#   'gun',
#   'at',
#   'charlottesville',
#   'rally'],
#  ['protesters',
#   'decrying',
#   'torture',
#   'dragged',
#   'from',
#   'gina',
#   'haspel',
#   'senate',
#   'hearing'],
#  ['att',
#   'hired',
#   'firm',
#   'linked',
#   'to',
#   'michael',
#   'cohen',
#   'to',
#   'get',
#   'the',
#   'inside',
#   'scoop',
#   'on',
#   'trump'],
#  ['the',
#   'rnc',
#   'is',
#   'selling',
#   'sickening',
#   'donald',
#   'trumpthemed',
#   'merch',
#   'ahead',
#   'of',
#   'mothers',
#   'day'],
#  ['don',
#   'blankenships',
#   'defeat',
#   'is',
#   'a',
#   'relief',
#   'to',
#   'the',
#   'families',
#   'of',
#   'upper',
#   'big',
#   'branch',
#   'miners'],
#  ['colbert',
#   'shreds',
#   'trump',
#   'over',
#   'broken',
#   'promises',
#   'what',
#   'are',
#   'you',
#   'talking',
#   'about'],
#  ['new',
#   'us',
#   'ambassador',
#   'to',
#   'germany',
#   'offends',
#   'hosts',
#   'just',
#   'hours',
#   'into',
#   'his',
#   'first',
#   'day'],
#  ['jordan',
#   'peeles',
#   'new',
#   'nightmare',
#   'is',
#   'coming',
#   'out',
#   'next',
#   'year'],
#  ['the',
#   'backstreet',
#   'boys',
#   'dressed',
#   'as',
#   'the',
#   'spice',
#   'girls',
#   'are',
#   'larger',
#   'than',
#   'life'],
#  ['seth',
#   'meyers',
#   'decodes',
#   'teen',
#   'slang',
#   'reveals',
#   'what',
#   'giuliani',
#   'really',
#   'means'],
#  ['heres',
#   'a',
#   'look',
#   'at',
#   'orlandos',
#   'interim',
#   'pulse',
#   'nightclub',
#   'memorial'],
#  ['trevor',
#   'noah',
#   'turns',
#   'donald',
#   'trumps',
#   'knives',
#   'comment',
#   'into',
#   'reggae',
#   'magic'],
#  ['senators',
#   'force',
#   'a',
#   'vote',
#   'that',
#   'may',
#   'ultimately',
#   'reverse',
#   'fcc',
#   'restore',
#   'net',
#   'neutrality'],
#  ['ny',
#   'legislature',
#   'has',
#   'plan',
#   'in',
#   'place',
#   'to',
#   'consider',
#   'replacements',
#   'for',
#   'eric',
#   'schneiderman'],
#  ['more',
#   'than',
#   'former',
#   'ambassadors',
#   'write',
#   'letter',
#   'opposing',
#   'gina',
#   'haspel',
#   'nomination'],
#  ['california',
#   'authority',
#   'says',
#   'states',
#   'new',
#   'homes',
#   'must',
#   'be',
#   'solar',
#   'powered'],
#  ['ny',
#   'governor',
#   'assigns',
#   'investigation',
#   'into',
#   'eric',
#   'schneiderman',
#   'abuse',
#   'allegations'],
#  ['how',
#   'the',
#   'refugee',
#   'caravan',
#   'became',
#   'a',
#   'scapegoat',
#   'for',
#   'trumps',
#   'border',
#   'crackdown'],
#  ['pennsylvania',
#   'becomes',
#   'latest',
#   'state',
#   'to',
#   'fund',
#   'urban',
#   'gun',
#   'violence',
#   'prevention'],
#  ['denver',
#   'mayors',
#   'son',
#   'caught',
#   'on',
#   'tape',
#   'berating',
#   'cop',
#   'as',
#   'a',
#   'faggot'],
#  ['progressive', 'prosecutors', 'win', 'primaries', 'in', 'north', 'carolina'],
#  ['what',
#   'did',
#   'att',
#   'and',
#   'novartis',
#   'get',
#   'for',
#   'the',
#   'money',
#   'they',
#   'paid',
#   'trumps',
#   'lawyer'],
#  ['the',
#   'hypocrisy',
#   'of',
#   'melania',
#   'trumps',
#   'online',
#   'safety',
#   'booklet',
#   'pointed',
#   'out',
#   'page',
#   'by',
#   'page'],
#  ['the',
#   'uninsured',
#   'rate',
#   'is',
#   'worsening',
#   'after',
#   'years',
#   'of',
#   'obamacares',
#   'gains'],
#  ['bernie', 'sanders', 'has', 'a', 'plan', 'to', 'revive', 'labor', 'unions'],
#  ['jim',
#   'carrey',
#   'bestows',
#   'scott',
#   'pruitt',
#   'with',
#   'a',
#   'savage',
#   'nickname',
#   'in',
#   'latest',
#   'painting'],
#  ['when', 'male', 'allies', 'become', 'abusers'],
#  ['mormon',
#   'church',
#   'to',
#   'end',
#   'its',
#   'centurylong',
#   'relationship',
#   'with',
#   'the',
#   'boy',
#   'scouts'],
#  ['our', 'snack', 'addiction', 'is', 'killing', 'orangutans'],
#  ['trumps',
#   'pick',
#   'for',
#   'cia',
#   'director',
#   'wont',
#   'say',
#   'torture',
#   'program',
#   'was',
#   'morally',
#   'wrong'],
#  ['anderson',
#   'cooper',
#   'burns',
#   'moronic',
#   'michael',
#   'cohen',
#   'over',
#   'russia',
#   'cash',
#   'claims'],
#  ['pinata',
#   'maker',
#   'apologizes',
#   'for',
#   'hanging',
#   'black',
#   'figures',
#   'in',
#   'the',
#   'likeness',
#   'of',
#   'lynchings'],
#  ['the', 'caliphate', 'of', 'trump', 'and', 'a', 'planet', 'in', 'ruins'],
#  ['a',
#   'gay',
#   'marriage',
#   'opponent',
#   'just',
#   'ousted',
#   'a',
#   'gop',
#   'incumbent',
#   'in',
#   'north',
#   'carolina'],
#  ['espn',
#   'eliminates',
#   'public',
#   'editor',
#   'role',
#   'calling',
#   'it',
#   'outdated'],
#  ['michael',
#   'cohen',
#   'was',
#   'selling',
#   'access',
#   'to',
#   'trump',
#   'says',
#   'group',
#   'that',
#   'paid',
#   'into',
#   'his',
#   'shell',
#   'company'],
#  ['mitch',
#   'mcconnell',
#   'mocks',
#   'blankenship',
#   'on',
#   'twitter',
#   'with',
#   'a',
#   'big',
#   'cloud',
#   'of',
#   'cocaine'],
#  ['exconvict',
#   'don',
#   'blankenship',
#   'loses',
#   'to',
#   'patrick',
#   'morrisey',
#   'in',
#   'west',
#   'virginia',
#   'senate',
#   'race'],
#  ['ohio', 'voters', 'pass', 'gerrymandering', 'reform', 'measure'],
#  ['trumps', 'iran', 'deal', 'exit', 'is', 'a', 'win', 'for', 'russia'],
#  ['cynthia',
#   'nixon',
#   'wants',
#   'new',
#   'yorkers',
#   'to',
#   'vote',
#   'for',
#   'the',
#   'homo',
#   'not',
#   'for',
#   'the',
#   'cuomo'],
#  ['ontario',
#   'canada',
#   'just',
#   'issued',
#   'its',
#   'first',
#   'nonbinary',
#   'birth',
#   'certificate'],
#  ['child',
#   'sexual',
#   'predator',
#   'roman',
#   'polanski',
#   'calls',
#   'me',
#   'too',
#   'movement',
#   'total',
#   'hypocrisy'],
#  ['this',
#   'is',
#   'america',
#   'producer',
#   'reveals',
#   'new',
#   'details',
#   'about',
#   'childish',
#   'gambinos',
#   'viral',
#   'video'],
#  ['terry',
#   'crews',
#   'black',
#   'men',
#   'arent',
#   'allowed',
#   'to',
#   'be',
#   'victims',
#   'until',
#   'theyre',
#   'dead'],
#  ['donald',
#   'glovers',
#   'this',
#   'is',
#   'america',
#   'through',
#   'the',
#   'eyes',
#   'of',
#   'a',
#   'jim',
#   'crow',
#   'historian'],
#  ['fox',
#   'news',
#   'judicial',
#   'analyst',
#   'issues',
#   'dark',
#   'warning',
#   'to',
#   'trump',
#   'over',
#   'michael',
#   'cohen'],
#  ['black',
#   'women',
#   'bishops',
#   'are',
#   'making',
#   'history',
#   'in',
#   'this',
#   'predominantly',
#   'white',
#   'church'],
#  ['geena',
#   'davis',
#   'and',
#   'th',
#   'husband',
#   'reza',
#   'jarrahy',
#   'are',
#   'divorcing'],
#  ['pauley',
#   'perrettes',
#   'abby',
#   'has',
#   'heartwrenching',
#   'farewell',
#   'on',
#   'ncis'],
#  ['lethal',
#   'weapon',
#   'fires',
#   'clayne',
#   'crawford',
#   'and',
#   'his',
#   'character',
#   'gets',
#   'shot'],
#  ['selena',
#   'gomez',
#   'pokes',
#   'fun',
#   'at',
#   'her',
#   'met',
#   'gala',
#   'spray',
#   'tan',
#   'mishap'],
#  ['protest',
#   'leader',
#   'nikol',
#   'pashinian',
#   'elected',
#   'prime',
#   'minister',
#   'of',
#   'armenia'],
#  ['kim', 'jong', 'un', 'secretly', 'met', 'with', 'xi', 'jinping', 'again'],
#  ['netanyahus',
#   'bombastic',
#   'iran',
#   'claims',
#   'found',
#   'a',
#   'perfect',
#   'audience',
#   'in',
#   'trump'],
#  ['netanyahus',
#   'chef',
#   'blasted',
#   'for',
#   'serving',
#   'japans',
#   'prime',
#   'minister',
#   'dessert',
#   'in',
#   'a',
#   'shoe'],
#  ['world',
#   'leaders',
#   'condemn',
#   'trump',
#   'for',
#   'withdrawing',
#   'from',
#   'iran',
#   'nuclear',
#   'deal'],
#  ['senate',
#   'republicans',
#   'shun',
#   'don',
#   'blankenship',
#   'on',
#   'day',
#   'of',
#   'west',
#   'virginia',
#   'primary'],
#  ['new',
#   'yorks',
#   'harvey',
#   'weinstein',
#   'probe',
#   'set',
#   'to',
#   'continue',
#   'despite',
#   'attorney',
#   'generals',
#   'exit'],
#  ['trump',
#   'to',
#   'announce',
#   'whether',
#   'us',
#   'will',
#   'break',
#   'the',
#   'iran',
#   'nuclear',
#   'deal'],
#  ['politicians',
#   'call',
#   'for',
#   'schneiderman',
#   'to',
#   'resign',
#   'over',
#   'physical',
#   'abuse',
#   'allegations'],
#  ['joe',
#   'scarborough',
#   'trumps',
#   'legal',
#   'strategy',
#   'is',
#   'like',
#   'a',
#   'monkey',
#   'throwing',
#   'poo',
#   'against',
#   'the',
#   'wall'],
#  ['kirsten', 'dunst', 'and', 'jesse', 'plemons', 'welcome', 'baby', 'boy'],
#  ['holy',
#   'matrimony',
#   'there',
#   'was',
#   'a',
#   'proposal',
#   'at',
#   'the',
#   'met',
#   'gala'],
#  ['nordstrom',
#   'rack',
#   'president',
#   'apologizes',
#   'after',
#   'store',
#   'accuses',
#   'three',
#   'black',
#   'men',
#   'of',
#   'theft'],
#  ['giuliani',
#   'says',
#   'trump',
#   'lawyer',
#   'michael',
#   'cohen',
#   'has',
#   'no',
#   'incriminating',
#   'information',
#   'about',
#   'the',
#   'president'],
#  ['lena',
#   'waithe',
#   'stuns',
#   'at',
#   'met',
#   'gala',
#   'as',
#   'a',
#   'queer',
#   'superhero'],
#  ['r',
#   'kelly',
#   'accusers',
#   'say',
#   'they',
#   'had',
#   'to',
#   'ask',
#   'permission',
#   'to',
#   'use',
#   'the',
#   'bathroom'],
#  ['trump',
#   'reportedly',
#   'tells',
#   'macron',
#   'hes',
#   'pulling',
#   'out',
#   'of',
#   'iran',
#   'nuclear',
#   'deal'],
#  ['how',
#   'the',
#   'deportation',
#   'crackdown',
#   'is',
#   'hurting',
#   'immigrant',
#   'victims',
#   'of',
#   'crime'],
#  ['seth',
#   'meyers',
#   'says',
#   'michael',
#   'cohen',
#   'tried',
#   'to',
#   'get',
#   'him',
#   'to',
#   'apologize',
#   'onair',
#   'to',
#   'trump'],
#  ['blessing', 'you', 'with', 'the', 'best', 'met', 'gala', 'tweets'],
#  ['farm',
#   'bill',
#   'would',
#   'cut',
#   'food',
#   'stamps',
#   'is',
#   'friendly',
#   'to',
#   'farmers'],
#  ['what', 'to', 'know', 'about', 'the', 'iran', 'nuclear', 'deal'],
#  ['derby', 'day', 'bet', 'wins', 'thrilled', 'texas', 'woman', 'million'],
#  ['democratic',
#   'meddling',
#   'in',
#   'west',
#   'virginia',
#   'and',
#   'other',
#   'things',
#   'to',
#   'watch',
#   'this',
#   'election',
#   'day'],
#  ['cynthia',
#   'erivos',
#   'met',
#   'gala',
#   'nails',
#   'featured',
#   'a',
#   'sistine',
#   'chapel',
#   'painting',
#   'with',
#   'black',
#   'women'],
#  ['keanu',
#   'reeves',
#   'and',
#   'alex',
#   'winter',
#   'are',
#   'coming',
#   'back',
#   'for',
#   'bill',
#   'ted',
#   'after',
#   '',
#   'years'],
#  ['solanges',
#   'durag',
#   'was',
#   'the',
#   'true',
#   'mvp',
#   'at',
#   'the',
#   'met',
#   'gala'],
#  ['top',
#   'house',
#   'republican',
#   'threatens',
#   'to',
#   'subpoena',
#   'trump',
#   'doj',
#   'official',
#   'over',
#   'census',
#   'citizenship',
#   'request'],
#  ['jimmy',
#   'kimmel',
#   'tries',
#   'so',
#   'hard',
#   'to',
#   'make',
#   'sense',
#   'of',
#   'rudys',
#   'latest',
#   'trump',
#   'defense',
#   'then',
#   'gives',
#   'up'],
#  ['the',
#   'religious',
#   'imagery',
#   'stitched',
#   'throughout',
#   'the',
#   'met',
#   'gala'],
#  ['bob',
#   'marleys',
#   'granddaughter',
#   'says',
#   'cops',
#   'racially',
#   'profiled',
#   'her',
#   'while',
#   'checking',
#   'out',
#   'of',
#   'airbnb'],
#  ['melania',
#   'trump',
#   'called',
#   'out',
#   'for',
#   'antibullying',
#   'campaign',
#   'that',
#   'ignores',
#   'her',
#   'husbands',
#   'actions'],
#  ['trevor',
#   'noah',
#   'watching',
#   'rudy',
#   'giuliani',
#   'is',
#   'like',
#   'smoking',
#   'weed',
#   'through',
#   'the',
#   'tv'],
#  ['janet',
#   'jackson',
#   'to',
#   'receive',
#   'icon',
#   'award',
#   'at',
#   'billboard',
#   'music',
#   'awards'],
#  ['white',
#   'house',
#   'prepares',
#   'to',
#   'send',
#   'congress',
#   'billion',
#   'spending',
#   'cuts',
#   'package'],
#  ['this',
#   'jared',
#   'kushnerbacked',
#   'bill',
#   'could',
#   'be',
#   's',
#   'last',
#   'shot',
#   'at',
#   'federal',
#   'prison',
#   'reform'],
#  ['george',
#   'zimmerman',
#   'accused',
#   'of',
#   'stalking',
#   'detective',
#   'working',
#   'on',
#   'trayvon',
#   'martin',
#   'film'],
#  ['passengers',
#   'lashing',
#   'out',
#   'at',
#   'scott',
#   'pruitt',
#   'justify',
#   'firstclass',
#   'travel',
#   'new',
#   'epa',
#   'memo',
#   'says'],
#  ['this',
#   'trump',
#   'country',
#   'house',
#   'district',
#   'just',
#   'became',
#   'a',
#   'key',
#   'progressive',
#   'battleground'],
#  ['mike',
#   'pences',
#   'brother',
#   'wins',
#   'primary',
#   'race',
#   'for',
#   'vice',
#   'presidents',
#   'former',
#   'house',
#   'seat'],
#  ['marines',
#   'investigating',
#   'avowed',
#   'white',
#   'supremacist',
#   'on',
#   'active',
#   'duty'],
#  ['trump',
#   'to',
#   'violate',
#   'iran',
#   'nuclear',
#   'deal',
#   'vows',
#   'to',
#   'reimpose',
#   'sanctions'],
#  ['us',
#   'olympic',
#   'committee',
#   'ignored',
#   'sexual',
#   'abuse',
#   'complaints',
#   'against',
#   'taekwondo',
#   'stars',
#   'lawsuit'],
#  ['blake',
#   'lively',
#   'brought',
#   'her',
#   'family',
#   'to',
#   'the',
#   'met',
#   'gala',
#   'without',
#   'you',
#   'even',
#   'noticing'],
#  ['bill',
#   'oreilly',
#   'offers',
#   'to',
#   'stand',
#   'next',
#   'to',
#   'sarah',
#   'sanders',
#   'to',
#   'handle',
#   'out',
#   'of',
#   'line',
#   'reporters'],
#  ['catholic',
#   'priest',
#   'praised',
#   'as',
#   'best',
#   'dressed',
#   'dude',
#   'at',
#   'met',
#   'gala',
#   'for',
#   'just',
#   'living',
#   'his',
#   'life'],
#  ['jimmy',
#   'kimmel',
#   'says',
#   'hideandseek',
#   'genius',
#   'dog',
#   'will',
#   'heal',
#   'our',
#   'nation'],
#  ['bank',
#   'of',
#   'america',
#   'appears',
#   'to',
#   'flip',
#   'on',
#   'firearm',
#   'promise',
#   'with',
#   'loan',
#   'to',
#   'remington'],
#  ['the',
#   'gentleman',
#   'caller',
#   'presents',
#   'queer',
#   'icons',
#   'as',
#   'youve',
#   'never',
#   'seen',
#   'them',
#   'before'],
#  ['eric', 'schneiderman', 'has', 'always', 'been', 'a', 'con', 'man'],
#  ['christiane',
#   'amanpour',
#   'heading',
#   'up',
#   'new',
#   'pbs',
#   'show',
#   'replacing',
#   'charlie',
#   'rose'],
#  ['madonna',
#   'teases',
#   'new',
#   'song',
#   'at',
#   'surprise',
#   'met',
#   'gala',
#   'performance'],
#  ['iron',
#   'man',
#   'black',
#   'widow',
#   'captain',
#   'america',
#   'thor',
#   'and',
#   'hawkeye',
#   'got',
#   'matching',
#   'tattoos'],
#  ['michael',
#   'cohen',
#   'accepted',
#   'from',
#   'firm',
#   'tied',
#   'to',
#   'russian',
#   'oligarch',
#   'reports'],
#  ['stephen',
#   'colbert',
#   'hits',
#   'rudy',
#   'giuliani',
#   'with',
#   'a',
#   'brutal',
#   'fact',
#   'check'],
#  ['katy',
#   'perry',
#   'sends',
#   'olive',
#   'branch',
#   'to',
#   'taylor',
#   'swift',
#   'and',
#   'the',
#   'world',
#   'rejoices'],
#  ['jada',
#   'pinkett',
#   'smith',
#   'gets',
#   'real',
#   'about',
#   'dating',
#   'will',
#   'smith',
#   'while',
#   'he',
#   'was',
#   'married'],
#  ['whoops',
#   'mark',
#   'hamill',
#   'just',
#   'spilled',
#   'the',
#   'beans',
#   'on',
#   'a',
#   'major',
#   'cameo',
#   'in',
#   'han',
#   'solo',
#   'movie'],
#  ['shawn',
#   'mendes',
#   'sweetly',
#   'attended',
#   'to',
#   'hailey',
#   'baldwins',
#   'gown',
#   'at',
#   'the',
#   'met',
#   'gala'],
#  ['orrin',
#   'hatch',
#   'is',
#   'sorry',
#   'he',
#   'suggested',
#   'trump',
#   'should',
#   'be',
#   'allowed',
#   'at',
#   'john',
#   'mccains',
#   'funeral'],
#  ['seth',
#   'meyers',
#   'has',
#   'perfect',
#   'line',
#   'to',
#   'confront',
#   'donald',
#   'trumps',
#   'lies'],
#  ['police',
#   'hope',
#   'to',
#   'use',
#   'dna',
#   'to',
#   'catch',
#   'the',
#   'zodiac',
#   'killer'],
#  ['lili',
#   'reinhart',
#   'and',
#   'cole',
#   'sprouse',
#   'finally',
#   'make',
#   'couple',
#   'debut',
#   'at',
#   'met',
#   'gala'],
#  ['how',
#   'sweetbitter',
#   'captures',
#   'the',
#   'grit',
#   'and',
#   'glamour',
#   'of',
#   'the',
#   'restaurant',
#   'world'],
#  ['mitch',
#   'mcconnell',
#   'bends',
#   'the',
#   'rules',
#   'again',
#   'to',
#   'confirm',
#   'trumps',
#   'judges'],
#  ['ryan', 'zinke', 'and', 'the', 'tale', 'of', 'two', 'fish'],
#  ['ny',
#   'attorney',
#   'general',
#   'eric',
#   'schneiderman',
#   'resigns',
#   'amid',
#   'abuse',
#   'allegations'],
#  ['sanctuary',
#   'cities',
#   'are',
#   'working',
#   'in',
#   'the',
#   'trump',
#   'era',
#   'but',
#   'at',
#   'a',
#   'surprising',
#   'cost'],
#  ['shepard',
#   'smith',
#   'you',
#   'cant',
#   'say',
#   'trump',
#   'pulled',
#   'out',
#   'of',
#   'iran',
#   'deal',
#   'he',
#   'made',
#   'decision',
#   'to',
#   'violate',
#   'it'],
#  ['stormy',
#   'daniels',
#   'finds',
#   'a',
#   'crunchy',
#   'new',
#   'way',
#   'to',
#   'chip',
#   'away',
#   'at',
#   'trump'],
#  ['these',
#   'rainbow',
#   'mountains',
#   'in',
#   'peru',
#   'look',
#   'like',
#   'theyre',
#   'straight',
#   'out',
#   'of',
#   'a',
#   'dr',
#   'seuss',
#   'book'],
#  ...]

# %%
type(splitted_text)
# Out:
# list

# %%
occurences = compute_word_occurences(splitted_text).head(1000)
occurences
# Out:
#        Word  Count
# 0    photos  10277
# 1     trump   9569
# 2       new   8554
# 3     video   5770
# 4    donald   4589
# ..      ...    ...
# 995    iraq    253
# 996    fail    253
# 997   vegas    253
# 998   crash    252
# 999  longer    252
#
# [1000 rows x 2 columns]

# %% [markdown]
# Nos stopwords on bien été supprimés !

# %%
occurences = compute_word_occurences(splitted_text).head(1000)
occurences
# Out:
#        Word  Count
# 0    photos  10277
# 1     trump   9569
# 2       new   8554
# 3     video   5770
# 4    donald   4589
# ..      ...    ...
# 995    iraq    253
# 996    fail    253
# 997   vegas    253
# 998   crash    252
# 999  longer    252
#
# [1000 rows x 2 columns]

# %% [markdown]
# # Pipeline

# %% [markdown]
# 1. **Ensuring data quality.** You have to make sure that there's no N/A in your data and that everything is in the good format shape. Having this as the entrance of your pipeline will save you a lot of time in the long run, so try defining it thoroughly.
#
#
# 2. **Filtering texts from unwanted characters**. Especially if you get data from web, you'll end up with HTML tags or encoding stuff that you don't need in your texts. Before applying anything to them, you need to get them cleaned up. Here, try removing the dates and the punctuation for instance.
#
#
# 3. **Unify your texts**. (*This is topic modeling specific*). You don't want to make the difference between a word at the beginning of a phrase of in the middle of it here. You should unify all your words by lowercasing them and deaccenting them as well.
#
#
# 4. **Converting sentences to lists of words**. Some words aren't needed for our analyses, such as *your*, *my*, etc. In order to remove them easily, you have to convert your sentences to lists of words. You can use the dummy function defined above but I'd advised against it. Try finding a function that does that smoothly in [gensim.utils](https://radimrehurek.com/gensim/utils.html)!
#
#
# 5. **Remove useless words**. You need to remove useless words from your corpus. You have two approaches: [use a hard defined list of stopwords](https://www.analyticsvidhya.com/blog/2019/08/how-to-remove-stopwords-text-normalization-nltk-spacy-gensim-python/) or rely on TF-IDF to identify useless words. The first is the simplest, the second might yield better results!
#
#
# 6. **Creating n-grams**. If you look at New York, it is composed of two words. As a result, a word count wouldn't really return a true count for *New York* per se. In NLP, we represent New York as New_York, which is considered a single word. The n-gram creation consists in identifying words that occur together often and regrouping them. It boosts interpretability for topic modeling in this case.
#
#
# 7. **Stemming / Lemmatization**. Shouldn't run, running, runnable be grouped and counted as a single word when we're identifying discussion topics? Yes, they should. Stemming is the process of cutting words to their word root (run- for instance) quite brutally while lemmatization will do the same by identifying the kind of word it is working on. You should convert the corpus words into those truncated representations to have a more realistic word count.
#
#
# 8. **Part of speech tagging**. POS helps in the identification of verbs, nouns, adjectives, etc. For topic models, it is a good idea to work only on verbs and nouns. Adjectives don't convey info about the actual underlying topic discussed at hand.

# %% [markdown]
# Jusque là, nous avons assurés une bonne qualité de nos données, unifié nos textes, convertit nos phrases et supprimé nos Stopwords.
#
# Selon le Pipeline, il nous reste maintenant à :
#
# 1. **Appliquer des regex**
# 2. **Créer des n-grams**
# 3. **Lemmatization / Steeming**
# 4. **Speach Tagging**

# %% [markdown]
# # Suppression des Regex

# %%
def filter_text(texts_in):
    """Removes incorrect patterns from a list of texts, such as hyperlinks, bullet points and so on"""
    
    texts_out = re.sub(r'https?:\/\/[A-Za-z0-9_.-~\-]*', ' ', str(texts_in), flags=re.MULTILINE)
    texts_out = re.sub(r'[(){}\[\]<>]', ' ', texts_out, flags=re.MULTILINE)
    texts_out = re.sub(r'&amp;#.*;', ' ', texts_out, flags=re.MULTILINE)
    texts_out = re.sub(r'&gt;', ' ', texts_out, flags=re.MULTILINE)
    texts_out = re.sub(r'â€™', "'", texts_out, flags=re.MULTILINE)
    texts_out = re.sub(r'\s+', ' ', texts_out, flags=re.MULTILINE)
    texts_out = re.sub(r'&#x200B;', ' ', texts_out, flags=re.MULTILINE)
    # Mail regex
    # This regex is correct but WAY TOO LONG to process. So we skip it with a simpler version
    # texts_out = re.sub(r"(?i)(?:[a-z0-9!#$%&'*+\/=?^_`{|}~-]+(?:\.[a-z0-9!#$%&'*+\/=?^_`{|}~-]+)*|\"(?:[\x01-\x08\x0b\x0c\x0e-\x1f\x21\x23-\x5b\x5d-\x7f]|\\[\x01-\x09\x0b\x0c\x0e-\x7f])*\")@(?:(?:[a-z0-9](?:[a-z0-9-]*[a-z0-9])?\.)+[a-z0-9](?:[a-z0-9-]*[a-z0-9])?|\[(?:(?:(2(5[0-5]|[0-4][0-9])|1[0-9][0-9]|[1-9]?[0-9]))\.){3}(?:(2(5[0-5]|[0-4][0-9])|1[0-9][0-9]|[1-9]?[0-9])|[a-z0-9-]*[a-z0-9]:(?:[\x01-\x08\x0b\x0c\x0e-\x1f\x21-\x5a\x53-\x7f]|\\[\x01-\x09\x0b\x0c\x0e-\x7f])+)\])", '', texts_out, flags=re.MULTILINE)
    texts_out = re.sub(r'[a-zA-Z0-9-_.]+@[a-zA-Z0-9-_.]+\.[a-zA-Z0-9-_.]+', '', texts_out, flags=re.MULTILINE)
    # Phone regex
    # This regex is correct but WAY TOO LONG to process. So we skip it with a simpler version
    # texts_out = re.sub(r".*?(\(?\d{3}\D{0,3}\d{3}\D{0,3}\d{4}).*?", '', texts_out, flags=re.MULTILINE)
    texts_out = re.sub(r"\(?\d{3}\D{0,3}\d{3}\D{0,3}\d{4}", '', texts_out, flags=re.MULTILINE)
    # Remove names in twitter
    texts_out = re.sub(r'@\S+( |\n)', '', texts_out, flags=re.MULTILINE)

    # Remove starts commonly used on social media
    texts_out = re.sub(r'\*', '', texts_out, flags=re.MULTILINE)
    return texts_out

# %%
splitted_text1 = [filter_text(t) for t in splitted_text]

# %%
def sent_to_words(sentences):
    """Converts sentences to words.

    Convert sentences in lists of words while removing the accents and the punctuation.

    @param:
        sentences: a list of strings, the sentences we want to convert
    @return
        A list of words' lists.
    """
    for sentence in tqdm(sentences):
        yield (simple_preprocess(str(sentence), deacc=True))

# %%
texts = list(sent_to_words(splitted_text))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 200853/200853 [00:06<00:00, 31663.03it/s]

# %% [markdown]
# # Création de n-grams

# %%
def create_bigrams(texts, bigram_count=15, threshold=10, convert_sent_to_words=False, as_str=True):
    """Identify bigrams in texts and return the texts with bigrams integrated"""
    if convert_sent_to_words:
        texts = list(sent_to_words(texts))
    
    bigram_model = Phraser(Phrases(texts, min_count=bigram_count, threshold=threshold))
    
    if as_str:
        return [" ".join(bigram_model[t]) for t in texts]

    else:
        return [bigram_model[t] for t in texts]

# %%
texts_t = create_bigrams(texts)

# %%
texts_t
# Out:
# ['mass_shootings texas last week tv',
#  'smith joins diplo nicky jam world cups official song',
#  'hugh grant marries first_time age',
#  'jim_carrey blasts castrato adam schiff democrats new artwork',
#  'julianna margulies uses donald_trump poop bags pick dog',
#  'morgan freeman devastated sexual_harassment claims could undermine legacy',
#  'donald_trump lovin new mcdonalds jingle tonight_show bit',
#  'watch amazon prime new week',
#  'mike myers reveals hed like fourth austin powers film',
#  'watch hulu new week',
#  'justin_timberlake visits texas school_shooting victims',
#  'south_korean president meets north_koreas kim_jong un talk trump summit',
#  'way life risk remote oystergrowing region called robots',
#  'trumps crackdown immigrant parents puts kids already strained system',
#  'trumps son concerned fbi obtained wiretaps putin ally met trump_jr',
#  'edward_snowden theres one trump loves vladimir_putin',
#  'booyah obama photographer hilariously trolls trumps spy claim',
#  'ireland votes repeal abortion amendment landslide referendum',
#  'ryan_zinke looks reel back critics grand pivot to conservation',
#  'trumps scottish golf resort pays women significantly less men report',
#  'weird fathers_day gifts dad doesnt know wants he',
#  'twitter universally entertaining',
#  'mystery wolflike animal reportedly shot montana baffles wildlife officials',
#  'north_korea still open talks trump cancels summit',
#  'men detonate bomb inside indian restaurant near toronto authorities say',
#  'thousands travel home ireland to vote abortion access',
#  'irish voters set liberalize abortion laws landslide exit poll signals',
#  'warriors coach steve kerr calls nfl ban protests fake patriotism',
#  'historic victory barbados elects first female prime_minister',
#  'police killed least black americans moment colin_kaepernick protested',
#  'jack johnson pardoned taboo sex still criminalized',
#  'bet chairman ceo debra lee stepping',
#  'rachel dolezal faces felony charges welfare fraud',
#  'bishop michael curry joins christian march white_house to reclaim jesus',
#  'kanye_west spent photo whitney houstons bathroom album cover',
#  'morgan freeman dropped marketing campaigns harassment accusations',
#  'chinese exclusion act help understand immigration politics today',
#  'trumps new magathemed swimwear sinks twitter',
#  'seth_meyers funny regret trump cancels north_korea summit',
#  'colbert wants turn nyc subway rides new terrible punishment',
#  'man faces charges pulling knife stun gun muslim students mcdonalds',
#  'jimmy_kimmel knows irans supreme leader watches tom jerry',
#  'people injured indiana school_shooting',
#  'people rattled much nigerian man looks_like chadwick boseman',
#  'david cross proves yet hes terrible apologizing',
#  'sesame_street creators sue makers upcoming adultthemed puppet film',
#  'missed saddest death avengers_infinity war',
#  'george_takei accuser walks_back story drugging sexual_assault',
#  'samantha bees parents think america basically war zone',
#  'pete davidson says mental_illness doesnt ruin romance',
#  'james_corden adam_levine get pulled carpool_karaoke',
#  'emilia clarke dishes final game_thrones scene',
#  'hollywood doesnt need difficult men make great tv',
#  'harvey_weinstein accusers say never_thought would arrested',
#  'harvey_weinstein turns police alleged sex crimes',
#  'john mayers weird new lowbudget video memeworthy masterpiece',
#  'boba fett getting star_wars movie',
#  'trump suggests north_korea summit could still happen',
#  'roger stone pressed damaging emails hillary_clinton wikileaks report',
#  'publix suspends contributions nrabacked politician amid protests',
#  'twitter bots may delivered donald_trumps victory research paper says',
#  'bag wet socks apparently living white_house press briefing room',
#  'member farright proud boys menaced twitter user doorstep',
#  'things nra blamed the texas school_shooting',
#  'heres_happens catholic hospital wont try save',
#  'trumps new executive_orders make easier fire federal workers',
#  'monsanto bayer set merge heres care',
#  'joy watching harvey_weinsteins perp walk',
#  'funniest_tweets women_week',
#  'queer_eye star bobby berk gave desk makeover incredible',
#  'older gay_men try new gay slang hilarious video',
#  'rupauls_drag race teaching straight people queer culture',
#  'fish market buys freedom fred pound octopus',
#  'north_korea threatens call trump summit warns nuclear showdown',
#  'investigation finds russian missile shot flight mh',
#  'north_korea demolishes tunnels nuclear test site reports say',
#  'kim_jong un baited trump canceling north_korea summit',
#  'michelle_obama reveals cover upcoming memoir becoming',
#  'late_night writers breathless royal_wedding recap one need',
#  'morgan freeman accused inappropriate behavior sexual_harassment',
#  'jets chairman christopher johnson wont fine players anthem protests',
#  'andy_cohen taylor_swift katy_perry drama',
#  'infinity_war writers try clear marvels problematic timeline',
#  'david blaine chews glass lets james_corden puncture cheek',
#  'amy_poehler parks recreation revival would amazing',
#  'colbert exposes the xa biggest flaw trumps_latest conspiracy_theory',
#  'seth_meyers gives donald_trump valuable marketing advice',
#  'launches auto import probe china vows defend interests',
#  'women pulled stops land dream job',
#  'wife asked husband fenty highlighter got pack highlighters hairbrush',
#  'trump roasted rushing defend tomi_lahren ignoring real victims',
#  'trump abruptly cancels north_korea summit kim_jong un',
#  'devin nuneslinked winery faced suit alleged coke prostitute yacht party',
#  'immigrant children accuse border_patrol abuse neglect report shows',
#  'irelands historic vote legalizing abortion haunted trump brexit',
#  'trump lawyer attended doj meeting confidential fbi informant',
#  'senate advances court_pick said planned_parenthood kills females year',
#  'rudy_giuliani trump wont interview mueller get spygate report',
#  'kentucky attorney running judge dies day primary win',
#  'chrissy_teigen taunts donald_trump twitter blocking ruling',
#  'koch network going one trumps favorite congressmen',
#  'trump posthumously pardons boxer jack johnson',
#  'ellen tears ashton_kutcher donates million wildlife fund',
#  'ariana_grande reveals bee tattoo honor manchester attack',
#  'kim_kardashian wished kanye_west happy anniversary fine pretty cute',
#  'chris_hemsworth dances wrecking ball kids living_room',
#  'moses farrow defends woody_allen accuses mia farrow abuse',
#  'gwyneth_paltrow says brad_pitt threatened kill harvey_weinstein',
#  'stephen king reveals donald_trump blocked twitter',
#  'fans back jessica walter addressed verbal harassment jeffrey tambor',
#  'jessica walter discusses jeffrey tambors alleged harassment male costars brush',
#  'harvey_weinstein expected turn to nypd sex crimes',
#  'samantha_bee torches ice lets shut fk',
#  'scott_pruitt twice introduced antiabortion bills giving men property rights fetuses',
#  'twitter critics mercilessly mock trump canceling summit kim',
#  'civil_rights groups rip senate bill revising sexual_harassment policy',
#  'alabama sues exclude undocumented_immigrants census count',
#  'cynthia_nixon vows keep fighting predictably losing party endorsement',
#  'white_house officials reportedly considered ignoring new climate research',
#  'read trumps letter kim_jong un canceling north_korea summit',
#  'south_korea responds trumps sudden cancellation kim_jong un summit',
#  'facebooks new ad rules prove basically charge regulating elections',
#  'border agent fatally_shoots migrant woman texas',
#  'trump opens door gun industry sell firearms abroad',
#  'stormy_daniels day declared west hollywood adult star gets key city',
#  'youre_going use selfcheckout machine whether like',
#  'ways_make family road_trips easier parents whove',
#  'jake_tapper shreds donald_trump long list conspiracy_theories',
#  'new_york daily_news rips nfl anthem kneeling ban',
#  'judge ruled one immigrant right hearing others',
#  'house_democrats offer internships students affected gun_violence',
#  'tig notaro tells ellen_degeneres sons passion trash',
#  'stormy_daniels thanks wonderful gay_dads west hollywood hands keys city',
#  'believe queer_eye season drops next month',
#  'gay man denied marriage license kim_davis loses bid unseat',
#  'anna kournikova dancing bouncing baby cutest thing',
#  'trump says nfl_players unwilling stand anthem maybe shouldnt country',
#  'facebook accused reading texts accessing microphones lawsuit',
#  'selfdriving uber fatal accident seconds react crash',
#  'amazon admits alexa device eavesdropped portland family',
#  'man discovers handgun impaled front bumper car',
#  'rescue cat hilarious wideeyed expression scan confirms pregnant',
#  'weirdest promposals include teen faked birth',
#  'trump american far right stoke hate canada',
#  'farright parties set form italys new government',
#  'sarah silverman sees reason louis_ck cant continue artist',
#  'southern baptist leader said abused women pray removed post',
#  'americans ever support samesex_marriage',
#  'brynn cartelli becomes youngestever winner voice',
#  'betsy_devos stirs uproar saying schools call ice undocumented kids',
#  'sandy_hook families fbi agent sue alex_jones defamation',
#  'high_school teacher defeats kentucky house majority leader gop_primary',
#  'lupe valdez makes_history texas winning democratic nod governor',
#  'report michael cohens business partner cooperating prosecutors',
#  'brandi chastain totally agrees hall_fame plaque looks nothing like her',
#  'scientists turn dna technology to search loch ness monster',
#  'late_night writer vows take red hats back trump_supporters',
#  'julia_louisdreyfus receive mark twain prize american humor',
#  'michelle_obama shares intimate wedding photo tribute husband barack',
#  'spot trevor_noah black_panther daily_show hosts stealth cameo revealed',
#  'donald glover fans execute stunning coup donald trumpthemed reddit forum',
#  'ti calls boycott restaurant offduty cop allegedly assaults black women',
#  'survivor rwandan genocide countrys first female neurosurgeon',
#  'stacey abrams wins democratic_primary georgia governor',
#  'trevor_noah reveals question hed ask donald_trump else dared',
#  'michelle_obama reflects scary time princeton sweet throwback snap',
#  'reasons started conversation whos responsible finishing',
#  'lourdes leon gives major madonna vibes moody new ad_campaign pics',
#  'ways netflix tricks watching shows movies',
#  'brad_pitt made ryan_reynolds one demeaning thing exchange deadpool cameo',
#  'robert_de niro bans trump every nobu restaurant',
#  'ariana_grande shuts fan blaming heartbreaking mac miller split',
#  'parents slam show dogs scenes grooming children sexual_abuse',
#  'dave grohl wants apologize to world massive jerk trump',
#  'emilia clarke introduced prince_william pretty embarrassing way',
#  'sarah paulson takes impressions next_level tonight_show',
#  'bs still ready party taken seriously',
#  'gina ortiz jones wins democratic runoff texas congressional race',
#  'fighter pilot amy mcgrath wins democratic_primary kentucky swing district',
#  'trump rallies conservatives promise abortion curbs',
#  'aclu suing strike ohios congressional map',
#  'latest school_shooting hasnt really stirred gun debate',
#  'donald_trump tweet rescues roseanne family season_finale',
#  'ellen grills mark wahlberg shirtless instagram selfies',
#  'idris_elba star new hunchback notre_dame netflix',
#  'maryland police charge church leaders past abuse atrisk teen girls',
#  'nfl bans kneeling national_anthem',
#  'conan_obrien muscles royal_wedding spoof ads',
#  'house_republicans report progress immigration deal',
#  'democrats werent invited review classified documents fbi informant',
#  'gop_candidate pointed gun teenager advances georgia governor primary runoff',
#  'walking definition entitled millennial swears hes an entitled millennial',
#  'democrats push included classified briefing fbi informant',
#  'machines dont always steal jobs increasingly rob our work humanity',
#  'trump praises tomi_lahren restaurant crowd tosses water insults',
#  'sarah sanders bothers called liar',
#  'trump blocking people twitter judge_rules',
#  'mostly nonchristian militia iraqi christians parliamentary seats christians want trump intervene',
#  'tulsi gabbards syria views cost support hawaii teachers union',
#  'jared_kushner received security clearance reports',
#  'arizona gop congressional_candidate compares abortion holocaust',
#  'gun reform advocate lucy mcbath heads runoff georgia house seat',
#  'star_wars burlesque show storms west_coast sexy stormtroopers',
#  'moderate wins heated democratic house primary texas',
#  'senators unveil bill crack sexual_harassment',
#  'trips take new_york city long weekend',
#  'disney reveals opening seasons star_wars theme_park lands',
#  'latest entries comedy wildlife photo awards cheer',
#  'bad lip reading reveals really said royal_wedding',
#  'australian archbishop convicted covering child sex_abuse',
#  'commander says irans people respond pompeos threats punch mouth',
#  'mark_zuckerberg extends facebook apology tour european gig',
#  'ariana_grande tweets message support manchester bombing anniversary',
#  'katy_perry says_shes single american_idol',
#  'call cops watch powerful monologue on racism',
#  'amazon selling cops facial recognition tool bad potentially racist move',
#  'miley_cyrus comes like wrecking ball prank sleeping jimmy_kimmel',
#  'vanessa bayer feared porn stars skit donald_trump snl',
#  'adam_rippon wins dancing_stars destined',
#  'emilia clarke never try imitate chewbacca ever',
#  'maddie poppe wins american_idol runnerup reveals theyre dating',
#  'colbert cant resist turning trumps nickname pee tape joke',
#  'seth_meyers forced tweak donald_trumps latest twitter rant time',
#  'boy says teacher told fault police shoot him age',
#  'cops accused racism detaining black man vegetation',
#  'white cop shouts black suspect pretend like going shoot',
#  'florida police report dead standoff panama city apartment complex',
#  'donald glover board lando calrissians pansexuality solo',
#  'charlize_theron play megyn_kelly film roger_ailes',
#  'shoppers boycott publix stores donations nrabacked candidate',
#  'bill_de blasio tells nypd stop arresting people smoking pot street',
#  'dhs head says_shes still somehow unaware intel russia interference boost trump',
#  'lawmaker introduces crowdfunding bill pay trumps border_wall',
#  'gop_lawmakers soon allowed review classified info russia investigation',
#  'james_corden reveals worst part royal_wedding ceremony',
#  'ariana_grande reportedly dating snl star pete davidson',
#  'jim_carrey pens new pledge allegiance students bulletriddled schools',
#  'ellen gets david spade open dating younger women',
#  'ceasefire jimmy_kimmel shreds sean_hannity dummies fox_friends',
#  'spoof royal_wedding video sees ceremony taking different turn',
#  'georgia gop governors primary focuses guns immigration',
#  'glaads movie report_finds troubling drop lgbtq representation',
#  'sephora offers instore beauty classes trans nonbinary community',
#  'georgia governors primary highlights competing visions democratic_party',
#  'california moves let schools coworkers red flag dangerous gun owners',
#  'talking grievance health_care outsider kentucky dem found inside track',
#  'problems commemorative trumpkim jong_un coin',
#  'giulianis new stance russian collusion illegal',
#  'onion hilariously trolls michael_cohen ceaseanddesist note',
#  'democrats want boost school funding to address teacher walkouts',
#  'emails lawmakers shrug trumps lax cellphone security',
#  'try stink bugflavored jelly bellys dont',
#  'power outage triggers extreme zombie activity alert florida city',
#  'congress wall_street favor banks post record profits',
#  'white_house sinkhole probably metaphor something',
#  'reporter shoved others barred epa meeting water contaminants',
#  'garry kasparov donald_trump russian connections aeroflot',
#  'lonely planets top european destinations take aim overtourism',
#  'attorney aaron schlossberg insists antispanish rant person',
#  'minutes reporter reveals trumps chilling reason slamming press',
#  'trump reportedly rejects phone security measures inconvenient',
#  'federal_court sides transgender teen gavin grimm bathroom fight',
#  'extrump adviser calls presidents claims informant spied campaign embarrassing',
#  'vietnam test happens abandons climate diplomacy',
#  'onethird americans_think trump successfully draining swamp',
#  'msnbc host hugh hewitt suggests trench coat control gun_control',
#  'bishop michael curry harry meghans love brought different worlds together',
#  'sarah paulson unapologetic year age gap girlfriend holland taylor',
#  'texans sides gun debate agree on safe storage on support',
#  'family gay man found critically injured near amtrak route wants answers',
#  'caitlyn_jenner trump worst president ever lgbtq_rights',
#  'boy_scout allegedly booted store company wont support homos',
#  'instagram adding mute button sake sanity',
#  'publix censors teens summa cum laude graduation cake',
#  'say sexist passengers female pilot perfect_response',
#  'times takes_aim mcdonalds walmart sexual_harassment complaints',
#  'venezuelas socialist leader nicolas maduro reelected amid allegations irregularities',
#  'iran says europes support nuclear_deal isnt_enough americas withdrawal',
#  'farright mob attacks yearold liberal greek mayor',
#  'shawn mendes khalid perform parkland survivors billboard_music awards',
#  'tamir rices mother opening youth center honor sons memory',
#  'judge_orders texas make voter_registration easier updating dmv info',
#  'kelly_clarkson calls moments action honor of texas shooting_victims billboard awards',
#  'kendrick_lamar stops white fan rapping nword onstage',
#  'gay man says pope_francis told god made like loves you like that',
#  'unusual asteroid could interstellar guest solar system',
#  'started suicide prevention site age still going strong',
#  'roger stone says_hes prepared conjured mueller indictment',
#  'hillary_clinton endorse andrew cuomos reelection',
#  'supreme_court made lot harder sue employer',
#  'blake farenthold may hired illegally new lobbyist job',
#  'bill konigsberg explores new side gay experience latest book',
#  'alone game shows biggest hurdles lgbtq athletes exist field',
#  'chrissy_teigen somehow gets even real_life childbirth',
#  'suits creator pens heartfelt open_letter attending royal_wedding',
#  'movies coming netflix week',
#  'obamas coming netflix queue',
#  'sorry ben_affleck make way justin therouxs giant rat tattoo',
#  'hillary_clinton tips russian hat trump yale commencement_speech',
#  'giuliani says mueller cant talk trump trump hears fbi source',
#  'democrats plan big anticorruption theme midterms',
#  'kelly_clarkson rejects moment silence calls change billboard_music awards',
#  'asked american public settle internets dumbest debates',
#  'fox_news viewers really dont like lifelong republican robert_mueller',
#  'trump team moves lift ban extreme hunting tactics alaska',
#  'howard stern tells trump sexualized ivanka makes david_letterman cringe',
#  'supreme_court helping companies get_away sexual_harassment',
#  'deadpool steals spot box_office avengers_infinity war',
#  'westworld subtly tease baby theory',
#  'donald glover tells ellen full circle star_wars moment his son',
#  'marvel exec tried stop jarring infinity_war death',
#  'jake_gyllenhaal set star villain spiderman sequel',
#  'janet_jackson becomes_first black woman receive billboard icon award',
#  'isnt pakistan bitch video captures drivers racist rant',
#  'grey gardens ladies unwitting godmothers reality_tv archetypes',
#  'yearold_boy superhero alabamas homeless population',
#  'john_oliver best time mocking royal_wedding',
#  'john_oliver needles dangerously unregulated rehab industry',
#  'jemele hill honored nabjs journalist year',
#  'french digital minister comes gay fight homophobia',
#  'belgian transgender ballet drama wins big cannes_film festival',
#  'yearold gay man proves youre never old attend first pride',
#  'super_pacs meddled west virginias senate primary didnt receive penny west virginians',
#  'airline passenger arrested_allegedly harassing woman peeing seat',
#  'mike pompeo promises crush iran achieve better deal',
#  'majestic islands europe tourists dont_know yet',
#  'cuba confirms killed countrys deadliest plane_crash since',
#  'china putting trade war hold treasurys steve mnuchin says',
#  'trumps top economic adviser says amazon threats lane',
#  'dems trump admin find common ground helping victims myanmars genocide',
#  'giuliani says mueller wrap trump obstruction probe september report',
#  'german broadcaster criticized racist coverage royal_wedding',
#  'kathryn newton boldest teen tv ready grow',
#  'stephanie kelton biggest idea washington',
#  'texas govs campaign cancels shotgun giveaway santa fe school_shooting',
#  'tina feys sarah_palin leads snl chorus lamenting trump',
#  'day american gushing snl goes smart aleck royal_wedding',
#  'starbucks says anyone sit cafes even without buying anything',
#  'alec_baldwins trump faces ominous sopranos scenario snl finale',
#  'asia argentos fiery speech closes cannes raped harvey_weinstein',
#  'tina_fey tries mean_girls musical snl',
#  'parents school_shooting victims decry moronic gop platitudes',
#  'trump real americans get tough russia_probe',
#  'chrissy_teigen john_legend announce name baby_boy adorable photo',
#  'texas lt gov dan patrick touts need arm teachers',
#  'david hogg calls media stop naming santa fe school shooter',
#  'trump sets showdown doj claims campaign surveillance',
#  'jim carreys latest painting slams kent state goldilocks ar',
#  'oliver north blames school_shootings ritalin',
#  'jimmy_kimmel tricks royal fans reviewing wedding big day',
#  'jimmy_fallon reveals viewers biggest wedding fails',
#  'protesters throw fiesta razz lawyer ranted spanish speakers',
#  'watch amazon prime new week',
#  'ferrell molly shannon cover royal_wedding cord and tish',
#  'artist formerly known cedric entertainer arrived',
#  'mark kelly trump rolled nra nothing guns parkland',
#  'gop_candidate set trust pays kids marrying white people',
#  'houston police_chief says_hes sick inaction gun_control',
#  'history national_anthem sports',
#  'bbc trolls president trump bigly huge royal_wedding crowd',
#  'victims santa fe high_school shooting',
#  'ceo took pay cut give employees year hes battling amazon',
#  'trump_jr met emissary gulf princes offering help with campaign report',
#  'trump misspells melanias name welcome home tweet twitter roars',
#  'jimmy_kimmel shreds cowardly trump lawmakers texas school_shooting',
#  'bill_maher reveals things dont_know michael_cohen',
#  'watch hulu new week',
#  'students stage sitin gun_control outside paul_ryans office get arrested',
#  'trump knew scary amount appearance bill_gates daughter',
#  'exrussian spy sergei skripal discharged uk hospital poisoning incident',
#  'cuba plane_crash reportedly kills',
#  'trump reassures north_korea threatens total decimation without deal',
#  'ariana_grande gives fans singing one last time surprise lives',
#  'cambridge_analytica files chapter bankruptcy facebook privacy row',
#  'santa fe high schoolers held gun_violence protest month shooting',
#  'michelle wolfs netflix trailer gives closer look new show',
#  'jeff_sessions uses exceptional power immigration courts limit judges authority',
#  'gop_rep introduces bill_would demand white_house apologize mccain',
#  'colbert super graphic way describing deep muellers probe goes',
#  'jack osbournes wife files divorce',
#  'meek mill backs trump event prison reform',
#  'new trump rule would cut federal funds clinics providing abortions',
#  'twitter_users joke trump wants prison reform hes headed',
#  'every_single chilean bishop offers resign countrys sex_abuse scandal',
#  'ariana_grande calls manchester attack worst humanity one_year later',
#  'chrissy_teigen spills first details new baby_boy love',
#  'alec_baldwin wife hilaria welcome another baby_boy',
#  'kate_mckinnon breaks another impression rudy_giuliani',
#  'smallvilles allison mack get involved sex cult first place',
#  'trump white_house kills yannylaurel debate ridiculous clip',
#  'jennifer_aniston play lesbian president netflixs first ladies',
#  'break book shadows charmed reboot trailer',
#  'former dave matthews band violinist boyd tinsley accused_sexual misconduct',
#  'many people cant name single book jimmy_kimmel',
#  'ellen_degeneres hilariously explains saved meghan markles life',
#  'lawyer ranted spanishspeakers faces office eviction disciplinary complaint',
#  'hannity flips mueller probe direct threat american republic',
#  'top democrats want answers global health security heads sudden departure',
#  'gun owners nongun owners actually agree lot gun reforms',
#  'twitter_users pan ted_cruz tweets prayers santa fe school_shooting victims',
#  'states ban bump_stocks enforce law',
#  'liberal billionaire tom steyer base',
#  'sen dean hellers campaign paid social_media influencer son',
#  'interior dept dodges watchdogs questions zinkes call alaska senators',
#  'blake_lively teases ryan_reynolds hugh jackmans bromance',
#  'happytime murders adultthemed movie puppets',
#  'photo daniel_radcliffe holding guns crazy slippers becomes magical meme',
#  'bill_gates says trump didnt_know difference hpv hiv',
#  'bachelorette bios are terrible',
#  'steven tyler admits hitting daughter livs famous pal watched',
#  'hospice overdosed patients hasten deaths former health_care executive admits',
#  'kimmel brings house giving trumps_latest tweet new ending',
#  'former wwf wrestler severely beaten outside california home',
#  'robert wilkie picked new va secretary surprise announcement',
#  'trumps new domestic gag rule would strip funds planned_parenthood',
#  'rudy_giuliani reverses trump teams position says president obstruct justice',
#  'social anxiety doesnt get attention deserves',
#  'deadpool already breaking box_office records',
#  'obamacare premiums way higher next_year didnt be',
#  'comprehensive list everything jr doesnt know infamous meeting',
#  'report manaforts former soninlaw cuts plea deal cooperate government',
#  'trump briefly responds santa fe school_shooting pivoting',
#  'late_night writer shreds roseanne better ever racist',
#  'trumps nasa chief apparently changed tune climate_change',
#  'freedom_caucus sinks key part paul_ryans welfare reform agenda',
#  'transphobic congressional hopeful berates person inside public restroom',
#  'singer ryan amador says loverboy second coming',
#  'newest head cracker hear brainstorm green needle',
#  'meditation like humans way clearing browser cache',
#  'funniest_tweets women_week',
#  'italy looks befriend russia populist parties try to form government',
#  'business groups might quietly killing bill_would bring sexual_abuse claims light',
#  'kushner family reportedly close getting bailout flagship tower',
#  'trump says_hell give charity royal_wedding well see',
#  'federal prosecutors still trying turn trump inauguration protesters felons',
#  'republican immigration fight derails food_stamp bill',
#  'retiring lawmakers added million campaign treasuries since last election',
#  'facing farm bill vote problems gop_leaders may make deal',
#  'methodists surprise gay minister worlds_best pastor certificates theft diploma',
#  'china marks another milestone quest become space superpower',
#  'stephen_colbert wants mueller give trump special anniversary gift',
#  'trumps stormy_daniels disclosure still leaves questions payments cohen',
#  'please enjoy animated history tina_fey snl return',
#  'controversial way california schools handling students misbehavior',
#  'deaf activist points marvels diversity problem isnt race',
#  'magnum pi trailer lots close shaves big mustache',
#  'gina haspel confirmed cia_director aid democrats',
#  'boulder city_council unanimously votes ban assault weapons highcapacity magazines',
#  'chrissy_teigen john_legend welcome baby_boy',
#  'terrifying clip shows never run tree thunderstorms',
#  'mitch_mcconnell taps antilgbtq bigot religious_freedom panel',
#  'seth_meyers gives donald_trump unexpected advice north_korea',
#  'devin_nunes fundraising fbi attacks tells potential donors trump says_hes hero',
#  'former mexican_president warns donald_trump youve_got get st together',
#  'fox_news first female ceo named sexual_harassment complaints',
#  'battle save dying soil',
#  'latino man insulted starbucks barista writes slur cup',
#  'snl cast member claims trump faked bizarre phone_call rehearsals',
#  'jimmy_kimmel comes clean may owe donald_trump apology',
#  'trevor_noah skewers betsy_devos fake forprofit university ad',
#  'serena_williams explains father didnt walk her aisle',
#  'star_wars writer confirms donald glovers character pansexual solo',
#  'medical professionals factcheck greys_anatomy sex scenes',
#  'amy_schumer nails meghan markles fairytale wedding actually sucks',
#  'michael keaton ends kent state commencement_speech im batman',
#  'black profiled share story',
#  'black actresses cannes protest racism french film industry',
#  'michael_jordan denies rumors doesnt date black women',
#  'scam pacs ripped conservatives propolice antiabortion messages prosecutors',
#  'mtv suspends catfish probes nev schulman sexual_misconduct claims',
#  'trumps ice increasingly arresting immigrants without criminal convictions',
#  'special_counsel hits roger stones social_media advisor subpoenas',
#  'whitney_houston sexually abused dee dee warwick cannes documentary',
#  'patton oswalts joker theory change watch dark_knight',
#  'josh holt american captive venezuela begs help in prison videos',
#  'obama photographer taunts donald_trump calling immigrants animals',
#  'backstreet boys release new_song dont go breaking heart',
#  'prince knight puts gayinclusive twist traditional fairy tales',
#  'gay_conversion therapy survivor recalls month nightmare powerful video',
#  'gq expertly spoofs vanity_fair annual comedy issue cover',
#  'rudy_giuliani offers headspinning new defense trump',
#  'cynthia nixons fix subway ads shred cuomos mta commuters rejoice',
#  'farm bill could huge blow animals',
#  'emails show interior expected learn nothing public input bears ears review',
#  'whistleblower leaked michael cohens financials potential coverup report',
#  'kidnapper accused using alligator hold man captive',
#  'miss america pageant headed women email scandal',
#  'north_korea threatens reconsider trump summit cancels south_korea talks',
#  'chemical_weapons likely used syria watchdog finds',
#  'hundreds israel beyond protest killings palestinians gaza border',
#  'researchers uncover secret pages diary anne frank',
#  'stephen piscotty returns bereavement hit momtribute home run',
#  'senate intelligence_committee backs gina haspel lead cia',
#  'pennsylvanias congressional delegation longer men',
#  'lando calrissian star_wars spinoff starring donald glover isnt happening',
#  'fake donald_trump sean_hannity pillow talk late_show',
#  'rapper ti arrested disorderly conduct public drunkenness',
#  'conservatives cook farm bill gambit get vote hardline immigration bill',
#  'top novartis lawyer resigns michael_cohen deal',
#  'isnt birth_control emoji',
#  'white_house eliminates cyber czar post first appointee leaves',
#  'emilys listbacked lawyer wins democratic_primary pennsylvania swing district',
#  'robin_williams biographer tells sweet story comic store visit',
#  'republicans attacking nancy_pelosi even nonhouse races',
#  'empire nothing military takes us gates of hell',
#  'longtime trump lawyer slams giuliani polarizing figure shouldnt deal mueller',
#  'bet_awards nominations dj khaled must screaming',
#  'beirut pride canceled organizer detained authorities',
#  'manhattan district attorney vows stop prosecuting minor marijuana cases',
#  'larry_nassar victims receive million michigan_state settlement',
#  'trump_jr left open possibility dad knew trump_tower meeting time',
#  'tom_cruise anklebreak scene goes laughs mission impossible trailer',
#  'many lives steven tyler',
#  'louisiana lawmakers approve restoring voting_rights people probation parole',
#  'thandie newtons cannes dress celebration black star_wars characters',
#  'trump paid cohen financial disclosure confirms',
#  'american citizen freed egypt jail',
#  'fox_news said settle group discrimination lawsuits million',
#  'tweeters take hard pass rncs dinner photo donald_trump prize',
#  'facebook removed million fake accounts first quarter',
#  'pink badass response troll said looked old',
#  'san_francisco adopt software app to help automatically clear old marijuana convictions',
#  'younger star sutton foster returns broadway roots new_album',
#  'senate hot seat scott_pruitt dodges questions mounting scandals',
#  'idaho inches closer electing nations first native_american governor',
#  'proabortion rights progressive wins nebraska democratic house primary',
#  'ryan_reynolds crashes colbert deadpool crack xrated trump jokes',
#  'ryan_reynolds genuinely hurt trading playground insults josh brolin',
#  'terry crews movement emancipation proclamation',
#  'christopher wylie warns senators cambridge_analytica steve_bannon want culture war',
#  'san_francisco may ban singleuse plastic straws',
#  'john travolta sure isnt greased lightning cannes dance floor',
#  'senate panel releases details trump_tower meeting probe',
#  'report contradicts michigan governor candidate test animal treatment',
#  'republican welfare plan keeping wages',
#  'years_ago today michael_jackson moonwalked tv first_time',
#  'hilary_duff publicly drags neighbor keeps night',
#  'jim_carrey jabs stooge donald_trump north_korea new artwork',
#  'trumps failure report stormy_daniels payoff referred to prosecutors',
#  'bohemian rhapsody trailer slammed ignoring freddie mercurys sexuality',
#  'fergie rides new_york city subway never',
#  'pauley perrette responds cbs statement multiple assaults claim',
#  'trump refers immigrants animals',
#  'angry white dudes rant people speaking spanish nyc goes_viral',
#  'democratic lawmaker gives scott_pruitt brutal reality_check senate hearing',
#  'trump picks mitch mcconnells brotherinlaw gordon hartogensis lead pension agency',
#  'fbi search cia leak suspect turned photos of sex assault unconscious friend',
#  'former trump pick top census role says citizenship question political',
#  'jared_kushner agitated infuriated meeting russians focused adoptions',
#  'sarah_huckabee sanders unusually honest seth_meyers spoof briefing',
#  'heres become kris jenners assistant according_to kris_jenner',
#  'chris_pratt bryce dallas howard really need service raptor flight',
#  'surprise shows coming netflix may',
#  'rex_tillerson warns grads living alternative realities',
#  'democrats force vote keep net_neutrality rules',
#  'larry_nassar blames victims says victimized newly released videos',
#  'video_shows yearold autism taunted abused bus_driver',
#  'yanny laurel heres real answer',
#  'populist cleric muqtada alsadr likely win iraqs parliamentary election',
#  'palestinian family says monthold died israeli tear gas gaza protest crackdown graphic',
#  'sichuan airlines copilot sucked halfway broken windshield',
#  'retail group spoofs ferris bueller ad bashing donald_trumps tariffs',
#  'washington officials_say state cover postage mailin ballots year',
#  'people think theyre civil politics opponents disagree',
#  'cambridge_analytica investigated justice_department fbi report',
#  'adorable video kids shows activism literally easy as pie',
#  'white_house blames deadly gaza violence hamas propaganda',
#  'gina haspel says cia shouldnt conducted interrogation program',
#  'tesla autopilot engaged horrific mph crash driver tells police',
#  'selling planes iran could saved lives exiting nuclear_deal make harder',
#  'speech fallen officers trump touts policies rails sanctuary_cities',
#  'eric greitens team pushes inquiry prosecutor charged',
#  'elizabeth_warren pledges big money turn heat gerrymandering',
#  'gay_conversion therapy illegal maryland',
#  'fox_news judicial analyst defends timeline muellers probe',
#  'stephen_colbert uses oprah analogy ridicule trumphannity bedtime chats',
#  'first_trailer queen biopic bohemian rhapsody',
#  'seth_meyers shreds trump scandals drain swamp devoid meaning',
#  'jim carreys new blooddripping portrait takes_aim national disgrace nra',
#  'scott_pruitt got security day epa new documents show',
#  'rabid antimuslim exfbi agent training texas police',
#  'khloe_kardashian explains chose true daughters name',
#  'game gina haspel track confirmed cia_director',
#  'topher grace really hated preparing play david_duke spike lees blackkklansman',
#  'sarah paulson deeply nerdy around rihanna filming oceans',
#  'blake farenthold says wont repay sexual_harassment settlement',
#  'spike_lee gets major love blackkklansman cannes rips trump',
#  'twitter_users hilariously skewered terrible stock photos jobs',
#  'ivanka jareds jerusalem visit slammed twitter',
#  'adam_rippon honors mom stunning dancing with stars performance',
#  'tomi_lahren hits_back genealogist researched family misses point',
#  'georgia gop gov candidate wants round immigrants deportation bus',
#  'daddys little ghoul new_york daily_news rips ivanka_trump embassy opening',
#  'death keeven robinson black louisiana man police custody ruled homicide',
#  'colbert savages peacetreaty barbie collusion ken embassy opening',
#  'twitter_users roast experts_say twice salary saved',
#  'woman challenging white maledominated tech industry inside',
#  'keith richards explains got rid trump nearly years_ago',
#  'damon wayans completely rips clayne crawford twitter outburst',
#  'like han solo hes scoundrel solo star_wars story forgot',
#  'pauley perrette reveals multiple physical assaults ncis exit',
#  'ariana_grande jimmy_fallon make sweet music cardboard instruments',
#  'trevor_noah dont watch fox_news neither',
#  'seattle passes controversial new tax citys biggest companies combat housing crisis',
#  'uber ends forced arbitration individual cases sexual_assault harassment',
#  'meet first_openly trans man graduate spelman college',
#  'canceled renewed tv_shows',
#  'teen claims visited heaven near death experience',
#  'willow smith tells shocked jada_pinkett smith selfharmed preteen',
#  'new farming technique using drastically less water catching',
#  'kristen_stewart ditches heels cannes red_carpet defying flats rule',
#  'david duchovny addresses nuttiest fan theories xfiles',
#  'judge overturns californias righttodie law',
#  'debbie_wasserman schultz nra shy terrorist organization',
#  'cardi responds girls song controversy apologizes to lgbtq_community',
#  'emotional support spider goat banned american_airlines',
#  'people cant agree whether voice saying yanny laurel',
#  'even bottom worlds deepest ocean trench safe plastic bags',
#  'open new embassy jerusalem nations prefer to wait peace deal',
#  'israeli forces kill dozens palestinians protests intensify embassy jerusalem',
#  'facebook suspends apps amid data misuse investigation',
#  'former senator harry_reid diagnosed pancreatic_cancer',
#  'new federal regulator takes_aim facebook',
#  'still apology white_house dying mccain dig',
#  'south_dakota congressional_candidate said terrorist attack would help win primary',
#  'ryan coogler would love see women wakanda spinoff',
#  'coffee shop refuses serve man racist rant woman niqab',
#  'supreme_court invalidates federal ban sports gambling',
#  'huge congrats fox_news getting guest journos to peddle bret baiers book',
#  'movies coming netflix week',
#  'prosecutor drops felony invasion privacy charge missouri gov eric greitens',
#  'israeli soccer_team beitar jerusalem add trump to name',
#  'vermont lawmakers pass genderneutral bathroom_bill send powerful_message',
#  'rita oras girls deemed tonedeaf harmful lgbtq pop artists',
#  'embassy jerusalem opens doors protests rage nearby',
#  'john_oliver reveals secret figuring whats going trumps mind',
#  'super mario looks_like without hair people freaked',
#  'channing tatums mothers_day message ex jenna dewan full love',
#  'star justin hartley says sexually_harassed fan',
#  'lois lanes pay_tribute late margot kidder led way',
#  'onion story blake farenthold gets new job lobbying congress',
#  'iowa gov says slowing signing countrys strictest abortion ban',
#  'cannes_film festival promises greater gender_equality times activism',
#  'childish gambinos america hits spot first week',
#  'jon_stewart dave_chappelle perform standup tour together',
#  'coach tells hurt ufc fighter continue says im done',
#  'melania_trump recovering kidney surgery',
#  'jon tester vulnerable senate democrat isnt voting like one',
#  'taraji_henson kelvin hayden get engaged mothers_day',
#  'young dolph gives baristas fired playing song get paid',
#  'come back bed explores intimacy experiencing sexual_assault',
#  'trump changed burger order make little healthier',
#  'michael avenatti posts photos cohen qatari investor accused of bribery',
#  'donald_trump lashes socalled leaks twitter_users pounce',
#  'trump orders help chinese phonemaker china approves money for trump project',
#  'hundreds protest cities_across poor peoples campaign',
#  'rihanna best response asked attending royal_wedding',
#  'lifetimes harry meghan royal romance good',
#  'gamechanging westworld brain capsule reveal beginning',
#  'margot kidder actress played lois lane superman dead',
#  'tomi_lahren gets owned genealogist remarks lowskilled immigrants',
#  'harrison_ford crashes new han solo actors interview get life',
#  'kylie_jenners exbodyguard tim chung denies hes actually stormis father',
#  'seann william scott replaces clayne crawford renewed lethal weapon',
#  'zach woods officially mvp silicon_valley',
#  'ryan_reynolds went south_korean singing show disguised unicorn',
#  'billie lourd honors tough mothers_day photo carrie_fisher',
#  'pink asks yearold concertgoer sing blown away',
#  'pastor thinks jews going hell speaks jerusalem embassy opening',
#  'chilis hit data breach credit debit card information compromised',
#  'trump called waffle_house hero james shaw jr thank disarming shooter',
#  'fox_news host trump fulfilled biblical prophecy moving embassy jerusalem',
#  'keyless cars killed dozen people since report',
#  'rare conjoined fawns scientists double take',
#  'least_killed dozens injured indonesia church bombings',
#  'irans president says country could remain nuclear_deal without',
#  'lindsey_graham trump officials owe mccain apology disgusting insult',
#  'amy_schumer goes fullon girl raunch saturday_night live',
#  'americans make iran_deal depends ask',
#  'like attending nra convention part fake_news media',
#  'possible autopilot use probed tesla crashes mph',
#  'michael bloomberg slams epidemic political lies danger democracy',
#  'massive cookout thrown park cops called black family bbq',
#  'michael ches stepmom melissa_mccarthy embarrasses weekend_update',
#  'handmaids_tale meets sex city funny terrifying snl spoof',
#  'video_shows security guard choking xa black teen accused shoplifting new_york',
#  'trump praises late mom mothers_day skips mention melania',
#  'trump promises help chinese company violated sanctions iran',
#  'sarah_huckabee sanders berated staffers mccain leak',
#  'parkland dad pointed message oliver north nras new president',
#  'john bolton trump sanctions european companies possible iran',
#  'michelle_obama shares_adorable throwback pic touching mothers_day tribute',
#  'tomi_lahren claims lowskilled immigrants country based',
#  'stalking cheetahs give oblivious family scare exit car safari park',
#  'der spiegel cover portrays trump finger flipping europe',
#  'italian tribunal lifts ban silvio berlusconi holding public office',
#  'north_korea plans dismantle nuclear test sites end may',
#  'knife attack paris leaves_dead several injured',
#  'watch hulu new week',
#  'watch amazon prime new week',
#  'late_show unveils spoof line trumpthemed mothers_day gifts',
#  'brooklyn ninenine finds new tv home stars fans rejoice',
#  'smith shares inspiring tale became fresh prince of belair',
#  'lgbtq groups call new oklahoma adoption law discriminatory',
#  'mueller reportedly investigating foreignlinked donors trumps_inauguration fund',
#  'stephen_colbert mocks proposal hang trump pence portraits post offices',
#  'boston dynamics robot dog may available sale soon',
#  'southern baptist leader apologizes past hurtful comments women',
#  'george soros progressive groups spend millions to elect reformist prosecutors',
#  'incredible photos show world need protect',
#  'avengers_infinity war directors reveal died survived screen',
#  'uber silences women sexual assaults',
#  'marvel introduces first official chinese superheroes',
#  'big_bang theory pays sweetest tribute stephen_hawking deleted scene',
#  'bill_maher shreds donald_trump likens mob boss',
#  'amazon holding seattle hostage',
#  'jim_carrey taunts psycho mike_pence biting new portrait',
#  'chadwick boseman lauds student protesters howard commencement_speech',
#  'want understand straight incels talk_to gay one',
#  'gathering military spouses puts white white_house',
#  'game show host prematurely congratulates contestant mortifying fail',
#  'women take cannes red_carpet to protest inequality film',
#  'men charged hate_crimes beating gay_couple',
#  'trump_administration rolls back protections transgender prison inmates',
#  'michael_cohen reportedly paid advise att time_warner merger',
#  'metoo statehouse least men gone harassment culture isnt',
#  'austin bars police_department selling old guns public',
#  'masterclass parody dubbing movie swear words falcon great',
#  'democrats say dont regret making easier confirm judges',
#  'donald glover fan would cast solo',
#  'seth_meyers skewers idea donald_trump winning nobel_peace prize',
#  'chuck_schumer turns melania_trumps best campaign donald_trump',
#  'trailer axed tremors reboot kevin bacon offers glimpse could',
#  'frightened rabbit singer scott hutchison dead',
#  'suspect custody shooting california high_school injured',
#  'colbert xa names official job unqualified white_house staffer',
#  'trevor_noah gives michael_cohen biting new breaking badthemed nickname',
#  'moral atlanta robbin season sometimes get top snatching others',
#  'pose character finds community new_yorks ball scene',
#  'accused golden_state killer faces four additional murder counts',
#  'jimmy_kimmel roasts donald_trump spoof nobel_peace prize ceremony video',
#  'sarah_palin says mccains regrets perpetual gutpunch',
#  'killed may australias worst mass_shooting since',
#  'deadpool david_beckham hug feud deadpool teaser',
#  'opposition gives trump hot lawyer',
#  'dogs may help prepare babies cats help prepare you for teenagers',
#  'john mccains wife rebukes white_house official mocked dying anyway',
#  'rupauls_drag race queens turn back time cher rusical',
#  'trump_administration axes funding nasa system monitors greenhouse gases',
#  'police search suspected serial killers dumping ground',
#  'kevin mchale think zero surprise came',
#  'pennsylvania house race embodies fight future the democratic_party',
#  'hackers tried breach tennessee county server election_night report',
#  'gay teacher suspended showing photo future wife sues texas district',
#  'school_district allegedly made lgbtq student read bible punishment',
#  'trump launched war christmas may people',
#  'elle fanning makes punkmusic debut talk_to girls parties',
#  'jake_tapper rips retired gen tom mcinerney insulting john_mccain',
#  'fox cuts_ties guest cited john_mccain defend torture',
#  'trumps attempt make example immigrant caravan backfiring',
#  'celebrities reading weird texts moms mothers_day treat',
#  'stormy_daniels actress doppelganger',
#  'oldest known man america says smokes dozen cigars day',
#  'tweeters erupt trump aides cruel taunt john_mccain dying anyway',
#  'mark_hamill weds sheldon amy big_bang theory fans geek',
#  'epa hid scott_pruitts dinner climate denier accused child sex_abuse',
#  'meghan mccain takes swipe white_house aide mocks fathers cancer',
#  'need talk white people calling cops people color',
#  'woman calls police black family bbqing lake oakland',
#  'tim allens last man standing coming_back one_year canceled',
#  'joe_biden berates white_house joke john mccains health',
#  'michael avenatti warns michael_cohen still documents release',
#  'fox_friends host mocks ny_times isis coverage unaware beat fox story',
#  'congressional_candidate says fk nra new tv ad',
#  'tsa tells sikh man remove turban finds hes canadian politician',
#  'john_stamos shows new baby bob saget lori loughlin',
#  'woman sent texts first date says love excessive thing',
#  'little extortionythis guy figured stormy_daniels old lawyer actually pretty',
#  'katie porter survived domestic_abuse used her campaign',
#  'trumps plan prescription drug prices looks nothing like promised',
#  'giuliani says cohen never spoke trump bigdollar clients',
#  'russian troll facebook ads barely targeted swing states',
#  'ted_cruz staff usaid met group called apartheid socalled injustice',
#  'plan family_vacation according_to travel experts',
#  'boston dynamics created running robot coming',
#  'cornell student delivers thesis underwear professor questions outfit',
#  'funniest_tweets women_week',
#  'israel reportedly fires dozens rockets syria',
#  'israel launches airstrikes syria iranian attacks',
#  'righttodie advocate david goodall ends life listening ode to joy',
#  'americans held north_korea return united_states',
#  'dozens dead torrential rains cause dam burst kenya',
#  'spotify stops promoting kellys music sexual_assault allegations',
#  'trump kim_jong un likely meet next month singapore',
#  'homeland_security denies report secretary drafted resignation letter',
#  'cecile richards running office future never_say never',
#  'aclu says kris_kobach still giving incorrect information voter_registration',
#  'ryan murphy donate pose profits to trans queer groups',
#  'rick morty renewed whopping episodes',
#  'ryan_reynolds warns deadpool fans dont say fking word',
#  'nurse charged death extrump adviser hr mcmasters father',
#  'trump going indiana to slam joe donnelly dont_expect democrat to hit back',
#  'rick moranis appear netflix sctv documentary',
#  'facing challenge right gop_lawmaker pulls support immigration bill',
#  'john_mccain urges senate reject gina haspels nomination cia',
#  'months later rio cops supposedly closing marielle francos killers',
#  'queer_eye star tan france doesnt give poorlydressed fans style advice',
#  'women coming eric schneidermans job',
#  'man pleads_guilty bacon vandalism tennessee islamic center',
#  'mike_pence robert_mueller russia_probe wrap',
#  'ready older kevin justin hartley is',
#  'net_neutrality rules end june fcc says',
#  'democratic candidate maryland governor dies cardiac arrest',
#  'officer puts man chokehold outside north_carolina waffle_house',
#  'trevor_noah cant_get enough blankenships nutty concession speech',
#  'brooklyn ninenine canceled twitter mourns',
#  'quiet struggle chuck_schumer left',
#  'gabby douglas utterly unrecognizable undercover boss',
#  'girls accused plotting kill classmate',
#  'curious case russian oligarch national_park service latrines',
#  'watch rudy_giuliani completely torpedo rudy giulianis trump arguments',
#  'fox business guest defends torture worked john_mccain',
#  'tom abby queer_eye remarried',
#  'pakistan passes historic transgender rights bill',
#  'phil mudd flips questions cia torture didnt america it',
#  'facebook ads house dems say russia ran election',
#  'kim_kardashian says tristan thompson blocked defended khloe',
#  'kenan thompson says_hell stay snl long as possible',
#  'jennifer_garner mom problems hilarious rap video ellen',
#  'dick_cheney suggests restarting torture interrogation program',
#  'greta gerwig loudly critiqued feel pretty moviegoer live tweeted',
#  'devin_nunes gets meeting secret russia_probe source threatening doj',
#  'queer_eye star karamo brown engaged director ian jordan',
#  'jet launched apple store incredible deals',
#  'tom hardy completely unrecognizable al capone new movie',
#  'woman alleges rapper young lo raped trapped chris browns home',
#  'republicans fill court seat denied obama years',
#  'sc man wanted white_supremacists kill black neighbor burn cross yard fbi',
#  'trump announces details meeting kim_jong un',
#  'samantha_bee delivers blistering takedown former ny ag eric schneiderman',
#  'jim carreys scathing portrait trump joker give nightmares',
#  'michelle wolf renews hostilities sarah_huckabee sanders',
#  'fans erupt fate elias koteas olinsky chicago pd',
#  'people street apologize old teachers on jimmy_kimmel live',
#  'stephen_colbert porn_star math michael_cohen donald_trump',
#  'pollen bomb every allergy sufferers worst_nightmare',
#  'jennifer_lopez dances least danceable songs tonight_show',
#  'white yale student calls cops black schoolmate napping dorm common room',
#  'rudy_giuliani quits law firm wild week interviews',
#  'teddy geiger makes first public appearance since coming transgender',
#  'ariana_grande mac miller reportedly break',
#  'avengers leaks get support yearold interview marvel directors',
#  'theres good excuse racist impact michigans medicaid proposal',
#  'fcc complaints minutes interview stormy_daniels',
#  'americans jailed korea home trump may made others situation worse',
#  'alex strangelove gay teen comedy doesnt turn away sex',
#  'woman says took home kittens find bobcats',
#  'video bear eating ice_cream dairy queen leads charges zoo owners',
#  'iranian lawmakers mock trumps mental capacity burn flag us pulls nuke deal',
#  'europeans scramble save iran_deal trump withdraws',
#  'north_korea releases american political prisoners advance historic summit',
#  'establishment gop notches win ohio primary vacant house seat',
#  'eric schneiderman praised movement days abuse_allegations emerged',
#  'trevor_noah unloads supposed advocate women eric schneiderman',
#  'year comeys firing scope mueller probe expands lawyers shell company',
#  'trumpinspired businessman wins indianas gop_senate primary',
#  'gop rival says tammy baldwin team terrorists silence on trump cia pick',
#  'jobs program might get people back work',
#  'jim parsons yes still need queer stories onscreen',
#  'trump accuser wins democratic nomination ohio legislature',
#  'mastermind waterboarded cia information share gina haspel',
#  'conservative senate democrat backs trumps agenda defeats progressive challenger',
#  'taylor_swift mightve made katy_perry kimye feud lives',
#  'kim_kardashian make history fashion councils first influencer award',
#  'nbc says believes matt lauers accusers monthslong investigation',
#  'russians ability change voter data didnt report says',
#  'elizabeth warrens pick wins ohios democratic gubernatorial primary',
#  'kkk leader found_guilty firing gun charlottesville rally',
#  'protesters decrying torture dragged gina haspel senate hearing',
#  'att hired firm linked michael_cohen to get inside scoop trump',
#  'rnc selling sickening donald trumpthemed merch ahead mothers_day',
#  'blankenships defeat relief families upper big branch miners',
#  'colbert shreds trump broken promises talking',
#  'new ambassador germany offends hosts hours first day',
#  'jordan peeles new nightmare coming next_year',
#  'backstreet boys dressed spice girls larger life',
#  'seth_meyers decodes teen slang reveals giuliani really_means',
#  'heres look orlandos interim pulse_nightclub memorial',
#  'trevor_noah turns donald_trumps knives comment reggae magic',
#  'senators force vote may ultimately reverse fcc restore net_neutrality',
#  'ny legislature plan place consider replacements eric schneiderman',
#  'former ambassadors write letter opposing gina haspel nomination',
#  'california authority says states new homes must solar powered',
#  'ny governor assigns investigation eric schneiderman abuse_allegations',
#  'refugee caravan became scapegoat trumps border crackdown',
#  'pennsylvania becomes latest state fund urban gun_violence prevention',
#  'denver mayors son caught_tape berating cop faggot',
#  'progressive prosecutors win primaries north_carolina',
#  'att novartis get money paid trumps lawyer',
#  'hypocrisy melania_trumps online safety booklet pointed page page',
#  'uninsured rate worsening years obamacares gains',
#  'bernie_sanders plan revive labor unions',
#  'jim_carrey bestows scott_pruitt savage nickname latest painting',
#  'male allies become abusers',
#  'mormon church end centurylong relationship boy_scouts',
#  'snack addiction killing orangutans',
#  'trumps_pick cia_director wont_say torture program morally wrong',
#  'anderson_cooper burns moronic michael_cohen russia cash claims',
#  'pinata maker apologizes hanging black figures likeness lynchings',
#  'caliphate trump planet ruins',
#  'gay_marriage opponent ousted gop incumbent north_carolina',
#  'espn eliminates public editor role calling outdated',
#  'michael_cohen selling access trump says group paid shell company',
#  'mitch_mcconnell mocks blankenship twitter big cloud cocaine',
#  'exconvict blankenship loses patrick morrisey west_virginia senate_race',
#  'ohio voters pass gerrymandering reform measure',
#  'trumps iran_deal exit win russia',
#  'cynthia_nixon wants new_yorkers vote homo for cuomo',
#  'ontario canada issued first nonbinary birth certificate',
#  'child sexual predator roman polanski calls movement total hypocrisy',
#  'america producer reveals new details childish gambinos viral_video',
#  'terry crews black men arent allowed victims theyre dead',
#  'donald glovers america eyes jim crow historian',
#  'fox_news judicial analyst issues dark warning trump michael_cohen',
#  'black women bishops making history predominantly white church',
#  'geena davis th husband reza jarrahy divorcing',
#  'pauley perrettes abby heartwrenching farewell ncis',
#  'lethal weapon fires clayne crawford character gets shot',
#  'selena_gomez pokes_fun met_gala spray tan mishap',
#  'protest leader nikol pashinian elected prime_minister armenia',
#  'kim_jong un secretly met xi jinping',
#  'netanyahus bombastic iran claims found perfect audience trump',
#  'netanyahus chef blasted serving japans prime_minister dessert shoe',
#  'world_leaders condemn trump withdrawing iran_nuclear deal',
#  'senate_republicans shun blankenship day west_virginia primary',
#  'new_yorks harvey_weinstein probe set continue despite attorney generals exit',
#  'trump announce whether break iran_nuclear deal',
#  'politicians call schneiderman resign physical abuse_allegations',
#  'joe_scarborough trumps legal strategy like monkey throwing poo wall',
#  'kirsten dunst jesse plemons welcome baby_boy',
#  'holy matrimony proposal met_gala',
#  'nordstrom rack president apologizes store accuses three black men theft',
#  'giuliani says trump lawyer michael_cohen incriminating information president',
#  'lena waithe stuns met_gala queer superhero',
#  'kelly accusers say ask permission to use bathroom',
#  'trump reportedly tells macron hes pulling iran_nuclear deal',
#  'deportation crackdown hurting immigrant victims crime',
#  'seth_meyers says michael_cohen tried get to apologize onair to trump',
#  'blessing best met_gala tweets',
#  'farm bill_would cut food_stamps friendly farmers',
#  'know iran_nuclear deal',
#  'derby day bet wins thrilled texas woman million',
#  'democratic meddling west_virginia things watch election day',
#  'cynthia erivos met_gala nails featured sistine chapel painting black women',
#  'keanu reeves alex winter coming_back bill ted years',
#  'solanges durag true mvp met_gala',
#  'top house republican threatens subpoena trump doj official census citizenship request',
#  'jimmy_kimmel tries hard make_sense rudys latest trump defense gives',
#  'religious imagery stitched throughout met_gala',
#  'bob marleys granddaughter says cops racially profiled checking airbnb',
#  'melania_trump called antibullying campaign ignores husbands actions',
#  'trevor_noah watching rudy_giuliani like smoking weed tv',
#  'janet_jackson receive icon award billboard_music awards',
#  'white_house prepares send congress billion spending cuts package',
#  'jared kushnerbacked bill could last shot federal prison reform',
#  'george_zimmerman accused stalking detective working trayvon_martin film',
#  'passengers lashing scott_pruitt justify firstclass travel new epa memo says',
#  'trump country house district became key progressive battleground',
#  'mike_pences brother wins primary race vice presidents former house seat',
#  'marines investigating avowed white_supremacist active duty',
#  'trump violate iran_nuclear deal vows to reimpose sanctions',
#  'olympic_committee ignored sexual_abuse complaints taekwondo stars lawsuit',
#  'blake_lively brought family met_gala without even noticing',
#  'bill_oreilly offers stand next to sarah sanders to handle line reporters',
#  'catholic priest praised best dressed dude met_gala living life',
#  'jimmy_kimmel says hideandseek genius dog heal nation',
#  'bank_america appears flip firearm promise loan to remington',
#  'gentleman caller presents queer icons youve_never seen',
#  'eric schneiderman always con man',
#  'christiane amanpour heading new pbs show replacing charlie rose',
#  'madonna teases new_song surprise met_gala performance',
#  'iron_man black widow captain_america thor hawkeye got matching tattoos',
#  'michael_cohen accepted firm tied russian oligarch reports',
#  'stephen_colbert hits rudy_giuliani brutal fact check',
#  'katy_perry sends olive branch taylor_swift world rejoices',
#  'jada_pinkett smith gets_real dating smith married',
#  'whoops mark_hamill spilled beans major cameo han solo movie',
#  'shawn mendes sweetly attended hailey baldwins gown met_gala',
#  'orrin hatch sorry suggested trump allowed john mccains funeral',
#  'seth_meyers perfect line confront donald_trumps lies',
#  'police hope use dna to catch zodiac killer',
#  'lili reinhart cole sprouse finally make couple debut met_gala',
#  'sweetbitter captures grit glamour restaurant world',
#  'mitch_mcconnell bends rules confirm trumps judges',
#  'ryan_zinke tale_two fish',
#  'ny attorney_general eric schneiderman resigns amid abuse_allegations',
#  'sanctuary_cities working trump_era surprising cost',
#  'shepard_smith cant say trump pulled iran_deal made decision violate',
#  'stormy_daniels finds crunchy new way chip away trump',
#  'rainbow mountains peru look_like theyre straight dr seuss book',
#  ...]
